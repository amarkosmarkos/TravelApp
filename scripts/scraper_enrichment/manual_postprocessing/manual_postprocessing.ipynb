# %% [markdown]
# # Manual Postprocessing - Datos Enriquecidos
#
# Este notebook procesa los datos enriquecidos para:
# 1. Agrupar entidades por tipo (ciudades, itinerarios, etc.)
# 2. Normalizar nombres de entidades
# 3. Combinar entidades similares

# %%
import json
import pandas as pd
from collections import defaultdict
from typing import Dict, List, Set
import re

# %% [markdown]
# ## 1. Cargar Datos Enriquecidos

# %%
# Cargar datos enriquecidos
input_file = "../../data/scraper_enrichment/enriched_data.jsonl"

data = []
with open(input_file, 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line.strip()))

print(f"Datos cargados: {len(data)} registros")
print(f"Columnas disponibles: {list(data[0].keys()) if data else 'No hay datos'}")
# Out:
# Datos cargados: 32 registros
# Columnas disponibles: ['url', 'source_name', 'scraped_at', 'entities']

# %% [markdown]
# ## 2. Extraer y Agrupar Entidades

# %%
import json
from collections import defaultdict
from pathlib import Path

# Ruta al archivo de entrada
input_path = Path('../../data/scraper_enrichment/enriched_data.jsonl')

# Cargar todas las entidades
all_entities = []
with open(input_path, 'r', encoding='utf-8') as f:
    for line in f:
        if line.strip():
            data = json.loads(line)
            all_entities.extend(data.get('entities', []))

print(f'Total de entidades extraídas: {len(all_entities)}')

# Agrupar entidades por tipo
entidades_por_tipo = defaultdict(list)
for entidad in all_entities:
    tipo = entidad.get('entity_type', 'desconocido')
    
    # Manejar si tipo es una lista
    if isinstance(tipo, list):
        tipo = tipo[0] if tipo else 'desconocido'
    elif tipo is None:
        tipo = 'desconocido'
    
    entidades_por_tipo[tipo].append(entidad)

# Mostrar entidades agrupadas por tipo
for tipo, entidades in entidades_por_tipo.items():
    print(f'\n=== {tipo.upper()} ({len(entidades)}) ===')
    for e in entidades:
        nombre = e.get('name') or e.get('title') or e.get('advice_text') or '[Sin nombre]'
        desc = e.get('description') or e.get('context') or ''
        print(f'- {nombre}: {desc[:120]}')
# Out:
# Total de entidades extraídas: 1516
#
# === SITE (805) ===
# - Tailandia: Diverse country with attractions for all tastes, known for its hospitality, delicious cuisine, and beautiful landscapes
# - Bangkok: Capital city of Thailand with a mix of modernity and tradition, known for its bustling streets, vibrant markets, and cul
# - Bangkok: One of the must-see places in Thailand, offering a mix of Western infrastructure and Eastern traditions. Explore the Gra
# - Chiang Mai: Known as the 'Northern Capital' of Thailand, offering a magical environment with nature, Buddhist temples, palaces, and
# - Chiang Mai: Explore the city for at least 2 days, with an option for additional excursions. Consider a tour to Chiang Rai from Chian
# - Doi Suthep: One of the most beautiful temples to visit in Thailand.
# - Phi Phi Islands: Famous island group in Thailand known for its beaches and clear turquoise waters. Includes Koh Phi Phi Don, Koh Phi Phi
# - Sukhothai Historical Park: Historical park located between Bangkok and Chiang Mai, showcasing ruins from the 13th and 14th centuries. Includes Wat
# - Sukhothai: Historical city in Thailand
# - Thai Thai Sukhothai Resort:
# - Koh Lipe: Small island in the Andaman Sea, known for its white sandy beaches and turquoise waters
# - Serendipity Beach Resort Koh Lipe:
# - Castaway Resort Koh Lipe:
# - Ayutthaya: Ancient city near Bangkok with historical temples
# - Ayutthaya: Ancient capital of the Kingdom of Siam, a UNESCO World Heritage Site
# - Khao Sok National Park: Extensive natural reserve in southern Thailand with diverse flora and fauna, including Asian elephants
# - Chiang Rai: Province in northern Thailand known for its tranquil landscapes, temples, and hiking routes
# - Koh Tao: Island on the east coast of Thailand known for diving and beautiful beaches
# - Koh Phangan: Tranquil island with relaxed beaches, meditation and yoga centers, waterfalls, and diving spots like Sail Rock. Stay at
# - Pai: Charming backpacker village near Chiang Mai with artists, bohemians, local crafts, healthy food, and night market. Explo
# - Kanchanaburi: Destination 140 km west of Bangkok offering a mix of nature and history. Explore WWII history at the famous Bridge over
# - Phuket: Popular island destination in Thailand.
# - Phuket: Phuket is the largest island in Thailand, known for its diverse range of activities including beaches, cultural sites, a
# - Krabi: Krabi is a province in Thailand known for its stunning limestone cliffs and beautiful beaches. The main city, also named
# - Koh Chang: Koh Chang, also known as the 'Elephant Island', is located in the Trat province near Cambodia. It is the third largest i
# - Koh Chang: The third largest island in Thailand with a variety of activities including relaxing on beaches like Kai Bae Beach and e
# - Koh Lanta: A unique island destination in Thailand known for its uncrowded beaches, especially Beautiful Beach, Klong Nin Beach, an
# - Koh Yao Noi: A peaceful island in the Andaman Sea with limited tourism development, ideal for relaxation on its beaches. Recommended
# - Koh Yao Yai: A larger island near Koh Yao Noi with similar peaceful and unspoiled beaches. Features the stunning Laem Had Beach and o
# - Lopburi: Known as the 'City of Monkeys' for its large population of macaques. Features a historic center surrounded by archaeolog
# - Lopburi: Known as the 'City of Monkeys' for its large population of macaques, surrounded by archaeological ruins reminiscent of A
# - Similan Islands: An archipelago of 9 islands in the Andaman Sea known for beautiful beaches, lush vegetation, and abundant marine life. P
# - Mae Hong Son: A rural paradise in northern Thailand near the Myanmar border, known for its unique temples influenced by Shan and Burme
# - Koh Kood: A tranquil island in the Trat province known for its pristine environment, quiet beaches, waterfalls, and opportunities
# - Koh Kood: An island to visit in Thailand
# - Chumphon: A province in Thailand known for its golden sandy beaches and palm trees
# - Wua Laen Beach: A beach in Chumphon with great value hotels like Rimsira
# - Chumphon National Park: National park in Chumphon offering diving and snorkeling trips
# - Nakhon Si Thammarat: A peaceful and authentic destination in southern Thailand known for historic temples and local markets
# - Wat Phra Mahathat Woramahawihan: An impressive temple in Nakhon Si Thammarat with a white stupa containing Buddha relics
# - Phimai: Historical destination in northeast Thailand with the Phimai Historical Park, a complex of Khmer temples
# - Phanom Rung: Important Hindu temple dedicated to Shiva in Buriram, Thailand
# - Prasat Hin Mueang Tum: Temple complex in Buriram dedicated to Shiva and Vishnu
# - Greece:
# - Turkey:
# - USA:
# - Amsterdam:
# - Thailand:
# - Koh Phi Phi:
# - Koh Lipe:
# - Andaman Islands:
# - Bangkok:
# - Indonesia:
# - Damnoen Saduak Floating Market: Famous and spectacular floating market located about 100km from Bangkok. It is the most touristy market in the area, wor
# - Taling Chang Floating Market: A less touristy alternative to Damnoen Saduak Floating Market, located near Bangkok. Offers a more peaceful experience a
# - Amphawa Floating Market: Another alternative to Damnoen Saduak Floating Market, known for its charming atmosphere and local vendors. Located near
# - Mae Klong Railway Market: A local market located on active railway tracks in Mae Klong, Thailand. The market stalls are swiftly removed when the t
# - Sukhothai Historical Park: A UNESCO World Heritage Site and the birthplace of Thailand. Explore the ancient temples and ruins by renting bicycles f
# - Kanchanaburi: A region in Thailand known for its historical significance, including the famous Bridge over the River Kwai and the Deat
# - Chiang Mai: A province in northern Thailand known for its ethnic diversity, hospitality, and natural beauty. Ideal for trekking, raf
# - Doi Inthanon National Park: Home to Thailand's highest peak, Doi Inthanon, reaching 2565 meters. Visitors can enjoy stunning views, pagodas, and wat
# - Ao Nang: The most touristy city in the Krabi area, serving as a perfect base for exploring the surrounding beaches and islands li
# - Koh Lipe: An island known for relaxation and diving, offering a quieter alternative to the popular Koh Tao. Ideal for snorkeling a
# - Koh Muk: A peaceful island with a local vibe and the stunning Emerald Cave, accessible only by boat and a short swim. Perfect for
# - Koh Tao: A renowned island in the Gulf of Thailand, famous for its coral reefs and diverse marine life, making it a top destinati
# - Koh Samui: The top island destination in Thailand, particularly popular for family tourism. Known for luxury resorts and internatio
# - Thailand:
# - Phuket:
# - Koh Phi Phi:
# - Koh Samui:
# - Koh Lanta:
# - Tailandia: Thailand is a country known for its rich culture, vibrant nightlife, historical sites, tropical beaches, and diverse lan
# - Bangkok: Bangkok is the capital city of Thailand, known for its bustling street life, ornate shrines, vibrant markets, and divers
# - Chiang Mai: Chiang Mai is a peaceful city in northern Thailand, known for its ancient temples, lush mountains, vibrant markets, and
# - Chiang Rai: Chiang Rai is a serene city in northern Thailand, famous for its unique temples, scenic landscapes, and relaxed atmosphe
# - Ayutthaya: Ayutthaya is a historic city in Thailand, known for its ancient ruins, temples, and historical sites. It was once the ca
# - Phuket: Phuket is Thailand's largest island, famous for its stunning beaches, crystal-clear waters, vibrant nightlife, and water
# - Krabi: Krabi is a province in southern Thailand, known for its picturesque landscapes, limestone cliffs, clear waters, and outd
# - Koh Lipe: Koh Lipe is a tranquil island resort located in southern Thailand, in the Andaman Sea near the border with Malaysia. It
# - Koh Lipe:
# - Sukhothai: Sukhothai is a province with significant historical sites, beautiful mountains, and forests. It is home to the UNESCO Wo
# - Sukhothai Historical Park: Explore the historical park of Sukhothai, a UNESCO World Heritage Site known for its ancient ruins and temples.
# - Similan Islands: Discover the stunning Similan Islands, a famous marine park known for diving, snorkeling, and picturesque beaches.
# - Koh Tao: Koh Tao is a beautiful island in Thailand known for its stunning beaches, snorkeling spots, and diving sites like Chumph
# - Ko Nang Yuan: Ko Nang Yuan is a group of picturesque islets near Koh Tao, offering stunning views and beautiful beaches like Ao Tanote
# - Chumphon Pinnacles: Chumphon Pinnacles is a top diving site near Koh Tao, known for its diverse marine life and underwater beauty.
# - HTMS Sattakut: HTMS Sattakut is a popular diving site off the coast of Koh Tao, offering unique underwater experiences.
# - White Rock: White Rock is an excellent diving site near Koh Tao, known for its crystal-clear waters and vibrant marine life.
# - Mirador John-Suwan: Mirador John-Suwan offers a panoramic view of the beauty of Koh Tao, providing a breathtaking vista of the island and su
# - Mirador Ko Nang Yuan: Mirador Ko Nang Yuan offers a stunning view of the Ko Nang Yuan islets, providing a unique perspective of the surroundin
# - Big Buddha Phuket: One of the important Buddhist temples in Phuket that must be visited.
# - Wat Chalong: One of the important Buddhist temples in Phuket that must be visited.
# - Cabo Promthep: Ideal place to enjoy stunning sea views located on a promontory at the southern end of the island.
# - Phuket City: Vibrant nightlife destination in Phuket.
# - Patong City: Vibrant nightlife destination in Phuket.
# - Phang Nga Bay: Scenic bay accessible by ferry or boat from the northeast coast of Phuket.
# - Old Phuket Town: Historical area in Phuket with a fusion of cuisines and a variety of dishes to experience.
# - Ko Siray: Island near Phuket worth exploring.
# - Patong Beach: Popular beach destination in Phuket.
# - Bangla Road: Street with numerous bars and restaurants in Patong City, Phuket.
# - Phuket International Airport: One of the busiest airports in Thailand with regular flights to/from various international and domestic destinations.
# - Central Bus Station Phuket: Main bus station in Phuket receiving buses from other regions like Bangkok, Krabi, Phang Nga, and Surat Thani.
# - Krabi: Discover the highlights and specialties of Krabi, Thailand
# - Chiang Mai: Explore the tranquil province of Chiang Mai, Thailand
# - The Ping River: Hotel with picturesque landscapes
# - The Night Bazaar: Hotel located in an energetic area
# - Chiang Mai Old City: Ideal place to visit local historical relics
# - Chiang Rai: City to visit near Chiang Mai
# - Ayutthaya: City to visit near Chiang Mai
# - Bangkok: City of contrasts with rich culture and modern advancements
# - Bangkok: Vibrant city known for its highlights, fantastic food, and lively nightlife
# - Suvarnabhumi Airport:
# - Don Muang Airport:
# - Hualamphong Station:
# - Erawan National Park:
# - Ko Samui:
# - Krabi:
# - Pattaya:
# - Sukhothai:
# - Ayutthaya:
# - Chiang Mai:
# - Chiang Rai:
# - Phuket:
# - Tailandia: A country in Southeast Asia known for its smiles, golden temples, tropical beaches, royal palaces, and street food.
# - Bangkok: The capital city of Thailand known for its vibrant street life, ornate shrines, and dynamic nightlife.
# - Phuket: A popular island destination in Thailand known for its beaches, resorts, and vibrant nightlife.
# - Krabi: A town in southern Thailand known for its stunning beaches, limestone cliffs, and clear waters ideal for diving.
# - Koh Samui: An island in the Gulf of Thailand known for its palm-fringed beaches, coconut groves, and dense, mountainous rainforest.
# - Ayutthaya: Historical city and former capital of the Ayutthaya Kingdom, now a UNESCO World Heritage Site with numerous ancient temp
# - Chiang Khan: Small town on the banks of the Mekong River, known for its wooden teak houses and vibrant street food scene.
# - Wat Pa Phu Kon: Tranquil temple located in the Na Yung-Nam Som National Forest, offering a peaceful environment for meditation and menta
# - Phanom Rung: Ancient Khmer city in Thailand with sandstone and laterite structures dating back to the 10th to 13th centuries, dedicat
# - Kanchanaburi: Tourist destination known for waterfalls, caves, national parks, and historical sites related to World War II, including
# - Chiang Mai: Historic city in northern Thailand known for its cultural heritage, Buddhist temples, and the old city area.
# - Aeropuerto Internacional:
# - Casco Antiguo:
# - Wat Phra Singh:
# - Wat Chiang Man:
# - Mercado Warorot:
# - Bazar Nocturno:
# - Mercados Nocturnos de los Sábados y Domingos:
# - Lago Huay:
# - Palacio de Bhubing:
# - Chiang Rai:
# - Triángulo de Oro:
# - Templo Blanco (Wat Rong Khun):
# - Lampang:
# - Centro de Conservación de Elefantes de Tailandia:
# - Koh Tao:
# - Phuket:
# - Koh Chang: Excellent for snorkeling, diving, camping, and hiking in the jungle.
# - Ao Nang: Touristic town famous for its long beach along the Andaman coast and as a diving hub.
# - Pattaya: Lively coastal city with a wide range of accommodations, nightlife, and activities.
# - Chumphon: Emerging destination in Thailand with 200 km of coastline and secluded beaches.
# - Koh Samui: Third largest island in Thailand known for its beautiful beaches, luxury hotels, and activities.
# - Ratchaburi: Historically significant city with the famous Damnoen Saduak Floating Market.
# - Samut Songkhram: Province known for fertile land and a variety of crops including fruits, vegetables, and seafood.
# - Ay Thai: Ay Thai
# - Samut Songkhram: Samut Songkhram is a fertile province full of plants and crops, with a great variety of vegetables, fruits, and seafood.
# - Sukhothai: Sukhothai is probably the most romantic of all the former Thai capitals. The magnificent temples and monuments of this g
# - Nakhon Si Thammarat: Nakhon Si Thammarat offers national parks, jungles, beaches, and shadow puppet theater. It is the second-largest provinc
# - Chiang Mai: Chiang Mai offers a variety of bars and restaurants for relaxation. Don't miss the Saturday and Sunday markets for a liv
# - Bangkok: Experience the traditional and modern aspects of Thailand's capital, Bangkok. Visit the Grand Palace, Wat Pho, Chinatown
# - Krabi: Krabi is a recommended beach destination in Thailand, known for its beautiful beaches and clear waters.
# - Phuket: Phuket, located in the Andaman Sea, offers tropical beauty with minimal rainfall between November and April.
# - Koh Samui: Koh Samui in the Gulf of Thailand is a great choice for a beach getaway with less rain between January and September.
# - Pai: A refuge for those who want to escape the hustle and bustle of big cities. Ideal for renting a motorbike and exploring t
# - Chiang Rai: Famous for unique temples like Wat Rong Khun (White Temple). Offers a more intimate and cultural experience compared to
# - Parque Nacional Khao Yai: One of the best places in Thailand for nature lovers. Offers trekking, wildlife observation, and stunning waterfalls lik
# - Phuket: Famous island destination in Thailand known for its beaches, entertainment, and infrastructure. Offers a variety of acti
# - Bahía de Phang Nga: Visually stunning tourist spot in Thailand known for its karst formations and the famous James Bond Island (Ko Tapu). Id
# - Islas Phi Phi: Iconic tropical paradise in Asia, famous for its natural beauty and turquoise waters. Popular destination for snorkeling
# - Islas Phi Phi: Explore the best of Phi Phi Islands with recommended activities like speedboat tours, diving, and bioluminescent bay exc
# - Railay: A hidden gem near Krabi accessible only by boat, known for stunning cliffs, crystal-clear waters, and beautiful beaches
# - Parque Nacional Khao Sok: Experience an adventure in the jungle at Khao Sok National Park, known for the Cheow Lan Lake surrounded by rock formati
# - Koh Tao: Discover the diving paradise of Koh Tao, a budget-friendly destination with clear waters, coral reefs, and a relaxed atm
# - Koh Pha Ngan: Known for the famous Full Moon Party, Koh Pha Ngan offers more than just nightlife. Experience spiritual retreats, yoga,
# - Koh Samui: Luxury and relaxation await in Koh Samui, the third-largest island in Thailand. Choose from a range of accommodations, v
# - Marino de Ang Thong:
# - Sukhothai: The first capital of the Kingdom of Siam, known for its historical park with well-preserved ruins and a peaceful atmosph
# - Koh Lipe: A small island near the border with Malaysia, known for its authentic essence, white sandy beaches, and crystal-clear wa
# - Lopburi: Lesser-known city in Thailand famous for the Phra Prang Sam Yot Temple where monkeys roam freely among the ruins. Hosts
# - Mae Hong Son: Located in the northwest of Thailand near the border with Myanmar, Mae Hong Son offers a remote and authentic experience
# - Erawan: Erawan National Park in Kanchanaburi province is famous for its seven-tiered waterfalls with turquoise natural pools. Vi
# - Isan: The forgotten northeast region of Thailand, Isan offers unique temples, authentic markets, and delicious local cuisine.
# - Krabi: Coastal province in southern Thailand known for its beaches and islands
# - Phuket: Largest island in Thailand with turquoise waters, white sandy beaches, and vibrant nightlife
# - Koh Samui: Island in the Gulf of Thailand with beautiful beaches, marine park, and diving tours
# - Ayutthaya Historical Park: Explore the famous ruins of the temples of the ancient capital of the Kingdom of Siam
# - Sukhothai Historical Park: Discover the ruins of the ancient city of Sukhothai, the first capital of the Kingdom of Siam
# - Chiang Mai: Explore the cultural and historical attractions of Chiang Mai
# - Elephant Sanctuary: A sanctuary that cares for rescued elephants from abusive situations, without circus shows or riding offers.
# - Thailand:
# - Bangkok:
# - Ayutthaya:
# - Chiang Mai:
# - Pai:
# - Chiang Rai:
# - Phuket:
# - Phi Phi Islands:
# - Koh Lipe:
# - Koh Tao:
# - Krabi:
# - Sukhothai:
# - Thailand:
# - Bangkok:
# - Koh Tao:
# - Chumphon:
# - Koh Lipe:
# - Ayutthaya:
# - Ayutthaya:
# - Bangkok:
# - Ayutthaya:
# - Chiang Mai:
# - Chiang Rai: City near the Golden Triangle in northern Thailand.
# - Chiang Mai: City in northern Thailand known for its ancient temples and vibrant culture.
# - Wat Chiang Man: Oldest temple in Chiang Mai, dating back to the 13th century.
# - Pagoda Royal: Beautiful temple in Chiang Mai.
# - Wat Phra Singh: Largest temple in Chiang Mai, featuring a golden stupa.
# - Doi Suthep: Mountain temple in Chiang Mai offering stunning views of the city.
# - Pai: Charming town surrounded by rice fields and known for its hippie atmosphere.
# - Gran Buda Blanco: White Buddha statue atop a hill in Pai, Thailand.
# - Wat Rong Khun: Famous White Temple in Chiang Rai, Thailand.
# - Templo Azul: Popular Blue Temple in Chiang Rai, Thailand.
# - Triángulo de Oro: Historical area where the borders of Thailand, Laos, and Myanmar meet.
# - Phuket: Island in southern Thailand known for its beaches and tourist attractions.
# - Panwa Beach: Popular beach in Phuket with white sand and clear waters.
# - Phi Phi Islands: Archipelago in Thailand famous for its stunning landscapes and beaches.
# - Maya Bay: Famous beach in the Phi Phi Islands, known for its appearance in the movie 'The Beach'.
# - Koh Phi Phi Don: Largest and only inhabited island in the Phi Phi archipelago.
# - Viking Nature Resort: Seaside resort in Koh Phi Phi Don, offering charming cabins by the sea.
# - Koh Lipe: Island in Thailand known for its pristine beaches and clear waters, ideal for diving.
# - Koh Tao: Island in Thailand famous for its coral reefs and turtle population, a popular diving destination.
# - Siam District: District in Bangkok known for its many shopping centers like MBK Center and Siam Paragon.
# - MBK Center: Shopping center in Bangkok's Siam District.
# - Siam Paragon: Shopping center in Bangkok's Siam District.
# - Grand Palace of Bangkok: Historical palace in Bangkok.
# - Kanchanaburi: City located 130 km northwest of Bangkok known for the Bridge over the River Kwai and historical significance during Wor
# - Bridge over the River Kwai: Historical bridge in Kanchanaburi, symbolizing the city's tragic past during World War II.
# - Erawan National Park: National park near Kanchanaburi known for Erawan Waterfall, a 7-tiered waterfall.
# - Ayutthaya: Historic city located 75 km north of Bangkok, former capital of the Kingdom of Siam and UNESCO World Heritage Site.
# - Ayutthaya: Historical city in Thailand with ancient ruins and temples
# - Lopburi: City known for its ancient temples and monkey population
# - Sukhothai: Ancient capital of the Kingdom of Siam with UNESCO World Heritage Site
# - Chiang Mai: Northern city in Thailand known for its temples and cultural activities
# - Chiang Rai: City in northern Thailand with cultural attractions and airport connections
# - Chiang Rai: A city in northern Thailand known for its unique temples and cultural attractions.
# - Wat Rong Khun: The White Temple, a famous and stunning temple in Chiang Rai.
# - Wat Rong Suea Ten: The Blue Temple, known for its blue decorations and statues.
# - Night Bazaar: A popular night market in Chiang Rai for buying souvenirs and local products.
# - Singha Park: A scenic park in Chiang Rai with a golden lion statue at the entrance.
# - Khun Korn Waterfall: The largest waterfall in the Chiang Rai area, easily accessible by a 30-minute walk from the parking lot.
# - Huai Pla Kang: A group of three giant and unique monuments located in Chiang Rai.
# - Mae Fah Luang Garden: A beautiful garden located on Doi Tung mountain in Chiang Rai.
# - Isan: Discover the authentic villages and magnificent landscapes of Isan by renting a scooter or a car. Don't miss the city of
# - Phuket: Phuket is the largest and one of the most touristy islands in Thailand, located in the Andaman Sea. Activities, nightlif
# - Krabi: Krabi, located across the Andaman Sea from Phuket, is known for its stunning karst formations. Attractions include Tiger
# - Ao Nang: Ao Nang, about 20 kilometers from Krabi, offers long sandy beaches and clear turquoise waters. Visitors can enjoy swimmi
# - Railay: Impressive beach surrounded by huge limestone cliffs, accessible only by long-tail boats. Popular for rock climbing with
# - Koh Phi Phi: Beautiful island group in the Andaman Sea, known for its stunning beaches and vibrant nightlife. Featured in the movie '
# - Koh Lanta: Serene island located south of Krabi, offering peaceful sandy beaches and a relaxed atmosphere. Ideal for scooter explor
# - Ko Yao Noi: Hidden gem island near Phuket, offering a tranquil and less crowded experience. Perfect for a peaceful getaway and relax
# - Ko Yao Noi: Perfect island for relaxation in bungalows by the sea, with beautiful beaches and day boat trips to discover other islan
# - Koh Samui: Second largest island in the Gulf of Thailand, known for luxury hotels, spas, beaches, and vibrant nightlife.
# - Ko Pha Ngan: Famous for the Full Moon Party on Haad Rin Beach, attracting partygoers with music, dancing, and drinks.
# - Similan Islands: Archipelago of 9 islands in the Andaman Sea, known for crystal-clear waters, marine life, and ideal for diving.
# - Pattaya: Pattaya is the main beach resort in Thailand, attracting tourists for its vibrant nightlife and entertainment options. I
# - Elephant Nature Park: Elephant Nature Park in Chiang Mai is a famous sanctuary known for its ethical treatment of elephants. Visitors can obse
# - Ko Tao: Ko Tao is a world-renowned diving destination in Thailand, offering beautiful underwater landscapes for snorkeling and d
# - Thai Massage: Thai massages are a popular relaxation option in Thailand, with many massage parlors and hotels offering this service. P
# - Thai Cuisine: Thailand is known for its diverse and flavorful cuisine, offering a wide range of dishes from street food to fine dining
# - Tailandia:
# - Bangkok:
# - Gran Palacio:
# - Gran Palacio: One of the most spectacular places to visit in Thailand
# - Mercado flotante de Damnoen Saduak: Famous floating market in Thailand
# - Parque Nacional Erawan: Home to the beautiful Erawan Waterfalls with seven levels of cascades
# - Ayutthaya: Former capital of the Kingdom of Siam, now a UNESCO World Heritage Site with ancient temples
# - Sukhothai: Capital of the first Thai kingdom, known for its beautiful temples
# - Chiang Rai: Northern tourist city in Thailand, located near the borders with Myanmar and Laos
# - Chiang Rai: Touristic city in northern Thailand, known for its special temples and beautiful natural surroundings. Close to the famo
# - White Temple: Unique temple in Chiang Rai, Thailand, designed by contemporary Thai artist Chalermchai Kositpipat. Known for its white
# - Blue Temple: New temple in Chiang Rai, Thailand, opened in 2016. Features a blue color theme both inside and outside the temple, offe
# - Golden Triangle: Area in northern Thailand where the borders of Thailand, Myanmar, and Laos meet. Known for opium production and the oppo
# - Chiang Mai: Second largest city in Thailand, surrounded by mountains and featuring historic temples, lively street markets, and oppo
# - Elephant Nature Park: Sanctuary in Thailand where rescued elephants are given a new life after being mistreated in circuses and tourist attrac
# - Elephant Nature Park: A must-visit ethical elephant sanctuary in Thailand
# - Doi Inthanon: The highest mountain in Thailand, standing at 2565 meters above sea level
# - Pai: A backpacker's paradise surrounded by nature, ideal for hiking and exploring waterfalls and caves
# - Phuket: One of the most famous islands to visit in Thailand, known for its vibrant atmosphere and beaches
# - James Bond Island: Famous island in Thailand, also known as Khao Phing Kan, featured in the James Bond movie 'The Man with the Golden Gun'
# - Ao Nang: A perfect enclave to discover the beauty of Krabi, offering access to nearby islands and beaches
# - Marina Resort Cliffhanger: Modern hotel with a nice pool, located about 15 minutes walk from the beach
# - Railay Beach: One of the most beautiful beaches in Thailand, famous for its cliffs and crystal-clear water
# - Ao Phra Nang: Considered one of the most beautiful beaches in Thailand, known for its stunning cliffs and clear water
# - Phi Phi Islands: Spectacular archipelago with stunning beaches, including Koh Phi Phi Don and Koh Phi Phi Lee
# - Koh Hong: Famous island in Thailand with white sandy beaches, crystal-clear water, and cliffs
# - Koh Poda: Small island near Ao Nang, known for its picturesque beaches and rock formations
# - Koh Lipe: Tiny island with stunning beaches, often referred to as the Maldives of Thailand
# - Khao Sok National Park: Impressive natural park in Thailand, featuring the largest area of virgin jungle in the country
# - Sukhothai: Historical heritage site in Thailand
# - Chiang Rai: City in Thailand known for its surroundings
# - Templo Blanco: Beautiful White Temple in Thailand
# - Templo Azul: Blue Temple in Thailand
# - Triángulo Dorado: Curious site in Thailand
# - Chiang Mai: Second largest city in Thailand
# - Elephant Nature Park: Nature park in Thailand
# - Doi Inthanon: Highest mountain in Thailand
# - Pai: Backpacker paradise surrounded by nature in Thailand
# - Phuket: Famous island in Thailand known for its atmosphere
# - James Bond Island: Island in Thailand known for James Bond movie
# - Bahía de Phang Nga: Bay in Thailand near James Bond Island
# - Muay Thai combat: Traditional Muay Thai combat in Thailand
# - Ao Nang: Perfect enclave to discover Krabi's beauty in Thailand
# - Railay Beach: Beautiful beach in Krabi, Thailand
# - Ao Phra Nang: Stunning beach in Krabi, Thailand
# - Islas Phi Phi: Beautiful islands in Thailand
# - Koh Hong: Paradise island for beach enjoyment in Thailand
# - Koh Poda: Island with the feeling of being deserted in Thailand
# - Koh Lipe: Small relaxing island in Thailand
# - Parque Nacional de Khao Sok: Largest virgin jungle in Thailand
# - Islas Similan: Great diving spot in Thailand
# - Koh Racha: Perfect islands for a trip from Phuket in Thailand
# - Koh Samui: One of the best islands in Thailand
# - Koh Phangan: Perfect setting for a Full Moon Party in Thailand
# - Parque Nacional Khao Yai: National park in Thailand
# - Koh Chang: Comprehensive island to visit in Thailand
# - Estados Unidos:
# - Tailandia:
# - Japón:
# - México:
# - Costa Rica:
# - Tailandia:
# - Bangkok:
# - Ayyuthaya:
# - Sukhotai:
# - Kanchanaburi:
# - Pattaya:
# - Koh Samet:
# - Chiang Mai:
# - Chiang Rai:
# - Mae Hong Son:
# - Krabi:
# - Phi Phi:
# - Koh Lanta Yai:
# - Railay:
# - Koh Lipe:
# - Chumphon:
# - Phuket:
# - Surat Thani:
# - Bangkok: Vibrant and stimulating capital of Thailand with iconic buildings, diverse gastronomy, and entertainment options.
# - Ayyuthaya: Ancient capital of Thailand with historical parks showcasing remnants of the old civilization.
# - Sukhotai: Former capital of Thailand known for its historical significance and archaeological sites.
# - Kanchanaburi: Attractive city and province in Thailand offering historical sites related to World War II, museums, and national parks.
# - Pattaya: Coastal city in Thailand known for its nightlife and tourism, particularly in the adult entertainment industry.
# - Koh Samet: Island near Bangkok known for its beautiful beaches and convenient location.
# - Chiang Mai: Northern city in Thailand known for its cultural richness and significant attractions.
# - Chiang Mai: Chiang Mai is known as the northern capital of Thailand, offering a collection of temples, historic buildings, and vibra
# - Chiang Rai: Chiang Rai is a popular destination in northern Thailand known for Wat Rong Khun, the White Temple, and other sacred sit
# - Mae Hong Son: Mae Hong Son province in northern Thailand offers a variety of attractions including Pai, a popular tourist town known f
# - Krabi: Krabi province in southern Thailand is renowned for its coastal beauty and popular beach destinations. It offers a range
# - Hat Phra Nang:
# - Blanco Hideout Railay:
# - Railay Princess Resort:
# - Rayavadee:
# - Koh Lipe: Considered one of the most beautiful islands in Thailand, offering white sandy beaches, turquoise seas, and a relaxing a
# - Bloom Hostel:
# - Wapi Resort:
# - Akira Lipe Resort:
# - Chumphon Archipelago: Home to three renowned islands: Koh Tao, Koh Pha Ngan, and Koh Samui, known for the Full Moon Party and excellent diving
# - Phuket: A developed area in Thailand resembling a miniature country, offering diverse experiences from vibrant nightlife to expl
# - Khao Yai National Park: One of Thailand's popular national parks, known for its diverse ecosystems and wildlife.
# - Erawan National Park: A scenic national park in Thailand featuring waterfalls and lush greenery.
# - Khao Sok National Park: A renowned national park in Thailand offering opportunities for jungle trekking and wildlife spotting.
# - Khao Sam Roi Yot National Park: A coastal national park in Thailand known for its limestone hills, caves, and diverse bird species.
# - Tailandia: One of the most interesting countries in Southeast Asia
# - Koh Lipe: A beautiful destination worth visiting in Thailand
# - Ayutthaya: Historical city in Thailand
# - Sukhothai: Historical city in Thailand
# - Kanchanaburi: City known for the famous bridge
# - Pattaya: Coastal city in Thailand
# - Koh Samet: Island in the Gulf of Thailand
# - Mae Hong Son: Province in northern Thailand
# - Koh Lanta Yai: Island in Thailand
# - Koh Lanta: Island in Thailand
# - Tailandia: Discover the beauty of Thailand with a 30-day itinerary, including practical information and tips.
# - Maha Vajiralongkorn: Current monarch of Thailand, son of Bhumibol Adulyadej, who reigned for 70 years.
# - Bangkok: Capital city of Thailand, a vibrant and bustling metropolis.
# - Tailandia:
# - Bombay:
# - New York:
# - Jordania:
# - Sri Lanka:
# - Bali:
# - El Hierro:
# - Zanzíbar:
# - Sarria:
# - Tenerife:
# - Estambul:
# - Alemania:
# - Zaanse Schans:
# - Vietnam:
# - Venecia:
# - Tailandia:
# - España:
# - Andalucía:
# - Aragón:
# - Baleares:
# - Cantabria:
# - Castilla La Mancha:
# - Castilla y León:
# - Cataluña:
# - Comunidad Valenciana:
# - Galicia:
# - Islas Canarias:
# - La Rioja:
# - Madrid:
# - Navarra:
# - País Vasco:
# - Europa:
# - Alemania:
# - Andorra:
# - Austria:
# - Bélgica:
# - Bosnia-Herzegovina:
# - Croacia:
# - Escocia:
# - Eslovaquia:
# - Francia:
# - Grecia:
# - Hungría:
# - Inglaterra:
# - Irlanda:
# - Islandia:
# - Italia:
# - Luxemburgo:
# - Malta:
# - Noruega:
# - Países Bajos:
# - Portugal:
# - República Checa:
# - Rusia:
# - África:
# - Egipto:
# - Marruecos:
# - América:
# - Colombia:
# - Cuba:
# - Estados Unidos:
# - México:
# - República Dominicana:
# - Asia:
# - Camboya:
# - Corea del Sur:
# - Emiratos Árabes Unidos:
# - Indonesia:
# - Israel:
# - Japón:
# - Jordania:
# - Malasia:
# - Maldivas:
# - Palestina:
# - Singapur:
# - Tailandia:
# - Turquía:
# - Vietnam:
# - Chiang Mai: Chiang Mai is a peaceful city in Thailand known for its traditional atmosphere, night market, nature activities, and tem
# - Wat Phra That Doi Suthep: Famous temple in Chiang Mai located on a mountain, offering stunning views and a serene atmosphere.
# - Wat Umong: Temple hidden in the jungle near Chiang Mai, providing a peaceful and natural setting for visitors.
# - Wat Pha Lat: Scenic temple surrounded by jungle in northern Thailand, offering a unique spiritual experience.
# - Doi Inthanon: Mountain peak in Thailand, home to the Doi Inthanon temple and breathtaking natural landscapes.
# - Triángulo del Oro: Historical site where the borders of Myanmar, Thailand, and Laos meet, offering a glimpse into the region's past.
# - Chiang Rai:
# - Krabi: Krabi is known for its stunning karst landscape and popular island excursions like the Four Islands tour and Hong Island
# - Koh Phi Phi: Koh Phi Phi is a must-visit island in Thailand, with Long Beach on Koh Phi Phi Don offering a peaceful and enjoyable exp
# - Ayutthaya:
# - Sukhothai:
# - Koh Lipe:
# - Koh Lanta:
# - Krabi:
# - Koh Pha Ngan:
# - Koh Samui:
# - Koh Tao:
# - Parque Natural de Erawan:
# - Parque Nacional de Khao Sok:
# - Parque Nacional de Khao Yai:
# - Mae Klong Railway Market: Mae Klong Railway Market is a unique market where vendors quickly clear their merchandise from the tracks multiple times
# - Damnoen Saduak Floating Market: Damnoen Saduak Floating Market is an iconic market located about 100 kilometers from Bangkok. Vendors row colorful boats
# - Ayutthaya Ruins: Ayutthaya, a UNESCO World Heritage Site, features impressive temples, stupa remnants, and Buddha statues partially hidde
# - Wat Rong Khun: Unique temple designed by artist Chalermchai Kositpipat as a living artwork. Symbolizes purity of Buddhism with white de
# - Nan Province: Lesser-known province northeast of Chiang Mai with lush mountains, rice fields, ethnic villages, and unique temples like
# - Phu Hin Rong Kla National Park: Hidden treasure in Phitsanulok province offering a blend of wild nature and history. Known for unique geological formati
# - Sukhothai Historical Park: First capital of the Thai kingdom in the 13th century. Tranquil site with ruins of temples spread across a green plain,
# - Wat Si Chum: Famous for its 15-meter tall seated Buddha hidden in a narrow brick room. The golden hand resting on its knees is one of
# - Wat Mahathat: A must-visit site in Sukhothai known for its sunrise views.
# - Phetchaburi: An ancient city with historical sites, architecture, and nature. Must-visit places include Wat Mahathat and the palace P
# - Tham Khao Luang: An underground sanctuary illuminated by natural light filtering through a rock opening.
# - Khao Sok National Park: A beautiful natural sanctuary in Thailand known for its ancient rainforest and Cheow Lan Lake.
# - Koh Tao: A small island in the Gulf of Thailand known for its crystal-clear waters, coral reefs, and abundant marine life. Ideal
# - Phi Phi Islands: Famous islands off the coast of Krabi known for their stunning karst cliffs and turquoise waters. Popular activities inc
# - Phi Phi Marine Park: A protected marine park known for responsible activities like diving.
# - Koh Yao Noi: Tranquil island with quiet beaches, local fishermen, and stunning views of karst formations.
# - James Bond Island: Famous for its rocky peak featured in the James Bond movie 'The Man with the Golden Gun'.
# - Railay: Accessible only by boat, surrounded by limestone cliffs, offering pristine beaches and jungle.
# - Pattaya: Coastal city known for water activities during the day and vibrant nightlife on Walking Street.
# - Grand Palais de Bangkok: Thailand is not just beaches and parties, the country is a true cultural adventure where every moment can be memorable.
# - Tailandia: Thailand offers a diverse range of cities and experiences, from cultural heritage in the north to stunning beaches in th
# - Chiang Mai: Cultural hub of Thailand with temples, heritage sites, and natural beauty.
# - Chiang Rai: City known for its temples, art, and unique culture.
# - Doi Suthep Temple: A pilgrimage site for Buddhists with beautiful views of Chiang Mai city.
# - Wat Phra Singh Temple: Houses the Phra Singh Buddha, an important Buddha statue, and is highly revered by locals.
# - Wat Chedi Luang Temple: Located in the city center, known for its City Pillar and reclining golden Buddha.
# - Sunday Walking Street Market: A market where you can try Khantoke food, typical of northern Thailand, on Sunday evenings.
# - Chiang Mai Women’s Correctional Institution: A unique massage site where female inmates offer massages to tourists.
# - Kanta Elephant Sanctuary: A sanctuary in Chiang Mai known for caring for elephants and providing a natural environment for them.
# - Chiang Rai: Less touristy city known for the White Temple and other unique attractions.
# - White Temple (Wat Rong Khun): Contemporary temple entirely constructed in white materials, known for its unique design.
# - Black Temple: Museum by artist Thawan Duchanee featuring over 40 black buildings.
# - Wat Phra Kaew Temple: One of the oldest temples in Chiang Rai, entirely made of wood.
# - Wat Phra Singh Temple: Lanna-style temple near the city hall, featuring a replica of the Phra Buddha Sihing statue.
# - Clock Tower: A landmark in the city center of Chiang Rai, illuminated beautifully at night.
# - Doi Khun National Park: National park with the longest railway tunnel in Thailand, ideal for nature lovers.
# - Golden Triangle: Area where Thailand, Myanmar, and Laos meet, surrounded by natural beauty and rivers.
# - Chiang Rai Night Bazaar: A market in the city center offering local cuisine and products.
# - Saturday Night Walking Street: Market where you can experience the local gastronomy and buy typical products of Chiang Rai.
# - Erawan Waterfalls: Popular waterfalls located in Erawan National Park, 75 kilometers from Kanchanaburi. The park offers a 2-kilometer walki
# - Bridge over the River Kwai: Historic bridge built by Japanese prisoners during World War II. It is a symbol of the area's significance during the wa
# - Hellfire Pass: Historical railway cutting made during World War II where prisoners worked under harsh conditions. The pass is a signifi
# - Sukhothai Historical Park: Ruins of temples and palaces, UNESCO World Heritage Site
# - Phuket: Popular destination with diverse beaches and nightlife
# - Phi Phi Islands: Paradisiacal beaches with turquoise waters, famous for Maya Bay
# - Krabi: Tranquil beaches with beautiful surroundings
# - Koh Samui: Relaxing island with a variety of beaches and water sports
# - Parque arqueológico de Ayutthaya: Ancient capital with over 300 temples and palaces, recognized as a UNESCO World Heritage Site.
# - Mercado Chatuchack: Largest market in Bangkok with over 8,000 stalls offering a variety of products.
# - Chatuchak Market: One of the must-visit places in Thailand, open only on weekends. A paradise for shopping enthusiasts.
# - Wat Si Chum: A characteristic and highly photographed temple in Sukhothai, Thailand, known for its majestic Buddha statue.
# - Phi Phi Island: Exquisite island in the Andaman Sea, popular for its white sandy beaches and crystal-clear waters.
# - Krabi and Phuket Islands: Ideal destinations for adventure seekers in Thailand, offering activities like diving and kayaking in the crystal-clear
# - Chiang Mai: Known for traditional spas and the famous Thai massage technique. A hub for digital nomads with a rich cultural heritage
# - Women of the Long Neck Karen Tribe: Fascinating community of women with elongated necks due to wearing copper rings from a young age. A unique cultural expe
# - Paradise Waterfall: Ideal for an adventurous experience like Tarzan, with natural pools and opportunities for cliff jumping.
# - Ayutthaya: One of the most important archaeological sites in Southeast Asia.
# - Sukhothai Historical Park: Ancient capital of the Kingdom of Sukhothai, declared a UNESCO World Heritage Site.
# - Wat Phra That Doi Suthep: Sacred temple on a mountain west of Chiang Mai city, founded in 1383.
# - Wat Phra Singh: Venerated temple in Chiang Mai, built in 1345.
# - Wat Chedi Luang: Impressive temple in Chiang Mai with a semi-ruined chedi surrounded by elephants.
# - White Temple: One of the most visited tourist attractions in Chiang Rai, known for its unique white architecture.
# - Black House: Unusual museum in Chiang Rai featuring bizarre artworks and structures.
# - Blue Temple: Unique temple in Chiang Rai with blue and golden exterior, housing a white Buddha inside.
# - Golden Triangle: Natural border formed by the Mekong River between Thailand, Laos, and Myanmar.
# - Golden Triangle: Natural border formed by the Mekong River between Thailand, Laos, and Myanmar
# - Maya Bay: Famous beach located in Phi Phi, Thailand
# - View Point de Phi Phi: Scenic viewpoint in Phi Phi, Thailand
# - Kanchanaburi: City near Bangkok, Thailand, known for the River Kwai and Erawan National Park
# - Lopburi: City in Thailand known for its ancient heritage and monkey population
# - Bahía de Phang Nga: Natural wonder located on Koh Tapu, also known as James Bond Island, in Thailand
# - Tailandia:
# - Route 66:
# - Costa Rica:
# - Japan:
# - Thailand:
# - Vietnam:
# - Singapore:
# - Bali:
# - Budapest:
# - Ireland:
# - Scotland:
# - Copenhagen:
# - Thailand: Fascinating country in Southeast Asia known for its rich culture, beautiful landscapes, white sandy beaches, and delicio
# - Bangkok: Vibrant capital city of Thailand known for its ornate shrines and vibrant street life.
# - Chiang Mai: Northern city in Thailand known for its ancient temples and vibrant markets.
# - Phuket: Island province in Thailand famous for its beaches, resorts, and nightlife.
# - Krabi: Province in southern Thailand known for its stunning beaches and limestone cliffs.
# - Koh Phi Phi: Group of islands in Thailand known for their crystal-clear waters and stunning scenery.
# - Koh Samui: Island in the Gulf of Thailand known for its palm-fringed beaches and coconut groves.
# - Koh Tao: Island in Thailand popular for its diving spots and vibrant marine life.
# - Koh Phangan: Island in the Gulf of Thailand known for its Full Moon Party and beautiful beaches.
# - Thailand:
# - Best Tours in Thailand: Immerse yourself in an unforgettable adventure through Thailand with our selection of the best tours, carefully chosen f
# - Packing List for Thailand: Explore in detail what you should consider packing for the trip to Thailand, from choosing the right clothing and person
# - Spanish Guides in Thailand: Immerse yourself in the fascinating culture, rich history, and stunning natural beauty of this exotic destination in Sou
# - Tours in Thailand: Our recommendations for tours in Thailand in Spanish, whether group or private, meticulously tailored to offer the best
# - Hotels in Thailand: Decide where to stay, ensuring maximum guarantees for a good rest. Thailand has hundreds of options for every budget, ma
# - Transfers in Thailand: Plan your mobility around the country, whether from the airport, hotel, train station, cruise, or transfer to any other
# - SIM Card with Internet: It is highly recommended to always have internet connection while traveling to Thailand, to stay connected with family,
# - Free Tours in Thailand: Take advantage and join our free tours in Thailand. There are only two, one in Bangkok and one in Chiang Mai, and they a
# - 20 Questions and Answers for the Trip to Thailand: Before embarking on a trip to this fascinating destination, it is natural to have questions about various aspects. Here,
# - Tu Guia en Tailandia: Travel assistance service in Thailand with Spanish-speaking support
# - Bangkok: Capital of Thailand with ancient temples, floating markets, and vibrant nightlife
# - Chiang Mai: City in northern Thailand known for natural beauty, national parks, and historic temples
# - Chiang Mai:
# - Wat Umong: Impressive cave temple in Chiang Mai
# - Wat Chedi Luang: Impressive temple in Chiang Mai
# - Phuket:
# - Krabi:
# - Phi Phi Islands:
# - Koh Samui:
# - Koh Tao:
# - Koh Tao: Island known for diving in Thailand
# - Chiang Rai: Known for natural beauty, diverse culture, and unique tourist attractions
# - Wat Rong Khung: The White Temple of Chiang Rai
# - Ayutthaya: Known for ruins including temples, palaces, and statues
# - Bangkok: Capital city of Thailand
# - Buddhist Temples and Ruins: Learn about Buddhism and the history of each temple or ruin in Thailand.
# - Luxurious and Incredible Boats: Enjoy transfers to the most beautiful landscapes and spectacular beaches of Thailand on luxurious boats.
# - James Bond Island and Canoe Route through Mangroves: Explore the famous James Bond Island and take a canoe route through mangroves in Phuket.
# - Jewels of Chiang Rai Tour: Discover the gems of Chiang Rai on a guided tour.
# - Snorkeling at Phi Phi Islands and Maya Beach: Experience snorkeling at the Phi Phi Islands and Maya Beach in Phuket.
# - Essence of Bangkok Tour: Immerse yourself in the essence of Bangkok on a guided tour.
# - Warm Welcome to Krabi Tour: Enjoy a warm welcome to Krabi on a guided tour.
# - Elephant Sanctuary in Chiang Mai: Visit the Elephant Sanctuary in Chiang Mai for an unforgettable experience.
# - Tropical Exoticism in Koh Phi Phi: Experience tropical exoticism on a traditional Thai boat tour in Koh Phi Phi.
# - Bioluminescent Plankton, Railay, and 4 Islands Tour in Krabi: Explore the bioluminescent plankton, Railay, and 4 islands on a tour in Krabi.
# - Chiang Mai Nightfall Tour: Discover the charms of Wat Phra That Doi Suthep and the meditation temple Wat Palad in Chiang Mai at night.
# - Non-Touristy Chiang Mai + Bamboo Rafting Tour: Experience the non-touristy side of Chiang Mai and enjoy bamboo rafting.
# - 111/11 Moo5:
# - Tailandia:
# - Bangkok: Capital of Thailand with a mix of ancient Buddhist temples and modern skyscrapers.
# - Chiang Mai: Cultural hub of Thailand with historical temples and monuments.
# - Chiang Rai: Home to the innovative White Temple and other unique temples.
# - Ayutthaya: Historical city with ancient ruins and temples.
# - Lampang: City known for its traditional horse-drawn carriages and temples.
# - Nan: City with a rich cultural heritage and natural beauty.
# - Phitsanulok: City with historical sites and temples.
# - Phuket: Famous beach destination in Thailand with stunning landscapes and activities.
# - Phi Phi: Island known for its beautiful beaches and crystal-clear waters.
# - Krabi: Paradise-like destination in Thailand with picturesque beaches and cliffs.
# - Pad Thai: Popular Thai dish of stir-fried rice noodles with chicken, shrimp, or tofu, seasoned with fish sauce, soy sauce, egg, li
# - Kuay Teow Lui Suan: Refreshing and light Thai-style spring rolls
# - Khao niao Mamuang: Sticky rice with mango, a sweet Thai dessert
# - Tailandia: The Kingdom of Thailand, a wonderful and touristy country that serves as a gateway to Southeast Asia for many travelers.
# - Bangkok: The chaotic capital city of Thailand, where scents, flavors, and cultures mix. It offers a variety of places and experie
# - Ayutthaya: Historical city that was once the capital of Thailand, known for its ruins of palaces and temples.
# - Sukhothai: Former capital of the Kingdom of Thailand, preserving a large number of palace and temple ruins.
# - Chiang Mai: A must-visit city in northern Thailand, offering a unique cultural experience and beautiful landscapes.
# - Chiang Rai: City in northern Thailand known for its temples and unique cultural attractions.
# - Koh Tao: Island in Thailand known for its diving spots and beautiful beaches.
# ...
# - Ensure to exchange money safely and at a good exchange rate to manage your budget effectively while traveling in Thailand.: Currency exchange tips
# - Stay informed about common scams and how to avoid them while traveling in Thailand.: Scam prevention tips
# - Consider visiting the islands of the Gulf of Thailand from June to September for minimal rainfall.: Island visit recommendation
# - Visit popular beach destinations like Phuket, Koh Phi Phi, or Krabi during the rainy season for fewer tourists and cheaper hotel prices.: Beach destination tip
# - Travel to Thailand in any season depending on your preferences and the region you want to explore.: Best time to visit Thailand recommendation
# - Traveling solo in Thailand is easy, especially for backpackers, but allow extra time for transportation and accommodation arrangements.: Solo travel tip
# - Consider booking a guided tour in Thailand if you are older, have a limited budget, and want a hassle-free travel experience.: Guided tour recommendation
# - Opt for a middle ground by planning your trip independently but booking quality hotels and tours in Spanish for a well-organized experience.: Independent travel with guided tours tip
# - Compare Thailand with other Southeast Asian countries like Vietnam to make an informed decision on your travel destination.: Comparison with Vietnam tip
# - Best time to visit Thailand is from November to April during the dry season. Avoid June to September due to heavy rainfall. Check exact festival dates online.: Travel tips for visiting Thailand
# - Avoid falling for Tuk Tuk scams in Bangkok offering cheap city tours. Be cautious with taxi drivers claiming attractions are closed to persuade you to take a tour with them.: Travel tips for Bangkok
# - Exchange USD to Thai Baht in larger denominations for better rates. Avoid changing money at the airport and carry clean, undamaged bills. Cash is preferred as many places do not accept credit cards.: Currency exchange tips for Thailand
# - Respect Thai culture, religion, and customs. Be patient and understanding when communicating as language barriers may exist. Avoid supporting activities that exploit animals.: Cultural tips for travelers in Thailand
# - Thailand is a great destination for backpackers with its easy travel options and diverse attractions. Make sure to check visa requirements, flights to Bangkok, travel insurance, best time to visit, and consider getting a local eSIM card for internet access.: Before traveling to Thailand
# - When planning your trip to Thailand, consider the monsoon season and its impact on beach destinations. Check the climate month by month to choose the best time to visit different regions of the country.: Best time to visit Thailand
# - For continuous internet access during your trip to Thailand, consider getting an eSIM card with unlimited data. This can be useful for staying connected while traveling.: eSIM card for Thailand
# - Avoid supporting animal exploitation in Thailand by being informed about the mistreatment in tiger centers, elephant sanctuaries, and volunteer programs. Choose ethical activities that respect wildlife and promote conservation efforts.: Animal welfare in Thailand
# - When planning a trip that includes snorkeling, ensure to practice responsible diving to minimize negative impacts on marine ecosystems. Respect and protect the underwater world during your exploration.: Responsible snorkeling and diving
# - Consider volunteering at animal welfare organizations in Thailand, such as Lanta Animal Welfare in Koh Lanta and Santisook in Chiang Mai, to help street animals in need of care and support.: Volunteering opportunities in Thailand
# - For budget travelers in Thailand, consider booking accommodations through platforms like Booking.com or Agoda.com for a wide range of options. Plan transportation in advance using services like 12go.asia for convenience and efficiency.: Budget travel tips for Thailand
# - The best time to travel to Thailand is during the dry season, from November to February, when the weather is cooler and pleasant for exploring beaches and cities. Avoid the rainy season from May to October.: When to travel to Thailand
# - Organizing a trip to Thailand involves planning your itinerary based on the destinations you are interested in, such as Bangkok, Chiang Mai, or the southern islands. Research the climate, local customs, and choose the best travel season. Make sure to book accommodation in advance and have all travel documents ready before departure.: How to organize a trip to Thailand
# - To travel to Thailand, you need a valid passport with at least six months validity. Some countries require a visa, so check if you need to apply for one before traveling. Also, ensure you have up-to-date vaccinations and a copy of your travel insurance. Pack light clothing, sunscreen, and appropriate plug adapters for the destination.: What do you need to travel to Thailand
# - The cheapest months to travel to Thailand are usually during the low season, between May and October, when rainfall is more frequent. Prices for flights and accommodation are lower due to reduced demand. Consider your preferences before planning your trip as the weather can be unpredictable.: When is it cheapest to travel to Thailand
# - It is recommended to book hotels in advance to find good deals, save time, and plan your day efficiently while traveling.: Hotel booking tips
# - Consider using travel cards to avoid paying commissions for transactions abroad and save money on currency exchange fees.: Travel card recommendations
# - Negotiate prices with tuk-tuk drivers and local merchants in Thailand to get the best deals and avoid overpaying.: Negotiation tips in Thailand
# - The currency in Thailand is the baht. It is recommended to carry a mix of cash and use ATMs for convenience. Consider exchanging money or withdrawing from ATMs with favorable rates.: Money in Thailand
# - When traveling to Thailand, it is advisable to have a travel insurance plan to ensure coverage for any unexpected events or emergencies during your trip.: Travel Insurance for Thailand
# - Thai massages are known for their intensity. Be prepared for a firm massage experience rather than a relaxing one.: Thai Massages
# - For traveling to Thailand from Spain, ensure your passport is valid for at least 6 months. Detailed information on entry and exit procedures and visa requirements for other passport holders are available.: Travel Documentation for Thailand
# - Thailand experiences consistent temperatures throughout the year. The monsoon season typically runs from May to October, but rain showers are not continuous. Plan your trip accordingly to enjoy your visit.: Best Time to Visit Thailand
# - This is a comprehensive travel guide for Thailand with valuable information on itineraries, transfers, budget, and cool videos.: Feedback on a travel guide for Thailand
# - The travel guide for Thailand is highly recommended for a comprehensive trip planning experience.: Feedback on a travel guide for Thailand.
# - Consider dedicating more days to the southern beaches if you enjoy beach activities.: Suggestion to allocate more time for beach destinations in Thailand.
# - Elephant Nature Park allows visitors to interact with elephants, and some elephants are comfortable with human contact.: Information about interacting with elephants at Elephant Nature Park.
# - The blog is made with WordPress.:
# - Cookies are used for various functionalities on the website, such as sharing content on social media and collecting feedback. They do not store any personal data.:
# - Performance cookies are used to understand and analyze the website's performance to provide a better user experience.:
# - Analytical cookies are used to understand how users interact with the website, providing information such as the number of visitors and traffic sources.:
# - Advertising cookies are used to display more relevant ads to users by tracking visitor behavior and collecting information to provide appropriate ads.:
#
# === EVENT (20) ===
# - Dragon Crest Mountain:
# - Ko Pha Ngan: A Thai paradise that invites you to live without haste:
# - Loy Kratong and Yi Peng: two festivals of lights in Thailand:
# - Backpacker's guide to Thailand:
# - Is it safe to travel to Thailand?:
# - Best islands in Thailand to visit:
# - Best time to travel to Thailand:
# - Solo travel to Thailand:
# - 10 must-see places in Thailand:
# - Lantern Festival: Fantastic festival of lanterns in November
# - Songkran Festival: One of the most famous festivals in Thailand, celebrated in April
# - Fascinante festival de las linternas flotantes en Tailandia: Fascinating festival of floating lanterns in Thailand
# - Yi Peng Festival: The Yi Peng Festival in Chiang Mai lights up the sky with thousands of floating lanterns every November. This celebratio
# - Yi Peng Festival: Chiang Mai lights up with thousands of flying lanterns during the Yi Peng Festival in November. Lanterns are released in
# - Loy Krathong Festival: During the Loy Krathong Festival, Thais decorate small rafts with flowers, candles, and incense to pay homage to the wat
# - CLOSURE OF MAYA BAY: Temporary closure of Maya Bay in Thailand in 2025
# - HONEYMOON IN THAILAND: Romantic, exotic, and perfect honeymoon destination in Thailand
# - THINGS NO ONE TELLS YOU BEFORE TRAVELING TO THAILAND: Important information to know before traveling to Thailand
# - THAILAND IN SUMMER: Discover the lesser-known side of Thailand in summer
# - THE RED LIGHT DISTRICT OF BANGKOK: All you need to know about the Red Light District in Bangkok
#
# === ACTIVITY (41) ===
# - Snorkeling: Enjoy snorkeling at The Three Rocks, Tanote Bay, and Hin Wong Bay near Koh Tao, where you can witness the vibrant marine
# - Hiking: Embark on a hiking adventure to explore the natural beauty of Koh Tao, with trails leading to scenic viewpoints and hidd
# - Diving: Experience world-class diving at Chumphon Pinnacles, HTMS Sattakut, and White Rock near Koh Tao, where you can discover
# - Culinary Experience: Indulge in a culinary journey on Koh Tao, savoring traditional dishes like kaeng khiao waan (green curry) and Massaman c
# - Explore Chiang Mai: Experience Songthaews, taxis, tuk-tuks, motorcycles, and Grab for transportation
# - El Gran Palacio de Bangkok: Official residence of the kings of Thailand for over 150 years, featuring the Wat Phra Kaew with the revered Emerald Bud
# - Un combate de muay thai: Experience the essential element of Thai culture with muay thai, a traditional martial art that combines dance, spiritua
# - El mercado sobre las vías de Mae Klong: Visit the unique market set up on the railway tracks of Mae Klong, where vendors quickly retract their stalls as the tra
# - El mercado flotante de Damnoen Saduak: Explore the bustling Damnoen Saduak floating market, a vibrant hub of local trade on boats along the canals of Thailand.
# - Las ruinas de Ayutthaya: Discover the ancient ruins of Ayutthaya, a UNESCO World Heritage Site showcasing the remnants of the former capital of T
# - El festival Yi Peng en Chiang Mai: Experience the magical Yi Peng Lantern Festival in Chiang Mai, where thousands of lanterns light up the night sky in a m
# - Una clase de cocina tailandesa: Immerse yourself in Thai culinary traditions with a cooking class, learning to prepare authentic dishes with local ingre
# - Los arrozales de Pai: Explore the picturesque rice fields of Pai, offering stunning views of the terraced landscapes and a tranquil escape fro
# - Las plantaciones de té de Mae Salong: Visit the tea plantations of Mae Salong, where lush green fields of tea bushes create a serene and scenic environment fo
# - El templo Blanco de Chiang Rai: Marvel at the White Temple of Chiang Rai, a contemporary masterpiece of Thai architecture with intricate white details a
# - La provincia de Nan: Discover the charming province of Nan, known for its cultural heritage, traditional villages, and stunning natural lands
# - El Parque Nacional Phu Hin Rong Kla: Explore the rugged beauty of Phu Hin Rong Kla National Park, home to diverse flora and fauna, scenic viewpoints, and hik
# - El parque histórico de Sukhothai: Step back in time at the historical park of Sukhothai, a UNESCO site with ancient ruins, temples, and Buddha statues fro
# - Los templos de Phetchaburi: Visit the temples of Phetchaburi, a town known for its hilltop temples, cave shrines, and historical sites reflecting Th
# - El Parque Nacional de Khao Sok: Immerse yourself in the natural wonders of Khao Sok National Park, a rainforest paradise with limestone cliffs, emerald
# - Koh Tao: Relax on the idyllic island of Koh Tao, known for its crystal-clear waters, vibrant coral reefs, and excellent diving an
# - Las islas Phi Phi: Explore the stunning Phi Phi Islands, a tropical paradise with turquoise waters, limestone cliffs, and vibrant marine li
# - Las playas de Koh Yao Noi: Unwind on the tranquil beaches of Koh Yao Noi, a hidden gem with pristine sands, swaying palm trees, and a peaceful atmo
# - Railay: Discover the breathtaking beauty of Railay Beach, a secluded paradise with towering limestone cliffs, clear waters, and
# - Pattaya: Experience the vibrant coastal city of Pattaya, known for its lively nightlife, water sports, and sandy beaches along th
# - Muay Thai: Muay Thai is a traditional Thai martial art that combines dance, spirituality, and power. It is a unique fighting style
# - Muay Thai Class: Experience the world of Muay Thai by taking a class in Bangkok. Many schools offer sessions for all levels, providing a
# - Elephant Sanctuary Excursion: Visit an elephant sanctuary in Chiang Mai to see these protected animals in their natural habitat.
# - Ziplining in Chiang Mai: Experience the jungle in a fun way by ziplining in Chiang Mai.
# - Gastronomic Tour: Embark on a gastronomic tour to taste the delights of local cuisine in Chiang Mai.
# - Thai Wedding: Celebrate your love with a traditional Thai wedding in Thailand.
# - Thai Cooking Class: Join a cooking class in Chiang Mai to learn how to prepare classic Thai dishes like pad thai, green curry, and tom kha k
# - Rice Fields of Pai: Take a day trip from Chiang Mai to Pai, a small hippie town surrounded by hills, waterfalls, and rice fields.
# - Tea Plantations of Mae Salong: Explore the tea plantations in Mae Salong, a peaceful village in Chiang Rai known for its unique blend of Thai and Chine
# - Descenso por el río en balsa de bambú: Enjoy a bamboo rafting experience on the river surrounded by stunning natural scenery.
# - Cursos de buceo: Take diving courses in the clear waters of Thailand to explore the underwater world.
# - Aprender sobre los elefantes: Engage in educational experiences to learn about elephants and their conservation in Thailand.
# - Visita parques nacionales: Explore the national parks of Thailand with diverse flora and fauna, including endangered species.
# - Compras y artesanía: Discover the vibrant shopping scene in Thailand, offering a variety of local crafts, silk, jewelry, and wooden products.
# - Mercados de noche: Experience the lively night markets in Thailand, perfect for strolling, tasting local food, and buying souvenirs.
# - Centros comerciales: Visit modern shopping malls in Thailand for a comfortable shopping experience, dining, and enjoying city views.
#
# === COUNTRY (18) ===
# - Hungary:
# - Ireland:
# - Northern Ireland:
# - Iceland:
# - Italy:
# - Luxembourg:
# - Malta:
# - Norway:
# - Netherlands:
# - Poland:
# - Portugal:
# - United Kingdom:
# - Czech Republic:
# - Romania:
# - Russia:
# - Sweden:
# - Switzerland:
# - Spain:
#
# === PROVINCE (16) ===
# - Andalusia:
# - Aragon:
# - Asturias:
# - Balearic Islands:
# - Canary Islands:
# - Castilla-La Mancha:
# - Castile and Leon:
# - Catalonia:
# - Valencian Community:
# - Extremadura:
# - Galicia:
# - La Rioja:
# - Madrid:
# - Murcia:
# - Navarre:
# - Basque Country:

# %%
from difflib import SequenceMatcher
from itertools import combinations
import json
from collections import defaultdict
from pathlib import Path

def similarity(a, b):
    """Calcula la similitud entre dos strings (0-1)"""
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

def load_entities_from_jsonl(file_path):
    """Carga las entidades desde el archivo JSONL y las agrupa por tipo"""
    entidades_por_tipo = defaultdict(list)
    
    # Convertir a Path object para manejo profesional de rutas
    file_path = Path(file_path)
    
    if not file_path.exists():
        print(f"❌ Error: El archivo {file_path} no existe")
        return entidades_por_tipo
    
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data = json.loads(line)
                url = data.get('url', 'URL desconocida')
                source_name = data.get('source_name', 'Fuente desconocida')
                
                # Agregar información de origen a cada entidad
                for entidad in data.get('entities', []):
                    entidad['source_url'] = url
                    entidad['source_name'] = source_name
                    
                    tipo = entidad.get('entity_type', 'desconocido')
                    if isinstance(tipo, list):
                        tipo = tipo[0] if tipo else 'desconocido'
                    elif tipo is None:
                        tipo = 'desconocido'
                    
                    entidades_por_tipo[tipo].append(entidad)
    
    return entidades_por_tipo

def find_similar_entities_with_urls(entidades_por_tipo, threshold=0.7):
    """Encuentra entidades similares de TODOS los tipos y las agrupa, mostrando las URLs de origen"""
    
    # Extraer TODAS las entidades con información de origen
    todas_entidades_con_origen = []
    
    for tipo, entidades in entidades_por_tipo.items():
        for entidad in entidades:
            nombre = entidad.get('name') or entidad.get('title') or entidad.get('advice_text') or '[Sin nombre]'
            if nombre and nombre != '[Sin nombre]':
                todas_entidades_con_origen.append({
                    'nombre': nombre,
                    'tipo': tipo,
                    'url': entidad.get('source_url', 'URL desconocida'),
                    'source_name': entidad.get('source_name', 'Fuente desconocida'),
                    'entidad_completa': entidad  # Guardar la entidad completa para más info
                })
    
    if not todas_entidades_con_origen:
        print("No se encontraron entidades")
        return
    
    # Encontrar grupos de entidades similares
    grupos_similares = []
    entidades_usadas = set()
    
    for i, entidad1 in enumerate(todas_entidades_con_origen):
        if entidad1['nombre'] in entidades_usadas:
            continue
            
        grupo = [entidad1]
        entidades_usadas.add(entidad1['nombre'])
        
        # Buscar entidades similares
        for entidad2 in todas_entidades_con_origen[i+1:]:
            if entidad2['nombre'] not in entidades_usadas:
                sim = similarity(entidad1['nombre'], entidad2['nombre'])
                if sim >= threshold and threshold < 0.85:
                    grupo.append(entidad2)
                    entidades_usadas.add(entidad2['nombre'])
        
        if len(grupo) > 1:  # Solo grupos con más de una entidad
            grupos_similares.append(grupo)
    
    # Mostrar resultados ordenados alfabéticamente
    print(f"=== ENTIDADES SIMILARES (similitud >= {threshold}) ===")
    print(f"Total de entidades: {len(todas_entidades_con_origen)}")
    print(f"Grupos de entidades similares: {len(grupos_similares)}")
    
    # Mostrar grupos ordenados alfabéticamente
    for grupo in sorted(grupos_similares, key=lambda x: x[0]['nombre'].lower()):
        print(f"\n📍 {grupo[0]['nombre']} (principal) - Tipo: {grupo[0]['tipo']}")
        print(f"   📍 URL: {grupo[0]['url']}")
        print(f"   📰 Fuente: {grupo[0]['source_name']}")
        
        for entidad in grupo[1:]:
            sim = similarity(grupo[0]['nombre'], entidad['nombre'])
            print(f"   └─ {entidad['nombre']} (similitud: {sim:.2f}) - Tipo: {entidad['tipo']}")
            print(f"      �� URL: {entidad['url']}")
            print(f"      �� Fuente: {entidad['source_name']}")
    
    # Mostrar entidades únicas (sin similares)
    entidades_unicas = [e for e in todas_entidades_con_origen if e['nombre'] not in entidades_usadas or 
                       not any(e['nombre'] in [ent['nombre'] for ent in grupo] for grupo in grupos_similares if len(grupo) > 1)]
    
    if entidades_unicas:
        print(f"\n��️  ENTIDADES ÚNICAS ({len(entidades_unicas)}):")
        for entidad in sorted(entidades_unicas, key=lambda x: x['nombre'].lower()):
            print(f"   • {entidad['nombre']} - Tipo: {entidad['tipo']}")
            print(f"     �� URL: {entidad['url']}")
            print(f"     �� Fuente: {entidad['source_name']}")

# Configurar rutas de forma profesional usando pathlib
current_dir = Path.cwd()
print(f"�� Directorio actual: {current_dir}")

# Construir la ruta al archivo JSONL de forma relativa
file_path = current_dir.parent.parent / "data" / "scraper_enrichment" / "enriched_data.jsonl"
print(f"📄 Archivo objetivo: {file_path}")

# Verificar si el archivo existe
if not file_path.exists():
    print(f"❌ Error: El archivo {file_path} no existe")
    print("🔍 Buscando archivo en ubicaciones alternativas...")
    
    # Intentar rutas alternativas
    alternative_paths = [
        current_dir.parent.parent.parent / "data" / "scraper_enrichment" / "enriched_data.jsonl",
        current_dir.parent.parent.parent.parent / "scripts" / "data" / "scraper_enrichment" / "enriched_data.jsonl",
        Path("scripts/data/scraper_enrichment/enriched_data.jsonl")
    ]
    
    for alt_path in alternative_paths:
        if alt_path.exists():
            file_path = alt_path
            print(f"✅ Encontrado en: {file_path}")
            break
    else:
        print("❌ No se pudo encontrar el archivo enriched_data.jsonl")
        exit()

# Cargar datos desde el archivo JSONL
print(f"🔄 Cargando datos desde: {file_path}")
entidades_por_tipo = load_entities_from_jsonl(file_path)

# Mostrar estadísticas de entidades por tipo
print(f"\n�� ESTADÍSTICAS POR TIPO:")
for tipo, entidades in entidades_por_tipo.items():
    print(f"   • {tipo}: {len(entidades)} entidades")

# Ejecutar la función
find_similar_entities_with_urls(entidades_por_tipo, threshold=0.75)
# Out:
# �� Directorio actual: d:\TravelApp\Project\scripts\scraper_enrichment\manual_postprocessing
# 📄 Archivo objetivo: d:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data.jsonl
# 🔄 Cargando datos desde: d:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data.jsonl
#
# �� ESTADÍSTICAS POR TIPO:
#    • site: 805 entidades
#    • transport: 41 entidades
#    • itinerary: 69 entidades
#    • desconocido: 387 entidades
#    • tip: 119 entidades
#    • event: 20 entidades
#    • activity: 41 entidades
#    • country: 18 entidades
#    • province: 16 entidades
# === ENTIDADES SIMILARES (similitud >= 0.75) ===
# Total de entidades: 1475
# Grupos de entidades similares: 102
#
# 📍 7-Day Itinerary Option 1: Explore Bangkok and Northern Temples (principal) - Tipo: itinerary
#    📍 URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#    📰 Fuente: mundo-nomada.com
#    └─ 7-Day Itinerary Option 3: From Bangkok to Northern Thailand (similitud: 0.78) - Tipo: itinerary
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#       �� Fuente: mundo-nomada.com
#
# 📍 Airlines to Thailand (principal) - Tipo: transport
#    📍 URL: https://mundo-nomada.com/viajar-a-tailandia/
#    📰 Fuente: mundo-nomada.com
#    └─ Family Trips to Thailand (similitud: 0.77) - Tipo: itinerary
#       �� URL: https://directiatravel.com/viajes-tailandia/guia
#       �� Fuente: directiatravel.com
#
# 📍 Alojamiento en Ayuthaya (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Alojamiento en Sukhothai (similitud: 0.81) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Alojamiento en Bangkok (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Alojamiento en Chiang Rai (similitud: 0.77) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Alojamiento en Chiang Mai (similitud: 0.77) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Alojamiento en Krabi (similitud: 0.76) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Alojamiento en Koh Lipe (similitud: 0.76) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Andalucía (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Andalusia (similitud: 0.78) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Andaman Islands (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Canary Islands (similitud: 0.76) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Ao Phra Nang (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Hat Phra Nang (similitud: 0.88) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#
# 📍 Aragón (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Aragon (similitud: 0.83) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Austria (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Asturias (similitud: 0.80) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Austrian Airlines (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Alaska Airlines (similitud: 0.75) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Ay Thai (principal) - Tipo: site
#    📍 URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#    📰 Fuente: www.expansion.com
#    └─ Pad Thai (similitud: 0.80) - Tipo: site
#       �� URL: https://directiatravel.com/viajes-tailandia/guia
#       �� Fuente: directiatravel.com
#    └─ Muay Thai (similitud: 0.88) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Ayutthaya (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Pattaya (similitud: 0.75) - Tipo: site
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#    └─ Ayyuthaya (similitud: 0.89) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#    └─ Ayutthaya Ruins (similitud: 0.75) - Tipo: site
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Best of Thailand in 10 Days (principal) - Tipo: itinerary
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Tour of Thailand in 11 days (similitud: 0.85) - Tipo: itinerary
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Best Tours in Thailand (principal) - Tipo: site
#    📍 URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#    📰 Fuente: tuguiaentailandia.com
#    └─ Tours in Thailand (similitud: 0.87) - Tipo: site
#       �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#       �� Fuente: tuguiaentailandia.com
#    └─ Free Tours in Thailand (similitud: 0.86) - Tipo: site
#       �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#       �� Fuente: tuguiaentailandia.com
#    └─ Resorts in Thailand (similitud: 0.78) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#    └─ Tours en Tailandia (similitud: 0.75) - Tipo: desconocido
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-5-dias/
#       �� Fuente: mundo-nomada.com
#
# 📍 Blue Temple (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Black Temple (similitud: 0.78) - Tipo: site
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#
# 📍 British Airways (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Etihad Airways (similitud: 0.76) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 bus (principal) - Tipo: transport
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Bus (similitud: 1.00) - Tipo: transport
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Camboya (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Cambodia (similitud: 0.80) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#
# 📍 Castaway Resort Koh Lipe (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Castaway Resort (similitud: 0.77) - Tipo: desconocido
#       �� URL: https://lamaletadecarla.com/guia-completa-para-viajar-a-tailandia/
#       �� Fuente: lamaletadecarla.com
#
# 📍 Castilla La Mancha (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Castilla-La Mancha (similitud: 0.94) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Chatuchak Market (principal) - Tipo: site
#    📍 URL: https://stories.weroad.es/que-ver-en-tailandia-8-lugares/
#    📰 Fuente: stories.weroad.es
#    └─ Chatuchak Weekend Market (similitud: 0.80) - Tipo: site
#       �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#       �� Fuente: translate.google.com
#
# 📍 Chiang Mai (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Chiang Rai (similitud: 0.90) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Chiang Khan (similitud: 0.76) - Tipo: site
#       �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#       �� Fuente: www.expansion.com
#    └─ Wat Chiang Man (similitud: 0.75) - Tipo: site
#       �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#       �� Fuente: www.expansion.com
#
# 📍 Chiang Mai 3-Day Itinerary (principal) - Tipo: itinerary
#    📍 URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#    📰 Fuente: www.voyagetips.com
#    └─ Thailand 30-Day Itinerary (similitud: 0.78) - Tipo: itinerary
#       �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#       �� Fuente: sinohasviajado.com
#
# 📍 Chiang Rai Airport (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Hat Yai Airport (similitud: 0.79) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Chumphon National Park (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Doi Khun National Park (similitud: 0.77) - Tipo: site
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#
# 📍 Colosseum (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Colosseum Rome (similitud: 0.78) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/guia-de-tailandia/
#       �� Fuente: comiviajeros.com
#
# 📍 Damnoen Saduak Floating Market (principal) - Tipo: site
#    📍 URL: https://heymondo.es/blog/que-ver-tailandia/
#    📰 Fuente: heymondo.es
#    └─ Amphawa Floating Market (similitud: 0.75) - Tipo: site
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#    └─ Klong Damnoen Saduak Floating Market (similitud: 0.91) - Tipo: desconocido
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#
# 📍 Desert Excursion (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Marrakech Desert Excursion (similitud: 0.76) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/guia-de-tailandia/
#       �� Fuente: comiviajeros.com
#
# 📍 Doi Inthanon National Park (principal) - Tipo: site
#    📍 URL: https://heymondo.es/blog/que-ver-tailandia/
#    📰 Fuente: heymondo.es
#    └─ Mu Ko Ang Thong National Park (similitud: 0.76) - Tipo: desconocido
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 Don Muang Airport (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Khon Kaen Airport (similitud: 0.76) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#    └─ Udon Thani Airport (similitud: 0.80) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Elephant Sanctuary (principal) - Tipo: site
#    📍 URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#    📰 Fuente: mundo-nomada.com
#    └─ Kanta Elephant Sanctuary (similitud: 0.86) - Tipo: site
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#    └─ Elephant Jungle Sanctuary (similitud: 0.84) - Tipo: site
#       �� URL: https://diaryoftrips.com/guia-de-tailandia/
#       �� Fuente: diaryoftrips.com
#    └─ Elephant Sanctuary Excursion (similitud: 0.78) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Flight from Bangkok to Chiang Mai (principal) - Tipo: transport
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Train from Bangkok to Chiang Mai (similitud: 0.86) - Tipo: transport
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#    └─ Bus from Bangkok to Chiang Mai (similitud: 0.86) - Tipo: transport
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#    └─ Flight to Chiang Mai (similitud: 0.75) - Tipo: transport
#       �� URL: https://diaryoftrips.com/guia-de-tailandia/
#       �� Fuente: diaryoftrips.com
#    └─ 5-day circuit from Bangkok to Chiang Mai (similitud: 0.79) - Tipo: itinerary
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Free Tours in Madrid (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Free Tours in Marrakech (similitud: 0.79) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#    └─ Free Tours in Venice (similitud: 0.75) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#    └─ Free Tours in Vienna (similitud: 0.75) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#    └─ Free Tours in Rome (similitud: 0.79) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#    └─ Free Tours in Milan (similitud: 0.82) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Free Tours in Salamanca (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Free Tours in Istanbul (similitud: 0.76) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Gran Palacio (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Gran Palacio Real (similitud: 0.83) - Tipo: desconocido
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#
# 📍 Grand Palace of Bangkok (principal) - Tipo: site
#    📍 URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#    📰 Fuente: www.voyagetips.com
#    └─ Grand Palais de Bangkok (similitud: 0.83) - Tipo: site
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#    └─ Grand Palace in Bangkok (similitud: 0.91) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#    └─ Grand Palace de Bangkok (similitud: 0.91) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#    └─ El Gran Palacio de Bangkok (similitud: 0.78) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Harry Potter Studios (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Harry Potter Studios London (similitud: 0.85) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/guia-de-tailandia/
#       �� Fuente: comiviajeros.com
#
# 📍 Hotels in Thailand (principal) - Tipo: site
#    📍 URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#    📰 Fuente: tuguiaentailandia.com
#    └─ Transfers in Thailand (similitud: 0.77) - Tipo: site
#       �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#       �� Fuente: tuguiaentailandia.com
#    └─ Markets in Thailand (similitud: 0.76) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#    └─ HONEYMOON IN THAILAND (similitud: 0.77) - Tipo: event
#       �� URL: https://tuguiaentailandia.com/
#       �� Fuente: tuguiaentailandia.com
#
# 📍 Ireland (principal) - Tipo: site
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Iceland (similitud: 0.86) - Tipo: country
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Is it safe to travel to Thailand? (principal) - Tipo: event
#    📍 URL: https://heymondo.es/blog/que-ver-tailandia/
#    📰 Fuente: heymondo.es
#    └─ Best time to travel to Thailand (similitud: 0.81) - Tipo: event
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#    └─ Solo travel to Thailand (similitud: 0.75) - Tipo: event
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#
# 📍 Islas Phi Phi (principal) - Tipo: site
#    📍 URL: https://mundoxdescubrir.com/que-ver-y-visitar-en-tailandia-top-20-lugares-imprescindibles-turismo/
#    📰 Fuente: mundoxdescubrir.com
#    └─ Las islas Phi Phi (similitud: 0.87) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Islas Similan (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Isla Similan (similitud: 0.96) - Tipo: desconocido
#       �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#       �� Fuente: www.conmochila.com
#
# 📍 Japón (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Japan (similitud: 0.80) - Tipo: site
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Kanchanaburi (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Kanchannaburi (similitud: 0.96) - Tipo: desconocido
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#
# 📍 Khao Sok National Park (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Khao Yai National Park (similitud: 0.86) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#    └─ Khao Sam Roi Yot National Park (similitud: 0.81) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#
# 📍 Ko Nang Yuan (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Mirador Ko Nang Yuan (similitud: 0.75) - Tipo: site
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 Koh Kood (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Koh Poda (similitud: 0.75) - Tipo: site
#       �� URL: https://lostraveleros.com/que-ver-en-tailandia/
#       �� Fuente: lostraveleros.com
#
# 📍 Koh Lanta Yai (principal) - Tipo: site
#    📍 URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#    📰 Fuente: www.nadaincluido.com
#    └─ Ko Lanta (similitud: 0.76) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Koh Muk (principal) - Tipo: site
#    📍 URL: https://heymondo.es/blog/que-ver-tailandia/
#    📰 Fuente: heymondo.es
#    └─ Koh Samui (similitud: 0.75) - Tipo: site
#       �� URL: https://heymondo.es/blog/que-ver-tailandia/
#       �� Fuente: heymondo.es
#    └─ Koh Munnork (similitud: 0.78) - Tipo: desconocido
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#    └─ Koh Maak (similitud: 0.80) - Tipo: desconocido
#       �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#       �� Fuente: www.conmochila.com
#
# 📍 Koh Phangan (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Koh Chang (similitud: 0.80) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Koh Pha Ngan (similitud: 0.96) - Tipo: site
#       �� URL: https://mundoxdescubrir.com/que-ver-y-visitar-en-tailandia-top-20-lugares-imprescindibles-turismo/
#       �� Fuente: mundoxdescubrir.com
#    └─ Ko Pha Ngan (similitud: 0.91) - Tipo: site
#       �� URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#       �� Fuente: www.voyagetips.com
#    └─ Koh Phayam (similitud: 0.76) - Tipo: desconocido
#       �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#       �� Fuente: www.conmochila.com
#
# 📍 Koh Phi Phi (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Koh Phi Phi Don (similitud: 0.85) - Tipo: site
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#    └─ Phi Phi (similitud: 0.78) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#
# 📍 Koh Samui Airport (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Sukhothai Airport (similitud: 0.76) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Koh Tao (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Koh Lanta (similitud: 0.75) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Ko Tao (similitud: 0.92) - Tipo: site
#       �� URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#       �� Fuente: www.voyagetips.com
#
# 📍 Koh Yao Noi (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Koh Yao Yai (similitud: 0.82) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Ko Yao Noi (similitud: 0.95) - Tipo: site
#       �� URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#       �� Fuente: www.voyagetips.com
#
# 📍 Luxemburgo (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Luxembourg (similitud: 0.90) - Tipo: country
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Mae Hong Son (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Mae Hong Son Loop (similitud: 0.83) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#    └─ Mae Hong Song (similitud: 0.96) - Tipo: site
#       �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#       �� Fuente: www.conmochila.com
#    └─ Mae Hong Son Airport (similitud: 0.75) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Mae Klong Railway Market (principal) - Tipo: site
#    📍 URL: https://heymondo.es/blog/que-ver-tailandia/
#    📰 Fuente: heymondo.es
#    └─ Maeklong Market (similitud: 0.77) - Tipo: site
#       �� URL: https://comiviajeros.com/guia-de-tailandia/
#       �� Fuente: comiviajeros.com
#
# 📍 Malasia (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Malaysia (similitud: 0.93) - Tipo: site
#       �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#       �� Fuente: mundo-nomada.com
#
# 📍 Mercado flotante de Damnoen Saduak (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ El mercado flotante de Damnoen Saduak (similitud: 0.96) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Mercado sobre las vías del tren (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ El mercado sobre las vías de Mae Klong (similitud: 0.78) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 minivan (principal) - Tipo: transport
#    📍 URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ mini van (similitud: 0.93) - Tipo: transport
#       �� URL: https://diaryoftrips.com/guia-de-tailandia/
#       �� Fuente: diaryoftrips.com
#
# 📍 Muay Thai combat (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Muay Thai Class (similitud: 0.77) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Nakhon Si Thammarat (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Nakhon Si Thammarat Airport (similitud: 0.83) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Navarra (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Navarre (similitud: 0.86) - Tipo: province
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Pai (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Spain (similitud: 0.75) - Tipo: country
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#
# 📍 Parque arqueológico de Ayutthaya (principal) - Tipo: site
#    📍 URL: https://stories.weroad.es/que-ver-en-tailandia-8-lugares/
#    📰 Fuente: stories.weroad.es
#    └─ Parque histórico de Ayutthaya (similitud: 0.79) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Parque Nacional Khao Yai (principal) - Tipo: site
#    📍 URL: https://mundoxdescubrir.com/que-ver-y-visitar-en-tailandia-top-20-lugares-imprescindibles-turismo/
#    📰 Fuente: mundoxdescubrir.com
#    └─ Parque Nacional Khao Sok (similitud: 0.88) - Tipo: site
#       �� URL: https://mundoxdescubrir.com/que-ver-y-visitar-en-tailandia-top-20-lugares-imprescindibles-turismo/
#       �� Fuente: mundoxdescubrir.com
#    └─ Parque Nacional Erawan (similitud: 0.78) - Tipo: site
#       �� URL: https://lostraveleros.com/que-ver-en-tailandia/
#       �� Fuente: lostraveleros.com
#    └─ Parque Nacional de Khao Sok (similitud: 0.82) - Tipo: site
#       �� URL: https://lostraveleros.com/que-ver-en-tailandia/
#       �� Fuente: lostraveleros.com
#    └─ Parque Nacional de Khao Yai (similitud: 0.94) - Tipo: site
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#    └─ El Parque Nacional de Khao Sok (similitud: 0.78) - Tipo: activity
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Patong Beach (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Panwa Beach (similitud: 0.78) - Tipo: site
#       �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#       �� Fuente: lacosmopolilla.com
#    └─ Karon Beach (similitud: 0.78) - Tipo: desconocido
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 Phang Nga Bay (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Wang Long Bay (similitud: 0.77) - Tipo: site
#       �� URL: https://diaryoftrips.com/guia-de-tailandia/
#       �� Fuente: diaryoftrips.com
#
# 📍 Phi Phi Islands (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Phi Phi Island (similitud: 0.97) - Tipo: site
#       �� URL: https://stories.weroad.es/que-ver-en-tailandia-8-lugares/
#       �� Fuente: stories.weroad.es
#
# 📍 Phuket International Airport (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Chiang Mai International Airport (similitud: 0.77) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#    └─ Krabi International Airport (similitud: 0.84) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Portimao (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Porto (similitud: 0.77) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Portugal (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ TAP Portugal (similitud: 0.80) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Ratchaburi (principal) - Tipo: site
#    📍 URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#    📰 Fuente: www.expansion.com
#    └─ Phetchaburi (similitud: 0.76) - Tipo: site
#       �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#       �� Fuente: www.civitatis.com
#
# 📍 Singapur (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Singapore (similitud: 0.82) - Tipo: site
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 snorkeling (principal) - Tipo: desconocido
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Snorkeling (similitud: 1.00) - Tipo: activity
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 songthaew (principal) - Tipo: transport
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Songthaews (similitud: 0.95) - Tipo: desconocido
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 Sukhothai (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Sukhotai (similitud: 0.94) - Tipo: site
#       �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#       �� Fuente: www.nadaincluido.com
#
# 📍 Sukhothai Historical Park (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Ayutthaya Historical Park (similitud: 0.80) - Tipo: site
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#       �� Fuente: mundo-nomada.com
#
# 📍 Suvarnabhumi Airport (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Bangkok Suvarnabhumi Airport (similitud: 0.83) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Tailandia (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Thailand (similitud: 0.82) - Tipo: site
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Irlanda (similitud: 0.75) - Tipo: site
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#    └─ Islandia (similitud: 0.82) - Tipo: site
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#    └─ Guía Tailandia (similitud: 0.78) - Tipo: site
#       �� URL: https://www.molaviajar.com/tienda/libros/118-guia-tailandia.html
#       �� Fuente: www.molaviajar.com
#
# 📍 Tailandia en 21 días (principal) - Tipo: itinerary
#    📍 URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Viaje a Tailandia de 15 días (similitud: 0.75) - Tipo: desconocido
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#       �� Fuente: mundo-nomada.com
#
# 📍 The Night Bazaar (principal) - Tipo: site
#    📍 URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#    📰 Fuente: www.mundoasiatours.com
#    └─ Night Bazaar (similitud: 0.86) - Tipo: site
#       �� URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#       �� Fuente: www.voyagetips.com
#
# 📍 Transport to Koh Phangan (principal) - Tipo: transport
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Transport to Koh Kood (similitud: 0.76) - Tipo: transport
#       �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Transportation in Thailand (principal) - Tipo: transport
#    📍 URL: https://mundo-nomada.com/viajar-a-tailandia/
#    📰 Fuente: mundo-nomada.com
#    └─ Transporte en Tailandia (similitud: 0.78) - Tipo: transport
#       �� URL: https://comiviajeros.com/guia-de-tailandia/
#       �� Fuente: comiviajeros.com
#
# 📍 Trat Airport (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Trang Airport (similitud: 0.88) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Travel Itinerary (principal) - Tipo: itinerary
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Thailand Itinerary (similitud: 0.76) - Tipo: itinerary
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Trip Itinerary (similitud: 0.80) - Tipo: itinerary
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#    └─ Thailand Travel Itinerary (similitud: 0.78) - Tipo: itinerary
#       �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#       �� Fuente: www.conmochila.com
#
# 📍 Travel Itinerary in Thailand (principal) - Tipo: itinerary
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ 5-Day Itinerary in Thailand (similitud: 0.84) - Tipo: itinerary
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-5-dias/
#       �� Fuente: mundo-nomada.com
#    └─ 7-Day Itinerary in Thailand (similitud: 0.84) - Tipo: itinerary
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#       �� Fuente: mundo-nomada.com
#    └─ 15-Day Itinerary in Thailand (similitud: 0.82) - Tipo: itinerary
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#
# 📍 Triángulo de Oro (principal) - Tipo: site
#    📍 URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#    📰 Fuente: www.expansion.com
#    └─ Triángulo Dorado (similitud: 0.88) - Tipo: site
#       �� URL: https://lostraveleros.com/que-ver-en-tailandia/
#       �� Fuente: lostraveleros.com
#    └─ Triángulo del Oro (similitud: 0.97) - Tipo: site
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#
# 📍 Tu Guia en Tailandia (principal) - Tipo: site
#    📍 URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#    📰 Fuente: tuguiaentailandia.com
#    └─ Guía de Tailandia (similitud: 0.81) - Tipo: itinerary
#       �� URL: https://clarabmartin.com/producto/guia-de-tailandia/
#       �� Fuente: clarabmartin.com
#
# 📍 tuk tuk (principal) - Tipo: transport
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ tuk-tuk (similitud: 0.86) - Tipo: transport
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 Types of Trips to Thailand (principal) - Tipo: itinerary
#    📍 URL: https://directiatravel.com/viajes-tailandia/guia
#    📰 Fuente: directiatravel.com
#    └─ Group Trips to Thailand (similitud: 0.78) - Tipo: itinerary
#       �� URL: https://directiatravel.com/viajes-tailandia/guia
#       �� Fuente: directiatravel.com
#    └─ Luxury Trips to Thailand (similitud: 0.76) - Tipo: itinerary
#       �� URL: https://directiatravel.com/viajes-tailandia/guia
#       �� Fuente: directiatravel.com
#    └─ Trip to Thailand (similitud: 0.76) - Tipo: itinerary
#       �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#       �� Fuente: www.viajeroscallejeros.com
#
# 📍 Ubon Ratchathani Airport (principal) - Tipo: site
#    📍 URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#    📰 Fuente: www.kayak.com.ar
#    └─ Surat Thani Airport (similitud: 0.79) - Tipo: site
#       �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#       �� Fuente: www.kayak.com.ar
#
# 📍 USA (principal) - Tipo: site
#    📍 URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#    📰 Fuente: www.viajeroscallejeros.com
#    └─ Rusia (similitud: 0.75) - Tipo: site
#       �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#       �� Fuente: imanesdeviaje.com
#
# 📍 Wapi Resort (principal) - Tipo: site
#    📍 URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#    📰 Fuente: www.nadaincluido.com
#    └─ JP Resort (similitud: 0.80) - Tipo: desconocido
#       �� URL: https://lamaletadecarla.com/guia-completa-para-viajar-a-tailandia/
#       �� Fuente: lamaletadecarla.com
#
# 📍 Wat Chedi Luang Temple (principal) - Tipo: site
#    📍 URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#    📰 Fuente: directiatravel.com
#    └─ Wat Chedi Luang (similitud: 0.81) - Tipo: site
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Wat Pha Lat (principal) - Tipo: site
#    📍 URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#    📰 Fuente: imanesdeviaje.com
#    └─ Wat Plai Laem (similitud: 0.75) - Tipo: desconocido
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#
# 📍 Wat Pho de Bangkok (principal) - Tipo: desconocido
#    📍 URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#    📰 Fuente: comiviajeros.com
#    └─ Wat Arun de Bangkok (similitud: 0.81) - Tipo: desconocido
#       �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#       �� Fuente: comiviajeros.com
#
# 📍 Wat Phra Singh (principal) - Tipo: site
#    📍 URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#    📰 Fuente: www.expansion.com
#    └─ Wat Phra Singh Temple (similitud: 0.80) - Tipo: site
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#    └─ Wat Phra Yai (similitud: 0.77) - Tipo: desconocido
#       �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#       �� Fuente: www.mundoasiatours.com
#    └─ Wat Phra Si Sanphet (similitud: 0.79) - Tipo: desconocido
#       �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#       �� Fuente: directiatravel.com
#
# 📍 Wat Rong Khun (principal) - Tipo: site
#    📍 URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#    📰 Fuente: lacosmopolilla.com
#    └─ Wat Rong Khung (similitud: 0.96) - Tipo: site
#       �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#       �� Fuente: tuguiaentailandia.com
#
# 📍 What to See in Thailand in 5 Days (principal) - Tipo: itinerary
#    📍 URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-5-dias/
#    📰 Fuente: mundo-nomada.com
#    └─ What to see in Thailand in 7 days (similitud: 0.97) - Tipo: itinerary
#       �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#       �� Fuente: mundo-nomada.com
#    └─ What to See and Do in Thailand in 30 Days (similitud: 0.86) - Tipo: itinerary
#       �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#       �� Fuente: sinohasviajado.com
#
# 📍 White Temple (principal) - Tipo: site
#    📍 URL: https://lostraveleros.com/que-ver-en-tailandia/
#    📰 Fuente: lostraveleros.com
#    └─ Tiger Temple (similitud: 0.75) - Tipo: site
#       �� URL: https://diaryoftrips.com/guia-de-tailandia/
#       �� Fuente: diaryoftrips.com
#
# ��️  ENTIDADES ÚNICAS (834):
#    • 10 Days in Thailand & Vietnam: 4 Itinerary Ideas - Tipo: itinerary
#      �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#      �� Fuente: translate.google.com
#    • 10 Days in Thailand: 3 Itineraries to Blow Your Mind - Tipo: itinerary
#      �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#      �� Fuente: translate.google.com
#    • 10 lugares que ver en Tailandia en 15 días - Tipo: itinerary
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com
#    • 10 must-see places in Thailand - Tipo: event
#      �� URL: https://heymondo.es/blog/que-ver-tailandia/
#      �� Fuente: heymondo.es
#    • 11-Day Guided Tour in Thailand - Tipo: itinerary
#      �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • 111/11 Moo5 - Tipo: site
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • 12-Day Family Trip in Thailand - Tipo: itinerary
#      �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • 16 Días / 15 Noches Bangkok – Chiang Rai – Chiang Mai – Krabi – Koh Phi Phi – Phuket - Tipo: itinerary
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • 17 Días / 16 Noches Viaje de 17 días a Tailandia Vietnam Camboya y Phuket - Tipo: itinerary
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • 18 Original and Must-See Temples - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • 2 Weeks in Thailand - Honeymoon Itinerary for Lovers - Tipo: itinerary
#      �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#      �� Fuente: translate.google.com
#    • 2 Weeks in Thailand: Ultimate Itinerary for First-Timer - Tipo: itinerary
#      �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#      �� Fuente: translate.google.com
#    • 20 Questions and Answers for the Trip to Thailand - Tipo: site
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • 25 Best Beaches in Thailand - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • 30-day Thailand itinerary - Tipo: itinerary
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • 4-Day Itinerary for Koh Samui - Tipo: desconocido
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • 5-Day Thailand Trip - Tipo: itinerary
#      �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-5-dias/
#      �� Fuente: mundo-nomada.com
#    • 5.234 viajeros felices en Tailandia - Tipo: desconocido
#      �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-5-dias/
#      �� Fuente: mundo-nomada.com
#    • 7-Day Itinerary Option 2: From Bangkok to the Beach - Tipo: itinerary
#      �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#      �� Fuente: mundo-nomada.com
#    • Activities in Bangkok - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Advertising cookies are used to display more relevant ads to users by tracking visitor behavior and collecting information to provide appropriate ads. - Tipo: tip
#      �� URL: https://comiviajeros.com/guia-de-tailandia/
#      �� Fuente: comiviajeros.com
#    • Aeropuerto Internacional - Tipo: site
#      �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      �� Fuente: www.expansion.com
#    • Aeropuertos en Tailandia - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Air Canada - Tipo: site
#      �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#      �� Fuente: www.kayak.com.ar
#    • Air France - Tipo: site
#      �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#      �� Fuente: www.kayak.com.ar
#    • Akira Lipe Resort - Tipo: site
#      �� URL: https://www.nadaincluido.com/que-ver-en-tailandia/
#      �� Fuente: www.nadaincluido.com
#    • Alemania - Tipo: site
# ...
#      �� URL: https://diaryoftrips.com/guia-de-tailandia/
#      �� Fuente: diaryoftrips.com
#    • Train Market - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Train to Chiang Mai - Tipo: transport
#      �� URL: https://diaryoftrips.com/guia-de-tailandia/
#      �� Fuente: diaryoftrips.com
#    • transport - Tipo: desconocido
#      �� URL: https://lamaletadecarla.com/guia-completa-para-viajar-a-tailandia/
#      �� Fuente: lamaletadecarla.com
#    • Travel to Thailand in any season depending on your preferences and the region you want to explore. - Tipo: tip
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Traveling during the low season (Mar-May) can offer better prices, while summer (monsoon season) may also have good deals. - Tipo: tip
#      �� URL: https://directiatravel.com/viajes-tailandia/guia
#      �� Fuente: directiatravel.com
#    • Traveling solo in Thailand is easy, especially for backpackers, but allow extra time for transportation and accommodation arrangements. - Tipo: tip
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Tropical Exoticism in Koh Phi Phi - Tipo: site
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • Turkey - Tipo: site
#      �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • Turkish Airlines - Tipo: site
#      �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#      �� Fuente: www.kayak.com.ar
#    • Turquía - Tipo: site
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com
#    • Un combate de muay thai - Tipo: activity
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • Una clase de cocina tailandesa - Tipo: activity
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • Unfortunately, we do not have information on obtaining a Thai visa for Colombian nationals living in Mexico. We recommend checking official sources for visa application details. - Tipo: tip
#      �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • United Airlines - Tipo: site
#      �� URL: https://www.kayak.com.ar/Tailandia.238.dc.guide
#      �� Fuente: www.kayak.com.ar
#    • United Kingdom - Tipo: country
#      �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#      �� Fuente: lacosmopolilla.com
#    • United States - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Up to You Bar - Tipo: site
#      �� URL: https://diaryoftrips.com/guia-de-tailandia/
#      �� Fuente: diaryoftrips.com
#    • Vaccinations for traveling to Thailand: no mandatory vaccines for residents of Spain, yellow fever vaccine required if coming from a high-risk country, recommended vaccines include hepatitis A and B, tetanus, and typhoid - Tipo: tip
#      �� URL: https://directiatravel.com/viajes-tailandia/guia
#      �� Fuente: directiatravel.com
#    • Vaccines and Health: Consult a healthcare professional for recommended vaccines and health advice before traveling to Thailand. If you have any doubts, you can consult the Thai embassy in the country where you reside. - Tipo: tip
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • Valencian Community - Tipo: province
#      �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#      �� Fuente: lacosmopolilla.com
#    • Vatican Museums - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Vatican Museums - Tipo: desconocido
#      �� URL: https://comiviajeros.com/guia-de-tailandia/
#      �� Fuente: comiviajeros.com
#    • Venecia - Tipo: site
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • Venice - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Viaje a TAILANDIA: El Itinerario Perfecto para tu Primera Vez en el País - Tipo: itinerary
#      �� URL: https://www.youtube.com/watch?v=3_BzVrCAbTw
#      �� Fuente: www.youtube.com
#    • Vietnam - Tipo: site
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • Vietnam - Tipo: site
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com
#    • Vietnam - Tipo: site
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Vietnam - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Vietnam - Tipo: site
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Vietnam - Tipo: desconocido
#      �� URL: https://mundo-nomada.com/tailandia/que-ver-en-tailandia-en-7-dias/
#      �� Fuente: mundo-nomada.com
#    • Vietnam - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • View Point de Phi Phi - Tipo: site
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Viking Nature Resort - Tipo: site
#      �� URL: https://lacosmopolilla.com/que-ver-en-tailandia/
#      �� Fuente: lacosmopolilla.com
#    • Vila Real - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • vintage-style hotel - Tipo: desconocido
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • Viseu - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Visit popular beach destinations like Phuket, Koh Phi Phi, or Krabi during the rainy season for fewer tourists and cheaper hotel prices. - Tipo: tip
#      �� URL: https://mundo-nomada.com/viajar-a-tailandia/
#      �� Fuente: mundo-nomada.com
#    • Visita parques nacionales - Tipo: activity
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • Visiting elephant sanctuaries in Thailand is a complex issue due to concerns about animal welfare. It is advised to research thoroughly and choose responsibly to support sanctuaries that prioritize the well-being of elephants. - Tipo: tip
#      �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • walking in the forest - Tipo: desconocido
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • Warm Welcome to Krabi Tour - Tipo: site
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • Wat Arun - Tipo: desconocido
#      �� URL: https://heymondo.es/blog/que-ver-tailandia/
#      �� Fuente: heymondo.es
#    • Wat Arun - Tipo: desconocido
#      �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      �� Fuente: www.expansion.com
#    • Wat Benchamabophit - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Chaiwatthanaram - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Chalong - Tipo: site
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • Wat Chalong - Tipo: desconocido
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • Wat Chedi Luang Varavihara - Tipo: site
#      �� URL: https://translate.google.com/translate?u=https://www.odynovotours.com/thailand/&hl=es&sl=en&tl=es&client=srp
#      �� Fuente: translate.google.com
#    • Wat Lokayasutharam - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Mahathat - Tipo: site
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • Wat Mahathat - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Pa Phu Kon - Tipo: site
#      �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      �� Fuente: www.expansion.com
#    • Wat Pho - Tipo: desconocido
#      �� URL: https://heymondo.es/blog/que-ver-tailandia/
#      �� Fuente: heymondo.es
#    • Wat Pho - Tipo: desconocido
#      �� URL: https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      �� Fuente: www.expansion.com
#    • Wat Pho - Tipo: desconocido
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Phra Kaew Temple - Tipo: site
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Wat Phra Mahathat Woramahawihan - Tipo: site
#      �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • Wat Phra That Doi Suthep - Tipo: site
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com
#    • Wat Phra That Doi Suthep - Tipo: site
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • Wat Phra That Doi Suthep - Tipo: site
#      �� URL: https://diaryoftrips.com/guia-de-tailandia/
#      �� Fuente: diaryoftrips.com
#    • Wat Phra That Doi Suthep - Tipo: desconocido
#      �� URL: https://heymondo.es/blog/que-ver-tailandia/
#      �� Fuente: heymondo.es
#    • Wat Rong Suea Ten - Tipo: site
#      �� URL: https://www.voyagetips.com/es/que-ver-en-tailandia/
#      �� Fuente: www.voyagetips.com
#    • Wat Si Chum - Tipo: site
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • Wat Si Chum - Tipo: site
#      �� URL: https://stories.weroad.es/que-ver-en-tailandia-8-lugares/
#      �� Fuente: stories.weroad.es
#    • Wat Umong - Tipo: site
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com
#    • Wat Umong - Tipo: site
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • West Coast USA - Tipo: desconocido
#      �� URL: https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/
#      �� Fuente: comiviajeros.com
#    • What to pack in your backpack: Coming soon. - Tipo: tip
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • When planning a trip that includes snorkeling, ensure to practice responsible diving to minimize negative impacts on marine ecosystems. Respect and protect the underwater world during your exploration. - Tipo: tip
#      �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#      �� Fuente: www.conmochila.com
#    • When planning your trip to Thailand, consider the monsoon season and its impact on beach destinations. Check the climate month by month to choose the best time to visit different regions of the country. - Tipo: tip
#      �� URL: https://www.conmochila.com/tailandia-guia-de-viaje
#      �� Fuente: www.conmochila.com
#    • When traveling to Thailand, it is advisable to have a travel insurance plan to ensure coverage for any unexpected events or emergencies during your trip. - Tipo: tip
#      �� URL: https://comiviajeros.com/guia-de-tailandia/
#      �� Fuente: comiviajeros.com
#    • When traveling to Thailand, it is recommended to gather essential tips and recommendations to enhance the travel experience. Internet connectivity in Thailand can be ensured by purchasing a SIM card from Holafly, offering data, WhatsApp number retention, and Spanish assistance. Explore the top tourist attractions and must-visit places in Thailand for a fulfilling journey. - Tipo: tip
#      �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • When visiting Koh Tao, don't miss the opportunity to try local delicacies like kaeng khiao waan and Massaman curry, which showcase the rich flavors of Thai cuisine. - Tipo: tip
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • Where to exchange money in Bangkok: In this comprehensive guide, we inform you about where, how, and when to exchange money for the trip to Thailand. Read the article to the end as we also inform you where not to exchange money and what you should not do. - Tipo: tip
#      �� URL: https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      �� Fuente: tuguiaentailandia.com
#    • While travel insurance is not mandatory, having travel insurance that covers medical emergencies, cancellations, theft, or accidents is highly recommended. Medical care in Thailand is of good quality, but costs can be high for uninsured tourists. - Tipo: tip
#      �� URL: https://mundoxdescubrir.com/que-ver-y-visitar-en-tailandia-top-20-lugares-imprescindibles-turismo/
#      �� Fuente: mundoxdescubrir.com
#    • White Rock - Tipo: site
#      �� URL: https://www.mundoasiatours.com/que-ver-en-tailandia/
#      �� Fuente: www.mundoasiatours.com
#    • White Temple (Wat Rong Khun) - Tipo: site
#      �� URL: https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer
#      �� Fuente: directiatravel.com
#    • Women of the Long Neck Karen Tribe - Tipo: site
#      �� URL: https://stories.weroad.es/que-ver-en-tailandia-8-lugares/
#      �� Fuente: stories.weroad.es
#    • Wua Laen Beach - Tipo: site
#      �� URL: https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • Yi Peng Festival - Tipo: event
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • Yi Peng Festival - Tipo: event
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • You can explore cities in Thailand without a motorcycle by using taxis or Grab to reach remote places. - Tipo: tip
#      �� URL: https://www.viajeroscallejeros.com/guia-viaje-tailandia/
#      �� Fuente: www.viajeroscallejeros.com
#    • Zaanse Schans - Tipo: site
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • Zanzíbar - Tipo: site
#      �� URL: https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias
#      �� Fuente: sinohasviajado.com
#    • Ziplining in Chiang Mai - Tipo: activity
#      �� URL: https://www.civitatis.com/blog/que-ver-tailandia/?srsltid=AfmBOopVm5DewW5Bgaa2HdG84MpmF_5_HW3bGEV8e-gpdZWt3bwJrPhs
#      �� Fuente: www.civitatis.com
#    • África - Tipo: site
#      �� URL: https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/
#      �� Fuente: imanesdeviaje.com

# %% [markdown]
# ## We check the normalized_entites integrity

# %%
import json
import ast
from pathlib import Path
from collections import defaultdict

def verificar_normalized_entities():
    """Verifica la estructura y contenido del archivo normalized_entities.py"""
    
    # Configurar rutas
    current_dir = Path.cwd()
    file_path = current_dir.parent.parent / "scraper_enrichment" / "auxs" / "normalized_entities.py"
    
    print("🔍 VERIFICACIÓN DE NORMALIZED_ENTITIES.PY")
    print("=" * 60)
    print(f"📄 Archivo: {file_path}")
    print(f" Directorio actual: {current_dir}")
    print()
    
    # Verificar si el archivo existe
    if not file_path.exists():
        print("❌ ERROR: El archivo normalized_entities.py no existe")
        return False
    
    print("✅ El archivo existe")
    print()
    
    # Leer el contenido del archivo
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        print("✅ Archivo leído correctamente")
    except Exception as e:
        print(f"❌ ERROR al leer el archivo: {e}")
        return False
    
    # Verificar si es un diccionario Python válido
    print("\n🔧 VERIFICACIÓN 1: ESTRUCTURA JSON/DICCIÓNARIO")
    print("-" * 50)
    
    try:
        # Buscar el diccionario en el archivo
        if 'NORMALIZED_ENTITIES = {' in content:
            # Extraer el diccionario
            start = content.find('NORMALIZED_ENTITIES = {')
            # Encontrar el final del diccionario (buscar el } que cierra el diccionario)
            brace_count = 0
            end = start
            
            for i, char in enumerate(content[start:], start):
                if char == '{':
                    brace_count += 1
                elif char == '}':
                    brace_count -= 1
                    if brace_count == 0:
                        end = i + 1
                        break
            
            dict_content = content[start:end]
            
            # Limpiar el contenido para evaluarlo
            dict_content = dict_content.replace('NORMALIZED_ENTITIES = ', '')
            
            # Evaluar el diccionario
            normalized_entities = ast.literal_eval(dict_content)
            print("✅ Estructura de diccionario válida")
            print(f" Total de entradas: {len(normalized_entities)}")
            
        else:
            print("❌ ERROR: No se encontró 'NORMALIZED_ENTITIES = {' en el archivo")
            return False
            
    except Exception as e:
        print(f"❌ ERROR: El archivo no tiene una estructura de diccionario válida: {e}")
        print(f"   Línea problemática aproximada: {dict_content[:200]}...")
        return False
    
    # Verificar que todas las claves están en los valores
    print("\n🔍 VERIFICACIÓN 2: CLAVES EN VALORES")
    print("-" * 50)
    
    claves_no_en_valores = []
    claves_en_valores = []
    
    for clave, valores in normalized_entities.items():
        if isinstance(valores, list):
            if clave in valores:
                claves_en_valores.append(clave)
            else:
                claves_no_en_valores.append(clave)
        else:
            print(f"⚠️  ADVERTENCIA: '{clave}' no tiene una lista de valores")
    
    if claves_en_valores:
        print(f"✅ {len(claves_en_valores)} claves SÍ están en sus valores:")
        for clave in claves_en_valores:
            print(f"   • {clave}")
    
    if claves_no_en_valores:
        print(f"❌ {len(claves_no_en_valores)} claves NO están en sus valores:")
        for clave in claves_no_en_valores:
            print(f"   • {clave}")
    
    # Verificar valores duplicados entre diferentes claves
    print("\n🔄 VERIFICACIÓN 3: VALORES DUPLICADOS ENTRE CLAVES")
    print("-" * 50)
    
    todos_valores = []
    valores_por_clave = {}
    
    for clave, valores in normalized_entities.items():
        if isinstance(valores, list):
            valores_por_clave[clave] = valores
            todos_valores.extend(valores)
    
    # Encontrar valores que aparecen en múltiples claves
    valores_duplicados = defaultdict(list)
    for valor in set(todos_valores):
        claves_que_contienen = [clave for clave, valores in valores_por_clave.items() if valor in valores]
        if len(claves_que_contienen) > 1:
            valores_duplicados[valor] = claves_que_contienen
    
    if valores_duplicados:
        print(f"⚠️  ADVERTENCIA: {len(valores_duplicadas)} valores aparecen en múltiples claves:")
        for valor, claves in valores_duplicados.items():
            print(f"   • '{valor}' aparece en: {', '.join(claves)}")
    else:
        print("✅ No hay valores duplicados entre diferentes claves")
    
    # Verificar claves duplicadas
    print("\n🔑 VERIFICACIÓN 4: CLAVES DUPLICADAS")
    print("-" * 50)
    
    claves_lista = list(normalized_entities.keys())
    claves_duplicadas = [clave for clave in set(claves_lista) if claves_lista.count(clave) > 1]
    
    if claves_duplicadas:
        print(f"❌ ERROR: {len(claves_duplicadas)} claves están duplicadas:")
        for clave in claves_duplicadas:
            print(f"   • {clave}")
    else:
        print("✅ No hay claves duplicadas")
    
    # Resumen final
    print("\n📋 RESUMEN FINAL")
    print("=" * 60)
    
    total_entradas = len(normalized_entities)
    claves_ok = len(claves_en_valores)
    claves_problema = len(claves_no_en_valores)
    valores_duplicados_count = len(valores_duplicados)
    claves_duplicadas_count = len(claves_duplicadas)
    
    print(f" Total de entradas: {total_entradas}")
    print(f"✅ Claves correctas: {claves_ok}")
    print(f"❌ Claves con problemas: {claves_problema}")
    print(f"⚠️  Valores duplicados: {valores_duplicados_count}")
    print(f"❌ Claves duplicadas: {claves_duplicadas_count}")
    
    # Estado general
    if claves_problema == 0 and claves_duplicadas_count == 0:
        print("\n🎉 ¡ESTADO PERFECTO! El archivo está bien estructurado")
        return True
    elif claves_problema == 0:
        print("\n⚠️  ADVERTENCIA: Hay claves duplicadas pero la estructura es correcta")
        return False
    else:
        print("\n❌ PROBLEMAS DETECTADOS: Revisar el archivo")
        return False

# Ejecutar la verificación
resultado = verificar_normalized_entities()
# Out:
# 🔍 VERIFICACIÓN DE NORMALIZED_ENTITIES.PY
# ============================================================
# 📄 Archivo: d:\TravelApp\Project\scripts\scraper_enrichment\auxs\normalized_entities.py
#  Directorio actual: d:\TravelApp\Project\scripts\scraper_enrichment\manual_postprocessing
#
# ✅ El archivo existe
#
# ✅ Archivo leído correctamente
#
# 🔧 VERIFICACIÓN 1: ESTRUCTURA JSON/DICCIÓNARIO
# --------------------------------------------------
# ✅ Estructura de diccionario válida
#  Total de entradas: 34
#
# 🔍 VERIFICACIÓN 2: CLAVES EN VALORES
# --------------------------------------------------
# ✅ 34 claves SÍ están en sus valores:
#    • Bangkok
#    • Chiang Mai
#    • Phuket
#    • Koh Samui
#    • Koh Phi Phi
#    • Similan
#    • Mae Hong Son
#    • Songthaew
#    • Malasia
#    • Ayutthaya
#    • Damnoen Saduak Floating Market
#    • minivan
#    • Night Bazaar
#    • tuk-tuk
#    • Wat Rong Khun
#    • Chatuchak Market
#    • Triángulo de Oro
#    • Grand Palace of Bangkok
#    • Chiang Rai
#    • Krabi
#    • Pattaya
#    • Hua Hin
#    • Koh Phangan
#    • Koh Tao
#    • Phra Nang
#    • Kanchanaburi
#    • Koh Chang
#    • Thailand
#    • Sukhothai
#    • Khao Sok National Park
#    • Buri Ram
#    • Koh Lanta
#    • Khao Yai
#    • Koh Yao Noi
#
# 🔄 VERIFICACIÓN 3: VALORES DUPLICADOS ENTRE CLAVES
# --------------------------------------------------
# ✅ No hay valores duplicados entre diferentes claves
#
# 🔑 VERIFICACIÓN 4: CLAVES DUPLICADAS
# --------------------------------------------------
# ✅ No hay claves duplicadas
#
# 📋 RESUMEN FINAL
# ============================================================
#  Total de entradas: 34
# ✅ Claves correctas: 34
# ❌ Claves con problemas: 0
# ⚠️  Valores duplicados: 0
# ❌ Claves duplicadas: 0
#
# 🎉 ¡ESTADO PERFECTO! El archivo está bien estructurado

# %% [markdown]
# ## We group the entities with same name

# %%
import json
import ast
from pathlib import Path
from collections import defaultdict, Counter

# === 1. Cargar el diccionario de normalización ===
def load_normalized_entities(py_path):
    with open(py_path, 'r', encoding='utf-8') as f:
        content = f.read()
    start = content.find('NORMALIZED_ENTITIES = {')
    if start == -1:
        raise ValueError("No se encontró NORMALIZED_ENTITIES en el archivo.")
    brace_count = 0
    end = start
    for i, char in enumerate(content[start:], start):
        if char == '{':
            brace_count += 1
        elif char == '}':
            brace_count -= 1
            if brace_count == 0:
                end = i + 1
                break
    dict_content = content[start:end].replace('NORMALIZED_ENTITIES = ', '')
    return ast.literal_eval(dict_content)

# === 2. Cargar las entidades enriquecidas ===
def load_enriched_entities(jsonl_path):
    entities = []
    with open(jsonl_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data = json.loads(line)
                url = data.get('url')
                for ent in data.get('entities', []):
                    ent['source_url'] = url
                    entities.append(ent)
    return entities

# === 3. Normalizar el nombre de la entidad ===
def normalize_entity_name(name, normalized_dict):
    if not name:
        return ""
    for norm, variations in normalized_dict.items():
        if name.lower() in [v.lower() for v in variations]:
            return norm
    return name

# === 4. Agrupar entidades (CORREGIDO) ===
def get_key(ent):
    # Agrupar por: tipo, subtipo, ciudad, nombre normalizado
    # PERO NO por descripción
    tipo = (ent.get('entity_type') or '').lower()
    subtipo = (ent.get('subtype') or '').lower()
    
    # Buscar ciudad en la jerarquía
    ciudad = None
    for h in ent.get('hierarchy', []):
        if (h.get('type') or '').lower() == 'city':
            ciudad = (h.get('name') or '').lower()
            break
    
    # Si no hay jerarquía, buscar en otros campos
    if not ciudad:
        ciudad = (ent.get('city') or '').lower()
    
    nombre = (ent.get('normalized_name') or '').lower()
    
    return (tipo, subtipo, ciudad, nombre)

def agrupar_entidades(entities, normalized_dict):
    agrupadas = defaultdict(list)
    for ent in entities:
        # Normalizar nombre
        original_name = ent.get('name') or ent.get('title') or ent.get('advice_text')
        ent['normalized_name'] = normalize_entity_name(original_name, normalized_dict)
        key = get_key(ent)
        agrupadas[key].append(ent)
    return agrupadas

# === 5. Generar la salida (MEJORADO) ===
def generar_salida(agrupadas, output_path):
    output = []
    for key, ents in agrupadas.items():
        if not key[3]:  # Saltar entidades sin nombre
            continue
            
        # Tomar la primera entidad como base
        base = dict(ents[0])
        base['appearances'] = len(ents)
        base['all_source_urls'] = list({e.get('source_url') for e in ents if e.get('source_url')})
        
        # COMBINAR DESCRIPCIONES (esto es lo que se combina, no se usa para distinguir)
        descripciones = []
        for ent in ents:
            desc = ent.get('description', '').strip()
            if desc and desc not in descripciones:
                descripciones.append(desc)
        
        if descripciones:
            if len(descripciones) == 1:
                base['description'] = descripciones[0]
            else:
                base['description'] = " | ".join(descripciones)
        
        # COMBINAR IMÁGENES
        todas_imagenes = []
        for ent in ents:
            imagenes = ent.get('images', [])
            if isinstance(imagenes, list):
                todas_imagenes.extend(imagenes)
        
        if todas_imagenes:
            base['images'] = list(set(todas_imagenes))  # Eliminar duplicados
        
        # COMBINAR WEBSITES OFICIALES
        websites = []
        for ent in ents:
            website = ent.get('official_website', '').strip()
            if website and website not in websites:
                websites.append(website)
        
        if websites:
            base['official_websites'] = websites
        
        output.append(base)
    
    # Guardar en JSONL
    with open(output_path, 'w', encoding='utf-8') as f:
        for ent in output:
            f.write(json.dumps(ent, ensure_ascii=False) + '\n')
    return output

# === 6. Estadísticas y prints bonitos ===
def print_stats(entities, agrupadas, output):
    print("🔎 Estadísticas del proceso de agrupación")
    print("="*60)
    print(f"Total de entidades originales: {len(entities)}")
    print(f"Total de grupos únicos tras agrupar: {len(agrupadas)}")
    print(f"Total de entidades en el archivo final: {len(output)}")
    print("\nEjemplo de grupo agrupado:")
    for k, v in agrupadas.items():
        if k[3]:  # Solo mostrar grupos con nombre
            print(f"  - Clave: {k}")
            print(f"    Nombres originales: {[e.get('name') for e in v]}")
            print(f"    Aparece en URLs: {[e.get('source_url') for e in v]}")
            print(f"    Número de apariciones: {len(v)}")
            print()
            break
    apariciones = [ent['appearances'] for ent in output]
    print(f"Media de apariciones por grupo: {sum(apariciones)/len(apariciones):.2f}")
    print(f"Máximo de apariciones en un grupo: {max(apariciones)}")
    print(f"Mínimo de apariciones en un grupo: {min(apariciones)}")
    print("="*60)

# === 7. Rutas ===
input_jsonl = Path(r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data.jsonl")
normalized_py = Path(r"D:\TravelApp\Project\scripts\scraper_enrichment\auxs\normalized_entities.py")
output_jsonl = Path(r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_2.jsonl")

# === 8. Proceso completo ===
normalized_dict = load_normalized_entities(normalized_py)
entities = load_enriched_entities(input_jsonl)
agrupadas = agrupar_entidades(entities, normalized_dict)
output = generar_salida(agrupadas, output_jsonl)
print_stats(entities, agrupadas, output)
print(f"\n✅ Archivo guardado en: {output_jsonl}")
# Out:
# 🔎 Estadísticas del proceso de agrupación
# ============================================================
# Total de entidades originales: 1516
# Total de grupos únicos tras agrupar: 1070
# Total de entidades en el archivo final: 1056
#
# Ejemplo de grupo agrupado:
#   - Clave: ('site', 'country', '', 'thailand')
#     Nombres originales: ['Tailandia', 'Thailand', 'Thailand', 'Tailandia', 'Tailandia', 'Thailand', 'Thailand', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Tailandia', 'Thailand', 'Thailand', 'Tailandia', 'Tailandia', 'Thailand', 'Thailand', 'Thailand', 'Thailand', 'Thailand', 'Thailand']
#     Aparece en URLs: ['https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/', 'https://www.viajeroscallejeros.com/lugares-que-visitar-en-tailandia/', 'https://heymondo.es/blog/que-ver-tailandia/', 'https://www.mundoasiatours.com/que-ver-en-tailandia/', 'https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html', 'https://lacosmopolilla.com/que-ver-en-tailandia/', 'https://lacosmopolilla.com/que-ver-en-tailandia/', 'https://lostraveleros.com/que-ver-en-tailandia/', 'https://www.nadaincluido.com/que-ver-en-tailandia/', 'https://www.nadaincluido.com/que-ver-en-tailandia/', 'https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias', 'https://sinohasviajado.com/que-hacer-en-tailandia-en-30-dias', 'https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/', 'https://imanesdeviaje.com/que-ver-en-tailandia-en-15-dias/', 'https://directiatravel.com/viajes-tailandia/guia/que-ver-y-hacer', 'https://comiviajeros.com/que-ver-en-tailandia-imprescindibles/', 'https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/', 'https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/', 'https://directiatravel.com/viajes-tailandia/guia', 'https://lamaletadecarla.com/guia-completa-para-viajar-a-tailandia/', 'https://mundo-nomada.com/viajar-a-tailandia/', 'https://www.conmochila.com/tailandia-guia-de-viaje', 'https://comiviajeros.com/guia-de-tailandia/', 'https://comiviajeros.com/guia-de-tailandia/', 'https://www.youtube.com/watch?v=-tPe1fHyfQY', 'https://www.kayak.com.ar/Tailandia.238.dc.guide']
#     Número de apariciones: 26
#
# Media de apariciones por grupo: 1.40
# Máximo de apariciones en un grupo: 26
# Mínimo de apariciones en un grupo: 1
# ============================================================
#
# ✅ Archivo guardado en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_2.jsonl

# %% [markdown]
# ## We show the data

# %%
import json
from pathlib import Path
from collections import Counter

def imprimir_entidades_agrupadas(output_path, max_mostrar=10):
    """
    Imprime información detallada de las entidades agrupadas
    """
    print("🔍 IMPRESOR DE ENTIDADES AGRUPADAS")
    print("=" * 80)
    
    # Cargar el archivo de salida
    with open(output_path, 'r', encoding='utf-8') as f:
        entidades = [json.loads(line) for line in f if line.strip()]
    
    print(f"�� Total de entidades agrupadas: {len(entidades)}")
    print()
    
    # Estadísticas generales
    tipos_entidad = Counter([e.get('entity_type', 'sin_tipo') for e in entidades])
    print("�� DISTRIBUCIÓN POR TIPO DE ENTIDAD:")
    for tipo, count in tipos_entidad.most_common():
        print(f"   • {tipo}: {count}")
    print()
    
    # Entidades con más apariciones
    entidades_por_apariciones = sorted(entidades, key=lambda x: x.get('appearances', 0), reverse=True)
    print(f"🏆 TOP {max_mostrar} ENTIDADES CON MÁS APARICIONES:")
    print("-" * 80)
    
    for i, ent in enumerate(entidades_por_apariciones[:max_mostrar], 1):
        print(f"{i:2d}. {ent.get('normalized_name', ent.get('name', 'Sin nombre'))}")
        print(f"     Tipo: {ent.get('entity_type', 'N/A')}")
        print(f"     Subtipo: {ent.get('subtype', 'N/A')}")
        print(f"     Apariciones: {ent.get('appearances', 0)}")
        print(f"     URLs: {len(ent.get('all_source_urls', []))}")
        if ent.get('description'):
            desc = ent['description'][:100] + "..." if len(ent['description']) > 100 else ent['description']
            print(f"     Descripción: {desc}")
        print()
    
    # Entidades únicas (solo aparecen una vez)
    entidades_unicas = [e for e in entidades if e.get('appearances', 0) == 1]
    print(f"⭐ ENTIDADES ÚNICAS (solo 1 aparición): {len(entidades_unicas)}")
    print("-" * 80)
    
    for i, ent in enumerate(entidades_unicas[:5], 1):  # Mostrar solo las primeras 5
        print(f"{i}. {ent.get('normalized_name', ent.get('name', 'Sin nombre'))} - {ent.get('entity_type', 'N/A')}")
    
    if len(entidades_unicas) > 5:
        print(f"   ... y {len(entidades_unicas) - 5} más")
    print()
    
    # Ejemplos de grupos con múltiples apariciones
    grupos_multiples = [e for e in entidades if e.get('appearances', 0) > 1]
    print(f"🔄 GRUPOS CON MÚLTIPLES APARICIONES: {len(grupos_multiples)}")
    print("-" * 80)
    
    for i, ent in enumerate(grupos_multiples[:3], 1):  # Mostrar solo los primeros 3
        print(f"{i}. {ent.get('normalized_name', ent.get('name', 'Sin nombre'))}")
        print(f"   Apariciones: {ent.get('appearances', 0)}")
        print(f"   URLs de origen:")
        for url in ent.get('all_source_urls', [])[:3]:  # Mostrar solo las primeras 3 URLs
            print(f"     • {url}")
        if len(ent.get('all_source_urls', [])) > 3:
            print(f"     • ... y {len(ent.get('all_source_urls', [])) - 3} más")
        print()
    
    # Verificar normalización
    print("🔧 VERIFICACIÓN DE NORMALIZACIÓN:")
    print("-" * 80)
    
    entidades_sin_normalizar = [e for e in entidades if e.get('normalized_name') == e.get('name')]
    entidades_normalizadas = [e for e in entidades if e.get('normalized_name') != e.get('name')]
    
    print(f"   • Entidades normalizadas: {len(entidades_normalizadas)}")
    print(f"   • Entidades sin cambios: {len(entidades_sin_normalizar)}")
    
    if entidades_normalizadas:
        print("   Ejemplos de normalización:")
        for ent in entidades_normalizadas[:3]:
            print(f"     • '{ent.get('name')}' → '{ent.get('normalized_name')}'")
    print()
    
    # Resumen final
    print("📋 RESUMEN FINAL")
    print("=" * 80)
    print(f"✅ Total entidades procesadas: {len(entidades)}")
    print(f"✅ Entidades únicas: {len(entidades_unicas)}")
    print(f"✅ Grupos múltiples: {len(grupos_multiples)}")
    print(f"✅ Tipos diferentes: {len(tipos_entidad)}")
    print(f"✅ Entidades normalizadas: {len(entidades_normalizadas)}")
    
    # Calcular estadísticas de apariciones
    apariciones = [e.get('appearances', 0) for e in entidades]
    if apariciones:
        print(f"✅ Media apariciones: {sum(apariciones)/len(apariciones):.2f}")
        print(f"✅ Máximo apariciones: {max(apariciones)}")
        print(f"✅ Mínimo apariciones: {min(apariciones)}")

# Ejecutar el impresor
output_path = Path(r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_2.jsonl")
imprimir_entidades_agrupadas(output_path, max_mostrar=15)
# Out:
# 🔍 IMPRESOR DE ENTIDADES AGRUPADAS
# ================================================================================
# �� Total de entidades agrupadas: 1056
#
# �� DISTRIBUCIÓN POR TIPO DE ENTIDAD:
#    • site: 522
#    • sin_tipo: 236
#    • tip: 119
#    • itinerary: 58
#    • activity: 41
#    • transport: 27
#    • event: 19
#    • country: 18
#    • province: 16
#
# 🏆 TOP 15 ENTIDADES CON MÁS APARICIONES:
# --------------------------------------------------------------------------------
#  1. Thailand
#      Tipo: site
#      Subtipo: country
#      Apariciones: 26
#      URLs: 19
#      Descripción: Diverse country with attractions for all tastes, known for its hospitality, delicious cuisine, and b...
#
#  2. Chiang Mai
#      Tipo: site
#      Subtipo: city
#      Apariciones: 17
#      URLs: 12
#      Descripción: Known as the 'Northern Capital' of Thailand, offering a magical environment with nature, Buddhist te...
#
#  3. Phuket
#      Tipo: site
#      Subtipo: island
#      Apariciones: 16
#      URLs: 14
#      Descripción: Popular island destination in Thailand. | Phuket is the largest island in Thailand, known for its di...
#
#  4. Bangkok
#      Tipo: site
#      Subtipo: city
#      Apariciones: 15
#      URLs: 10
#      Descripción: Capital city of Thailand with a mix of modernity and tradition, known for its bustling streets, vibr...
#
#  5. Koh Samui
#      Tipo: site
#      Subtipo: island
#      Apariciones: 15
#      URLs: 12
#      Descripción: The top island destination in Thailand, particularly popular for family tourism. Known for luxury re...
#
#  6. Ayutthaya
#      Tipo: site
#      Subtipo: city
#      Apariciones: 14
#      URLs: 9
#      Descripción: Ancient city near Bangkok with historical temples | Ayutthaya is a historic city in Thailand, known ...
#
#  7. Koh Phi Phi
#      Tipo: site
#      Subtipo: island
#      Apariciones: 13
#      URLs: 10
#      Descripción: Famous island group in Thailand known for its beaches and clear turquoise waters. Includes Koh Phi P...
#
#  8. Koh Lipe
#      Tipo: site
#      Subtipo: island
#      Apariciones: 13
#      URLs: 8
#      Descripción: Small island in the Andaman Sea, known for its white sandy beaches and turquoise waters | An island ...
#
#  9. Koh Tao
#      Tipo: site
#      Subtipo: island
#      Apariciones: 13
#      URLs: 9
#      Descripción: Island on the east coast of Thailand known for diving and beautiful beaches | A renowned island in t...
#
# 10. Bangkok
#      Tipo: N/A
#      Subtipo: city
#      Apariciones: 13
#      URLs: 8
#      Descripción: Capital city of Thailand where traditional and contemporary elements blend together. Known for its c...
#
# 11. Krabi
#      Tipo: site
#      Subtipo: province
#      Apariciones: 10
#      URLs: 8
#      Descripción: Krabi is a province in Thailand known for its stunning limestone cliffs and beautiful beaches. The m...
#
# 12. Thailand
#      Tipo: N/A
#      Subtipo: country
#      Apariciones: 10
#      URLs: 8
#      Descripción: Popular country in Southeast Asia
#
# 13. Ayutthaya
#      Tipo: N/A
#      Subtipo: city
#      Apariciones: 10
#      URLs: 7
#      Descripción: Ancient capital of the Kingdom of Siam, a UNESCO World Heritage Site with a collection of temples an...
#
# 14. Chiang Mai
#      Tipo: site
#      Subtipo: city
#      Apariciones: 9
#      URLs: 8
#      Descripción: Explore the city for at least 2 days, with an option for additional excursions. Consider a tour to C...
#
# 15. Sukhothai
#      Tipo: site
#      Subtipo: city
#      Apariciones: 9
#      URLs: 7
#      Descripción: Historical city in Thailand | The first capital of the Kingdom of Siam, known for its historical par...
#
# ⭐ ENTIDADES ÚNICAS (solo 1 aparición): 927
# --------------------------------------------------------------------------------
# 1. Grab - transport
# 2. taxi - transport
# 3. Songthaew - transport
# 4. Sukhothai Historical Park - site
# 5. 5-day circuit from Bangkok to Chiang Mai - itinerary
#    ... y 922 más
#
# 🔄 GRUPOS CON MÚLTIPLES APARICIONES: 129
# --------------------------------------------------------------------------------
# 1. Thailand
#    Apariciones: 26
#    URLs de origen:
#      • https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      • https://tuguiaentailandia.com/guia-completa-para-el-viaje-a-tailandia-importante-a-saber/
#      • https://www.conmochila.com/tailandia-guia-de-viaje
#      • ... y 16 más
#
# 2. Bangkok
#    Apariciones: 15
#    URLs de origen:
#      • https://www.nadaincluido.com/que-ver-en-tailandia/
#      • https://www.mundoasiatours.com/que-ver-en-tailandia/
#      • https://lamaletadecarla.com/guia-completa-para-viajar-a-tailandia/
#      • ... y 7 más
#
# 3. Chiang Mai
#    Apariciones: 17
#    URLs de origen:
#      • https://www.nadaincluido.com/que-ver-en-tailandia/
#      • https://www.mundoasiatours.com/que-ver-en-tailandia/
#      • https://www.expansion.com/fueradeserie/viajes/2023/09/05/64f5b529e5fdeaa9778b45f4.html
#      • ... y 9 más
#
# 🔧 VERIFICACIÓN DE NORMALIZACIÓN:
# --------------------------------------------------------------------------------
#    • Entidades normalizadas: 225
#    • Entidades sin cambios: 831
#    Ejemplos de normalización:
#      • 'Tailandia' → 'Thailand'
#      • 'tuk tuk' → 'tuk-tuk'
#      • 'songthaew' → 'Songthaew'
#
# 📋 RESUMEN FINAL
# ================================================================================
# ✅ Total entidades procesadas: 1056
# ✅ Entidades únicas: 927
# ✅ Grupos múltiples: 129
# ✅ Tipos diferentes: 9
# ✅ Entidades normalizadas: 225
# ✅ Media apariciones: 1.40
# ✅ Máximo apariciones: 26
# ✅ Mínimo apariciones: 1

# %% [markdown]
# ## We do manual modification of the entities

# %%
# === BLOQUE PARA JUPYTER NOTEBOOK ===
import sys
from pathlib import Path

# Añadir el directorio del script al path
current_dir = Path.cwd()
script_dir = current_dir / "entidades_editor.py"
sys.path.append(str(current_dir))

# Importar la clase
from entidades_editor import iniciar_editor

# Definir rutas
input_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl"
output_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl"

print("🚀 Iniciando Editor de Entidades...")
print(f"📥 Entrada: {input_path}")
print(f"📤 Salida: {output_path}")
print()

# Iniciar el editor
iniciar_editor(input_path, output_path)
# Out:
# 🚀 Iniciando Editor de Entidades...
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
#
# ✅ Usando archivo existente: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Cargadas 1051 entidades desde D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ OSM añadido: OSM:N2082718893
# ✅ Wikidata añadido: Q669271
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl

# %% [markdown]
# ## Llamas a API de NOMINATIN

# %%
# === BLOQUE PARA JUPYTER NOTEBOOK ===
import sys
from pathlib import Path

# Añadir el directorio del script al path
current_dir = Path.cwd()
script_dir = current_dir / "nominatim_enricher.py"
sys.path.append(str(current_dir))

# Importar las funciones
from nominatim_enricher import process_sites_with_nominatim, show_sample_results

# Definir rutas
input_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl"
output_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl"

print("�� INICIANDO ENRIQUECIMIENTO CON NOMINATIM")
print("=" * 60)
print(f"📥 Entrada: {input_path}")
print(f"📤 Salida: {output_path}")
print()

# Procesar todos los sitios
stats = process_sites_with_nominatim(input_path, output_path)

# Mostrar ejemplos de resultados
show_sample_results(output_path, num_samples=10)

print("\n🎯 RESUMEN FINAL:")
print(f"   • Total de sitios procesados: {stats['total_sites']}")
print(f"   • Sitios encontrados: {stats['found_sites']}")
print(f"   • Tasa de éxito: {stats['success_rate']*100:.1f}%")
print(f"   • Distribución por calidad: {stats['quality_stats']}")
# Out:
# �� INICIANDO ENRIQUECIMIENTO CON NOMINATIM
# ============================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl
#
# 🚀 INICIANDO ENRIQUECIMIENTO CON NOMINATIM
# ============================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_3.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl
#
# 📊 Estadísticas:
#    • Total de entidades: 1049
#    • Sitios a procesar: 520
#
# 🔄 Procesando sitio 1/520: Tailandia
# 🔍 Buscando: 'Tailandia' (name_only)
# ✅ Encontrado: Tailândia, Região Geográfica Imediata de Abaetetuba, Região Geográfica Intermediária de Belém, Pará, Região Norte, 68695-000, Brasil (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 2/520: Bangkok
# 🔍 Buscando: 'Bangkok' (name_only)
# ✅ Encontrado: กรุงเทพมหานคร, ประเทศไทย (score: 0.72, nivel: good)
#
# 🔄 Procesando sitio 3/520: Chiang Mai
# 🔍 Buscando: 'Chiang Mai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.57, nivel: fair)
#
# 🔄 Procesando sitio 4/520: Doi Suthep
# 🔍 Buscando: 'Doi Suthep' (name_only)
# ✅ Encontrado: ดอยสุเทพ, บ้านภูพิงค์ฯ, ป่าแดด, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 5/520: Phi Phi Islands
# 🔍 Buscando: 'Phi Phi Islands' (name_only)
# ✅ Encontrado: หมู่เกาะพีพี, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 6/520: Sukhothai Historical Park
# 🔍 Buscando: 'Sukhothai Historical Park' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์สุโขทัย, ถนนจรดวิถีถ่อง, บ้านศรีชุม, เมืองเก่า, Mueang Sukhothai, จังหวัดสุโขทัย, 64210, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 7/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 8/520: Thai Thai Sukhothai Resort
# 🔍 Buscando: 'Thai Thai Sukhothai Resort' (name_only)
# ✅ Encontrado: resort +, ถนนสิงหวัฒน์, บ้านหนองหญ้าปล้อง, บ้านข่อยสองนาง, Kong Krailat, จังหวัดสุโขทัย, 64170, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 9/520: Koh Lipe
# 🔍 Buscando: 'Koh Lipe' (name_only)
# ✅ Encontrado: Koh Lipe, 35, Baldwin Street, Kensington-Chinatown, University—Rosedale, Toronto, Golden Horseshoe, Ontario, M5T 1L1, Canada (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 10/520: Serendipity Beach Resort Koh Lipe
# 🔍 Buscando: 'Serendipity Beach Resort Koh Lipe' (name_only)
# ❌ No encontrado: Serendipity Beach Resort Koh Lipe
# 📈 Progreso: 10/520 sitios procesados
#
# 🔄 Procesando sitio 11/520: Castaway Resort Koh Lipe
# 🔍 Buscando: 'Castaway Resort Koh Lipe' (name_only)
# ❌ No encontrado: Castaway Resort Koh Lipe
#
# 🔄 Procesando sitio 12/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 13/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 14/520: Khao Sok National Park
# 🔍 Buscando: 'Khao Sok National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเขาสก, Ban Ta Khun, จังหวัดสุราษฎร์ธานี, 84230, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 15/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 16/520: Koh Tao
# 🔍 Buscando: 'Koh Tao' (name_only)
# ✅ Encontrado: เกาะเต่า, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.45, nivel: poor)
#
# 🔄 Procesando sitio 17/520: Koh Phangan
# 🔍 Buscando: 'Koh Phangan' (name_only)
# ✅ Encontrado: เกาะพะงัน, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.41, nivel: poor)
#
# 🔄 Procesando sitio 18/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
#
# 🔄 Procesando sitio 19/520: Kanchanaburi
# 🔍 Buscando: 'Kanchanaburi' (name_only)
# ✅ Encontrado: กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 20/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
# 📈 Progreso: 20/520 sitios procesados
#
# 🔄 Procesando sitio 21/520: Krabi
# 🔍 Buscando: 'Krabi' (name_only)
# ✅ Encontrado: กระบี่, กระบี่น้อย, Mueang Krabi, จังหวัดกระบี่, 81300, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 22/520: Koh Chang
# 🔍 Buscando: 'Koh Chang' (name_only)
# ✅ Encontrado: เกาะช้าง, Ko Chang, จังหวัดตราด, 23120, ประเทศไทย (score: 0.17, nivel: poor)
#
# 🔄 Procesando sitio 23/520: Koh Lanta
# 🔍 Buscando: 'Koh Lanta' (name_only)
# ✅ Encontrado: Koh Lanta, Gorriti, Palermo Hollywood, Palermo, Buenos Aires, Distrito Audiovisual, Comuna 14, Ciudad Autónoma de Buenos Aires, C1414DKE, Argentina (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 24/520: Koh Yao Noi
# 🔍 Buscando: 'Koh Yao Noi' (name_only)
# ✅ Encontrado: Coastal Escape Koh Yao Noi, ถนนศรีรักษ์, เกาะยาว, เกาะยาวใหญ่, Ko Yao, จังหวัดพังงา, 82160, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 25/520: Koh Yao Yai
# 🔍 Buscando: 'Koh Yao Yai' (name_only)
# ✅ Encontrado: Koh Yao Ice Cream and Bakery, ถนนศรีรักษ์, เกาะยาว, เกาะยาวใหญ่, Ko Yao, จังหวัดพังงา, 82160, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 26/520: Lopburi
# 🔍 Buscando: 'Lopburi' (name_only)
# ✅ Encontrado: ลพบุรี, ถนนใหญ่, Mueang Lop Buri, จังหวัดลพบุรี, 15000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 27/520: Lopburi
# 🔍 Buscando: 'Lopburi' (name_only)
# ✅ Encontrado: ลพบุรี, ถนนใหญ่, Mueang Lop Buri, จังหวัดลพบุรี, 15000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 28/520: Similan Islands
# 🔍 Buscando: 'Similan Islands' (name_only)
# ✅ Encontrado: Similan island number 7 - Ko Hin Pusar, จังหวัดพังงา, ประเทศไทย (score: 0.17, nivel: poor)
#
# 🔄 Procesando sitio 29/520: Mae Hong Son
# 🔍 Buscando: 'Mae Hong Son' (name_only)
# ✅ Encontrado: จังหวัดแม่ฮ่องสอน, ประเทศไทย (score: 0.50, nivel: fair)
#
# 🔄 Procesando sitio 30/520: Koh Kood
# 🔍 Buscando: 'Koh Kood' (name_only)
# ✅ Encontrado: เกาะกูด, อ่าวผักแว่น, Ko Kut, จังหวัดตราด, ประเทศไทย (score: 0.29, nivel: poor)
# 📈 Progreso: 30/520 sitios procesados
#
# 🔄 Procesando sitio 31/520: Chumphon
# 🔍 Buscando: 'Chumphon' (name_only)
# ✅ Encontrado: ชุมพร, บางหมาก, Mueang Chumphon, จังหวัดชุมพร, 86000, ประเทศไทย (score: 0.37, nivel: poor)
#
# 🔄 Procesando sitio 32/520: Wua Laen Beach
# 🔍 Buscando: 'Wua Laen Beach' (name_only)
# ✅ Encontrado: View Resort Thung WUA Laen Beach, ถนนท่าแซะ - ศูนย์ราชการชุมพร, หาดทุ่งวัวแล่น, สะพลี, Pathio, จังหวัดชุมพร, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 33/520: Chumphon National Park
# 🔍 Buscando: 'Chumphon National Park' (name_only)
# ✅ Encontrado: National park, ชพ.2046, หาดทรายรี, Mueang Chumphon, จังหวัดชุมพร, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 34/520: Nakhon Si Thammarat
# 🔍 Buscando: 'Nakhon Si Thammarat' (name_only)
# ✅ Encontrado: เทศบาลนครนครศรีธรรมราช, โพธิ์เสด็จ, Mueang Nakhon Si Thammarat, จังหวัดนครศรีธรรมราช, ประเทศไทย (score: 0.45, nivel: poor)
#
# 🔄 Procesando sitio 35/520: Wat Phra Mahathat Woramahawihan
# 🔍 Buscando: 'Wat Phra Mahathat Woramahawihan' (name_only)
# ❌ No encontrado: Wat Phra Mahathat Woramahawihan
#
# 🔄 Procesando sitio 36/520: Phimai
# 🔍 Buscando: 'Phimai' (name_only)
# ✅ Encontrado: พิมาย, รังกาใหญ่, Phimai, จังหวัดนครราชสีมา, 30110, ประเทศไทย (score: 0.32, nivel: poor)
#
# 🔄 Procesando sitio 37/520: Phanom Rung
# 🔍 Buscando: 'Phanom Rung' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์พนมรุ้ง, ยายแย้มวัฒนา, อำเภอเฉลิมพระเกียรติ, จังหวัดบุรีรัมย์, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 38/520: Prasat Hin Mueang Tum
# 🔍 Buscando: 'Prasat Hin Mueang Tum' (name_only)
# ❌ No encontrado: Prasat Hin Mueang Tum
#
# 🔄 Procesando sitio 39/520: Greece
# 🔍 Buscando: 'Greece' (name_only)
# ✅ Encontrado: Ελλάς (score: 0.85, nivel: good)
#
# 🔄 Procesando sitio 40/520: Turkey
# 🔍 Buscando: 'Turkey' (name_only)
# ✅ Encontrado: Türkiye (score: 0.88, nivel: good)
# 📈 Progreso: 40/520 sitios procesados
#
# 🔄 Procesando sitio 41/520: USA
# 🔍 Buscando: 'USA' (name_only)
# ✅ Encontrado: United States (score: 1.00, nivel: excellent)
#
# 🔄 Procesando sitio 42/520: Amsterdam
# 🔍 Buscando: 'Amsterdam' (name_only)
# ✅ Encontrado: Amsterdam, Noord-Holland, Nederland (score: 0.78, nivel: good)
#
# 🔄 Procesando sitio 43/520: Andaman Islands
# 🔍 Buscando: 'Andaman Islands' (name_only)
# ✅ Encontrado: Andaman Islands, Andaman and Nicobar Islands, India (score: 0.57, nivel: fair)
#
# 🔄 Procesando sitio 44/520: Indonesia
# 🔍 Buscando: 'Indonesia' (name_only)
# ✅ Encontrado: Indonesia (score: 0.87, nivel: good)
#
# 🔄 Procesando sitio 45/520: Damnoen Saduak Floating Market
# 🔍 Buscando: 'Damnoen Saduak Floating Market' (name_only)
# ✅ Encontrado: Damnoen Saduak Floating Market, รบ.3003, ดำเนินสะดวก, ศรีดอนไผ่, อำเภอดำเนินสะดวก, จังหวัดราชบุรี, 70130, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 46/520: Taling Chang Floating Market
# 🔍 Buscando: 'Taling Chang Floating Market' (name_only)
# ❌ No encontrado: Taling Chang Floating Market
#
# 🔄 Procesando sitio 47/520: Amphawa Floating Market
# 🔍 Buscando: 'Amphawa Floating Market' (name_only)
# ✅ Encontrado: ตลาดน้ําอัมพวา, ถนนศรีอัมพวา, อัมพวา, สวนหลวง, อำเภออัมพวา, จังหวัดสมุทรสงคราม, 75110, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 48/520: Mae Klong Railway Market
# 🔍 Buscando: 'Mae Klong Railway Market' (name_only)
# ✅ Encontrado: ตลาดร่มหุบ, ถนนเกษมสุขุม, ชุมสาย, สมุทรสงคราม, อำเภอเมืองสมุทรสงคราม, จังหวัดสมุทรสงคราม, 75000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 49/520: Sukhothai Historical Park
# 🔍 Buscando: 'Sukhothai Historical Park' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์สุโขทัย, ถนนจรดวิถีถ่อง, บ้านศรีชุม, เมืองเก่า, Mueang Sukhothai, จังหวัดสุโขทัย, 64210, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 50/520: Kanchanaburi
# 🔍 Buscando: 'Kanchanaburi' (name_only)
# ✅ Encontrado: กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย (score: 0.43, nivel: poor)
# 📈 Progreso: 50/520 sitios procesados
#
# 🔄 Procesando sitio 51/520: Chiang Mai
# 🔍 Buscando: 'Chiang Mai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.57, nivel: fair)
#
# 🔄 Procesando sitio 52/520: Doi Inthanon National Park
# 🔍 Buscando: 'Doi Inthanon National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติดอยอินทนนท์, Chom Thong, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 53/520: Ao Nang
# 🔍 Buscando: 'Ao Nang' (name_only)
# ✅ Encontrado: ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 54/520: Koh Muk
# 🔍 Buscando: 'Koh Muk' (name_only)
# ✅ Encontrado: เกาะมุก, หาดฝรั่ง, Kantang, จังหวัดตรัง, 92100, ประเทศไทย (score: 0.17, nivel: poor)
#
# 🔄 Procesando sitio 55/520: Koh Samui
# 🔍 Buscando: 'Koh Samui' (name_only)
# ✅ Encontrado: เกาะสมุย, Ko Samui, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 56/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 57/520: Koh Lipe
# 🔍 Buscando: 'Koh Lipe' (name_only)
# ✅ Encontrado: Koh Lipe, 35, Baldwin Street, Kensington-Chinatown, University—Rosedale, Toronto, Golden Horseshoe, Ontario, M5T 1L1, Canada (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 58/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 59/520: Sukhothai Historical Park
# 🔍 Buscando: 'Sukhothai Historical Park' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์สุโขทัย, ถนนจรดวิถีถ่อง, บ้านศรีชุม, เมืองเก่า, Mueang Sukhothai, จังหวัดสุโขทัย, 64210, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 60/520: Similan Islands
# 🔍 Buscando: 'Similan Islands' (name_only)
# ✅ Encontrado: Similan island number 7 - Ko Hin Pusar, จังหวัดพังงา, ประเทศไทย (score: 0.17, nivel: poor)
# 📈 Progreso: 60/520 sitios procesados
#
# 🔄 Procesando sitio 61/520: Ko Nang Yuan
# 🔍 Buscando: 'Ko Nang Yuan' (name_only)
# ✅ Encontrado: เกาะนางยวน, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.13, nivel: poor)
#
# 🔄 Procesando sitio 62/520: Chumphon Pinnacles
# 🔍 Buscando: 'Chumphon Pinnacles' (name_only)
# ❌ No encontrado: Chumphon Pinnacles
#
# 🔄 Procesando sitio 63/520: HTMS Sattakut
# 🔍 Buscando: 'HTMS Sattakut' (name_only)
# ❌ No encontrado: HTMS Sattakut
#
# 🔄 Procesando sitio 64/520: White Rock
# 🔍 Buscando: 'White Rock' (name_only)
# ✅ Encontrado: White Rock, Metro Vancouver Regional District, British Columbia, Canada (score: 0.49, nivel: poor)
#
# 🔄 Procesando sitio 65/520: Mirador John-Suwan
# 🔍 Buscando: 'Mirador John-Suwan' (name_only)
# ✅ Encontrado: John-Suwan Mountain Viewpoint, Haad Tien Beach Resort, บ้านโฉลกบ้านเก่า, เกาะเต่า, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, 84369, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 66/520: Mirador Ko Nang Yuan
# 🔍 Buscando: 'Mirador Ko Nang Yuan' (name_only)
# ❌ No encontrado: Mirador Ko Nang Yuan
#
# 🔄 Procesando sitio 67/520: Big Buddha Phuket
# 🔍 Buscando: 'Big Buddha Phuket' (name_only)
# ✅ Encontrado: Big Buddha, ซอยยอดเสน่ห์ 1, ฉลอง, ตำบลกะรน, อำเภอเมืองภูเก็ต, จังหวัดภูเก็ต, 83100, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 68/520: Wat Chalong
# 🔍 Buscando: 'Wat Chalong' (name_only)
# ✅ Encontrado: Wat Chalong, ถนนบ้านนาใหญ่-บ้านฉลอง, บ้านฉลอง, ฉลอง, ตำบลฉลอง, อำเภอเมืองภูเก็ต, จังหวัดภูเก็ต, 83230, ประเทศไทย (score: 0.23, nivel: poor)
#
# 🔄 Procesando sitio 69/520: Cabo Promthep
# 🔍 Buscando: 'Cabo Promthep' (name_only)
# ❌ No encontrado: Cabo Promthep
#
# 🔄 Procesando sitio 70/520: Phuket City
# 🔍 Buscando: 'Phuket City' (name_only)
# ✅ Encontrado: Phuket City, 22, Lireweg, Nieuw-Vennep-Zuid, Nieuw-Vennep, Haarlemmermeer, Noord-Holland, Nederland, 2153 PH, Nederland (score: 0.00, nivel: poor)
# 📈 Progreso: 70/520 sitios procesados
#
# 🔄 Procesando sitio 71/520: Patong City
# 🔍 Buscando: 'Patong City' (name_only)
# ✅ Encontrado: Patong City Hometel, ถนนราชปาทานุสรณ์, ป่าตอง, ตำบลป่าตอง, อำเภอกะทู้, จังหวัดภูเก็ต, 83159, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 72/520: Phang Nga Bay
# 🔍 Buscando: 'Phang Nga Bay' (name_only)
# ✅ Encontrado: Phang Nga Bay, จังหวัดพังงา, ประเทศไทย (score: 0.39, nivel: poor)
#
# 🔄 Procesando sitio 73/520: Old Phuket Town
# 🔍 Buscando: 'Old Phuket Town' (name_only)
# ✅ Encontrado: The Miners Phuket Old Town, ถนนพังงา, ตำบลตลาดเหนือ, เทศบาลนครภูเก็ต, อำเภอเมืองภูเก็ต, จังหวัดภูเก็ต, 83000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 74/520: Ko Siray
# 🔍 Buscando: 'Ko Siray' (name_only)
# ❌ No encontrado: Ko Siray
#
# 🔄 Procesando sitio 75/520: Patong Beach
# 🔍 Buscando: 'Patong Beach' (name_only)
# ✅ Encontrado: หาดป่าตอง, ป่าตอง, ตำบลป่าตอง, อำเภอกะทู้, จังหวัดภูเก็ต, ประเทศไทย (score: 0.33, nivel: poor)
#
# 🔄 Procesando sitio 76/520: Bangla Road
# 🔍 Buscando: 'Bangla Road' (name_only)
# ✅ Encontrado: ถนนบางลา, ป่าตอง, ตำบลป่าตอง, อำเภอกะทู้, จังหวัดภูเก็ต, 83150, ประเทศไทย (score: 0.05, nivel: poor)
#
# 🔄 Procesando sitio 77/520: Phuket International Airport
# 🔍 Buscando: 'Phuket International Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติภูเก็ต, ถนนเทพกระษัตรี, ตำบลไม้ขาว, ป่าคลอก, อำเภอถลาง, จังหวัดภูเก็ต, 83140, ประเทศไทย (score: 0.49, nivel: poor)
#
# 🔄 Procesando sitio 78/520: Central Bus Station Phuket
# 🔍 Buscando: 'Central Bus Station Phuket' (name_only)
# ❌ No encontrado: Central Bus Station Phuket
#
# 🔄 Procesando sitio 79/520: Krabi
# 🔍 Buscando: 'Krabi' (name_only)
# ✅ Encontrado: กระบี่, กระบี่น้อย, Mueang Krabi, จังหวัดกระบี่, 81300, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 80/520: The Ping River
# 🔍 Buscando: 'The Ping River' (name_only)
# ❌ No encontrado: The Ping River
# 📈 Progreso: 80/520 sitios procesados
#
# 🔄 Procesando sitio 81/520: The Night Bazaar
# 🔍 Buscando: 'The Night Bazaar' (name_only)
# ✅ Encontrado: The Night Bazaar Place, ถนนเจริญประเทศ ซอย1, QHouse Villa, เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, 55520, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 82/520: Chiang Mai Old City
# 🔍 Buscando: 'Chiang Mai Old City' (name_only)
# ✅ Encontrado: Slumber Party Chiang Mai Old Town, 23, ถนนราชมรรคา ซอย 3, Muang Chiang Mai, เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 83/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 84/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 85/520: Bangkok
# 🔍 Buscando: 'Bangkok' (name_only)
# ✅ Encontrado: กรุงเทพมหานคร, ประเทศไทย (score: 0.72, nivel: good)
#
# 🔄 Procesando sitio 86/520: Bangkok
# 🔍 Buscando: 'Bangkok' (name_only)
# ✅ Encontrado: กรุงเทพมหานคร, ประเทศไทย (score: 0.72, nivel: good)
#
# 🔄 Procesando sitio 87/520: Suvarnabhumi Airport
# 🔍 Buscando: 'Suvarnabhumi Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานสุวรรณภูมิ, ซอยกิ่งแก้ว 38, บ้านคลองหนองบอน, ตำบลราชาเทวะ, องค์การบริหารส่วนตำบลราชาเทวะ, อำเภอบางพลี, จังหวัดสมุทรปราการ, ประเทศไทย (score: 0.53, nivel: fair)
#
# 🔄 Procesando sitio 88/520: Don Muang Airport
# 🔍 Buscando: 'Don Muang Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานดอนเมือง, ซอยสรงประภา 3, แขวงดอนเมือง, เขตดอนเมือง, กรุงเทพมหานคร, 10210, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 89/520: Hualamphong Station
# 🔍 Buscando: 'Hualamphong Station' (name_only)
# ✅ Encontrado: สถานีรถไฟกรุงเทพ, ตรอกสลักหิน, ชุมชนตรอกสลักหิน, แขวงรองเมือง, เขตปทุมวัน, กรุงเทพมหานคร, 10330, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 90/520: Erawan National Park
# 🔍 Buscando: 'Erawan National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเอราวัณ, Si Sawat, จังหวัดกาญจนบุรี, ประเทศไทย (score: 0.37, nivel: poor)
# 📈 Progreso: 90/520 sitios procesados
#
# 🔄 Procesando sitio 91/520: Ko Samui
# 🔍 Buscando: 'Ko Samui' (name_only)
# ✅ Encontrado: เกาะสมุย, Ko Samui, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 92/520: Krabi
# 🔍 Buscando: 'Krabi' (name_only)
# ✅ Encontrado: กระบี่, กระบี่น้อย, Mueang Krabi, จังหวัดกระบี่, 81300, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 93/520: Pattaya
# 🔍 Buscando: 'Pattaya' (name_only)
# ✅ Encontrado: เมืองพัทยา, หนองปลาไหล, Bang Lamung, จังหวัดชลบุรี, ประเทศไทย (score: 0.56, nivel: fair)
#
# 🔄 Procesando sitio 94/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 95/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 96/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 97/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
#
# 🔄 Procesando sitio 98/520: Krabi
# 🔍 Buscando: 'Krabi' (name_only)
# ✅ Encontrado: กระบี่, กระบี่น้อย, Mueang Krabi, จังหวัดกระบี่, 81300, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 99/520: Chiang Khan
# 🔍 Buscando: 'Chiang Khan' (name_only)
# ✅ Encontrado: Chiang Khan, จังหวัดเลย, 42110, ประเทศไทย (score: 0.24, nivel: poor)
#
# 🔄 Procesando sitio 100/520: Wat Pa Phu Kon
# 🔍 Buscando: 'Wat Pa Phu Kon' (name_only)
# ✅ Encontrado: Wat Pa Phu Kon, อด.5044, นายูง, Na Yung, จังหวัดอุดรธานี, ประเทศไทย (score: 0.00, nivel: poor)
# 📈 Progreso: 100/520 sitios procesados
#
# 🔄 Procesando sitio 101/520: Phanom Rung
# 🔍 Buscando: 'Phanom Rung' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์พนมรุ้ง, ยายแย้มวัฒนา, อำเภอเฉลิมพระเกียรติ, จังหวัดบุรีรัมย์, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 102/520: Kanchanaburi
# 🔍 Buscando: 'Kanchanaburi' (name_only)
# ✅ Encontrado: กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 103/520: Aeropuerto Internacional
# 🔍 Buscando: 'Aeropuerto Internacional' (name_only)
# ✅ Encontrado: 香港國際機場 Hong Kong International Airport, 跑道南路 South Runway Road, 赤鱲角 Chek Lap Kok, 離島區 Islands District, 新界 New Territories, 香港 Hong Kong, 中国 (score: 0.59, nivel: fair)
#
# 🔄 Procesando sitio 104/520: Casco Antiguo
# 🔍 Buscando: 'Casco Antiguo' (name_only)
# ✅ Encontrado: Altstadt, Grünes Quartier, Stadtteil I, Bern, Verwaltungskreis Bern-Mittelland, Verwaltungsregion Bern-Mittelland, Bern/Berne, 3011, Schweiz/Suisse/Svizzera/Svizra (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 105/520: Wat Phra Singh
# 🔍 Buscando: 'Wat Phra Singh' (name_only)
# ✅ Encontrado: วัดพระสิงห์, ถนนราชมรรคา ซอย 9, เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, 55520, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 106/520: Wat Chiang Man
# 🔍 Buscando: 'Wat Chiang Man' (name_only)
# ✅ Encontrado: วัดเชียงมั่น, ถนนพระปกเกล้า ซอย 13, บ้านวิภาวดี, เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, 55520, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 107/520: Mercado Warorot
# 🔍 Buscando: 'Mercado Warorot' (name_only)
# ❌ No encontrado: Mercado Warorot
#
# 🔄 Procesando sitio 108/520: Bazar Nocturno
# 🔍 Buscando: 'Bazar Nocturno' (name_only)
# ❌ No encontrado: Bazar Nocturno
#
# 🔄 Procesando sitio 109/520: Mercados Nocturnos de los Sábados y Domingos
# 🔍 Buscando: 'Mercados Nocturnos de los Sábados y Domingos' (name_only)
# ❌ No encontrado: Mercados Nocturnos de los Sábados y Domingos
#
# 🔄 Procesando sitio 110/520: Lago Huay
# 🔍 Buscando: 'Lago Huay' (name_only)
# ✅ Encontrado: อ่างเก็บน้ำห้วยมงคล, บ้านป่าเสลา, หนองพลับ, อำเภอหัวหิน, จังหวัดประจวบคีรีขันธ์, 77110, ประเทศไทย (score: 0.11, nivel: poor)
# 📈 Progreso: 110/520 sitios procesados
#
# 🔄 Procesando sitio 111/520: Palacio de Bhubing
# 🔍 Buscando: 'Palacio de Bhubing' (name_only)
# ❌ No encontrado: Palacio de Bhubing
#
# 🔄 Procesando sitio 112/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 113/520: Triángulo de Oro
# 🔍 Buscando: 'Triángulo de Oro' (name_only)
# ✅ Encontrado: Triángulo de Oro, Melilla, 52001, España (score: 0.13, nivel: poor)
#
# 🔄 Procesando sitio 114/520: Templo Blanco (Wat Rong Khun)
# 🔍 Buscando: 'Templo Blanco (Wat Rong Khun)' (name_only)
# ✅ Encontrado: Wat Rong Khun, ถนนร่องขุ่น, บ้านสันดอนแก้ว, บ้านร่องขุ่น, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.33, nivel: poor)
#
# 🔄 Procesando sitio 115/520: Lampang
# 🔍 Buscando: 'Lampang' (name_only)
# ✅ Encontrado: เทศบาลนครลำปาง, พิชัย, Mueang Lampang, จังหวัดลำปาง, ประเทศไทย (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 116/520: Centro de Conservación de Elefantes de Tailandia
# 🔍 Buscando: 'Centro de Conservación de Elefantes de Tailandia' (name_only)
# ❌ No encontrado: Centro de Conservación de Elefantes de Tailandia
#
# 🔄 Procesando sitio 117/520: Koh Tao
# 🔍 Buscando: 'Koh Tao' (name_only)
# ✅ Encontrado: เกาะเต่า, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.45, nivel: poor)
#
# 🔄 Procesando sitio 118/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
#
# 🔄 Procesando sitio 119/520: Ao Nang
# 🔍 Buscando: 'Ao Nang' (name_only)
# ✅ Encontrado: ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 120/520: Pattaya
# 🔍 Buscando: 'Pattaya' (name_only)
# ✅ Encontrado: เมืองพัทยา, หนองปลาไหล, Bang Lamung, จังหวัดชลบุรี, ประเทศไทย (score: 0.56, nivel: fair)
# 📈 Progreso: 120/520 sitios procesados
#
# 🔄 Procesando sitio 121/520: Ratchaburi
# 🔍 Buscando: 'Ratchaburi' (name_only)
# ✅ Encontrado: ราชบุรี, หลุมดิน, Mueang Ratchaburi, จังหวัดราชบุรี, 70000, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 122/520: Samut Songkhram
# 🔍 Buscando: 'Samut Songkhram' (name_only)
# ✅ Encontrado: จังหวัดสมุทรสงคราม, ประเทศไทย (score: 0.50, nivel: poor)
#
# 🔄 Procesando sitio 123/520: Ay Thai
# 🔍 Buscando: 'Ay Thai' (name_only)
# ✅ Encontrado: AY Traders Ltd, 59b, Derby Street, Strangeways, Manchester, Greater Manchester, England, M8 8HW, United Kingdom (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 124/520: Samut Songkhram
# 🔍 Buscando: 'Samut Songkhram' (name_only)
# ✅ Encontrado: จังหวัดสมุทรสงคราม, ประเทศไทย (score: 0.50, nivel: poor)
#
# 🔄 Procesando sitio 125/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 126/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
#
# 🔄 Procesando sitio 127/520: Chiang Rai
# 🔍 Buscando: 'Chiang Rai' (name_only)
# ✅ Encontrado: เทศบาลนครเชียงราย, ท่าสาย, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.47, nivel: poor)
#
# 🔄 Procesando sitio 128/520: Parque Nacional Khao Yai
# 🔍 Buscando: 'Parque Nacional Khao Yai' (name_only)
# ❌ No encontrado: Parque Nacional Khao Yai
#
# 🔄 Procesando sitio 129/520: Bahía de Phang Nga
# 🔍 Buscando: 'Bahía de Phang Nga' (name_only)
# ❌ No encontrado: Bahía de Phang Nga
#
# 🔄 Procesando sitio 130/520: Islas Phi Phi
# 🔍 Buscando: 'Islas Phi Phi' (name_only)
# ✅ Encontrado: เกาะพีพีเล, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย (score: 0.32, nivel: poor)
# 📈 Progreso: 130/520 sitios procesados
#
# 🔄 Procesando sitio 131/520: Railay
# 🔍 Buscando: 'Railay' (name_only)
# ✅ Encontrado: อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 132/520: Parque Nacional Khao Sok
# 🔍 Buscando: 'Parque Nacional Khao Sok' (name_only)
# ❌ No encontrado: Parque Nacional Khao Sok
#
# 🔄 Procesando sitio 133/520: Marino de Ang Thong
# 🔍 Buscando: 'Marino de Ang Thong' (name_only)
# ❌ No encontrado: Marino de Ang Thong
#
# 🔄 Procesando sitio 134/520: Lopburi
# 🔍 Buscando: 'Lopburi' (name_only)
# ✅ Encontrado: ลพบุรี, ถนนใหญ่, Mueang Lop Buri, จังหวัดลพบุรี, 15000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 135/520: Mae Hong Son
# 🔍 Buscando: 'Mae Hong Son' (name_only)
# ✅ Encontrado: จังหวัดแม่ฮ่องสอน, ประเทศไทย (score: 0.50, nivel: fair)
#
# 🔄 Procesando sitio 136/520: Erawan
# 🔍 Buscando: 'Erawan' (name_only)
# ✅ Encontrado: Erawan, จังหวัดเลย, 42220, ประเทศไทย (score: 0.24, nivel: poor)
#
# 🔄 Procesando sitio 137/520: Isan
# 🔍 Buscando: 'Isan' (name_only)
# ✅ Encontrado: 이산면, 영주시, 경상북도, 36170, 대한민국 (score: 0.28, nivel: poor)
#
# 🔄 Procesando sitio 138/520: Ayutthaya Historical Park
# 🔍 Buscando: 'Ayutthaya Historical Park' (name_only)
# ✅ Encontrado: อุทยานประวัติศาสตร์พระนครศรีอยุธยา, ตำบลประตูชัย, เทศบาลนครพระนครศรีอยุธยา, อำเภอพระนครศรีอยุธยา, จังหวัดพระนครศรีอยุธยา, 13000, ประเทศไทย (score: 0.41, nivel: poor)
#
# 🔄 Procesando sitio 139/520: Elephant Sanctuary
# 🔍 Buscando: 'Elephant Sanctuary' (name_only)
# ✅ Encontrado: Elephant Sanctuary, 107, บ้านทุ่งศรีทอง, บ้านแม่มาลัย, จอมแจ้ง, Mae Taeng, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 140/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
# 📈 Progreso: 140/520 sitios procesados
#
# 🔄 Procesando sitio 141/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
#
# 🔄 Procesando sitio 142/520: Chumphon
# 🔍 Buscando: 'Chumphon' (name_only)
# ✅ Encontrado: ชุมพร, บางหมาก, Mueang Chumphon, จังหวัดชุมพร, 86000, ประเทศไทย (score: 0.37, nivel: poor)
#
# 🔄 Procesando sitio 143/520: Pagoda Royal
# 🔍 Buscando: 'Pagoda Royal' (name_only)
# ✅ Encontrado: The Royal Pagoda, 995, North Broadway, New Chinatown, Chinatown, Los Angeles, Los Angeles County, California, 90012, United States (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 144/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
#
# 🔄 Procesando sitio 145/520: Gran Buda Blanco
# 🔍 Buscando: 'Gran Buda Blanco' (name_only)
# ❌ No encontrado: Gran Buda Blanco
#
# 🔄 Procesando sitio 146/520: Wat Rong Khun
# 🔍 Buscando: 'Wat Rong Khun' (name_only)
# ✅ Encontrado: Wat Rong Khun, ถนนร่องขุ่น, บ้านสันดอนแก้ว, บ้านร่องขุ่น, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.33, nivel: poor)
#
# 🔄 Procesando sitio 147/520: Templo Azul
# 🔍 Buscando: 'Templo Azul' (name_only)
# ✅ Encontrado: Calle Templo de San Juan, San Juan, León, Guanajuato, 37295, México (score: 0.05, nivel: poor)
#
# 🔄 Procesando sitio 148/520: Triángulo de Oro
# 🔍 Buscando: 'Triángulo de Oro' (name_only)
# ✅ Encontrado: Triángulo de Oro, Melilla, 52001, España (score: 0.13, nivel: poor)
#
# 🔄 Procesando sitio 149/520: Panwa Beach
# 🔍 Buscando: 'Panwa Beach' (name_only)
# ✅ Encontrado: Panwa Beach, ตำบลวิชิต, อำเภอเมืองภูเก็ต, จังหวัดภูเก็ต, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 150/520: Maya Bay
# 🔍 Buscando: 'Maya Bay' (name_only)
# ✅ Encontrado: Maya Bay, Rue Jaufré Rudel, Zone Commerciale de Purpan, Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan, Toulouse, Haute-Garonne, Occitanie, France métropolitaine, 31300, France (score: 0.00, nivel: poor)
# 📈 Progreso: 150/520 sitios procesados
#
# 🔄 Procesando sitio 151/520: Koh Phi Phi Don
# 🔍 Buscando: 'Koh Phi Phi Don' (name_only)
# ✅ Encontrado: เกาะพีพีดอน, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 152/520: Viking Nature Resort
# 🔍 Buscando: 'Viking Nature Resort' (name_only)
# ❌ No encontrado: Viking Nature Resort
#
# 🔄 Procesando sitio 153/520: Siam District
# 🔍 Buscando: 'Siam District' (name_only)
# ✅ Encontrado: district, ถนนราษฎร์บูรณะ, แขวงราษฎร์บูรณะ, เขตราษฎร์บูรณะ, กรุงเทพมหานคร, 10140, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 154/520: MBK Center
# 🔍 Buscando: 'MBK Center' (name_only)
# ✅ Encontrado: MBK Center, ถนนพญาไท, แขวงวังใหม่, เขตปทุมวัน, กรุงเทพมหานคร, 10330, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 155/520: Siam Paragon
# 🔍 Buscando: 'Siam Paragon' (name_only)
# ✅ Encontrado: Siam Paragon, 991, ถนนพระรามที่ 1, สยาม, แขวงปทุมวัน, เขตปทุมวัน, กรุงเทพมหานคร, 10330, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 156/520: Grand Palace of Bangkok
# 🔍 Buscando: 'Grand Palace of Bangkok' (name_only)
# ❌ No encontrado: Grand Palace of Bangkok
#
# 🔄 Procesando sitio 157/520: Bridge over the River Kwai
# 🔍 Buscando: 'Bridge over the River Kwai' (name_only)
# ❌ No encontrado: Bridge over the River Kwai
#
# 🔄 Procesando sitio 158/520: Erawan National Park
# 🔍 Buscando: 'Erawan National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเอราวัณ, Si Sawat, จังหวัดกาญจนบุรี, ประเทศไทย (score: 0.37, nivel: poor)
#
# 🔄 Procesando sitio 159/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 160/520: Wat Rong Suea Ten
# 🔍 Buscando: 'Wat Rong Suea Ten' (name_only)
# ✅ Encontrado: วัดร่องเสือเต้น, ถนนวัดร่องเสือเต้น, รั้วเหล็กเหนือ, ห้วยปลากั้ง, เทศบาลนครเชียงราย, แม่ยาว, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.13, nivel: poor)
# 📈 Progreso: 160/520 sitios procesados
#
# 🔄 Procesando sitio 161/520: Night Bazaar
# 🔍 Buscando: 'Night Bazaar' (name_only)
# ✅ Encontrado: Night Bazaar, Ward 104 Kondapur, Greater Hyderabad Municipal Corporation West Zone, Hyderabad, Serilingampalle mandal, Ranga Reddy, Telangana, India (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 162/520: Singha Park
# 🔍 Buscando: 'Singha Park' (name_only)
# ✅ Encontrado: สิงห์ปาร์ค, บ้านแม่กรณ์, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.08, nivel: poor)
#
# 🔄 Procesando sitio 163/520: Khun Korn Waterfall
# 🔍 Buscando: 'Khun Korn Waterfall' (name_only)
# ✅ Encontrado: ขุนกรฌ์ (ฝนตกปิด), Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.13, nivel: poor)
#
# 🔄 Procesando sitio 164/520: Huai Pla Kang
# 🔍 Buscando: 'Huai Pla Kang' (name_only)
# ✅ Encontrado: ห้วยปลากั้ง, บ้านป่าบงน้ำล้อม, บ้านน้ำแพร่ใต้, ยางฮอม, Khun Tan, จังหวัดเชียงราย, 57340, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 165/520: Mae Fah Luang Garden
# 🔍 Buscando: 'Mae Fah Luang Garden' (name_only)
# ✅ Encontrado: สวนแม่ฟ้าหลวง The Mae Fah Luang Garden, ถนนห้วยไคร้ - ห้วยน้ำริน, บัานผาหมี, บ้านผาฮี้, อำเภอแม่สาย, เวียงพางคำ, Mae Sai, จังหวัดเชียงราย, 57130, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 166/520: Ao Nang
# 🔍 Buscando: 'Ao Nang' (name_only)
# ✅ Encontrado: ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 167/520: Railay
# 🔍 Buscando: 'Railay' (name_only)
# ✅ Encontrado: อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 168/520: Koh Phi Phi
# 🔍 Buscando: 'Koh Phi Phi' (name_only)
# ✅ Encontrado: Koh Phi Phi, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 169/520: Koh Lanta
# 🔍 Buscando: 'Koh Lanta' (name_only)
# ✅ Encontrado: Koh Lanta, Gorriti, Palermo Hollywood, Palermo, Buenos Aires, Distrito Audiovisual, Comuna 14, Ciudad Autónoma de Buenos Aires, C1414DKE, Argentina (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 170/520: Ko Yao Noi
# 🔍 Buscando: 'Ko Yao Noi' (name_only)
# ✅ Encontrado: เกาะยาวน้อย, แหลมยาง, เกาะยาวใหญ่, Ko Yao, จังหวัดพังงา, ประเทศไทย (score: 0.17, nivel: poor)
# 📈 Progreso: 170/520 sitios procesados
#
# 🔄 Procesando sitio 171/520: Pattaya
# 🔍 Buscando: 'Pattaya' (name_only)
# ✅ Encontrado: เมืองพัทยา, หนองปลาไหล, Bang Lamung, จังหวัดชลบุรี, ประเทศไทย (score: 0.56, nivel: fair)
#
# 🔄 Procesando sitio 172/520: Elephant Nature Park
# 🔍 Buscando: 'Elephant Nature Park' (name_only)
# ✅ Encontrado: Elephant Nature Park, 1, ชม.3052, บ้านแม่ตะมาน, แม่แตง, Mae Taeng, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 173/520: Thai Massage
# 🔍 Buscando: 'Thai Massage' (name_only)
# ✅ Encontrado: Thai Massage, 27, Neue Bahnhofstraße, Friedrichshain, Friedrichshain-Kreuzberg, Berlin, 10245, Deutschland (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 174/520: Thai Cuisine
# 🔍 Buscando: 'Thai Cuisine' (name_only)
# ✅ Encontrado: Thai Cuisine, Foothill Boulevard, Highway Highlands, Glendale, Los Angeles County, California, 91214, United States (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 175/520: Gran Palacio
# 🔍 Buscando: 'Gran Palacio' (name_only)
# ✅ Encontrado: Grand Palais, Avenue de Selves, Quartier des Champs-Élysées, Paris 8e Arrondissement, Paris, France métropolitaine, 75008, France (score: 0.56, nivel: fair)
#
# 🔄 Procesando sitio 176/520: Gran Palacio
# 🔍 Buscando: 'Gran Palacio' (name_only)
# ✅ Encontrado: Grand Palais, Avenue de Selves, Quartier des Champs-Élysées, Paris 8e Arrondissement, Paris, France métropolitaine, 75008, France (score: 0.56, nivel: fair)
#
# 🔄 Procesando sitio 177/520: Parque Nacional Erawan
# 🔍 Buscando: 'Parque Nacional Erawan' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเอราวัณ, Si Sawat, จังหวัดกาญจนบุรี, ประเทศไทย (score: 0.37, nivel: poor)
#
# 🔄 Procesando sitio 178/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 179/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 180/520: White Temple
# 🔍 Buscando: 'White Temple' (name_only)
# ✅ Encontrado: วัดร่องขุ่น, ถนนร่องขุ่น, บ้านสันดอนแก้ว, บ้านร่องขุ่น, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.33, nivel: poor)
# 📈 Progreso: 180/520 sitios procesados
#
# 🔄 Procesando sitio 181/520: Blue Temple
# 🔍 Buscando: 'Blue Temple' (name_only)
# ✅ Encontrado: Blue Temple, ถนนวัดร่องเสือเต้น, รั้วเหล็กเหนือ, ห้วยปลากั้ง, เทศบาลนครเชียงราย, แม่ยาว, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 182/520: Golden Triangle
# 🔍 Buscando: 'Golden Triangle' (name_only)
# ✅ Encontrado: Golden Triangle, Cherry Hill Township, Camden County, New Jersey, United States (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 183/520: Elephant Nature Park
# 🔍 Buscando: 'Elephant Nature Park' (name_only)
# ✅ Encontrado: Elephant Nature Park, 1, ชม.3052, บ้านแม่ตะมาน, แม่แตง, Mae Taeng, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 184/520: Doi Inthanon
# 🔍 Buscando: 'Doi Inthanon' (name_only)
# ✅ Encontrado: ดอยอินทนนท์, Doi Inthanon, 1009, Mae Chaem, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 185/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
#
# 🔄 Procesando sitio 186/520: James Bond Island
# 🔍 Buscando: 'James Bond Island' (name_only)
# ✅ Encontrado: เขาตะปู, จังหวัดพังงา, ประเทศไทย (score: 0.13, nivel: poor)
#
# 🔄 Procesando sitio 187/520: Ao Nang
# 🔍 Buscando: 'Ao Nang' (name_only)
# ✅ Encontrado: ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 188/520: Marina Resort Cliffhanger
# 🔍 Buscando: 'Marina Resort Cliffhanger' (name_only)
# ❌ No encontrado: Marina Resort Cliffhanger
#
# 🔄 Procesando sitio 189/520: Railay Beach
# 🔍 Buscando: 'Railay Beach' (name_only)
# ✅ Encontrado: Railay Beach Café, Railay promenade, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 190/520: Ao Phra Nang
# 🔍 Buscando: 'Ao Phra Nang' (name_only)
# ✅ Encontrado: หาดพระนาง, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย (score: 0.11, nivel: poor)
# 📈 Progreso: 190/520 sitios procesados
#
# 🔄 Procesando sitio 191/520: Phi Phi Islands
# 🔍 Buscando: 'Phi Phi Islands' (name_only)
# ✅ Encontrado: หมู่เกาะพีพี, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 192/520: Koh Hong
# 🔍 Buscando: 'Koh Hong' (name_only)
# ✅ Encontrado: Koh Thai, 雲咸街 Wyndham Street, SoHo, 半山 Mid-Levels, 中西區 Central and Western District, 香港島 Hong Kong Island, 香港 Hong Kong, 中国 (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 193/520: Koh Poda
# 🔍 Buscando: 'Koh Poda' (name_only)
# ✅ Encontrado: เกาะปอดะ, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย (score: 0.23, nivel: poor)
#
# 🔄 Procesando sitio 194/520: Koh Lipe
# 🔍 Buscando: 'Koh Lipe' (name_only)
# ✅ Encontrado: Koh Lipe, 35, Baldwin Street, Kensington-Chinatown, University—Rosedale, Toronto, Golden Horseshoe, Ontario, M5T 1L1, Canada (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 195/520: Khao Sok National Park
# 🔍 Buscando: 'Khao Sok National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเขาสก, Ban Ta Khun, จังหวัดสุราษฎร์ธานี, 84230, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 196/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 197/520: Templo Blanco
# 🔍 Buscando: 'Templo Blanco' (name_only)
# ✅ Encontrado: Wat Rong Khun, ถนนร่องขุ่น, บ้านสันดอนแก้ว, บ้านร่องขุ่น, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.33, nivel: poor)
#
# 🔄 Procesando sitio 198/520: Templo Azul
# 🔍 Buscando: 'Templo Azul' (name_only)
# ✅ Encontrado: Calle Templo de San Juan, San Juan, León, Guanajuato, 37295, México (score: 0.05, nivel: poor)
#
# 🔄 Procesando sitio 199/520: Triángulo Dorado
# 🔍 Buscando: 'Triángulo Dorado' (name_only)
# ✅ Encontrado: Triángulo Dorado, Carrera 113, Villas de Granada, UPZs Localidad Engativá, Localidad Engativá, Bogotá, Bogotá, Distrito Capital, RAP (Especial) Central, 111031, Colombia (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 200/520: Elephant Nature Park
# 🔍 Buscando: 'Elephant Nature Park' (name_only)
# ✅ Encontrado: Elephant Nature Park, 1, ชม.3052, บ้านแม่ตะมาน, แม่แตง, Mae Taeng, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.26, nivel: poor)
# 📈 Progreso: 200/520 sitios procesados
#
# 🔄 Procesando sitio 201/520: Doi Inthanon
# 🔍 Buscando: 'Doi Inthanon' (name_only)
# ✅ Encontrado: ดอยอินทนนท์, Doi Inthanon, 1009, Mae Chaem, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 202/520: Pai
# 🔍 Buscando: 'Pai' (name_only)
# ✅ Encontrado: 拜城县, ئاقسۇ ۋىلايىتى - 阿克苏地区, 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی, 中国 (score: 0.46, nivel: poor)
#
# 🔄 Procesando sitio 203/520: Muay Thai combat
# 🔍 Buscando: 'Muay Thai combat' (name_only)
# ✅ Encontrado: maximum Muay Thai combat center, ถนนทวีวงศ์, ป่าตอง, ตำบลป่าตอง, อำเภอกะทู้, จังหวัดภูเก็ต, 83150, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 204/520: Ao Nang
# 🔍 Buscando: 'Ao Nang' (name_only)
# ✅ Encontrado: ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย (score: 0.31, nivel: poor)
#
# 🔄 Procesando sitio 205/520: Railay Beach
# 🔍 Buscando: 'Railay Beach' (name_only)
# ✅ Encontrado: Railay Beach Café, Railay promenade, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 206/520: Ao Phra Nang
# 🔍 Buscando: 'Ao Phra Nang' (name_only)
# ✅ Encontrado: หาดพระนาง, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 207/520: Koh Hong
# 🔍 Buscando: 'Koh Hong' (name_only)
# ✅ Encontrado: Koh Thai, 雲咸街 Wyndham Street, SoHo, 半山 Mid-Levels, 中西區 Central and Western District, 香港島 Hong Kong Island, 香港 Hong Kong, 中国 (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 208/520: Koh Poda
# 🔍 Buscando: 'Koh Poda' (name_only)
# ✅ Encontrado: เกาะปอดะ, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย (score: 0.23, nivel: poor)
#
# 🔄 Procesando sitio 209/520: Koh Racha
# 🔍 Buscando: 'Koh Racha' (name_only)
# ✅ Encontrado: Ra Ya Father Resort, Koh Racha Yai, จังหวัดภูเก็ต, 83100, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 210/520: Estados Unidos
# 🔍 Buscando: 'Estados Unidos' (name_only)
# ✅ Encontrado: United States (score: 1.00, nivel: excellent)
# 📈 Progreso: 210/520 sitios procesados
#
# 🔄 Procesando sitio 211/520: Tailandia
# 🔍 Buscando: 'Tailandia' (name_only)
# ✅ Encontrado: Tailândia, Região Geográfica Imediata de Abaetetuba, Região Geográfica Intermediária de Belém, Pará, Região Norte, 68695-000, Brasil (score: 0.44, nivel: poor)
#
# 🔄 Procesando sitio 212/520: Japón
# 🔍 Buscando: 'Japón' (name_only)
# ✅ Encontrado: 日本 (score: 0.93, nivel: excellent)
#
# 🔄 Procesando sitio 213/520: México
# 🔍 Buscando: 'México' (name_only)
# ✅ Encontrado: México (score: 0.88, nivel: good)
#
# 🔄 Procesando sitio 214/520: Costa Rica
# 🔍 Buscando: 'Costa Rica' (name_only)
# ✅ Encontrado: Costa Rica (score: 0.76, nivel: good)
#
# 🔄 Procesando sitio 215/520: Kanchanaburi
# 🔍 Buscando: 'Kanchanaburi' (name_only)
# ✅ Encontrado: กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 216/520: Koh Samet
# 🔍 Buscando: 'Koh Samet' (name_only)
# ✅ Encontrado: เกาะเสม็ด, อ่าวกิวนาใน, Mueang Rayong, จังหวัดระยอง, ประเทศไทย (score: 0.34, nivel: poor)
#
# 🔄 Procesando sitio 217/520: Koh Lanta Yai
# 🔍 Buscando: 'Koh Lanta Yai' (name_only)
# ❌ No encontrado: Koh Lanta Yai
#
# 🔄 Procesando sitio 218/520: Railay
# 🔍 Buscando: 'Railay' (name_only)
# ✅ Encontrado: อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 219/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
#
# 🔄 Procesando sitio 220/520: Surat Thani
# 🔍 Buscando: 'Surat Thani' (name_only)
# ✅ Encontrado: เทศบาลนครสุราษฎร์ธานี, วัดประดู่, Mueang Surat Thani, จังหวัดสุราษฎร์ธานี, 84000, ประเทศไทย (score: 0.45, nivel: poor)
# 📈 Progreso: 220/520 sitios procesados
#
# 🔄 Procesando sitio 221/520: Blanco Hideout Railay
# 🔍 Buscando: 'Blanco Hideout Railay' (name_only)
# ✅ Encontrado: Blanco Hideout Hostel, Railay promenade, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 222/520: Railay Princess Resort
# 🔍 Buscando: 'Railay Princess Resort' (name_only)
# ✅ Encontrado: Railay Princess Resort & Spa, Railay promenade, อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 223/520: Rayavadee
# 🔍 Buscando: 'Rayavadee' (name_only)
# ✅ Encontrado: Rayavadee, Olofsgatan, Klara, Norrmalm, Norra innerstadens stadsdelsområde, Stockholm, Stockholms kommun, Stockholms län, 111 37, Sverige (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 224/520: Bloom Hostel
# 🔍 Buscando: 'Bloom Hostel' (name_only)
# ✅ Encontrado: Bloom Hostel, 188, Cours de la Somme, Bordeaux, Port de la Lune, Nansouty - Saint-Genès, Bordeaux, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33800, France (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 225/520: Wapi Resort
# 🔍 Buscando: 'Wapi Resort' (name_only)
# ✅ Encontrado: Wapi Resort, ถนนคนเดินหลีเป๊ะ, หาดพัทยา, บ้านเกาะหลีเป๊ะ, Mueang Satun, จังหวัดสตูล, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 226/520: Akira Lipe Resort
# 🔍 Buscando: 'Akira Lipe Resort' (name_only)
# ❌ No encontrado: Akira Lipe Resort
#
# 🔄 Procesando sitio 227/520: Chumphon Archipelago
# 🔍 Buscando: 'Chumphon Archipelago' (name_only)
# ❌ No encontrado: Chumphon Archipelago
#
# 🔄 Procesando sitio 228/520: Phuket
# 🔍 Buscando: 'Phuket' (name_only)
# ✅ Encontrado: จังหวัดภูเก็ต, ประเทศไทย (score: 0.54, nivel: fair)
#
# 🔄 Procesando sitio 229/520: Khao Yai National Park
# 🔍 Buscando: 'Khao Yai National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเขาใหญ่, จังหวัดปราจีนบุรี, ประเทศไทย (score: 0.45, nivel: poor)
#
# 🔄 Procesando sitio 230/520: Erawan National Park
# 🔍 Buscando: 'Erawan National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเอราวัณ, Si Sawat, จังหวัดกาญจนบุรี, ประเทศไทย (score: 0.37, nivel: poor)
# 📈 Progreso: 230/520 sitios procesados
#
# 🔄 Procesando sitio 231/520: Khao Sok National Park
# 🔍 Buscando: 'Khao Sok National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเขาสก, Ban Ta Khun, จังหวัดสุราษฎร์ธานี, 84230, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 232/520: Khao Sam Roi Yot National Park
# 🔍 Buscando: 'Khao Sam Roi Yot National Park' (name_only)
# ✅ Encontrado: อุทยานแห่งชาติเขาสามร้อยยอด, Sam Roi Yot, จังหวัดประจวบคีรีขันธ์, ประเทศไทย (score: 0.39, nivel: poor)
#
# 🔄 Procesando sitio 233/520: Maha Vajiralongkorn
# 🔍 Buscando: 'Maha Vajiralongkorn' (name_only)
# ❌ No encontrado: Maha Vajiralongkorn
#
# 🔄 Procesando sitio 234/520: Bombay
# 🔍 Buscando: 'Bombay' (name_only)
# ✅ Encontrado: Mumbai Suburban, Maharashtra, India (score: 0.71, nivel: good)
#
# 🔄 Procesando sitio 235/520: New York
# 🔍 Buscando: 'New York' (name_only)
# ✅ Encontrado: City of New York, New York, United States (score: 0.87, nivel: good)
#
# 🔄 Procesando sitio 236/520: Jordania
# 🔍 Buscando: 'Jordania' (name_only)
# ✅ Encontrado: الأردن (score: 0.77, nivel: good)
#
# 🔄 Procesando sitio 237/520: Sri Lanka
# 🔍 Buscando: 'Sri Lanka' (name_only)
# ✅ Encontrado: Sri Lanka (score: 0.78, nivel: good)
#
# 🔄 Procesando sitio 238/520: Bali
# 🔍 Buscando: 'Bali' (name_only)
# ✅ Encontrado: Bali, Nusa Tenggara, Indonesia (score: 0.64, nivel: fair)
#
# 🔄 Procesando sitio 239/520: El Hierro
# 🔍 Buscando: 'El Hierro' (name_only)
# ✅ Encontrado: El Hierro, Santa Cruz de Tenerife, Canarias, España (score: 0.52, nivel: fair)
#
# 🔄 Procesando sitio 240/520: Zanzíbar
# 🔍 Buscando: 'Zanzíbar' (name_only)
# ✅ Encontrado: Zanzibar City مدينة زنجبار, Mjini, Unguja Mjini Magharibi, Zanzibar زنجبار, 71109, Tanzania (score: 0.48, nivel: poor)
# 📈 Progreso: 240/520 sitios procesados
#
# 🔄 Procesando sitio 241/520: Sarria
# 🔍 Buscando: 'Sarria' (name_only)
# ✅ Encontrado: Sarria, Lugo, Galicia, España (score: 0.50, nivel: fair)
#
# 🔄 Procesando sitio 242/520: Tenerife
# 🔍 Buscando: 'Tenerife' (name_only)
# ✅ Encontrado: Tenerife, Canarias, España (score: 0.63, nivel: fair)
#
# 🔄 Procesando sitio 243/520: Estambul
# 🔍 Buscando: 'Estambul' (name_only)
# ✅ Encontrado: İstanbul, Fatih, İstanbul, Marmara Bölgesi, 34122, Türkiye (score: 0.77, nivel: good)
#
# 🔄 Procesando sitio 244/520: Alemania
# 🔍 Buscando: 'Alemania' (name_only)
# ✅ Encontrado: Deutschland (score: 0.95, nivel: excellent)
#
# 🔄 Procesando sitio 245/520: Zaanse Schans
# ...
#
# 🔄 Procesando sitio 463/520: Elephant Jungle Sanctuary
# 🔍 Buscando: 'Elephant Jungle Sanctuary' (name_only)
# ✅ Encontrado: Elephant Jungle Sanctuary Phuket, 2/12, ถนนวิชิตสงคราม, กะทู้, ตำบลกะทู้, อำเภอกะทู้, จังหวัดภูเก็ต, 83120, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 464/520: Wat Phra That Doi Suthep
# 🔍 Buscando: 'Wat Phra That Doi Suthep' (name_only)
# ✅ Encontrado: วัดพระธาตุดอยสุเทพราชวรวิหาร, ถนนห้วยแก้ว, ป่าแดด, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 465/520: Doi Suthep
# 🔍 Buscando: 'Doi Suthep' (name_only)
# ✅ Encontrado: ดอยสุเทพ, บ้านภูพิงค์ฯ, ป่าแดด, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 466/520: White Temple
# 🔍 Buscando: 'White Temple' (name_only)
# ✅ Encontrado: วัดร่องขุ่น, ถนนร่องขุ่น, บ้านสันดอนแก้ว, บ้านร่องขุ่น, ป่าอ้อดอนชัย, Mueang Chiang Rai, จังหวัดเชียงราย, ประเทศไทย (score: 0.33, nivel: poor)
#
# 🔄 Procesando sitio 467/520: Blue Temple
# 🔍 Buscando: 'Blue Temple' (name_only)
# ✅ Encontrado: Blue Temple, ถนนวัดร่องเสือเต้น, รั้วเหล็กเหนือ, ห้วยปลากั้ง, เทศบาลนครเชียงราย, แม่ยาว, Mueang Chiang Rai, จังหวัดเชียงราย, 57000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 468/520: Tiger Kingdom
# 🔍 Buscando: 'Tiger Kingdom' (name_only)
# ✅ Encontrado: Tiger Kingdom, เลียบถนนคลองชลประทาน, แม่ริม, ริมเหนือ, Mae Rim, จังหวัดเชียงใหม่, 50180, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 469/520: Sukhothai
# 🔍 Buscando: 'Sukhothai' (name_only)
# ✅ Encontrado: สุโขทัย, Mueang Sukhothai, จังหวัดสุโขทัย, ประเทศไทย (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 470/520: Kanchanaburi
# 🔍 Buscando: 'Kanchanaburi' (name_only)
# ✅ Encontrado: กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย (score: 0.43, nivel: poor)
# 📈 Progreso: 470/520 sitios procesados
#
# 🔄 Procesando sitio 471/520: Mae Hong Song
# 🔍 Buscando: 'Mae Hong Song' (name_only)
# ✅ Encontrado: จังหวัดแม่ฮ่องสอน, ประเทศไทย (score: 0.50, nivel: fair)
#
# 🔄 Procesando sitio 472/520: Mae Kampong
# 🔍 Buscando: 'Mae Kampong' (name_only)
# ✅ Encontrado: Nam Mae Kampong, บ้านปางมะโน, Mae On, จังหวัดเชียงใหม่, ประเทศไทย (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 473/520: Nong Khai
# 🔍 Buscando: 'Nong Khai' (name_only)
# ✅ Encontrado: จังหวัดหนองคาย, ประเทศไทย (score: 0.50, nivel: poor)
#
# 🔄 Procesando sitio 474/520: Phitsanulok
# 🔍 Buscando: 'Phitsanulok' (name_only)
# ✅ Encontrado: จังหวัดพิษณุโลก, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 475/520: Guía Tailandia
# 🔍 Buscando: 'Guía Tailandia' (name_only)
# ❌ No encontrado: Guía Tailandia
#
# 🔄 Procesando sitio 476/520: Ayutthaya
# 🔍 Buscando: 'Ayutthaya' (name_only)
# ✅ Encontrado: จังหวัดพระนครศรีอยุธยา, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 477/520: Elephant Nature Park
# 🔍 Buscando: 'Elephant Nature Park' (name_only)
# ✅ Encontrado: Elephant Nature Park, 1, ชม.3052, บ้านแม่ตะมาน, แม่แตง, Mae Taeng, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.26, nivel: poor)
#
# 🔄 Procesando sitio 478/520: Maeklong Market
# 🔍 Buscando: 'Maeklong Market' (name_only)
# ✅ Encontrado: ตลาดร่มหุบ, ถนนเพชรสมุทร, ชุมสาย, สมุทรสงคราม, อำเภอเมืองสมุทรสงคราม, จังหวัดสมุทรสงคราม, 75000, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 479/520: Damnoen Saduak Floating Market
# 🔍 Buscando: 'Damnoen Saduak Floating Market' (name_only)
# ✅ Encontrado: Damnoen Saduak Floating Market, รบ.3003, ดำเนินสะดวก, ศรีดอนไผ่, อำเภอดำเนินสะดวก, จังหวัดราชบุรี, 70130, ประเทศไทย (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 480/520: Madrid
# 🔍 Buscando: 'Madrid' (name_only)
# ✅ Encontrado: Madrid, Comunidad de Madrid, España (score: 0.81, nivel: good)
# 📈 Progreso: 480/520 sitios procesados
#
# 🔄 Procesando sitio 481/520: Khon Kaen Airport
# 🔍 Buscando: 'Khon Kaen Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานขอนแก่น, ซอย 6, ศิริการ์เด้น 2, บ้านสุภัทรา, บ้านเป็ด, อำเภอเมืองขอนแก่น, จังหวัดขอนแก่น, 40000, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 482/520: Ubon Ratchathani Airport
# 🔍 Buscando: 'Ubon Ratchathani Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานอุบลราชธานี, ชยางกูร 2.1, ตำบลในเมือง, เทศบาลนครอุบลราชธานี, ปทุม, อำเภอเมืองอุบลราชธานี, จังหวัดอุบลราชธานี, 34000, ประเทศไทย (score: 0.39, nivel: poor)
#
# 🔄 Procesando sitio 483/520: Bangkok Suvarnabhumi Airport
# 🔍 Buscando: 'Bangkok Suvarnabhumi Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานสุวรรณภูมิ, ถนนสุวรรณภูมิ 4, แขวงลาดกระบัง, เขตลาดกระบัง, กรุงเทพมหานคร, องค์การบริหารส่วนตำบลหนองปรือ, อำเภอบางพลี, จังหวัดสมุทรปราการ, 10520, ประเทศไทย (score: 0.53, nivel: fair)
#
# 🔄 Procesando sitio 484/520: Bangkok Don Mueang International Airport
# 🔍 Buscando: 'Bangkok Don Mueang International Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานดอนเมือง, ถนนพหลโยธิน, แขวงสนามบิน, เขตดอนเมือง, กรุงเทพมหานคร, 10210, ประเทศไทย (score: 0.51, nivel: fair)
#
# 🔄 Procesando sitio 485/520: Chiang Rai Airport
# 🔍 Buscando: 'Chiang Rai Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานเชียงราย, 404, ถนน ท่าอากาศยานนานาชาติแม่ฟ้าหลวง, บ้านดู่, นางแล, Mueang Chiang Rai, จังหวัดเชียงราย, 57100, ประเทศไทย (score: 0.41, nivel: poor)
#
# 🔄 Procesando sitio 486/520: Udon Thani Airport
# 🔍 Buscando: 'Udon Thani Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติอุดรธานี, ซอยพรมประกาย, เทศบาลนครอุดรธานี, หนองสำโรง, อำเภอเมืองอุดรธานี, จังหวัดอุดรธานี, 41000, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 487/520: Trat Airport
# 🔍 Buscando: 'Trat Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานตราด, 3156, แหลมงอบ, Khao Saming, จังหวัดตราด, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 488/520: Chiang Mai International Airport
# 🔍 Buscando: 'Chiang Mai International Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติเชียงใหม่, 60, ถนนสวนดอก, สุเทพ, ป่าแดด, Mueang Chiang Mai, จังหวัดเชียงใหม่, 50200, ประเทศไทย (score: 0.45, nivel: poor)
#
# 🔄 Procesando sitio 489/520: Koh Samui Airport
# 🔍 Buscando: 'Koh Samui Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติสมุย, Phatong Residence, บ้านปลายแหลม, Ko Samui, จังหวัดสุราษฎร์ธานี, 84320, ประเทศไทย (score: 0.41, nivel: poor)
#
# 🔄 Procesando sitio 490/520: Mae Hong Son Airport
# 🔍 Buscando: 'Mae Hong Son Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานแม่ฮ่องสอน, ถนนประชาอุทิศ, แม่ฮ่องสอน, Mueang Mae Hong Son, จังหวัดแม่ฮ่องสอน, 58000, ประเทศไทย (score: 0.38, nivel: poor)
# 📈 Progreso: 490/520 sitios procesados
#
# 🔄 Procesando sitio 491/520: Nakhon Si Thammarat Airport
# 🔍 Buscando: 'Nakhon Si Thammarat Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาตินครศรีธรรมราช, 4103, ท่าแพ, ปากพูน, Mueang Nakhon Si Thammarat, จังหวัดนครศรีธรรมราช, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 492/520: Phuket International Airport
# 🔍 Buscando: 'Phuket International Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติภูเก็ต, ถนนเทพกระษัตรี, ตำบลไม้ขาว, ป่าคลอก, อำเภอถลาง, จังหวัดภูเก็ต, 83140, ประเทศไทย (score: 0.49, nivel: poor)
#
# 🔄 Procesando sitio 493/520: Rayong Utapao Rayong Pattaya Airport
# 🔍 Buscando: 'Rayong Utapao Rayong Pattaya Airport' (name_only)
# ❌ No encontrado: Rayong Utapao Rayong Pattaya Airport
#
# 🔄 Procesando sitio 494/520: Hua Hin Airport
# 🔍 Buscando: 'Hua Hin Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานหัวหิน, ถนนเพชรเกษม, ตะวันสีทอง, หัวหิน, อำเภอหัวหิน, จังหวัดประจวบคีรีขันธ์, 77110, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 495/520: Buri Ram Airport
# 🔍 Buscando: 'Buri Ram Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานบุรีรัมย, 219, ตำบลร่อนทอง, อำเภอสตึก, ศรีสตึก, จังหวัดบุรีรัมย์, 31150, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 496/520: Trang Airport
# 🔍 Buscando: 'Trang Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานตรัง, 404, ตรัง, โคกหล่อ, Mueang Trang, จังหวัดตรัง, 92000, ประเทศไทย (score: 0.38, nivel: poor)
#
# 🔄 Procesando sitio 497/520: Surat Thani Airport
# 🔍 Buscando: 'Surat Thani Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานสุราษฎร์ธานี, 4291, Phunphin, จังหวัดสุราษฎร์ธานี, ประเทศไทย (score: 0.40, nivel: poor)
#
# 🔄 Procesando sitio 498/520: Hat Yai Airport
# 🔍 Buscando: 'Hat Yai Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติหาดใหญ่, 99, บ้านโปะหมอ-กองบิน 56, โคกม่วง, Khlong Hoi Khong, จังหวัดสงขลา, 90115, ประเทศไทย (score: 0.42, nivel: poor)
#
# 🔄 Procesando sitio 499/520: Krabi International Airport
# 🔍 Buscando: 'Krabi International Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานนานาชาติกระบี่, 4, Nuea Khlong, จังหวัดกระบี่, ประเทศไทย (score: 0.43, nivel: poor)
#
# 🔄 Procesando sitio 500/520: Sukhothai Airport
# 🔍 Buscando: 'Sukhothai Airport' (name_only)
# ✅ Encontrado: ท่าอากาศยานสุโขทัย, สท.4013, บ้านหนองป่าตอ, บ้านขอนซุง, เมืองบางขลัง, Sawankhalok, จังหวัดสุโขทัย, ประเทศไทย (score: 0.37, nivel: poor)
# 📈 Progreso: 500/520 sitios procesados
#
# 🔄 Procesando sitio 501/520: Lufthansa
# 🔍 Buscando: 'Lufthansa' (name_only)
# ✅ Encontrado: Lufthansa, 18, Rue Hamdani Lahcene, Paradou, Résidence Palmira, Hydra ⵃⵉⴷⵔⴰ حيدرة, Bir Mourad Raïs, Alger, 16405, Algérie ⵍⵣⵣⴰⵢⴻⵔ الجزائر (score: 0.62, nivel: fair)
#
# 🔄 Procesando sitio 502/520: KLM
# 🔍 Buscando: 'KLM' (name_only)
# ✅ Encontrado: KLM, 55, Amsterdamseweg, Amstelveen, Noord-Holland, Nederland, 1182 GP, Nederland (score: 0.59, nivel: fair)
#
# 🔄 Procesando sitio 503/520: British Airways
# 🔍 Buscando: 'British Airways' (name_only)
# ✅ Encontrado: British Airways, T1 - T3 walkway, Ringway, Wythenshawe, Manchester, Greater Manchester, England, M90 1QD, United Kingdom (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 504/520: Delta
# 🔍 Buscando: 'Delta' (name_only)
# ✅ Encontrado: Delta County, Texas, United States (score: 0.59, nivel: fair)
#
# 🔄 Procesando sitio 505/520: SWISS
# 🔍 Buscando: 'SWISS' (name_only)
# ✅ Encontrado: Schweiz/Suisse/Svizzera/Svizra (score: 0.88, nivel: good)
#
# 🔄 Procesando sitio 506/520: Turkish Airlines
# 🔍 Buscando: 'Turkish Airlines' (name_only)
# ✅ Encontrado: Turkish Airlines, 35, Валовая улица, район Замоскворечье, Москва, Центральный федеральный округ, 115054, Россия (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 507/520: Iberia
# 🔍 Buscando: 'Iberia' (name_only)
# ✅ Encontrado: Iberia, España (score: 0.69, nivel: fair)
#
# 🔄 Procesando sitio 508/520: United Airlines
# 🔍 Buscando: 'United Airlines' (name_only)
# ✅ Encontrado: United Airlines, 11555, West Touhy Avenue, Chicago, Elk Grove Township, Cook County, Illinois, 60666, United States (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 509/520: Air France
# 🔍 Buscando: 'Air France' (name_only)
# ✅ Encontrado: Air France, 37, Allées de Tourny, Bordeaux, Port de la Lune, Bordeaux Centre, Bordeaux, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33000, France (score: 0.62, nivel: fair)
#
# 🔄 Procesando sitio 510/520: Austrian Airlines
# 🔍 Buscando: 'Austrian Airlines' (name_only)
# ✅ Encontrado: Austrian Airlines, Aeroporti, Vrellë, Vrellë e Goleshit, Komuna e Lipjanit / Opština Lipljan, Rajoni i Prishtinës / Prištinski okrug, 10070, Kosova / Kosovo (score: 0.00, nivel: poor)
# 📈 Progreso: 510/520 sitios procesados
#
# 🔄 Procesando sitio 511/520: Emirates
# 🔍 Buscando: 'Emirates' (name_only)
# ✅ Encontrado: طيران الإمارات, طريق المطار, مطار دبي الدولي, دبي, الإمارات العربية المتحدة (score: 0.30, nivel: poor)
#
# 🔄 Procesando sitio 512/520: Qatar Airways
# 🔍 Buscando: 'Qatar Airways' (name_only)
# ✅ Encontrado: Qatar Airways, Karlstraße, Königsplatz, Maxvorstadt, München, Bayern, 80333, Deutschland (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 513/520: Air Canada
# 🔍 Buscando: 'Air Canada' (name_only)
# ✅ Encontrado: Air Canada, St. Anthony's Way, Radius Park, Bedfont, London Borough of Hounslow, London, Greater London, England, TW14 0NG, United Kingdom (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 514/520: Scandinavian Airlines
# 🔍 Buscando: 'Scandinavian Airlines' (name_only)
# ✅ Encontrado: Scandinavian Airlines, 10000, Lower Express Road, O'hare Express North, O'Hare, Chicago, Jefferson Township, Cook County, Illinois, 60666, United States (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 515/520: Alaska Airlines
# 🔍 Buscando: 'Alaska Airlines' (name_only)
# ✅ Encontrado: Alaska Airlines, SeaTac, King County, Washington, United States (score: 0.11, nivel: poor)
#
# 🔄 Procesando sitio 516/520: Finnair
# 🔍 Buscando: 'Finnair' (name_only)
# ✅ Encontrado: Bolt Arena, 5, Urheilukatu, Eläintarha, Taka-Töölö, Eteläinen suurpiiri, Helsinki, Helsingin seutukunta, Uusimaa, Manner-Suomi, 00250, Suomi / Finland (score: 0.41, nivel: poor)
#
# 🔄 Procesando sitio 517/520: Etihad Airways
# 🔍 Buscando: 'Etihad Airways' (name_only)
# ✅ Encontrado: etihad airways, جناح ایونیو, French Colony, ایف-7, اسلام آباد, زون 1, وفاقی دارالحکومت اسلام آباد, 44000, پاکستان (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 518/520: TAP Portugal
# 🔍 Buscando: 'TAP Portugal' (name_only)
# ✅ Encontrado: TAP Portugal, 72, Sienna, Mirów, Wola, Warszawa, województwo mazowieckie, 00-833, Polska (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 519/520: Singapore Airlines
# 🔍 Buscando: 'Singapore Airlines' (name_only)
# ✅ Encontrado: Singapore Airlines, 2, Orchard Turn, Cairnhill, Orchard Road, Orchard, Central, Singapore, 238801, Singapore (score: 0.00, nivel: poor)
#
# 🔄 Procesando sitio 520/520: Cathay Pacific
# 🔍 Buscando: 'Cathay Pacific' (name_only)
# ✅ Encontrado: Cathay Pacific, 25, Via Giovanni Battista Pergolesi, Centrale, Municipio 2, Milano, Lombardia, 20124, Italia (score: 0.00, nivel: poor)
# 📈 Progreso: 520/520 sitios procesados
#
# 🎉 PROCESAMIENTO COMPLETADO
# ============================================================
# 📊 Resultados:
#    • Sitios procesados: 520
#    • Sitios encontrados: 420
#    • Tasa de éxito: 80.8%
#
# 🏆 Calidad de matches:
#    • Poor: 277 (66.0%)
#    • Good: 72 (17.1%)
#    • Fair: 59 (14.0%)
#    • Excellent: 12 (2.9%)
#
# 💾 Archivo guardado en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl
#
# 📋 EJEMPLOS DE RESULTADOS (primeros 10)
# ============================================================
# 📍 Tailandia
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 185612
#    • Wikipedia: N/A
#    • Coordenadas: -2.9360960, -48.9523366
#    • Calidad: poor (0.44)
#    • Búsqueda usada: name_only
#
# 📍 Bangkok
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 92277
#    • Wikipedia: N/A
#    • Coordenadas: 13.7524938, 100.4935089
#    • Calidad: good (0.72)
#    • Búsqueda usada: name_only
#
# 📍 Chiang Mai
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 18271830
#    • Wikipedia: N/A
#    • Coordenadas: 18.7882778, 98.9858802
#    • Calidad: fair (0.57)
#    • Búsqueda usada: name_only
#
# 📍 Doi Suthep
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 2082718893
#    • Wikipedia: N/A
#    • Coordenadas: 18.8166077, 98.8923600
#    • Calidad: poor (0.30)
#    • Búsqueda usada: name_only
#
# 📍 Phi Phi Islands
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 6099530
#    • Wikipedia: N/A
#    • Coordenadas: 7.7522403, 98.7766434
#    • Calidad: poor (0.11)
#    • Búsqueda usada: name_only
#
# 📍 Sukhothai Historical Park
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 538179351
#    • Wikipedia: N/A
#    • Coordenadas: 17.0203334, 99.7038571
#    • Calidad: poor (0.42)
#    • Búsqueda usada: name_only
#
# 📍 Sukhothai
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 249060591
#    • Wikipedia: N/A
#    • Coordenadas: 17.0109180, 99.8203682
#    • Calidad: poor (0.30)
#    • Búsqueda usada: name_only
#
# 📍 Thai Thai Sukhothai Resort
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 6153256886
#    • Wikipedia: N/A
#    • Coordenadas: 16.9555585, 99.9776818
#    • Calidad: poor (0.00)
#    • Búsqueda usada: name_only
#
# 📍 Koh Lipe
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: True
#    • OSM ID: 11800686902
#    • Wikipedia: N/A
#    • Coordenadas: 43.6558832, -79.3934500
#    • Calidad: poor (0.00)
#    • Búsqueda usada: name_only
#
# 📍 Serendipity Beach Resort Koh Lipe
#    • Ciudad: N/A
#    • País: N/A
#    • Encontrado: False
#    • No encontrado en Nominatim
#
#
# 🎯 RESUMEN FINAL:
#    • Total de sitios procesados: 520
#    • Sitios encontrados: 420
#    • Tasa de éxito: 80.8%
#    • Distribución por calidad: {'poor': 277, 'good': 72, 'fair': 59, 'excellent': 12}

# %% [markdown]
# ## We short the elements by the number of appearences

# %%
import json
from pathlib import Path
from collections import defaultdict

def ordenar_por_appearances(input_path, output_path):
    """Ordena las entidades por appearances de forma descendente"""
    
    print("🔄 ORDENANDO ENTIDADES POR APARICIONES")
    print("=" * 50)
    print(f"📥 Entrada: {input_path}")
    print(f"📤 Salida: {output_path}")
    print()
    
    # Cargar todas las entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f"�� Total de entidades cargadas: {len(entidades)}")
    
    # Ordenar por appearances (descendente)
    entidades_ordenadas = sorted(
        entidades, 
        key=lambda x: x.get('appearances', 0), 
        reverse=True
    )
    
    # Guardar ordenadas
    with open(output_path, 'w', encoding='utf-8') as f:
        for entidad in entidades_ordenadas:
            f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
    
    print(f"✅ Entidades ordenadas y guardadas en: {output_path}")
    
    # Mostrar top 20
    print(f"\n🏆 TOP 20 POR APARICIONES:")
    print("-" * 50)
    
    for i, entidad in enumerate(entidades_ordenadas[:20], 1):
        nombre = entidad.get('name', 'Sin nombre')
        appearances = entidad.get('appearances', 0)
        tipo = entidad.get('entity_type', 'sin_tipo')
        subtipo = entidad.get('subtype', 'N/A')
        
        print(f"{i:2d}. {nombre}")
        print(f"     • Apariciones: {appearances}")
        print(f"     • Tipo: {tipo}")
        print(f"     • Subtipo: {subtipo}")
        
        # Mostrar datos de Nominatim si existen
        nominatim_data = entidad.get('nominatim_match', {})
        if nominatim_data.get('found'):
            quality = nominatim_data.get('quality_level', 'N/A')
            score = nominatim_data.get('quality_score', 0)
            print(f"     • Nominatim: {quality} ({score:.2f})")
        
        print()
    
    # Estadísticas generales
    total_appearances = sum(e.get('appearances', 0) for e in entidades_ordenadas)
    avg_appearances = total_appearances / len(entidades_ordenadas) if entidades_ordenadas else 0
    
    print(f"📈 ESTADÍSTICAS:")
    print(f"   • Total de apariciones: {total_appearances}")
    print(f"   • Promedio de apariciones: {avg_appearances:.1f}")
    print(f"   • Máximo de apariciones: {entidades_ordenadas[0].get('appearances', 0) if entidades_ordenadas else 0}")
    print(f"   • Mínimo de apariciones: {entidades_ordenadas[-1].get('appearances', 0) if entidades_ordenadas else 0}")
    
    return {
        'total_entidades': len(entidades_ordenadas),
        'total_appearances': total_appearances,
        'max_appearances': entidades_ordenadas[0].get('appearances', 0) if entidades_ordenadas else 0,
        'min_appearances': entidades_ordenadas[-1].get('appearances', 0) if entidades_ordenadas else 0
    }

# Ejecutar ordenamiento
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo de entrada
input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
    print("�� Asegúrate de haber ejecutado el editor primero")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    stats = ordenar_por_appearances(input_file, output_file)
    print(f"\n🎉 ¡Ordenamiento completado!")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
# 🔄 ORDENANDO ENTIDADES POR APARICIONES
# ==================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# �� Total de entidades cargadas: 481
# ✅ Entidades ordenadas y guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# 🏆 TOP 20 POR APARICIONES:
# --------------------------------------------------
#  1. Chiang Rai
#      • Apariciones: 5
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: poor (0.47)
#
#  2. Sukhothai
#      • Apariciones: 4
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: poor (0.30)
#
#  3. Krabi
#      • Apariciones: 4
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: poor (0.44)
#
#  4. Pai
#      • Apariciones: 4
#      • Tipo: sin_tipo
#      • Subtipo: city
#
#  5. Doi Inthanon
#      • Apariciones: 4
#      • Tipo: site
#      • Subtipo: mountain
#      • Nominatim: poor (0.42)
#
#  6. Koh Lipe
#      • Apariciones: 4
#      • Tipo: sin_tipo
#      • Subtipo: island
#
#  7. Ayutthaya
#      • Apariciones: 4
#      • Tipo: sin_tipo
#      • Subtipo: city
#
#  8. Lopburi
#      • Apariciones: 4
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: poor (0.43)
#
#  9. Chiang Mai
#      • Apariciones: 3
#      • Tipo: sin_tipo
#      • Subtipo: city
#
# 10. Pattaya
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: fair (0.56)
#
# 11. Phuket
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: fair (0.54)
#
# 12. Kanchanaburi
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: poor (0.43)
#
# 13. Phitsanulok
#      • Apariciones: 3
#      • Tipo: sin_tipo
#      • Subtipo: city
#
# 14. Railay
#      • Apariciones: 3
#      • Tipo: sin_tipo
#      • Subtipo: beach
#
# 15. Bangkok
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: city
#      • Nominatim: good (0.72)
#
# 16. Koh Tao
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: island
#
# 17. Koh Lanta
#      • Apariciones: 3
#      • Tipo: site
#      • Subtipo: island
#
# 18. Koh Phangan
#      • Apariciones: 2
#      • Tipo: site
#      • Subtipo: island
#      • Nominatim: poor (0.41)
#
# 19. Phuket
#      • Apariciones: 2
#      • Tipo: site
#      • Subtipo: island
#      • Nominatim: fair (0.54)
#
# 20. Koh Samui
#      • Apariciones: 2
#      • Tipo: site
#      • Subtipo: island
#      • Nominatim: poor (0.47)
#
# 📈 ESTADÍSTICAS:
#    • Total de apariciones: 567
#    • Promedio de apariciones: 1.2
#    • Máximo de apariciones: 5
#    • Mínimo de apariciones: 1
#
# 🎉 ¡Ordenamiento completado!

# %% [markdown]
# ## We match the entities by name and subtype

# %%
import json
from pathlib import Path
from collections import defaultdict

def agrupar_por_nombre_subtipo(input_path, output_path):
    """Agrupa entidades que tengan el mismo nombre y subtipo"""
    
    print("🔄 AGRUPANDO ENTIDADES POR NOMBRE Y SUBTIPO")
    print("=" * 50)
    print(f"📥 Entrada: {input_path}")
    print(f"📤 Salida: {output_path}")
    print()
    
    # Cargar todas las entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f"�� Total de entidades cargadas: {len(entidades)}")
    
    # Agrupar por nombre y subtipo
    grupos = defaultdict(list)
    
    for entidad in entidades:
        nombre = entidad.get('name', '').strip().lower()
        subtipo = entidad.get('subtype', '').strip().lower()
        
        if nombre and subtipo:
            clave = (nombre, subtipo)
            grupos[clave].append(entidad)
    
    # Crear entidades agrupadas
    entidades_agrupadas = []
    grupos_procesados = 0
    
    for (nombre, subtipo), entidades_grupo in grupos.items():
        if len(entidades_grupo) > 1:
            # Hay múltiples entidades para agrupar
            print(f"🔄 Agrupando: '{nombre}' (subtipo: {subtipo}) - {len(entidades_grupo)} entidades")
            
            # Tomar la primera entidad como base
            base = dict(entidades_grupo[0])
            
            # Combinar datos
            descripciones = []
            todas_imagenes = []
            websites = []
            todas_urls = []
            source_urls = []
            
            # Procesar todas las entidades del grupo
            for entidad in entidades_grupo:
                # Descripciones
                desc = entidad.get('description', '').strip()
                if desc and desc not in descripciones:
                    descripciones.append(desc)
                
                # Imágenes
                imagenes = entidad.get('images', [])
                if isinstance(imagenes, list):
                    todas_imagenes.extend(imagenes)
                
                # Websites
                website = entidad.get('official_website', '').strip()
                if website and website not in websites:
                    websites.append(website)
                
                # URLs de origen
                url = entidad.get('source_url', '').strip()
                if url and url not in todas_urls:
                    todas_urls.append(url)
                
                # URLs de origen (campo all_source_urls)
                all_urls = entidad.get('all_source_urls', [])
                if isinstance(all_urls, list):
                    source_urls.extend(all_urls)
            
            # Actualizar la entidad base
            if descripciones:
                base['description'] = " | ".join(descripciones)
            
            if todas_imagenes:
                base['images'] = list(set(todas_imagenes))  # Eliminar duplicados
            
            if websites:
                base['official_website'] = " | ".join(websites)
            
            if todas_urls:
                base['source_url'] = todas_urls[0]  # Mantener la primera como principal
                base['all_source_urls'] = list(set(source_urls + todas_urls))  # Combinar todas
            
            # Añadir contador de apariciones
            base['appearances'] = len(entidades_grupo)
            
            # Añadir información de agrupación
            base['agrupado_por'] = f"nombre_subtipo: {nombre}_{subtipo}"
            base['entidades_originales'] = len(entidades_grupo)
            
            entidades_agrupadas.append(base)
            grupos_procesados += 1
            
        else:
            # Solo una entidad, añadir sin cambios
            entidades_agrupadas.append(entidades_grupo[0])
    
    # Guardar resultados
    with open(output_path, 'w', encoding='utf-8') as f:
        for entidad in entidades_agrupadas:
            f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
    
    # Estadísticas
    print(f"\n�� AGRUPACIÓN COMPLETADA")
    print("=" * 50)
    print(f"📊 Estadísticas:")
    print(f"   • Entidades originales: {len(entidades)}")
    print(f"   • Entidades finales: {len(entidades_agrupadas)}")
    print(f"   • Grupos procesados: {grupos_procesados}")
    print(f"   • Entidades eliminadas: {len(entidades) - len(entidades_agrupadas)}")
    print(f"   • Reducción: {((len(entidades) - len(entidades_agrupadas)) / len(entidades) * 100):.1f}%")
    
    # Mostrar ejemplos de agrupaciones
    print(f"\n📋 EJEMPLOS DE AGRUPACIONES:")
    print("-" * 50)
    
    for i, entidad in enumerate(entidades_agrupadas[:10], 1):
        nombre = entidad.get('name', 'Sin nombre')
        subtipo = entidad.get('subtype', 'N/A')
        appearances = entidad.get('appearances', 1)
        
        if appearances > 1:
            print(f"{i}. {nombre} ({subtipo})")
            print(f"   • Apariciones: {appearances}")
            print(f"   • Descripción: {entidad.get('description', 'N/A')[:100]}...")
            print()
    
    return {
        'entidades_originales': len(entidades),
        'entidades_finales': len(entidades_agrupadas),
        'grupos_procesados': grupos_procesados,
        'reduccion_porcentual': ((len(entidades) - len(entidades_agrupadas)) / len(entidades) * 100)
    }

# Ejecutar agrupación
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo de entrada
input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
    print(" Asegúrate de haber ejecutado el ordenamiento primero")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    stats = agrupar_por_nombre_subtipo(input_file, output_file)
    print(f"\n🎉 ¡Agrupación completada!")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
# 🔄 AGRUPANDO ENTIDADES POR NOMBRE Y SUBTIPO
# ==================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# �� Total de entidades cargadas: 1015
# 🔄 Agrupando: 'thailand' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'phuket' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'bangkok' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'koh samui' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'koh tao' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'krabi' (subtipo: province) - 2 entidades
# 🔄 Agrupando: 'ayutthaya' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'sukhothai' (subtipo: city) - 4 entidades
# 🔄 Agrupando: 'chiang rai' (subtipo: city) - 5 entidades
# 🔄 Agrupando: 'chiang mai' (subtipo: city) - 3 entidades
# 🔄 Agrupando: 'krabi' (subtipo: city) - 4 entidades
# 🔄 Agrupando: 'islas phi phi' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'koh chang' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'lopburi' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'pai' (subtipo: city) - 4 entidades
# 🔄 Agrupando: 'koh lipe' (subtipo: island) - 3 entidades
# 🔄 Agrupando: 'pattaya' (subtipo: city) - 3 entidades
# 🔄 Agrupando: 'similan islands' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'sukhothai historical park' (subtipo: historical park) - 2 entidades
# 🔄 Agrupando: 'phuket' (subtipo: city) - 3 entidades
# 🔄 Agrupando: 'wat rong khun' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'kanchanaburi' (subtipo: city) - 3 entidades
# 🔄 Agrupando: 'koh samet' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'vietnam' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'phitsanulok' (subtipo: city) - 3 entidades
# 🔄 Agrupando: 'doi suthep' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'khao sok national park' (subtipo: national park) - 2 entidades
# 🔄 Agrupando: 'koh lanta' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'koh kood' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'wat pho' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'erawan waterfalls' (subtipo: waterfall) - 2 entidades
# 🔄 Agrupando: 'isan' (subtipo: region) - 2 entidades
# 🔄 Agrupando: 'elephant nature park' (subtipo: sanctuary) - 2 entidades
# 🔄 Agrupando: 'doi inthanon' (subtipo: mountain) - 4 entidades
# 🔄 Agrupando: 'ao nang' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'wat phra that doi suthep' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'nan' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'koh yao yai' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'ao nang' (subtipo: beach) - 2 entidades
# 🔄 Agrupando: 'koh muk' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'big buddha phuket' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'wat chalong' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'railay' (subtipo: beach) - 3 entidades
# 🔄 Agrupando: 'railay' (subtipo: peninsula) - 2 entidades
# 🔄 Agrupando: 'cambodia' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'malaysia' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'laos' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'templo azul' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'koh phi phi' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'elephant nature park' (subtipo: park) - 2 entidades
# 🔄 Agrupando: 'new york' (subtipo: city) - 2 entidades
# 🔄 Agrupando: 'bali' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'tenerife' (subtipo: island) - 2 entidades
# 🔄 Agrupando: 'portugal' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'camboya' (subtipo: country) - 2 entidades
# 🔄 Agrupando: 'wat mahathat' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'wat phra singh temple' (subtipo: temple) - 2 entidades
# 🔄 Agrupando: 'bridge over the river kwai' (subtipo: bridge) - 2 entidades
# 🔄 Agrupando: 'vatican museums' (subtipo: museum) - 2 entidades
#
# �� AGRUPACIÓN COMPLETADA
# ==================================================
# 📊 Estadísticas:
#    • Entidades originales: 1015
#    • Entidades finales: 481
#    • Grupos procesados: 59
#    • Entidades eliminadas: 534
#    • Reducción: 52.6%
#
# 📋 EJEMPLOS DE AGRUPACIONES:
# --------------------------------------------------
# 1. Thailand (country)
#    • Apariciones: 2
#    • Descripción: Diverse country with attractions for all tastes, known for its hospitality, delicious cuisine, and b...
#
# 2. Phuket (island)
#    • Apariciones: 2
#    • Descripción: Popular island destination in Thailand. | Phuket is the largest island in Thailand, known for its di...
#
# 3. Bangkok (city)
#    • Apariciones: 2
#    • Descripción: Capital city of Thailand with a mix of modernity and tradition, known for its bustling streets, vibr...
#
# 4. Koh Samui (island)
#    • Apariciones: 2
#    • Descripción: The top island destination in Thailand, particularly popular for family tourism. Known for luxury re...
#
# 5. Phi Phi Islands (archipielago)
#    • Apariciones: 13
#    • Descripción: Famous island group in Thailand known for its beaches and clear turquoise waters. Includes Koh Phi P...
#
# 6. Koh Tao (island)
#    • Apariciones: 2
#    • Descripción: Island on the east coast of Thailand known for diving and beautiful beaches | A renowned island in t...
#
# 7. Krabi (province)
#    • Apariciones: 2
#    • Descripción: Krabi is a province in Thailand known for its stunning limestone cliffs and beautiful beaches. The m...
#
# 8. Ayutthaya (city)
#    • Apariciones: 2
#    • Descripción: Ancient capital of the Kingdom of Siam, a UNESCO World Heritage Site with a collection of temples an...
#
# 9. Sukhothai (city)
#    • Apariciones: 4
#    • Descripción: Historical city in Thailand | The first capital of the Kingdom of Siam, known for its historical par...
#
# 10. Chiang Rai (city)
#    • Apariciones: 5
#    • Descripción: Chiang Rai is a serene city in northern Thailand, famous for its unique temples, scenic landscapes, ...
#
#
# 🎉 ¡Agrupación completada!

# %%
import json
from pathlib import Path
from collections import defaultdict

def calcular_apariciones_desde_4(input_path_4):
    """Calcula apariciones usando el campo appearances existente"""
    
    print("🔄 CALCULANDO APARICIONES DESDE ENRICHED_DATA_4.JSONL")
    print("=" * 60)
    print(f"📥 Entrada: {input_path_4}")
    print()
    
    # Cargar entidades del archivo 4
    entidades = []
    with open(input_path_4, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades cargadas: {len(entidades)}")
    
    # Agrupar por nombre y subtipo, SUMANDO appearances existentes
    apariciones_por_entidad = defaultdict(int)
    
    for entidad in entidades:
        nombre = entidad.get('name', '').strip().lower()
        subtipo = entidad.get('subtype', '').strip().lower()
        appearances = entidad.get('appearances', 1)  # ← USAR EL CAMPO EXISTENTE
        
        if nombre and subtipo:
            clave = (nombre, subtipo)
            apariciones_por_entidad[clave] += appearances  # ← SUMAR appearances
    
    print(f"📈 Entidades únicas encontradas: {len(apariciones_por_entidad)}")
    
    # Mostrar top 10 por apariciones
    print(f"\n🏆 TOP 10 POR APARICIONES:")
    print("-" * 50)
    
    sorted_apariciones = sorted(apariciones_por_entidad.items(), key=lambda x: x[1], reverse=True)
    
    for i, ((nombre, subtipo), count) in enumerate(sorted_apariciones[:10], 1):
        print(f"{i:2d}. {nombre} ({subtipo}): {count} apariciones")
    
    return apariciones_por_entidad
def actualizar_y_ordenar_5(input_path_5, output_path_5, estructura_apariciones):
    """Actualiza apariciones en 5 y ordena por apariciones descendentes"""
    
    print(f"\n🔄 ACTUALIZANDO Y ORDENANDO ENRICHED_DATA_5.JSONL")
    print("=" * 60)
    print(f"📥 Entrada: {input_path_5}")
    print(f"📤 Salida: {output_path_5}")
    print()
    
    # Cargar entidades del archivo 5
    entidades_actualizadas = []
    
    with open(input_path_5, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidad = json.loads(line)
                
                # Buscar apariciones para esta entidad
                nombre = entidad.get('name', '').strip().lower()
                subtipo = entidad.get('subtype', '').strip().lower()
                
                if nombre and subtipo:
                    clave = (nombre, subtipo)
                    apariciones_calculadas = estructura_apariciones.get(clave, 1)
                    
                    # Actualizar appearances
                    entidad['appearances'] = apariciones_calculadas
                    print(f"✅ {nombre} ({subtipo}): {apariciones_calculadas} apariciones")
                
                entidades_actualizadas.append(entidad)
    
    # ORDENAR por apariciones descendentes
    entidades_ordenadas = sorted(
        entidades_actualizadas, 
        key=lambda x: x.get('appearances', 0), 
        reverse=True
    )
    
    # Guardar archivo ordenado
    with open(output_path_5, 'w', encoding='utf-8') as f:
        for entidad in entidades_ordenadas:
            f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
    
    print(f"\n📊 RESUMEN:")
    print(f"   • Entidades procesadas: {len(entidades_ordenadas)}")
    print(f"   • Archivo guardado: {output_path_5}")
    
    # Mostrar top 10 del archivo final
    print(f"\n🏆 TOP 10 FINAL:")
    print("-" * 50)
    
    for i, entidad in enumerate(entidades_ordenadas[:10], 1):
        nombre = entidad.get('name', 'Sin nombre')
        subtipo = entidad.get('subtype', 'N/A')
        appearances = entidad.get('appearances', 0)
        print(f"{i:2d}. {nombre} ({subtipo}): {appearances} apariciones")

# Ejecutar el proceso completo
input_file_4 = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl"
input_file_5 = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_file_5 = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar archivos
path_4 = Path(input_file_4)
path_5 = Path(input_file_5)

if not path_4.exists():
    print(f"❌ ERROR: No existe enriched_data_4.jsonl")
elif not path_5.exists():
    print(f"❌ ERROR: No existe enriched_data_5.jsonl")
else:
    print("✅ Archivos encontrados, iniciando proceso...")
    
    # Paso 1: Calcular apariciones desde archivo 4
    estructura_apariciones = calcular_apariciones_desde_4(input_file_4)
    
    # Paso 2: Actualizar apariciones en archivo 5 y ordenar
    actualizar_y_ordenar_5(input_file_5, output_file_5, estructura_apariciones)
    
    print(f"\n🎉 ¡PROCESO COMPLETADO!")
    print(f"📁 Archivo actualizado y ordenado: {output_file_5}")
# Out:
# ✅ Archivos encontrados, iniciando proceso...
# 🔄 CALCULANDO APARICIONES DESDE ENRICHED_DATA_4.JSONL
# ============================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_4.jsonl
#
#  Entidades cargadas: 1049
# 📈 Entidades únicas encontradas: 488
#
# 🏆 TOP 10 POR APARICIONES:
# --------------------------------------------------
#  1. tailandia (country): 36 apariciones
#  2. bangkok (city): 32 apariciones
#  3. ayutthaya (city): 26 apariciones
#  4. chiang rai (city): 25 apariciones
#  5. koh samui (island): 23 apariciones
#  6. phuket (island): 21 apariciones
#  7. sukhothai (city): 19 apariciones
#  8. koh lipe (island): 19 apariciones
#  9. koh tao (island): 19 apariciones
# 10. krabi (city): 15 apariciones
#
# 🔄 ACTUALIZANDO Y ORDENANDO ENRICHED_DATA_5.JSONL
# ============================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# ✅ chiang rai (city): 25 apariciones
# ✅ sukhothai (city): 19 apariciones
# ✅ krabi (city): 15 apariciones
# ✅ pai (city): 8 apariciones
# ✅ doi inthanon (mountain): 5 apariciones
# ✅ koh lipe (island): 19 apariciones
# ✅ ayutthaya (city): 26 apariciones
# ✅ lopburi (city): 9 apariciones
# ✅ chiang mai (city): 12 apariciones
# ✅ pattaya (city): 6 apariciones
# ✅ phuket (city): 7 apariciones
# ✅ kanchanaburi (city): 5 apariciones
# ✅ phitsanulok (city): 5 apariciones
# ✅ railay (beach): 3 apariciones
# ✅ bangkok (city): 32 apariciones
# ✅ koh tao (island): 19 apariciones
# ✅ koh lanta (island): 7 apariciones
# ✅ koh phangan (island): 12 apariciones
# ✅ phuket (island): 21 apariciones
# ✅ koh samui (island): 23 apariciones
# ✅ krabi (province): 14 apariciones
# ✅ islas phi phi (island): 7 apariciones
# ✅ koh chang (island): 7 apariciones
# ✅ similan islands (island): 5 apariciones
# ✅ sukhothai historical park (historical park): 4 apariciones
# ✅ wat rong khun (temple): 4 apariciones
# ✅ koh samet (island): 4 apariciones
# ✅ vietnam (country): 5 apariciones
# ✅ doi suthep (temple): 3 apariciones
# ✅ khao sok national park (national park): 4 apariciones
# ✅ koh kood (island): 3 apariciones
# ✅ wat pho (temple): 3 apariciones
# ✅ erawan waterfalls (waterfall): 3 apariciones
# ✅ isan (region): 3 apariciones
# ✅ elephant nature park (sanctuary): 3 apariciones
# ✅ ao nang (city): 3 apariciones
# ✅ wat phra that doi suthep (temple): 3 apariciones
# ✅ nan (city): 3 apariciones
# ✅ koh yao yai (island): 2 apariciones
# ✅ ao nang (beach): 2 apariciones
# ✅ koh muk (island): 2 apariciones
# ✅ big buddha phuket (temple): 2 apariciones
# ✅ wat chalong (temple): 2 apariciones
# ✅ railay (peninsula): 2 apariciones
# ✅ cambodia (country): 2 apariciones
# ✅ malaysia (country): 2 apariciones
# ✅ laos (country): 2 apariciones
# ✅ templo azul (temple): 2 apariciones
# ✅ koh phi phi (island): 2 apariciones
# ✅ elephant nature park (park): 2 apariciones
# ✅ new york (city): 2 apariciones
# ✅ bali (island): 2 apariciones
# ✅ tenerife (island): 2 apariciones
# ✅ portugal (country): 2 apariciones
# ✅ camboya (country): 2 apariciones
# ✅ wat mahathat (temple): 2 apariciones
# ✅ wat phra singh temple (temple): 2 apariciones
# ✅ bridge over the river kwai (bridge): 2 apariciones
# ✅ vatican museums (museum): 2 apariciones
# ✅ indonesia (country): 4 apariciones
# ✅ phi phi islands (archipielago): 13 apariciones
# ✅ kanchannaburi (city): 6 apariciones
# ✅ mae hong son (province): 4 apariciones
# ✅ koh yao noi (island): 3 apariciones
# ✅ chumphon (province): 3 apariciones
# ✅ wat phra singh (temple): 3 apariciones
# ✅ bahía de phang nga (bay): 3 apariciones
# ✅ maya bay (beach): 3 apariciones
# ✅ james bond island (island): 3 apariciones
# ✅ phi phi (city): 3 apariciones
# ✅ koh samui (city): 3 apariciones
# ✅ thailand (country): 1 apariciones
# ✅ nakhon si thammarat (city): 1 apariciones
# ✅ wat arun (temple): 2 apariciones
# ✅ damnoen saduak floating market (floating market): 2 apariciones
# ✅ phuket (site): 2 apariciones
# ✅ wat chiang man (temple): 2 apariciones
# ✅ khao yai national park (national park): 2 apariciones
# ✅ parque nacional khao yai (national park): 2 apariciones
# ✅ islas phi phi (island group): 2 apariciones
# ✅ white temple (temple): 2 apariciones
# ✅ blue temple (temple): 2 apariciones
# ✅ golden triangle (landmark): 2 apariciones
# ✅ ao phra nang (beach): 2 apariciones
# ✅ koh lanta yai (island): 2 apariciones
# ✅ phuket (province): 2 apariciones
# ✅ jordania (country): 2 apariciones
# ✅ alemania (country): 2 apariciones
# ✅ wat umong (temple): 2 apariciones
# ✅ wat si chum (temple): 2 apariciones
# ✅ koh tao (city): 2 apariciones
# ✅ bahía railay (city): 2 apariciones
# ✅ koh munnork (city): 2 apariciones
# ✅ wat chedi luang (temple): 2 apariciones
# ✅ sukhothai historical park (historical complex): 1 apariciones
# ✅ ayutthaya (archaeological park): 1 apariciones
# ✅ chiang rai (province): 1 apariciones
# ✅ mae hong son (town): 1 apariciones
# ✅ gran palacio real (landmark): 1 apariciones
# ✅ río chao phraya (river): 1 apariciones
# ✅ taling chang floating market (floating market): 1 apariciones
# ✅ amphawa floating market (floating market): 1 apariciones
# ✅ mae klong railway market (railway market): 1 apariciones
# ✅ pai (village): 1 apariciones
# ✅ phuket (peninsula): 1 apariciones
# ✅ phi phi islands (archipelago): 1 apariciones
# ✅ sukhothai (province): 1 apariciones
# ✅ similan islands (marine park): 1 apariciones
# ✅ ko nang yuan (island): 1 apariciones
# ✅ chumphon pinnacles (diving site): 1 apariciones
# ✅ htms sattakut (diving site): 1 apariciones
# ✅ white rock (diving site): 1 apariciones
# ✅ mirador john-suwan (viewpoint): 1 apariciones
# ✅ mirador ko nang yuan (viewpoint): 1 apariciones
# ✅ bophut (beach): 1 apariciones
# ✅ chaweng noi (beach): 1 apariciones
# ✅ mae name (beach): 1 apariciones
# ✅ lamai (beach): 1 apariciones
# ✅ taling ngam (beach): 1 apariciones
# ✅ resorts (resort): 1 apariciones
# ✅ hotels (hotel): 1 apariciones
# ✅ spas (spa): 1 apariciones
# ✅ restaurants (restaurant): 1 apariciones
# ✅ bars (bar): 1 apariciones
# ✅ nightclubs (nightclub): 1 apariciones
# ✅ walking in the forest (activity): 1 apariciones
# ✅ mountain climbing (activity): 1 apariciones
# ✅ fisherman’s village (site): 1 apariciones
# ✅ elephant sanctuary (site): 1 apariciones
# ✅ mu ko ang thong national park (national park): 1 apariciones
# ✅ tarnim and magic garden (garden): 1 apariciones
# ✅ wat plai laem (temple): 1 apariciones
# ✅ wat phra yai (temple): 1 apariciones
# ✅ coconut tasting (activity): 1 apariciones
# ✅ fishing (activity): 1 apariciones
# ✅ banyan tree samui (accommodation): 1 apariciones
# ✅ the ritz-carlton (accommodation): 1 apariciones
# ✅ vintage-style hotel (accommodation): 1 apariciones
# ✅ songthaews (activity): 1 apariciones
# ✅ grab (activity): 1 apariciones
# ✅ navigo (activity): 1 apariciones
# ✅ taxi (activity): 1 apariciones
# ✅ motorcycle rental (activity): 1 apariciones
# ✅ car rental (activity): 1 apariciones
# ✅ bangkok (site): 1 apariciones
# ✅ koh tao (site): 1 apariciones
# ✅ ayutthaya (site): 1 apariciones
# ✅ krabi (site): 1 apariciones
# ✅ hua hin (site): 1 apariciones
# ✅ ko chang (site): 1 apariciones
# ✅ ko lanta (site): 1 apariciones
# ✅ karon beach (beach): 1 apariciones
# ✅ bang tao beach (beach): 1 apariciones
# ✅ ao sane beach (beach): 1 apariciones
# ✅ mai khao beach (beach): 1 apariciones
# ✅ surfing (activity): 1 apariciones
# ✅ kayaking (activity): 1 apariciones
# ✅ jetskiing (activity): 1 apariciones
# ✅ snorkeling (activity): 1 apariciones
# ✅ scuba diving (activity): 1 apariciones
# ✅ parasailing (activity): 1 apariciones
# ✅ suvarnabhumi airport (airport): 1 apariciones
# ✅ don muang airport (airport): 1 apariciones
# ✅ hualamphong station (train station): 1 apariciones
# ✅ erawan national park (national park): 1 apariciones
# ✅ ko samui (island): 1 apariciones
# ✅ palacio real o gran palacio (palace): 1 apariciones
# ✅ mercado de fin de semana en chatuchak (market): 1 apariciones
# ✅ chinatown (neighborhood): 1 apariciones
# ✅ distrito de siam (district): 1 apariciones
# ✅ chiang khan (town): 1 apariciones
# ✅ wat pa phu kon (temple): 1 apariciones
# ✅ phanom rung (historical site): 1 apariciones
# ✅ kanchanaburi (town): 1 apariciones
# ✅ templo blanco (wat rong khun) (temple): 1 apariciones
# ✅ buri ram (city): 1 apariciones
# ✅ ao nang (town): 1 apariciones
# ✅ ratchaburi (city): 1 apariciones
# ✅ samut songkhram (province): 1 apariciones
# ✅ tours en tailandia (tours): 1 apariciones
# ✅ phang nga bay (bay): 1 apariciones
# ✅ mae hong son (city): 1 apariciones
# ✅ parque nacional khao sok (national park): 1 apariciones
# ✅ marino de ang thong (island): 1 apariciones
# ✅ erawan (waterfall): 1 apariciones
# ✅ ayutthaya historical park (historical park): 1 apariciones
# ✅ elephant sanctuary (sanctuary): 1 apariciones
# ✅ multipaís (country): 1 apariciones
# ✅ chumphon (city): 1 apariciones
# ✅ pagoda royal (temple): 1 apariciones
# ✅ pai (town): 1 apariciones
# ✅ gran buda blanco (monument): 1 apariciones
# ✅ triángulo de oro (landmark): 1 apariciones
# ✅ panwa beach (beach): 1 apariciones
# ✅ koh phi phi don (island): 1 apariciones
# ✅ viking nature resort (resort): 1 apariciones
# ✅ templo de la cueva del tigre (temple): 1 apariciones
# ✅ wat rong suea ten (temple): 1 apariciones
# ✅ night bazaar (market): 1 apariciones
# ✅ singha park (park): 1 apariciones
# ✅ khun korn waterfall (waterfall): 1 apariciones
# ✅ huai pla kang (pagoda): 1 apariciones
# ✅ mae fah luang garden (garden): 1 apariciones
# ✅ ko yao noi (island): 1 apariciones
# ✅ thai massage (activity): 1 apariciones
# ✅ thai cuisine (cuisine): 1 apariciones
# ✅ gran palacio (temple): 1 apariciones
# ✅ gran palacio (palace): 1 apariciones
# ✅ parque nacional erawan (national park): 1 apariciones
# ✅ ayutthaya (historical site): 1 apariciones
# ✅ sukhothai (historical site): 1 apariciones
# ✅ racha islands (island): 1 apariciones
# ✅ sukhothai (historical heritage): 1 apariciones
# ✅ templo blanco (temple): 1 apariciones
# ✅ triángulo dorado (curious site): 1 apariciones
# ✅ pai (backpacker paradise): 1 apariciones
# ✅ muay thai combat (activity): 1 apariciones
# ✅ ao nang (enclave): 1 apariciones
# ✅ railay beach (beach): 1 apariciones
# ✅ koh hong (island): 1 apariciones
# ✅ koh poda (island): 1 apariciones
# ✅ koh racha (island): 1 apariciones
# ✅ surat thani (province): 1 apariciones
# ✅ maha vajiralongkorn (person): 1 apariciones
# ✅ bombay (city): 1 apariciones
# ✅ sri lanka (country): 1 apariciones
# ✅ el hierro (island): 1 apariciones
# ✅ zanzíbar (island): 1 apariciones
# ✅ sarria (city): 1 apariciones
# ✅ estambul (city): 1 apariciones
# ✅ zaanse schans (city): 1 apariciones
# ✅ venecia (city): 1 apariciones
# ✅ españa (country): 1 apariciones
# ✅ andalucía (province): 1 apariciones
# ✅ aragón (province): 1 apariciones
# ✅ baleares (province): 1 apariciones
# ✅ cantabria (province): 1 apariciones
# ✅ castilla la mancha (province): 1 apariciones
# ✅ castilla y león (province): 1 apariciones
# ✅ cataluña (province): 1 apariciones
# ✅ comunidad valenciana (province): 1 apariciones
# ✅ galicia (province): 1 apariciones
# ✅ islas canarias (province): 1 apariciones
# ✅ la rioja (province): 1 apariciones
# ✅ madrid (province): 1 apariciones
# ✅ navarra (province): 1 apariciones
# ✅ país vasco (province): 1 apariciones
# ✅ europa (continent): 1 apariciones
# ✅ andorra (country): 1 apariciones
# ✅ austria (country): 1 apariciones
# ✅ bélgica (country): 1 apariciones
# ✅ bosnia-herzegovina (country): 1 apariciones
# ✅ croacia (country): 1 apariciones
# ✅ escocia (country): 1 apariciones
# ✅ eslovaquia (country): 1 apariciones
# ✅ francia (country): 1 apariciones
# ✅ grecia (country): 1 apariciones
# ✅ hungría (country): 1 apariciones
# ✅ inglaterra (country): 1 apariciones
# ✅ irlanda (country): 1 apariciones
# ✅ islandia (country): 1 apariciones
# ✅ italia (country): 1 apariciones
# ✅ luxemburgo (country): 1 apariciones
# ✅ malta (country): 1 apariciones
# ✅ noruega (country): 1 apariciones
# ✅ países bajos (country): 1 apariciones
# ✅ república checa (country): 1 apariciones
# ✅ rusia (country): 1 apariciones
# ✅ áfrica (continent): 1 apariciones
# ✅ egipto (country): 1 apariciones
# ✅ marruecos (country): 1 apariciones
# ✅ américa (continent): 1 apariciones
# ✅ colombia (country): 1 apariciones
# ✅ cuba (country): 1 apariciones
# ✅ estados unidos (country): 1 apariciones
# ✅ méxico (country): 1 apariciones
# ✅ república dominicana (country): 1 apariciones
# ✅ asia (continent): 1 apariciones
# ✅ corea del sur (country): 1 apariciones
# ✅ emiratos árabes unidos (country): 1 apariciones
# ✅ israel (country): 1 apariciones
# ✅ japón (country): 1 apariciones
# ✅ malasia (country): 1 apariciones
# ✅ maldivas (country): 1 apariciones
# ✅ palestina (country): 1 apariciones
# ✅ singapur (country): 1 apariciones
# ✅ turquía (country): 1 apariciones
# ✅ wat pha lat (temple): 1 apariciones
# ✅ triángulo del oro (historical site): 1 apariciones
# ✅ parque natural de erawan (park): 1 apariciones
# ✅ parque nacional de khao sok (park): 1 apariciones
# ✅ parque nacional de khao yai (park): 1 apariciones
# ✅ tham khao luang (cave): 1 apariciones
# ✅ phi phi marine park (marine park): 1 apariciones
# ✅ doi suthep temple (temple): 1 apariciones
# ✅ wat chedi luang temple (temple): 1 apariciones
# ✅ white temple (wat rong khun) (temple): 1 apariciones
# ✅ black temple (museum): 1 apariciones
# ✅ wat phra kaew temple (temple): 1 apariciones
# ✅ palacio real (temple): 1 apariciones
# ✅ wat benchamabophit (temple): 1 apariciones
# ✅ klong damnoen saduak floating market (market): 1 apariciones
# ✅ train market (market): 1 apariciones
# ✅ khao san road (street): 1 apariciones
# ✅ patpong night market (market): 1 apariciones
# ✅ ayutthaya historical park (park): 1 apariciones
# ✅ wat phra si sanphet (temple): 1 apariciones
# ✅ wat chaiwatthanaram (temple): 1 apariciones
# ✅ wat lokayasutharam (temple): 1 apariciones
# ✅ hellfire pass (historical site): 1 apariciones
# ✅ sukhothai historical park (national park): 1 apariciones
# ✅ parque arqueológico de ayutthaya (archaeological park): 1 apariciones
# ✅ mercado chatuchack (market): 1 apariciones
# ✅ chatuchak market (market): 1 apariciones
# ✅ krabi and phuket islands (island): 1 apariciones
# ✅ women of the long neck karen tribe (cultural): 1 apariciones
# ✅ ang thong marine park (marine park): 1 apariciones
# ✅ bangkok royal palace (palace): 1 apariciones
# ✅ koh phangan waterfall (waterfall): 1 apariciones
# ✅ paradise waterfall (waterfall): 1 apariciones
# ✅ grand palace de bangkok (site): 1 apariciones
# ✅ wat pho de bangkok (site): 1 apariciones
# ✅ wat arun de bangkok (site): 1 apariciones
# ✅ mercado sobre las vías del tren (site): 1 apariciones
# ✅ mercado flotante (site): 1 apariciones
# ✅ parque histórico de ayutthaya (site): 1 apariciones
# ✅ ayutthaya (archaeological site): 1 apariciones
# ✅ black house (museum): 1 apariciones
# ✅ golden triangle (natural border): 1 apariciones
# ✅ view point de phi phi (viewpoint): 1 apariciones
# ✅ route 66 (guide): 1 apariciones
# ✅ costa rica (guide): 1 apariciones
# ✅ japan (guide): 1 apariciones
# ✅ thailand (guide): 1 apariciones
# ✅ vietnam (guide): 1 apariciones
# ✅ singapore (sightseeing): 1 apariciones
# ✅ bali (sightseeing): 1 apariciones
# ✅ budapest (guide): 1 apariciones
# ✅ ireland (guide): 1 apariciones
# ✅ scotland (guide): 1 apariciones
# ✅ copenhagen (guide): 1 apariciones
# ✅ alhambra (museum): 1 apariciones
# ✅ colosseum (museum): 1 apariciones
# ✅ seine river boat tour (boat tour): 1 apariciones
# ✅ harry potter studios (museum): 1 apariciones
# ✅ desert excursion (excursion): 1 apariciones
# ✅ free tours in madrid (tour): 1 apariciones
# ✅ free tours in barcelona (tour): 1 apariciones
# ✅ free tours in salamanca (tour): 1 apariciones
# ✅ free tours in marrakech (tour): 1 apariciones
# ✅ free tours in venice (tour): 1 apariciones
# ✅ free tours in vienna (tour): 1 apariciones
# ✅ free tours in istanbul (tour): 1 apariciones
# ✅ free tours in rome (tour): 1 apariciones
# ✅ free tours in milan (tour): 1 apariciones
# ✅ free tours in amsterdam (tour): 1 apariciones
# ✅ alsace (region): 1 apariciones
# ✅ south of france (region): 1 apariciones
# ✅ scotland (region): 1 apariciones
# ✅ ireland (country): 1 apariciones
# ✅ black forest (region): 1 apariciones
# ✅ switzerland (country): 1 apariciones
# ✅ singapore (country): 1 apariciones
# ✅ ibiza (island): 1 apariciones
# ✅ united states (country): 1 apariciones
# ✅ rome (city): 1 apariciones
# ✅ venice (city): 1 apariciones
# ✅ london (city): 1 apariciones
# ✅ west coast usa (region): 1 apariciones
# ✅ england (country): 1 apariciones
# ✅ lisbon (city): 1 apariciones
# ✅ sintra (city): 1 apariciones
# ✅ madeira (island): 1 apariciones
# ✅ funchal (city): 1 apariciones
# ✅ algarve (region): 1 apariciones
# ✅ portimao (city): 1 apariciones
# ✅ benagil caves boat tour (boat tour): 1 apariciones
# ✅ paiva walkways (walkway): 1 apariciones
# ✅ vila real (city): 1 apariciones
# ✅ chaves (city): 1 apariciones
# ✅ viseu (city): 1 apariciones
# ✅ porto (city): 1 apariciones
# ✅ buddhist temples and ruins (historical sites): 1 apariciones
# ✅ luxurious and incredible boats (transportation): 1 apariciones
# ✅ james bond island and canoe route through mangroves (tour): 1 apariciones
# ✅ jewels of chiang rai tour (tour): 1 apariciones
# ✅ snorkeling at phi phi islands and maya beach (tour): 1 apariciones
# ✅ essence of bangkok tour (tour): 1 apariciones
# ✅ warm welcome to krabi tour (tour): 1 apariciones
# ✅ elephant sanctuary in chiang mai (tour): 1 apariciones
# ✅ tropical exoticism in koh phi phi (tour): 1 apariciones
# ✅ bioluminescent plankton, railay, and 4 islands tour in krabi (tour): 1 apariciones
# ✅ chiang mai nightfall tour (tour): 1 apariciones
# ✅ non-touristy chiang mai + bamboo rafting tour (tour): 1 apariciones
# ✅ lampang (city): 1 apariciones
# ✅ pad thai (dish): 1 apariciones
# ✅ kuay teow lui suan (dish): 1 apariciones
# ✅ khao niao mamuang (dish): 1 apariciones
# ✅ jp resort (accommodation): 1 apariciones
# ✅ parque marino de tarutao (park): 1 apariciones
# ✅ castaway resort (accommodation): 1 apariciones
# ✅ transport (transport): 1 apariciones
# ✅ california (state): 1 apariciones
# ✅ siam paragon (mall): 1 apariciones
# ✅ central world (mall): 1 apariciones
# ✅ chatuchak weekend market (street market): 1 apariciones
# ✅ wat chedi luang varavihara (temple): 1 apariciones
# ✅ poda island (island): 1 apariciones
# ✅ ria (currency_exchange): 1 apariciones
# ✅ koh phayam (island): 1 apariciones
# ✅ koh larn (island): 1 apariciones
# ✅ koh maak (island): 1 apariciones
# ✅ koh surin (island): 1 apariciones
# ✅ isla similan (island): 1 apariciones
# ✅ khao lak (city): 1 apariciones
# ✅ hua hin (city): 1 apariciones
# ✅ mae hong song (city): 1 apariciones
# ✅ mae kampong (village): 1 apariciones
# ✅ nong khai (city): 1 apariciones
# ✅ phuket (beach): 1 apariciones
# ✅ krabi (beach): 1 apariciones
# ✅ koh samui (beach): 1 apariciones
# ✅ koh phi phi (beach): 1 apariciones
# ✅ koh phangan (beach): 1 apariciones
# ✅ koh kood (beach): 1 apariciones
# ✅ koh phayam (beach): 1 apariciones
# ✅ tarjetas esim para móvil (travel card): 1 apariciones
# ✅ iati seguros (insurance): 1 apariciones
# ✅ tarjetas turísticas de nueva york (travel card): 1 apariciones
# ✅ tarjeta revolut (travel card): 1 apariciones
# ✅ excursiones y tours en español (tour): 1 apariciones
# ✅ maeklong market (market): 1 apariciones
# ✅ damnoen saduak floating market (market): 1 apariciones
# ✅ alhambra granada (museum): 1 apariciones
# ✅ cíes islands (island): 1 apariciones
# ✅ colosseum rome (museum): 1 apariciones
# ✅ seine river boat tour (activity): 1 apariciones
# ✅ harry potter studios london (museum): 1 apariciones
# ✅ amsterdam boat tour (activity): 1 apariciones
# ✅ marrakech desert excursion (activity): 1 apariciones
# ✅ madrid (city): 1 apariciones
# ✅ khon kaen airport (airport): 1 apariciones
# ✅ ubon ratchathani airport (airport): 1 apariciones
# ✅ bangkok suvarnabhumi airport (airport): 1 apariciones
# ✅ bangkok don mueang international airport (airport): 1 apariciones
# ✅ chiang rai airport (airport): 1 apariciones
# ✅ udon thani airport (airport): 1 apariciones
# ✅ trat airport (airport): 1 apariciones
# ✅ chiang mai international airport (airport): 1 apariciones
# ✅ koh samui airport (airport): 1 apariciones
# ✅ mae hong son airport (airport): 1 apariciones
# ✅ nakhon si thammarat airport (airport): 1 apariciones
# ✅ phuket international airport (airport): 1 apariciones
# ✅ rayong utapao rayong pattaya airport (airport): 1 apariciones
# ✅ hua hin airport (airport): 1 apariciones
# ✅ buri ram airport (airport): 1 apariciones
# ✅ trang airport (airport): 1 apariciones
# ✅ surat thani airport (airport): 1 apariciones
# ✅ hat yai airport (airport): 1 apariciones
# ✅ krabi international airport (airport): 1 apariciones
# ✅ sukhothai airport (airport): 1 apariciones
# ✅ lufthansa (airline): 1 apariciones
# ✅ klm (airline): 1 apariciones
# ✅ british airways (airline): 1 apariciones
# ✅ delta (airline): 1 apariciones
# ✅ swiss (airline): 1 apariciones
# ✅ turkish airlines (airline): 1 apariciones
# ✅ iberia (airline): 1 apariciones
# ✅ united airlines (airline): 1 apariciones
# ✅ air france (airline): 1 apariciones
# ✅ austrian airlines (airline): 1 apariciones
# ✅ emirates (airline): 1 apariciones
# ✅ qatar airways (airline): 1 apariciones
# ✅ air canada (airline): 1 apariciones
# ✅ scandinavian airlines (airline): 1 apariciones
# ✅ alaska airlines (airline): 1 apariciones
# ✅ finnair (airline): 1 apariciones
# ✅ etihad airways (airline): 1 apariciones
# ✅ tap portugal (airline): 1 apariciones
# ✅ singapore airlines (airline): 1 apariciones
# ✅ cathay pacific (airline): 1 apariciones
#
# 📊 RESUMEN:
#    • Entidades procesadas: 481
#    • Archivo guardado: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# 🏆 TOP 10 FINAL:
# --------------------------------------------------
#  1. Bangkok (city): 32 apariciones
#  2. Ayutthaya (city): 26 apariciones
#  3. Chiang Rai (city): 25 apariciones
#  4. Koh Samui (island): 23 apariciones
#  5. Phuket (island): 21 apariciones
#  6. Sukhothai (city): 19 apariciones
#  7. Koh Lipe (island): 19 apariciones
#  8. Koh Tao (island): 19 apariciones
#  9. Krabi (city): 15 apariciones
# 10. Krabi (province): 14 apariciones
#
# 🎉 ¡PROCESO COMPLETADO!
# 📁 Archivo actualizado y ordenado: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl

# %% [markdown]
# ## We manually modify the Nominatim API and the old data for the enriched database

# %%
# === BLOQUE PARA JUPYTER NOTEBOOK - EDITOR CON NOMINATIM ===
import sys
from pathlib import Path

# Añadir el directorio del script al path
current_dir = Path.cwd()
script_dir = current_dir / "entidades_editor.py"
sys.path.append(str(current_dir))

# Importar la clase
from entidades_editor import iniciar_editor

# Definir rutas para enriched_data_4.jsonl
input_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

print("🚀 Iniciando Editor de Entidades con Nominatim...")
print("=" * 60)
print(f"📥 Entrada: {input_path}")
print(f"📤 Salida: {output_path}")
print()

# Verificar que el archivo de entrada existe
input_file = Path(input_path)
if not input_file.exists():
    print(f"❌ ERROR: No existe el archivo de entrada: {input_path}")
    print("�� Asegúrate de haber ejecutado primero el enriquecimiento con Nominatim")
else:
    print(f"✅ Archivo de entrada encontrado: {input_file.name}")
    print(f"📊 Tamaño: {input_file.stat().st_size / 1024:.1f} KB")
    print()

# Iniciar el editor
print("��️ Abriendo interfaz gráfica...")
iniciar_editor(input_path, output_path)

print("\n🎯 FUNCIONALIDADES DISPONIBLES:")
print("   • Navegación: Primera, anterior, siguiente, última")
print("   • Edición: Modificar JSON con agrupamiento automático")
print("   • Eliminación: Eliminar entidades")
print("   • OSM/Wikidata: Añadir identificadores manualmente")
print("   • Nominatim: Ver datos de enriquecimiento")
print("   • Guardado automático: Se guarda tras cada cambio")
print("   • Copia automática: enriched_data_4.jsonl → enriched_data_5.jsonl")
print()
print("💡 CONSEJOS:")
print("   • Los sitios tienen campo 'nominatim_match' con datos de OSM")
print("   • Puedes verificar calidad de matches (excellent, good, fair, poor)")
print("   • Coordenadas y Wikipedia ya están incluidas si se encontraron")
print("   • Puedes añadir OSM/Wikidata manualmente si faltan")
# Out:
# 🚀 Iniciando Editor de Entidades con Nominatim...
# ============================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# ✅ Archivo de entrada encontrado: enriched_data_5.jsonl
# 📊 Tamaño: 164.7 KB
#
# ��️ Abriendo interfaz gráfica...
# ✅ Usando archivo existente: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Cargadas 124 entidades desde D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# 🎯 FUNCIONALIDADES DISPONIBLES:
#    • Navegación: Primera, anterior, siguiente, última
#    • Edición: Modificar JSON con agrupamiento automático
#    • Eliminación: Eliminar entidades
#    • OSM/Wikidata: Añadir identificadores manualmente
#    • Nominatim: Ver datos de enriquecimiento
#    • Guardado automático: Se guarda tras cada cambio
#    • Copia automática: enriched_data_4.jsonl → enriched_data_5.jsonl
#
# 💡 CONSEJOS:
#    • Los sitios tienen campo 'nominatim_match' con datos de OSM
#    • Puedes verificar calidad de matches (excellent, good, fair, poor)
#    • Coordenadas y Wikipedia ya están incluidas si se encontraron
#    • Puedes añadir OSM/Wikidata manualmente si faltan

# %% [markdown]
# ## We print all types and subtypes

# %%
import json
from pathlib import Path
from collections import defaultdict, Counter

def analizar_tipos_entidades(input_path):
    """Analiza y muestra todos los tipos y subtipos de entidades"""
    
    print("�� ANALIZANDO TIPOS Y SUBTIPOS DE ENTIDADES")
    print("=" * 60)
    print(f"📥 Archivo: {input_path}")
    print()
    
    # Cargar entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades cargadas: {len(entidades)}")
    print()
    
    # Contar tipos y subtipos
    tipos_counter = Counter()
    subtipos_counter = Counter()
    combinaciones = defaultdict(int)
    
    for entidad in entidades:
        tipo = entidad.get('entity_type', 'sin_tipo')
        subtipo = entidad.get('subtype', 'sin_subtipo')
        
        tipos_counter[tipo] += 1
        subtipos_counter[subtipo] += 1
        combinaciones[f"{tipo}_{subtipo}"] += 1
    
    # Mostrar tipos principales
    print("��️  TIPOS DE ENTIDADES:")
    print("-" * 40)
    for tipo, count in tipos_counter.most_common():
        print(f"   • {tipo}: {count}")
    
    print()
    
    # Mostrar subtipos principales
    print("📋 SUBTIPOS DE ENTIDADES:")
    print("-" * 40)
    for subtipo, count in subtipos_counter.most_common():
        print(f"   • {subtipo}: {count}")
    
    print()
    
    # Mostrar combinaciones más frecuentes
    print("�� COMBINACIONES TIPO-SUBTIPO (TOP 20):")
    print("-" * 50)
    for combinacion, count in sorted(combinaciones.items(), key=lambda x: x[1], reverse=True)[:20]:
        tipo, subtipo = combinacion.split('_', 1)
        print(f"   • {tipo} + {subtipo}: {count}")
    
    print()
    
    # Estadísticas generales
    print("📊 ESTADÍSTICAS:")
    print("-" * 30)
    print(f"   • Tipos únicos: {len(tipos_counter)}")
    print(f"   • Subtipos únicos: {len(subtipos_counter)}")
    print(f"   • Combinaciones únicas: {len(combinaciones)}")
    
    # Mostrar entidades sin tipo o subtipo
    sin_tipo = sum(1 for e in entidades if not e.get('entity_type'))
    sin_subtipo = sum(1 for e in entidades if not e.get('subtype'))
    
    if sin_tipo > 0:
        print(f"   • Entidades sin tipo: {sin_tipo}")
    if sin_subtipo > 0:
        print(f"   • Entidades sin subtipo: {sin_subtipo}")
    
    return {
        'tipos': dict(tipos_counter),
        'subtipos': dict(subtipos_counter),
        'combinaciones': dict(combinaciones),
        'total_entidades': len(entidades)
    }

# Ejecutar análisis
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo
input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    stats = analizar_tipos_entidades(input_file)
    
    print(f"\n🎯 RESUMEN:")
    print(f"   • Total de entidades: {stats['total_entidades']}")
    print(f"   • Tipos principales: {list(stats['tipos'].keys())[:5]}")
    print(f"   • Subtipos principales: {list(stats['subtipos'].keys())[:5]}")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
# �� ANALIZANDO TIPOS Y SUBTIPOS DE ENTIDADES
# ============================================================
# 📥 Archivo: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
#  Entidades cargadas: 124
#
# ��️  TIPOS DE ENTIDADES:
# ----------------------------------------
#    • site: 124
#
# 📋 SUBTIPOS DE ENTIDADES:
# ----------------------------------------
#    • island: 22
#    • city: 20
#    • airport: 18
#    • temple: 13
#    • province: 4
#    • national park: 4
#    • town: 4
#    • Temple: 3
#    • Historical Park: 2
#    • beach: 2
#    • Marine Park: 2
#    • historical site: 2
#    • City: 2
#    • mall: 2
#    • archipielago: 1
#    • mountain: 1
#    • waterfall: 1
#    • sanctuary: 1
#    • bay: 1
#    • peninsula: 1
#    • floating market: 1
#    • landmark: 1
#    • country: 1
#    • historical complex: 1
#    • archaeological park: 1
#    • Island: 1
#    • train station: 1
#    • Town: 1
#    • Province: 1
#    • Park: 1
#    • Waterfall: 1
#    • Garden: 1
#    • cave: 1
#    • museum: 1
#    • street: 1
#    • market: 1
#    • natural park: 1
#    • village: 1
#
# �� COMBINACIONES TIPO-SUBTIPO (TOP 20):
# --------------------------------------------------
#    • site + island: 22
#    • site + city: 20
#    • site + airport: 18
#    • site + temple: 13
#    • site + province: 4
#    • site + national park: 4
#    • site + town: 4
#    • site + Temple: 3
#    • site + Historical Park: 2
#    • site + beach: 2
#    • site + Marine Park: 2
#    • site + historical site: 2
#    • site + City: 2
#    • site + mall: 2
#    • site + archipielago: 1
#    • site + mountain: 1
#    • site + waterfall: 1
#    • site + sanctuary: 1
#    • site + bay: 1
#    • site + peninsula: 1
#
# 📊 ESTADÍSTICAS:
# ------------------------------
#    • Tipos únicos: 1
#    • Subtipos únicos: 38
#    • Combinaciones únicas: 38
#
# 🎯 RESUMEN:
#    • Total de entidades: 124
#    • Tipos principales: ['site']
#    • Subtipos principales: ['city', 'island', 'province', 'archipielago', 'mountain']

# %%
import json
from pathlib import Path

def normalizar_tipos_subtipos(input_path, output_path):
    """Normaliza tipos y subtipos según las reglas especificadas"""
    
    print("�� NORMALIZANDO TIPOS Y SUBTIPOS")
    print("=" * 50)
    print(f"📥 Entrada: {input_path}")
    print(f"📤 Salida: {output_path}")
    print()
    
    # Cargar entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades cargadas: {len(entidades)}")
    
    # Contadores para cambios
    cambios_tipo = 0
    cambios_subtipo = 0
    
    # Procesar cada entidad
    for entidad in entidades:
        # Normalizar tipo a minúsculas
        tipo_original = entidad.get('entity_type', '')
        if tipo_original:
            tipo_nuevo = tipo_original.lower()
            if tipo_nuevo != tipo_original:
                entidad['entity_type'] = tipo_nuevo
                cambios_tipo += 1
        
        # Normalizar subtipo a minúsculas y aplicar reglas
        subtipo_original = entidad.get('subtype', '')
        if subtipo_original:
            subtipo_nuevo = subtipo_original.lower()
            
            # Aplicar reglas de normalización
            if subtipo_nuevo in ['historical park', 'historical site', 'historical complex', 'archaeological park']:
                subtipo_nuevo = 'historic'
                print(f"✅ {entidad.get('name', 'N/A')}: {subtipo_original} → historic")
            
            elif subtipo_nuevo in ['national park', 'marine park']:
                subtipo_nuevo = 'natural park'
                print(f"✅ {entidad.get('name', 'N/A')}: {subtipo_original} → natural park")
            
            elif subtipo_nuevo in ['town', 'village']:
                subtipo_nuevo = 'city'
                print(f"✅ {entidad.get('name', 'N/A')}: {subtipo_original} → city")
            
            # Aplicar cambio si es diferente
            if subtipo_nuevo != subtipo_original:
                entidad['subtype'] = subtipo_nuevo
                cambios_subtipo += 1
    
    # Guardar archivo normalizado
    with open(output_path, 'w', encoding='utf-8') as f:
        for entidad in entidades:
            f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
    
    print(f"\n�� RESUMEN DE CAMBIOS:")
    print("-" * 30)
    print(f"   • Tipos normalizados: {cambios_tipo}")
    print(f"   • Subtipos normalizados: {cambios_subtipo}")
    print(f"   • Total de cambios: {cambios_tipo + cambios_subtipo}")
    print(f"   • Archivo guardado: {output_path}")
    
    # Mostrar estadísticas finales
    print(f"\n📈 ESTADÍSTICAS FINALES:")
    print("-" * 30)
    
    tipos_finales = {}
    subtipos_finales = {}
    
    for entidad in entidades:
        tipo = entidad.get('entity_type', 'sin_tipo')
        subtipo = entidad.get('subtype', 'sin_subtipo')
        
        tipos_finales[tipo] = tipos_finales.get(tipo, 0) + 1
        subtipos_finales[subtipo] = subtipos_finales.get(subtipo, 0) + 1
    
    print("Tipos finales:")
    for tipo, count in sorted(tipos_finales.items()):
        print(f"   • {tipo}: {count}")
    
    print("\nSubtipos finales:")
    for subtipo, count in sorted(subtipos_finales.items()):
        print(f"   • {subtipo}: {count}")
    
    return {
        'cambios_tipo': cambios_tipo,
        'cambios_subtipo': cambios_subtipo,
        'total_cambios': cambios_tipo + cambios_subtipo,
        'tipos_finales': tipos_finales,
        'subtipos_finales': subtipos_finales
    }

# Ejecutar normalización
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo de entrada
input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    stats = normalizar_tipos_subtipos(input_file, output_file)
    
    print(f"\n🎉 ¡NORMALIZACIÓN COMPLETADA!")
    print(f"📁 Archivo normalizado: {output_file}")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
# �� NORMALIZANDO TIPOS Y SUBTIPOS
# ==================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
#  Entidades cargadas: 124
#
# �� RESUMEN DE CAMBIOS:
# ------------------------------
#    • Tipos normalizados: 0
#    • Subtipos normalizados: 0
#    • Total de cambios: 0
#    • Archivo guardado: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
# 📈 ESTADÍSTICAS FINALES:
# ------------------------------
# Tipos finales:
#    • site: 124
#
# Subtipos finales:
#    • airport: 18
#    • archipielago: 1
#    • bay: 1
#    • beach: 2
#    • cave: 1
#    • city: 28
#    • country: 1
#    • floating market: 1
#    • garden: 1
#    • historic: 6
#    • island: 23
#    • landmark: 1
#    • mall: 2
#    • market: 1
#    • mountain: 1
#    • museum: 1
#    • natural park: 7
#    • park: 1
#    • peninsula: 1
#    • province: 5
#    • sanctuary: 1
#    • street: 1
#    • temple: 16
#    • train station: 1
#    • waterfall: 2
#
# 🎉 ¡NORMALIZACIÓN COMPLETADA!
# 📁 Archivo normalizado: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl

# %% [markdown]
# ## We print the entities without subtype

# %%
import json
from pathlib import Path

def mostrar_entidades_sin_tipo(input_path):
    """Muestra las entidades sin tipo con su posición en el archivo"""
    
    print(" ENTIDADES SIN TIPO")
    print("=" * 50)
    print(f"📥 Archivo: {input_path}")
    print()
    
    # Cargar entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades totales: {len(entidades)}")
    print()
    
    # Encontrar entidades sin tipo
    entidades_sin_tipo = []
    
    for i, entidad in enumerate(entidades, 1):
        tipo = entidad.get('entity_type', '').strip()
        if not tipo:
            entidades_sin_tipo.append((i, entidad))
    
    print(f" Entidades sin tipo encontradas: {len(entidades_sin_tipo)}")
    print()
    
    if entidades_sin_tipo:
        print("�� LISTADO DE ENTIDADES SIN TIPO:")
        print("-" * 50)
        
        for pos, entidad in entidades_sin_tipo:
            nombre = entidad.get('name', 'Sin nombre')
            subtipo = entidad.get('subtype', 'Sin subtipo')
            descripcion = entidad.get('description', 'Sin descripción')
            
            # Truncar descripción si es muy larga
            if len(descripcion) > 100:
                descripcion = descripcion[:100] + "..."
            
            print(f"{pos:3d}/{len(entidades)}. {nombre}")
            print(f"     • Subtipo: {subtipo}")
            print(f"     • Descripción: {descripcion}")
            
            # Mostrar otros campos relevantes
            appearances = entidad.get('appearances', 0)
            if appearances > 0:
                print(f"     • Apariciones: {appearances}")
            
            # Mostrar si tiene datos de Nominatim
            nominatim_data = entidad.get('nominatim_match', {})
            if nominatim_data.get('found'):
                quality = nominatim_data.get('quality_level', 'N/A')
                print(f"     • Nominatim: {quality}")
            
            print()
    else:
        print("✅ No se encontraron entidades sin tipo")
    
    # Estadísticas
    porcentaje = (len(entidades_sin_tipo) / len(entidades)) * 100 if entidades else 0
    print(f"📊 ESTADÍSTICAS:")
    print(f"   • Entidades sin tipo: {len(entidades_sin_tipo)}")
    print(f"   • Porcentaje: {porcentaje:.1f}%")
    print(f"   • Posiciones: {[pos for pos, _ in entidades_sin_tipo] if entidades_sin_tipo else 'Ninguna'}")

# Ejecutar análisis
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo
input_path = Path(input_file)
if not input_path.exists():import json
from pathlib import Path

def mostrar_entidades_incompletas(input_path):
    """Muestra las entidades sin tipo o sin subtipo con su posición"""
    
    print(" ENTIDADES SIN TIPO O SIN SUBTIPO")
    print("=" * 60)
    print(f"📥 Archivo: {input_path}")
    print()
    
    # Cargar entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades totales: {len(entidades)}")
    print()
    
    # Encontrar entidades incompletas
    entidades_sin_tipo = []
    entidades_sin_subtipo = []
    
    for i, entidad in enumerate(entidades, 1):
        tipo = entidad.get('entity_type', '').strip()
        subtipo = entidad.get('subtype', '').strip()
        
        if not tipo:
            entidades_sin_tipo.append((i, entidad))
        
        if not subtipo:
            entidades_sin_subtipo.append((i, entidad))
    
    # Mostrar entidades sin tipo
    print(f" Entidades sin tipo: {len(entidades_sin_tipo)}")
    print(f" Entidades sin subtipo: {len(entidades_sin_subtipo)}")
    print()
    
    if entidades_sin_tipo:
        print(" ENTIDADES SIN TIPO:")
        print("-" * 50)
        
        for pos, entidad in entidades_sin_tipo:
            nombre = entidad.get('name', 'Sin nombre')
            subtipo = entidad.get('subtype', 'Sin subtipo')
            descripcion = entidad.get('description', 'Sin descripción')
            
            # Truncar descripción si es muy larga
            if len(descripcion) > 100:
                descripcion = descripcion[:100] + "..."
            
            print(f"{pos:3d}/{len(entidades)}. {nombre}")
            print(f"     • Subtipo: {subtipo}")
            print(f"     • Descripción: {descripcion}")
            
            # Mostrar otros campos relevantes
            appearances = entidad.get('appearances', 0)
            if appearances > 0:
                print(f"     • Apariciones: {appearances}")
            
            print()
    
    # Mostrar entidades sin subtipo
    if entidades_sin_subtipo:
        print(" ENTIDADES SIN SUBTIPO:")
        print("-" * 50)
        
        for pos, entidad in entidades_sin_subtipo:
            nombre = entidad.get('name', 'Sin nombre')
            tipo = entidad.get('entity_type', 'Sin tipo')
            descripcion = entidad.get('description', 'Sin descripción')
            
            # Truncar descripción si es muy larga
            if len(descripcion) > 100:
                descripcion = descripcion[:100] + "..."
            
            print(f"{pos:3d}/{len(entidades)}. {nombre}")
            print(f"     • Tipo: {tipo}")
            print(f"     • Descripción: {descripcion}")
            
            # Mostrar otros campos relevantes
            appearances = entidad.get('appearances', 0)
            if appearances > 0:
                print(f"     • Apariciones: {appearances}")
            
            print()
    
    # Si no hay entidades incompletas
    if not entidades_sin_tipo and not entidades_sin_subtipo:
        print("✅ No se encontraron entidades sin tipo o sin subtipo")
    
    # Estadísticas
    porcentaje_sin_tipo = (len(entidades_sin_tipo) / len(entidades)) * 100 if entidades else 0
    porcentaje_sin_subtipo = (len(entidades_sin_subtipo) / len(entidades)) * 100 if entidades else 0
    
    print(f"📊 ESTADÍSTICAS:")
    print(f"   • Entidades sin tipo: {len(entidades_sin_tipo)} ({porcentaje_sin_tipo:.1f}%)")
    print(f"   • Entidades sin subtipo: {len(entidades_sin_subtipo)} ({porcentaje_sin_subtipo:.1f}%)")
    
    if entidades_sin_tipo:
        posiciones_sin_tipo = [pos for pos, _ in entidades_sin_tipo]
        print(f"   • Posiciones sin tipo: {posiciones_sin_tipo}")
    
    if entidades_sin_subtipo:
        posiciones_sin_subtipo = [pos for pos, _ in entidades_sin_subtipo]
        print(f"   • Posiciones sin subtipo: {posiciones_sin_subtipo}")

# Ejecutar análisis
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"

# Verificar que existe el archivo
input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    mostrar_entidades_incompletas(input_file)
    print(f"❌ ERROR: No existe el archivo: {input_file}")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
#  ENTIDADES SIN TIPO O SIN SUBTIPO
# ============================================================
# 📥 Archivo: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
#
#  Entidades totales: 124
#
#  Entidades sin tipo: 0
#  Entidades sin subtipo: 0
#
# ✅ No se encontraron entidades sin tipo o sin subtipo
# 📊 ESTADÍSTICAS:
#    • Entidades sin tipo: 0 (0.0%)
#    • Entidades sin subtipo: 0 (0.0%)
# ❌ ERROR: No existe el archivo: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl

# %% [markdown]
# ## We are goint to properly structure the jerarquy

# %% [markdown]
# ### We add Thailand to all the elements

# %%
import json
from pathlib import Path

def anadir_jerarquia_thailand(input_path, output_path):
    """Añade jerarquía de Tailandia a todas las entidades excepto al propio país"""
    
    print("🔄 AÑADIENDO JERARQUÍA DE TAILANDIA")
    print("=" * 50)
    print(f"📥 Entrada: {input_path}")
    print(f"📤 Salida: {output_path}")
    print()
    
    # Cargar entidades
    entidades = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entidades.append(json.loads(line))
    
    print(f" Entidades cargadas: {len(entidades)}")
    
    # Procesar cada entidad
    entidades_actualizadas = []
    cambios_realizados = 0
    normalizaciones = 0
    
    for entidad in entidades:
        nombre = entidad.get('name', '').strip()
        subtipo = entidad.get('subtype', '').strip()
        
        # No añadir jerarquía al propio país Tailandia
        if nombre.lower() == 'thailand' and subtipo.lower() == 'country':
            entidades_actualizadas.append(entidad)
            continue
        
        # Verificar si ya tiene jerarquía
        hierarchy_actual = entidad.get('hierarchy', [])
        
        # Normalizar "Tailandia" a "Thailand" en la jerarquía existente
        hierarchy_normalizada = []
        for item in hierarchy_actual:
            if (item.get('type') == 'country' and 
                item.get('name', '').lower() in ['thailand', 'tailandia']):
                # Normalizar a "Thailand"
                item_normalizado = item.copy()
                item_normalizado['name'] = 'Thailand'
                item_normalizado['code'] = 'TH'
                hierarchy_normalizada.append(item_normalizado)
                if item.get('name', '').lower() == 'tailandia':
                    normalizaciones += 1
                    print(f"🔄 {nombre}: Normalizado 'Tailandia' → 'Thailand'")
            else:
                hierarchy_normalizada.append(item)
        
        # Buscar si ya tiene Tailandia en la jerarquía normalizada
        tiene_thailand = any(
            item.get('type') == 'country' and 
            item.get('name', '').lower() == 'thailand'
            for item in hierarchy_normalizada
        )
        
        if not tiene_thailand:
            # Añadir Tailandia al principio de la jerarquía
            nueva_hierarchy = [
                {"type": "country", "name": "Thailand", "code": "TH"}
            ] + hierarchy_normalizada
            
            entidad['hierarchy'] = nueva_hierarchy
            cambios_realizados += 1
            print(f"✅ {nombre}: Añadida jerarquía de Thailand")
        else:
            # Usar la jerarquía normalizada
            entidad['hierarchy'] = hierarchy_normalizada
        
        entidades_actualizadas.append(entidad)
    
    # Guardar archivo actualizado
    with open(output_path, 'w', encoding='utf-8') as f:
        for entidad in entidades_actualizadas:
            f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
    
    print(f"\n📊 RESUMEN:")
    print(f"   • Entidades procesadas: {len(entidades)}")
    print(f"   • Jerarquías añadidas: {cambios_realizados}")
    print(f"   • Normalizaciones 'Tailandia' → 'Thailand': {normalizaciones}")
    print(f"   • Archivo guardado: {output_path}")

# Ejecutar
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl"
output_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl"

input_path = Path(input_file)
if not input_path.exists():
    print(f"❌ ERROR: No existe el archivo: {input_file}")
else:
    print(f"✅ Archivo encontrado: {input_path.name}")
    anadir_jerarquia_thailand(input_file, output_file)
    print(f"\n�� ¡Jerarquía añadida y normalizada!")
# Out:
# ✅ Archivo encontrado: enriched_data_5.jsonl
# 🔄 AÑADIENDO JERARQUÍA DE TAILANDIA
# ==================================================
# 📥 Entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_5.jsonl
# 📤 Salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl
#
#  Entidades cargadas: 124
# 🔄 Ayutthaya: Normalizado 'Tailandia' → 'Thailand'
# ✅ Koh Samui: Añadida jerarquía de Thailand
# ✅ Phuket: Añadida jerarquía de Thailand
# ✅ Sukhothai: Añadida jerarquía de Thailand
# ✅ Koh Lipe: Añadida jerarquía de Thailand
# 🔄 Chiang Mai: Normalizado 'Tailandia' → 'Thailand'
# ✅ Koh Phangan: Añadida jerarquía de Thailand
# 🔄 Pai: Normalizado 'Tailandia' → 'Thailand'
# 🔄 Kanchannaburi: Normalizado 'Tailandia' → 'Thailand'
# ✅ Doi Inthanon: Añadida jerarquía de Thailand
# 🔄 Kanchanaburi: Normalizado 'Tailandia' → 'Thailand'
# ✅ Phitsanulok: Añadida jerarquía de Thailand
# ✅ Similan Islands: Añadida jerarquía de Thailand
# ✅ Sukhothai Historical Park: Añadida jerarquía de Thailand
# ✅ Wat Rong Khun: Añadida jerarquía de Thailand
# 🔄 Koh Samet: Normalizado 'Tailandia' → 'Thailand'
# ✅ Railay: Añadida jerarquía de Thailand
# ✅ Doi Suthep: Añadida jerarquía de Thailand
# ✅ Koh Kood: Añadida jerarquía de Thailand
# ✅ Wat Pho: Añadida jerarquía de Thailand
# ✅ Erawan Waterfalls: Añadida jerarquía de Thailand
# ✅ Ao Nang: Añadida jerarquía de Thailand
# ✅ Wat Phra That Doi Suthep: Añadida jerarquía de Thailand
# ✅ Nan: Añadida jerarquía de Thailand
# ✅ Chumphon: Añadida jerarquía de Thailand
# ✅ Wat Phra Singh: Añadida jerarquía de Thailand
# ✅ Bahía de Phang Nga: Añadida jerarquía de Thailand
# ✅ Maya Bay: Añadida jerarquía de Thailand
# ✅ Koh Muk: Añadida jerarquía de Thailand
# ✅ Damnoen Saduak Floating Market: Añadida jerarquía de Thailand
# ✅ Khao Yai National Park: Añadida jerarquía de Thailand
# ✅ White Temple: Añadida jerarquía de Thailand
# ✅ Blue Temple: Añadida jerarquía de Thailand
# ✅ Golden Triangle: Añadida jerarquía de Thailand
# ✅ Wat Umong: Añadida jerarquía de Thailand
# ✅ Wat Si Chum: Añadida jerarquía de Thailand
# ✅ Wat Chedi Luang: Añadida jerarquía de Thailand
# ✅ Nakhon Si Thammarat: Añadida jerarquía de Thailand
# ✅ Mae Hong Son: Añadida jerarquía de Thailand
# ✅ Similan Islands: Añadida jerarquía de Thailand
# ✅ Ko Nang Yuan: Añadida jerarquía de Thailand
# ✅ Suvarnabhumi Airport: Añadida jerarquía de Thailand
# ✅ Don Muang Airport: Añadida jerarquía de Thailand
# ✅ Hualamphong Station: Añadida jerarquía de Thailand
# ✅ Erawan National Park: Añadida jerarquía de Thailand
# ✅ Ko Samui: Añadida jerarquía de Thailand
# ✅ Chiang Khan: Añadida jerarquía de Thailand
# ✅ Wat Pa Phu Kon: Añadida jerarquía de Thailand
# ✅ Phanom Rung: Añadida jerarquía de Thailand
# ✅ Kanchanaburi: Añadida jerarquía de Thailand
# ✅ Templo Blanco (Wat Rong Khun): Añadida jerarquía de Thailand
# ✅ Buri Ram: Añadida jerarquía de Thailand
# ✅ Ao Nang: Añadida jerarquía de Thailand
# ✅ Ratchaburi: Añadida jerarquía de Thailand
# ✅ Samut Songkhram: Añadida jerarquía de Thailand
# ✅ Ayutthaya Historical Park: Añadida jerarquía de Thailand
# ✅ Koh Phi Phi Don: Añadida jerarquía de Thailand
# ✅ Templo de la Cueva del Tigre: Añadida jerarquía de Thailand
# ✅ Wat Rong Suea Ten: Añadida jerarquía de Thailand
# ✅ Singha Park: Añadida jerarquía de Thailand
# ✅ Khun Korn Waterfall: Añadida jerarquía de Thailand
# ✅ Mae Fah Luang Garden: Añadida jerarquía de Thailand
# ✅ Ko Yao Noi: Añadida jerarquía de Thailand
# ✅ Koh Poda: Añadida jerarquía de Thailand
# ✅ Koh Racha: Añadida jerarquía de Thailand
# 🔄 Surat Thani: Normalizado 'Tailandia' → 'Thailand'
# ✅ Wat Pha Lat: Añadida jerarquía de Thailand
# ✅ Tham Khao Luang: Añadida jerarquía de Thailand
# ✅ Phi Phi Marine Park: Añadida jerarquía de Thailand
# ✅ Black Temple: Añadida jerarquía de Thailand
# ✅ Khao San Road: Añadida jerarquía de Thailand
# ✅ Hellfire Pass: Añadida jerarquía de Thailand
# ✅ Chatuchak Market: Añadida jerarquía de Thailand
# 🔄 Lampang: Normalizado 'Tailandia' → 'Thailand'
# ✅ Siam Paragon: Añadida jerarquía de Thailand
# ✅ Central World: Añadida jerarquía de Thailand
# ✅ Wat Chedi Luang Varavihara: Añadida jerarquía de Thailand
# ✅ Mae Kampong: Añadida jerarquía de Thailand
# ✅ Nong Khai: Añadida jerarquía de Thailand
# ✅ Chiang Rai Airport: Añadida jerarquía de Thailand
# ✅ Udon Thani Airport: Añadida jerarquía de Thailand
# ✅ Trat Airport: Añadida jerarquía de Thailand
# ✅ Chiang Mai International Airport: Añadida jerarquía de Thailand
# ✅ Koh Samui Airport: Añadida jerarquía de Thailand
# ✅ Mae Hong Son Airport: Añadida jerarquía de Thailand
# ✅ Nakhon Si Thammarat Airport: Añadida jerarquía de Thailand
# ✅ Phuket International Airport: Añadida jerarquía de Thailand
# ✅ Rayong Utapao Rayong Pattaya Airport: Añadida jerarquía de Thailand
# ✅ Hua Hin Airport: Añadida jerarquía de Thailand
# ✅ Buri Ram Airport: Añadida jerarquía de Thailand
# ✅ Trang Airport: Añadida jerarquía de Thailand
# ✅ Surat Thani Airport: Añadida jerarquía de Thailand
# ✅ Hat Yai Airport: Añadida jerarquía de Thailand
# ✅ Krabi International Airport: Añadida jerarquía de Thailand
# ✅ Sukhothai Airport: Añadida jerarquía de Thailand
#
# 📊 RESUMEN:
#    • Entidades procesadas: 124
#    • Jerarquías añadidas: 87
#    • Normalizaciones 'Tailandia' → 'Thailand': 8
#    • Archivo guardado: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl
#
# �� ¡Jerarquía añadida y normalizada!

# %% [markdown]
# ###  Añadimos manualmente las otras jerarquias

# %%
import tkinter as tk
from tkinter import ttk, messagebox, scrolledtext
import json
from pathlib import Path
from collections import defaultdict

class HierarchyEditor:
    def __init__(self, root, input_path, output_path):
        self.root = root
        self.root.title("Editor de Jerarquías - TravelApp")
        self.root.geometry("1600x1000")
        
        # Rutas de archivos
        self.input_path = Path(input_path)
        self.output_path = Path(output_path)
        
        # Cargar datos
        self.entidades = self.cargar_entidades()
        self.indice_actual = 0
        
        # Subtipos válidos para jerarquía
        self.subtipos_validos = ['city', 'province', 'island', 'archipielago', 'peninsula', 'town', 'bay', 'country']
        
        # Crear diccionario de entidades por subtipo
        self.entidades_por_subtipo = self.organizar_por_subtipo()
        
        self.crear_interfaz()
        self.mostrar_entidad_actual()

    def crear_interfaz(self):
        """Crea la interfaz gráfica"""
        # Frame principal
        main_frame = ttk.Frame(self.root, padding="10")
        main_frame.grid(row=0, column=0, sticky=(tk.W, tk.E, tk.N, tk.S))

        # Configurar grid
        self.root.columnconfigure(0, weight=1)
        self.root.rowconfigure(0, weight=1)
        main_frame.columnconfigure(1, weight=1)
        main_frame.rowconfigure(2, weight=1)

        # Información de archivo
        ttk.Label(main_frame, text=f"Archivo: {self.input_path.name}", font=("Arial", 12, "bold")).grid(row=0, column=0, columnspan=4, sticky=tk.W, pady=(0, 10))

        # Contador de entidades - MÁS GRANDE Y VISIBLE
        self.contador_label = ttk.Label(main_frame, text="", font=("Arial", 14, "bold"), foreground="blue")
        self.contador_label.grid(row=1, column=0, columnspan=4, sticky=tk.W, pady=(0, 15))

        # Frame izquierdo - Navegación y entidad actual
        left_frame = ttk.Frame(main_frame)
        left_frame.grid(row=2, column=0, sticky=(tk.W, tk.E, tk.N, tk.S), padx=(0, 10))

        # Botones de navegación
        ttk.Button(left_frame, text="⏮️ Primera", command=self.primera_entidad, width=15).pack(fill=tk.X, pady=2)
        ttk.Button(left_frame, text="⏪ Anterior", command=self.anterior_entidad, width=15).pack(fill=tk.X, pady=2)
        ttk.Button(left_frame, text="⏩ Siguiente", command=self.siguiente_entidad, width=15).pack(fill=tk.X, pady=2)
        ttk.Button(left_frame, text="⏭️ Última", command=self.ultima_entidad, width=15).pack(fill=tk.X, pady=2)

        # Botones de acciones
        ttk.Button(left_frame, text="💾 Guardar", command=self.guardar_entidades, width=15).pack(fill=tk.X, pady=10)
        ttk.Button(left_frame, text="🔄 Recargar", command=self.recargar_entidades, width=15).pack(fill=tk.X, pady=2)
        ttk.Button(left_frame, text="➕ AÑADIR ESTA ENTIDAD", command=self.anadir_entidad_actual, width=15).pack(fill=tk.X, pady=10)

        # Frame central - Entidad actual y edición de jerarquía
        center_frame = ttk.Frame(main_frame)
        center_frame.grid(row=2, column=1, sticky=(tk.W, tk.E, tk.N, tk.S), padx=(0, 10))

        # Información de la entidad actual
        ttk.Label(center_frame, text="ENTIDAD ACTUAL:", font=("Arial", 12, "bold")).pack(anchor=tk.W)

        self.entidad_info = ttk.Label(center_frame, text="", font=("Arial", 10))
        self.entidad_info.pack(anchor=tk.W, pady=(0, 10))

        # Jerarquía actual
        ttk.Label(center_frame, text="JERARQUÍA ACTUAL:", font=("Arial", 12, "bold")).pack(anchor=tk.W)

        self.jerarquia_text = scrolledtext.ScrolledText(center_frame, height=8, width=50, font=("Consolas", 9))
        self.jerarquia_text.pack(fill=tk.BOTH, expand=True, pady=(0, 10))

        # FRAME PARA AÑADIR ELEMENTOS A LA JERARQUÍA
        hierarchy_edit_frame = ttk.LabelFrame(center_frame, text="AÑADIR A JERARQUÍA", padding="5")
        hierarchy_edit_frame.pack(fill=tk.X, pady=(0, 10))

        # Tipo de jerarquía
        ttk.Label(hierarchy_edit_frame, text="Tipo:").grid(row=0, column=0, sticky=tk.W, padx=(0, 5))
        self.tipo_var = tk.StringVar(value="city")
        tipo_combo = ttk.Combobox(hierarchy_edit_frame, textvariable=self.tipo_var, values=self.subtipos_validos, width=15)
        tipo_combo.grid(row=0, column=1, sticky=tk.W, padx=(0, 10))

        # Nombre de jerarquía (combobox dependiente del subtipo)
        ttk.Label(hierarchy_edit_frame, text="Entidad:").grid(row=0, column=2, sticky=tk.W, padx=(0, 5))
        self.nombre_var = tk.StringVar()
        self.nombre_combo = ttk.Combobox(hierarchy_edit_frame, textvariable=self.nombre_var, width=30)
        self.nombre_combo.grid(row=0, column=3, sticky=tk.W, padx=(0, 10))

        def actualizar_nombres_entidades(*args):
            subtipo = self.tipo_var.get()
            nombres_entidades = [ent.get('name', 'Sin nombre') for ent in self.entidades if ent.get('subtype') == subtipo]
            self.nombre_combo['values'] = nombres_entidades
            if nombres_entidades:
                self.nombre_var.set(nombres_entidades[0])
            else:
                self.nombre_var.set("")

        # Actualiza la lista de entidades cuando cambias el tipo
        self.tipo_var.trace('w', actualizar_nombres_entidades)
        actualizar_nombres_entidades()

        # Código (opcional)
        ttk.Label(hierarchy_edit_frame, text="Código:").grid(row=0, column=4, sticky=tk.W, padx=(0, 5))
        self.codigo_var = tk.StringVar()
        codigo_entry = ttk.Entry(hierarchy_edit_frame, textvariable=self.codigo_var, width=8)
        codigo_entry.grid(row=0, column=5, sticky=tk.W, padx=(0, 10))

        # Botón para añadir
        ttk.Button(hierarchy_edit_frame, text="➕ Añadir", command=self.anadir_a_jerarquia).grid(row=0, column=6, padx=(0, 5))

        # Botón para eliminar último elemento
        ttk.Button(hierarchy_edit_frame, text="🗑️ Eliminar último", command=self.eliminar_ultimo_jerarquia).grid(row=0, column=7)

        # Frame derecho - Lista de entidades por subtipo
        right_frame = ttk.Frame(main_frame)
        right_frame.grid(row=2, column=2, sticky=(tk.W, tk.E, tk.N, tk.S), padx=(0, 10))

        ttk.Label(right_frame, text="ENTIDADES POR SUBTIPO:", font=("Arial", 12, "bold")).pack(anchor=tk.W)

        # Notebook para pestañas de subtipos
        self.notebook = ttk.Notebook(right_frame)
        self.notebook.pack(fill=tk.BOTH, expand=True)

        self.crear_pestanas_subtipos()

        # Frame inferior - Área de visualización completa
        bottom_frame = ttk.Frame(main_frame)
        bottom_frame.grid(row=3, column=0, columnspan=4, sticky=(tk.W, tk.E, tk.N, tk.S), pady=(10, 0))

        ttk.Label(bottom_frame, text="JSON COMPLETO:", font=("Arial", 12, "bold")).pack(anchor=tk.W)
        self.text_area = scrolledtext.ScrolledText(bottom_frame, height=12, width=120, font=("Consolas", 9))
        self.text_area.pack(fill=tk.BOTH, expand=True)    
        
    def cargar_entidades(self):
        """Carga las entidades desde el archivo"""
        entidades = []
        try:
            with open(self.input_path, 'r', encoding='utf-8') as f:
                for line in f:
                    if line.strip():
                        entidades.append(json.loads(line))
            print(f"✅ Cargadas {len(entidades)} entidades desde {self.input_path}")
            return entidades
        except Exception as e:
            messagebox.showerror("Error", f"No se pudo cargar el archivo: {e}")
            return []
    
    def organizar_por_subtipo(self):
        """Organiza las entidades por subtipo para la interfaz"""
        organizadas = defaultdict(list)
        
        for entidad in self.entidades:
            subtipo = entidad.get('subtype', '').strip()
            if subtipo in self.subtipos_validos:
                organizadas[subtipo].append(entidad)
        
        return dict(organizadas)
    
    def guardar_entidades(self):
        """Guarda las entidades en el archivo de salida"""
        try:
            with open(self.output_path, 'w', encoding='utf-8') as f:
                for entidad in self.entidades:
                    f.write(json.dumps(entidad, ensure_ascii=False) + '\n')
            print(f"✅ Entidades guardadas en: {self.output_path}")
            messagebox.showinfo("Éxito", f"Entidades guardadas en:\n{self.output_path}")
        except Exception as e:
            messagebox.showerror("Error", f"No se pudo guardar: {e}")
    
    
    
    def anadir_entidad_actual(self):
        """Añade la entidad actual a la jerarquía de otra entidad"""
        if not self.entidades:
            return
        
        entidad_actual = self.entidades[self.indice_actual]
        nombre_actual = entidad_actual.get('name', 'Sin nombre')
        subtipo_actual = entidad_actual.get('subtype', 'Sin subtipo')
        
        # Crear ventana de selección
        self.crear_ventana_seleccion_entidad(nombre_actual, subtipo_actual)
    
    def crear_ventana_seleccion_entidad(self, nombre_actual, subtipo_actual):
        """Crea una ventana para seleccionar a qué entidad añadir la jerarquía"""
        ventana = tk.Toplevel(self.root)
        ventana.title(f"Añadir '{nombre_actual}' a jerarquía")
        ventana.geometry("600x400")
        ventana.transient(self.root)
        ventana.grab_set()
        
        # Frame principal
        main_frame = ttk.Frame(ventana, padding="10")
        main_frame.pack(fill=tk.BOTH, expand=True)
        
        # Título
        ttk.Label(main_frame, text=f"¿A qué entidad quieres añadir '{nombre_actual}' ({subtipo_actual})?", 
                 font=("Arial", 12, "bold")).pack(pady=(0, 10))
        
        # Frame para búsqueda
        search_frame = ttk.Frame(main_frame)
        search_frame.pack(fill=tk.X, pady=(0, 10))
        
        ttk.Label(search_frame, text="Buscar:").pack(side=tk.LEFT)
        search_var = tk.StringVar()
        search_entry = ttk.Entry(search_frame, textvariable=search_var, width=30)
        search_entry.pack(side=tk.LEFT, padx=(5, 0))
        
        # Lista de entidades
        listbox_frame = ttk.Frame(main_frame)
        listbox_frame.pack(fill=tk.BOTH, expand=True)
        
        listbox = tk.Listbox(listbox_frame, font=("Arial", 10))
        listbox.pack(fill=tk.BOTH, expand=True)
        
        # Función para filtrar entidades
        def filtrar_entidades(*args):
            listbox.delete(0, tk.END)
            busqueda = search_var.get().lower()
            
            for i, entidad in enumerate(self.entidades):
                nombre = entidad.get('name', '').lower()
                if busqueda in nombre:
                    listbox.insert(tk.END, f"{entidad.get('name')} ({entidad.get('subtype', 'N/A')})")
        
        # Binding para búsqueda
        search_var.trace('w', filtrar_entidades)
        
        # Cargar todas las entidades inicialmente
        filtrar_entidades()
        
        # Botones
        button_frame = ttk.Frame(main_frame)
        button_frame.pack(fill=tk.X, pady=(10, 0))
        
        def seleccionar_entidad():
            selection = listbox.curselection()
            if selection:
                # Obtener el nombre de la entidad seleccionada
                texto_seleccionado = listbox.get(selection[0])
                nombre_destino = texto_seleccionado.split(' (')[0]
                
                # Encontrar la entidad destino
                for i, entidad in enumerate(self.entidades):
                    if entidad.get('name') == nombre_destino:
                        # Añadir la entidad actual a la jerarquía de la entidad destino
                        entidad_destino = self.entidades[i]
                        hierarchy = entidad_destino.get('hierarchy', [])
                        
                        nuevo_elemento = {
                            "type": subtipo_actual,
                            "name": nombre_actual
                        }
                        
                        hierarchy.append(nuevo_elemento)
                        entidad_destino['hierarchy'] = hierarchy
                        
                        print(f"✅ Añadido '{nombre_actual}' ({subtipo_actual}) a la jerarquía de '{nombre_destino}'")
                        messagebox.showinfo("Éxito", f"Añadido '{nombre_actual}' a la jerarquía de '{nombre_destino}'")
                        
                        # Actualizar la visualización si la entidad destino es la actual
                        if i == self.indice_actual:
                            self.mostrar_entidad_actual()
                        
                        ventana.destroy()
                        return
                
                messagebox.showerror("Error", f"No se encontró la entidad: {nombre_destino}")
        
        ttk.Button(button_frame, text="✅ Añadir", command=seleccionar_entidad).pack(side=tk.LEFT, padx=(0, 5))
        ttk.Button(button_frame, text="❌ Cancelar", command=ventana.destroy).pack(side=tk.LEFT)
        
        # Focus en la búsqueda
        search_entry.focus()
    
    def anadir_a_jerarquia(self):
        """Añade un elemento a la jerarquía de la entidad actual"""
        if not self.entidades:
            return
        
        tipo = self.tipo_var.get().strip()
        nombre = self.nombre_var.get().strip()
        codigo = self.codigo_var.get().strip()
        
        if not tipo or not nombre:
            messagebox.showwarning("Advertencia", "Debes especificar tipo y nombre")
            return
        
        # Crear nuevo elemento de jerarquía
        nuevo_elemento = {"type": tipo, "name": nombre}
        if codigo:
            nuevo_elemento["code"] = codigo
        
        # Añadir a la jerarquía actual
        entidad = self.entidades[self.indice_actual]
        hierarchy = entidad.get('hierarchy', [])
        hierarchy.append(nuevo_elemento)
        entidad['hierarchy'] = hierarchy
        
        # Limpiar campos
        self.nombre_var.set("")
        self.codigo_var.set("")
        
        # Actualizar visualización
        self.mostrar_entidad_actual()
        print(f"✅ Añadido a jerarquía: {tipo} - {nombre}")
    
    def eliminar_ultimo_jerarquia(self):
        """Elimina el último elemento de la jerarquía"""
        if not self.entidades:
            return
        
        entidad = self.entidades[self.indice_actual]
        hierarchy = entidad.get('hierarchy', [])
        
        if hierarchy:
            elemento_eliminado = hierarchy.pop()
            entidad['hierarchy'] = hierarchy
            self.mostrar_entidad_actual()
            print(f"🗑️ Eliminado de jerarquía: {elemento_eliminado.get('type')} - {elemento_eliminado.get('name')}")
        else:
            messagebox.showinfo("Info", "La jerarquía ya está vacía")
    
    def crear_pestanas_subtipos(self):
        """Crea pestañas para cada subtipo"""
        for subtipo in self.subtipos_validos:
            if subtipo in self.entidades_por_subtipo:
                # Crear frame para la pestaña
                frame = ttk.Frame(self.notebook)
                self.notebook.add(frame, text=subtipo.upper())
                
                # Lista de entidades para este subtipo
                listbox = tk.Listbox(frame, font=("Arial", 9))
                listbox.pack(fill=tk.BOTH, expand=True, padx=5, pady=5)
                
                # Añadir entidades a la lista
                for entidad in self.entidades_por_subtipo[subtipo]:
                    nombre = entidad.get('name', 'Sin nombre')
                    listbox.insert(tk.END, nombre)
                
                # Binding para seleccionar entidad
                listbox.bind('<Double-Button-1>', lambda e, lb=listbox, st=subtipo: self.seleccionar_entidad_desde_lista(lb, st))
    
    def seleccionar_entidad_desde_lista(self, listbox, subtipo):
        """Selecciona una entidad desde la lista de subtipos"""
        selection = listbox.curselection()
        if selection:
            nombre_seleccionado = listbox.get(selection[0])
            
            # Encontrar la entidad en el índice global
            for i, entidad in enumerate(self.entidades):
                if entidad.get('name') == nombre_seleccionado and entidad.get('subtype') == subtipo:
                    self.indice_actual = i
                    self.mostrar_entidad_actual()
                    break
    
    def mostrar_entidad_actual(self):
        """Muestra la entidad actual en la interfaz"""
        if not self.entidades:
            self.contador_label.config(text="No hay entidades")
            self.entidad_info.config(text="")
            self.jerarquia_text.delete(1.0, tk.END)
            self.text_area.delete(1.0, tk.END)
            return
        
        entidad = self.entidades[self.indice_actual]
        
        # Actualizar contador - MÁS VISIBLE
        self.contador_label.config(text=f"📋 ENTIDAD {self.indice_actual + 1} DE {len(self.entidades)}")
        
        # Información de la entidad
        nombre = entidad.get('name', 'Sin nombre')
        subtipo = entidad.get('subtype', 'Sin subtipo')
        tipo = entidad.get('entity_type', 'Sin tipo')
        
        info_text = f"Nombre: {nombre}\nTipo: {tipo}\nSubtipo: {subtipo}"
        self.entidad_info.config(text=info_text)
        
        # Mostrar jerarquía actual
        hierarchy = entidad.get('hierarchy', [])
        self.jerarquia_text.delete(1.0, tk.END)
        
        if hierarchy:
            for i, item in enumerate(hierarchy, 1):
                tipo_hier = item.get('type', 'N/A')
                nombre_hier = item.get('name', 'N/A')
                codigo = item.get('code', '')
                codigo_text = f" ({codigo})" if codigo else ""
                self.jerarquia_text.insert(tk.END, f"{i}. {tipo_hier}: {nombre_hier}{codigo_text}\n")
        else:
            self.jerarquia_text.insert(tk.END, "Sin jerarquía")
        
        # Mostrar JSON completo
        json_str = json.dumps(entidad, indent=2, ensure_ascii=False)
        self.text_area.delete(1.0, tk.END)
        self.text_area.insert(1.0, json_str)
    
    def primera_entidad(self):
        """Va a la primera entidad"""
        if self.entidades:
            self.indice_actual = 0
            self.mostrar_entidad_actual()
    
    def anterior_entidad(self):
        """Va a la entidad anterior"""
        if self.entidades and self.indice_actual > 0:
            self.indice_actual -= 1
            self.mostrar_entidad_actual()
    
    def siguiente_entidad(self):
        """Va a la entidad siguiente"""
        if self.entidades and self.indice_actual < len(self.entidades) - 1:
            self.indice_actual += 1
            self.mostrar_entidad_actual()
    
    def ultima_entidad(self):
        """Va a la última entidad"""
        if self.entidades:
            self.indice_actual = len(self.entidades) - 1
            self.mostrar_entidad_actual()
    
    def recargar_entidades(self):
        """Recarga las entidades desde el archivo"""
        self.entidades = self.cargar_entidades()
        self.entidades_por_subtipo = self.organizar_por_subtipo()
        self.indice_actual = 0
        self.mostrar_entidad_actual()
        messagebox.showinfo("Éxito", "Entidades recargadas desde el archivo")

    

def iniciar_editor_hierarchy(input_path, output_path):
    """Función para iniciar el editor de jerarquías desde notebook"""
    root = tk.Tk()
    app = HierarchyEditor(root, input_path, output_path)
    root.mainloop()

# %%
# BLOQUE 2: EDITOR DE JERARQUÍAS
# ===============================

import sys
from pathlib import Path

# Añadir el directorio del script al path
script_dir = Path(r"D:\TravelApp\Project\scripts\scraper_enrichment\manual_postprocessing")
sys.path.append(str(script_dir))

# Importar el editor

# Configurar rutas
input_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl"
output_file = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6_final.jsonl"

print("🚀 INICIANDO EDITOR DE JERARQUÍAS")
print("=" * 50)
print(f"�� Archivo de entrada: {input_file}")
print(f"�� Archivo de salida: {output_file}")
print()
print("📋 FUNCIONALIDADES:")
print("   • Navegación entre entidades")
print("   • Visualización por subtipos (city, province, island, etc.)")
print("   • Visualización de jerarquía actual")
print("   • AÑADIR elementos a la jerarquía")
print("   • ELIMINAR elementos de la jerarquía")
print("   • JSON completo de cada entidad")
print("   • Guardado de cambios")
print()
print("💡 INSTRUCCIONES:")
print("   1. Usa los botones de navegación para moverte entre entidades")
print("   2. Haz doble clic en las listas de subtipos para ir a una entidad específica")
print("   3. Revisa la jerarquía actual en el panel central")
print("   4. Para AÑADIR a jerarquía:")
print("      - Selecciona tipo (city, province, etc.)")
print("      - Escribe el nombre")
print("      - Opcionalmente añade código")
print("      - Clica '➕ Añadir'")
print("   5. Para ELIMINAR: clica '🗑️ Eliminar último'")
print("   6. Usa '💾 Guardar' para salvar los cambios")
print()

# Iniciar la interfaz
iniciar_editor_hierarchy(input_file, output_file)
# Out:
# 🚀 INICIANDO EDITOR DE JERARQUÍAS
# ==================================================
# �� Archivo de entrada: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl
# �� Archivo de salida: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6_final.jsonl
#
# 📋 FUNCIONALIDADES:
#    • Navegación entre entidades
#    • Visualización por subtipos (city, province, island, etc.)
#    • Visualización de jerarquía actual
#    • AÑADIR elementos a la jerarquía
#    • ELIMINAR elementos de la jerarquía
#    • JSON completo de cada entidad
#    • Guardado de cambios
#
# 💡 INSTRUCCIONES:
#    1. Usa los botones de navegación para moverte entre entidades
#    2. Haz doble clic en las listas de subtipos para ir a una entidad específica
#    3. Revisa la jerarquía actual en el panel central
#    4. Para AÑADIR a jerarquía:
#       - Selecciona tipo (city, province, etc.)
#       - Escribe el nombre
#       - Opcionalmente añade código
#       - Clica '➕ Añadir'
#    5. Para ELIMINAR: clica '🗑️ Eliminar último'
#    6. Usa '💾 Guardar' para salvar los cambios
#
# ✅ Cargadas 124 entidades desde D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl
# ✅ Añadido a jerarquía: province - Chiang Rai
# 🗑️ Eliminado de jerarquía: island - Koh Samui
# 🗑️ Eliminado de jerarquía: island - Phuket
# 🗑️ Eliminado de jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: island - Koh Tao
# ✅ Añadido a jerarquía: country - Thailand
# ✅ Añadido a jerarquía: province - Krabi
# ✅ Añadido a jerarquía: island - Phuket
# 🗑️ Eliminado de jerarquía: province - Chiang Mai
# 🗑️ Eliminado de jerarquía: province - Sukhothai
# 🗑️ Eliminado de jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: province - Surat Thani
# ✅ Añadido a jerarquía: country - Thailand
# ✅ Añadido a jerarquía: province - Krabi
# 🗑️ Eliminado de jerarquía: island - Koh Kood
# 🗑️ Eliminado de jerarquía: bay - Bahía de Phang Nga
# 🗑️ Eliminado de jerarquía: city - Krabi
# 🗑️ Eliminado de jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: city - Krabi
# ✅ Añadido a jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: country - Thailand
# ✅ Añadido a jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: province - Ratchaburi
# 🗑️ Eliminado de jerarquía: city - Bangkok
# 🗑️ Eliminado de jerarquía: region - Northern Thailand
# ✅ Añadido a jerarquía: city - Sukhothai
# 🗑️ Eliminado de jerarquía: province - Mae Hong Son
# 🗑️ Eliminado de jerarquía: town - Mae Hong Son
# 🗑️ Eliminado de jerarquía: province - Phang Nga
# 🗑️ Eliminado de jerarquía: Country - Thailand
# 🗑️ Eliminado de jerarquía: Island - Ko Nang Yuan
# 🗑️ Eliminado de jerarquía: city - Bangkok
# 🗑️ Eliminado de jerarquía: city - Bangkok
# 🗑️ Eliminado de jerarquía: province - Loei
# 🗑️ Eliminado de jerarquía: region - Northeast Thailand
# 🗑️ Eliminado de jerarquía: province - Buriram
# ✅ Añadido a jerarquía: city - Buri Ram
# 🗑️ Eliminado de jerarquía: province - Kanchanaburi
# 🗑️ Eliminado de jerarquía: city - Buri Ram
# 🗑️ Eliminado de jerarquía: Province - Krabi
# 🗑️ Eliminado de jerarquía: Town - Ao Nang
# 🗑️ Eliminado de jerarquía: City - Ratchaburi
# 🗑️ Eliminado de jerarquía: Province - Samut Songkhram
# 🗑️ Eliminado de jerarquía: island - Phi Phi Islands
# ✅ Añadido a jerarquía: archipielago - Phi Phi Islands
# 🗑️ Eliminado de jerarquía: city - Krabi
# ✅ Añadido a jerarquía: province - Krabi
# 🗑️ Eliminado de jerarquía: City - Chiang Rai
# 🗑️ Eliminado de jerarquía: country - Thailand
# ✅ Añadido a jerarquía: province - Chiang Rai
# ✅ Añadido a jerarquía: country - Thailand
# 🗑️ Eliminado de jerarquía: province - Phuket
# 🗑️ Eliminado de jerarquía: city - Phuket
# 🗑️ Eliminado de jerarquía: island - Koh Poda
# 🗑️ Eliminado de jerarquía: island - Koh Racha
# 🗑️ Eliminado de jerarquía: island - Koh Phi Phi
# ✅ Añadido a jerarquía: archipielago - Phi Phi Islands
# ✅ Añadido a jerarquía: city - Bangkok
# 🗑️ Eliminado de jerarquía: province - Kanchanaburi
# 🗑️ Eliminado de jerarquía: village - Mae Kampong
# 🗑️ Eliminado de jerarquía: city - Nong Khai
# 🗑️ Eliminado de jerarquía: city - Chiang Rai
# ✅ Añadido a jerarquía: city - Chiang Rai
# 🗑️ Eliminado de jerarquía: city - Udon Thani
# 🗑️ Eliminado de jerarquía: city - Trat
# 🗑️ Eliminado de jerarquía: city - Koh Samui
# ✅ Añadido a jerarquía: island - Koh Samui
# 🗑️ Eliminado de jerarquía: city - Mae Hong Son
# 🗑️ Eliminado de jerarquía: city - Nakhon Si Thammarat
# 🗑️ Eliminado de jerarquía: city - Phuket
# ✅ Añadido a jerarquía: city - Phuket
# ✅ Añadido a jerarquía: island - Phuket
# 🗑️ Eliminado de jerarquía: city - Buri Ram
# ✅ Añadido a jerarquía: city - Buri Ram
# 🗑️ Eliminado de jerarquía: city - Surat Thani
# 🗑️ Eliminado de jerarquía: city - Krabi
# ✅ Añadido a jerarquía: city - Krabi
# ✅ Añadido a jerarquía: province - Krabi
# 🗑️ Eliminado de jerarquía: city - Sukhothai
# ✅ Añadido a jerarquía: city - Sukhothai
# ✅ Entidades guardadas en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6_final.jsonl

# %% [markdown]
# ## We plot how many sections are in the jsonl

# %%
import json
from collections import Counter

ruta = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_8.jsonl"

contador = Counter()
total = 0

with open(ruta, encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        entidad = json.loads(line)
        for key in entidad.keys():
            contador[key] += 1
        total += 1

print(f"Total de entidades: {total}\n")
print("Claves (secciones) encontradas, ordenadas por ocurrencias:\n")
for key, count in contador.most_common():
    print(f"{key}: {count}")
# Out:
# Total de entidades: 124
#
# Claves (secciones) encontradas, ordenadas por ocurrencias:
#
# entity_type: 124
# name: 124
# subtype: 124
# hierarchy: 124
# normalized_name: 124
# appearances: 124
# all_source_urls: 124
# lat: 102
# lon: 102
# type: 102
# description: 96
# wikidata_id: 32
# avg_visit_duration: 28

# %%
import sys
import os
from pathlib import Path

# Obtener la ruta absoluta del archivo
current_dir = Path.cwd()  # manual_postprocessing
auxs_dir = current_dir.parent / 'auxs'  # subir un nivel y entrar en auxs
normalized_cities_path = auxs_dir / 'normalized_cities.py'

# Importar usando importlib
import importlib.util
spec = importlib.util.spec_from_file_location("normalized_cities", str(normalized_cities_path))
normalized_cities = importlib.util.module_from_spec(spec)
sys.modules["normalized_cities"] = normalized_cities
spec.loader.exec_module(normalized_cities)

# Extraer las funciones y variables
NORMALIZED_CITIES = normalized_cities.NORMALIZED_CITIES
normalize_city = normalized_cities.normalize_city
get_city_info = normalized_cities.get_city_info

# Probar la normalización
print("=== PRUEBA DE NORMALIZACIÓN DE CIUDADES ===")

# Lista de ciudades para probar
ciudades_prueba = [
    "Bangkok City",
    "Chiangmai", 
    "Ko Samui",
    "Phi Phi",
    "Krung Thep",
    "Ciudad Desconocida"
]

for ciudad in ciudades_prueba:
    normalizada = normalize_city(ciudad)
    info = get_city_info(ciudad)
    
    if info:
        print(f"✅ {ciudad} → {normalizada}")
        print(f"   Variaciones: {info['variations']}")
    else:
        print(f"❌ {ciudad} → {normalizada} (no normalizada)")

print(f"\n=== ESTADÍSTICAS ===")
print(f"Total de ciudades normalizadas: {len(NORMALIZED_CITIES)}")

# Mostrar todas las ciudades con sus variaciones
print(f"\n=== TODAS LAS CIUDADES CON VARIACIONES ===")
for ciudad, variaciones in sorted(NORMALIZED_CITIES.items()):
    print(f"🏙️  {ciudad}:")
    for var in variaciones:
        print(f"   • {var}")
    print()
# Out:
# === PRUEBA DE NORMALIZACIÓN DE CIUDADES ===
# ✅ Bangkok City → Bangkok
#    Variaciones: ['Bangkok', 'Bangkok City', 'Krung Thep', 'Krung Thep Maha Nakhon', 'BKK', 'กรุงเทพมหานคร']
# ✅ Chiangmai → Chiang Mai
#    Variaciones: ['Chiang Mai', 'Chiangmai', 'Chiang-Mai', 'Chiang Mai City', 'เชียงใหม่']
# ✅ Ko Samui → Koh Samui
#    Variaciones: ['Koh Samui', 'Ko Samui', 'Samui Island', 'Samui', 'เกาะสมุย']
# ✅ Phi Phi → Koh Phi Phi
#    Variaciones: ['Koh Phi Phi', 'Ko Phi Phi', 'Phi Phi Islands', 'Phi Phi', 'เกาะพีพี']
# ✅ Krung Thep → Bangkok
#    Variaciones: ['Bangkok', 'Bangkok City', 'Krung Thep', 'Krung Thep Maha Nakhon', 'BKK', 'กรุงเทพมหานคร']
# ❌ Ciudad Desconocida → Ciudad Desconocida (no normalizada)
#
# === ESTADÍSTICAS ===
# Total de ciudades normalizadas: 15
#
# === TODAS LAS CIUDADES CON VARIACIONES ===
# 🏙️  Ayutthaya:
#    • Ayutthaya
#    • Ayutthaya Historical Park
#    • Ayutthaya City
#    • Phra Nakhon Si Ayutthaya
#    • พระนครศรีอยุธยา
#
# 🏙️  Bangkok:
#    • Bangkok
#    • Bangkok City
#    • Krung Thep
#    • Krung Thep Maha Nakhon
#    • BKK
#    • กรุงเทพมหานคร
#
# 🏙️  Chiang Mai:
#    • Chiang Mai
#    • Chiangmai
#    • Chiang-Mai
#    • Chiang Mai City
#    • เชียงใหม่
#
# 🏙️  Chiang Rai:
#    • Chiang Rai
#    • Chiangrai
#    • Chiang Rai City
#    • เชียงราย
#
# 🏙️  Hua Hin:
#    • Hua Hin
#    • Huahin
#    • Hua Hin Beach
#    • หัวหิน
#
# 🏙️  Kanchanaburi:
#    • Kanchanaburi
#    • Kanchanaburi Province
#    • กาญจนบุรี
#
# 🏙️  Koh Lanta:
#    • Koh Lanta
#    • Ko Lanta
#    • Lanta Island
#    • เกาะลันตา
#
# 🏙️  Koh Phangan:
#    • Koh Phangan
#    • Ko Phangan
#    • Phangan Island
#    • เกาะพะงัน
#
# 🏙️  Koh Phi Phi:
#    • Koh Phi Phi
#    • Ko Phi Phi
#    • Phi Phi Islands
#    • Phi Phi
#    • เกาะพีพี
#
# 🏙️  Koh Samui:
#    • Koh Samui
#    • Ko Samui
#    • Samui Island
#    • Samui
#    • เกาะสมุย
#
# 🏙️  Koh Tao:
#    • Koh Tao
#    • Ko Tao
#    • Tao Island
#    • เกาะเต่า
#
# 🏙️  Krabi:
#    • Krabi
#    • Krabi Town
#    • Krabi Province
#    • กระบี่
#
# 🏙️  Pattaya:
#    • Pattaya
#    • Pattaya City
#    • Pattaya Beach
#    • พัทยา
#
# 🏙️  Phuket:
#    • Phuket
#    • Phuket Island
#    • Phuket Town
#    • ภูเก็ต
#
# 🏙️  Sukhothai:
#    • Sukhothai
#    • Sukhothai Historical Park
#    • สุโขทัย

# %% [markdown]
# ## We delete the innecesary sections

# %%
import json
from pathlib import Path

input_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_6.jsonl"
output_path = r"D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_7.jsonl"

# Claves a eliminar
claves_a_quitar = [
    "source_url", "location_text", "images", "user_impressions", "agrupado_por",
    "entidades_originales", "official_website", "official_websites", "osm_uid",
    "price", "restrictions", "wikidata", "currency", "security", "lat", "lon",
    "nearby_suggestions"
]

n_modificados = 0
n_total = 0

with open(input_path, encoding="utf-8") as fin, open(output_path, "w", encoding="utf-8") as fout:
    for line in fin:
        if not line.strip():
            continue
        entidad = json.loads(line)
        n_total += 1

        # 1. Meter source_url en all_source_urls y eliminar source_url
        source_url = entidad.get("source_url")
        if source_url:
            all_urls = entidad.get("all_source_urls", [])
            if source_url not in all_urls:
                all_urls.append(source_url)
                entidad["all_source_urls"] = all_urls
            n_modificados += 1
        if "source_url" in entidad:
            del entidad["source_url"]

        # 2-8. Eliminar las claves indicadas
        for clave in claves_a_quitar:
            if clave in entidad:
                del entidad[clave]

        # Guardar la entidad limpia
        fout.write(json.dumps(entidad, ensure_ascii=False) + "\n")

print(f"Guardado en: {output_path}")
print(f"Entidades procesadas: {n_total}")
print(f"Entidades en las que se añadió source_url a all_source_urls: {n_modificados}")
# Out:
# Guardado en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_7.jsonl
# Entidades procesadas: 124
# Entidades en las que se añadió source_url a all_source_urls: 124

# %% [markdown]
# ## Deletion of unnecesary info and adding lat, long and type to the entity with osm_id

# %%
import json
import requests
import time

input_file = "D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_7.jsonl"
output_file = "D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_8.jsonl"

def get_osm_info(osm_id):
    try:
        if isinstance(osm_id, str) and osm_id.startswith("OSM:"):
            osm_id = osm_id.replace("OSM:", "")
        
        # Determinar el tipo correctamente
        if osm_id.startswith("R"):
            osm_type = "R"
            osm_number = osm_id[1:]
        elif osm_id.startswith("W"):
            osm_type = "W"
            osm_number = osm_id[1:]
        elif osm_id.startswith("N"):  # ← AÑADIR ESTA LÍNEA
            osm_type = "N"
            osm_number = osm_id[1:]
        else:
            osm_type = "W"
            osm_number = osm_id

        url = f"https://nominatim.openstreetmap.org/lookup?osm_ids={osm_type}{osm_number}&format=json"
        print(f"  → URL: {url}")
        headers = {
            "User-Agent": "TravelAppDataScript/1.2 (4@dominio.com)"
        }
        response = requests.get(url, headers=headers)
        if response.status_code == 200 and response.json():
            data = response.json()[0]
            print(f"  → Respuesta API: {data}")
            lat = data.get('lat')
            lon = data.get('lon')
            typ = data.get('type')
            print(f"  → Extraído: lat={lat}, lon={lon}, type={typ}")
            return lat, lon, typ
        else:
            print(f"  → Error en respuesta: {response.status_code}")
            return None, None, None
    except Exception as e:
        print(f"  → Error: {e}")
        return None, None, None
with open(input_file, "r", encoding="utf-8") as fin, open(output_file, "w", encoding="utf-8") as fout:
    for line in fin:
        entity = json.loads(line)
        lat, lon, typ = None, None, None
        
        # 1. PRIORIDAD: Si tiene osm_id directo → LLAMAR A LA API
        if "osm_id" in entity and entity["osm_id"]:
            print(f"\n=== {entity['name']} ===")
            print(f"Tiene osm_id: {entity['osm_id']}")
            lat, lon, typ = get_osm_info(entity["osm_id"])
            time.sleep(1)  # Respetar rate limit
            
        # 2. Si NO tiene osm_id directo pero tiene nominatim_match → EXTRAER DE AHÍ
        elif "nominatim_match" in entity and entity["nominatim_match"] and entity["nominatim_match"].get("data"):
            print(f"\n=== {entity['name']} ===")
            print(f"Tiene nominatim_match")
            nom_data = entity["nominatim_match"]["data"]
            lat = nom_data.get("lat")
            lon = nom_data.get("lon")
            typ = nom_data.get("type")
            print(f"  → Extraído de nominatim: lat={lat}, lon={lon}, type={typ}")
        
        # 3. Mostrar lo que se va a añadir
        print(f"  → AÑADIENDO A LA ENTIDAD: lat={lat}, lon={lon}, type={typ}")
        
        # 4. Añadir los campos al nivel superior
        if lat is not None:
            entity["lat"] = lat
        if lon is not None:
            entity["lon"] = lon
        if typ is not None:
            entity["type"] = typ
            
        # 5. Eliminar los campos originales
        entity.pop("osm_id", None)
        entity.pop("nominatim_match", None)
        
        fout.write(json.dumps(entity, ensure_ascii=False) + "\n")

print("\nProceso completado!")
# Out:
# === Bangkok ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.7524938, lon=100.4935089, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=13.7524938, lon=100.4935089, type=administrative
#
# === Ayutthaya ===
# Tiene osm_id: OSM:R10839539
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R10839539&format=json
#   → Respuesta API: {'place_id': 237853454, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10839539, 'lat': '14.3535427', 'lon': '100.5645684', 'class': 'boundary', 'type': 'administrative', 'place_rank': 14, 'importance': 0.49306700633523093, 'addresstype': 'city', 'name': 'เทศบาลนครพระนครศรีอยุธยา', 'display_name': 'เทศบาลนครพระนครศรีอยุธยา, อำเภอพระนครศรีอยุธยา, จังหวัดพระนครศรีอยุธยา, 13000, ประเทศไทย', 'address': {'city': 'เทศบาลนครพระนครศรีอยุธยา', 'county': 'อำเภอพระนครศรีอยุธยา', 'province': 'จังหวัดพระนครศรีอยุธยา', 'ISO3166-2-lvl4': 'TH-14', 'postcode': '13000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['14.3320045', '14.3782033', '100.5430696', '100.5885023']}
#   → Extraído: lat=14.3535427, lon=100.5645684, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=14.3535427, lon=100.5645684, type=administrative
#
# === Chiang Rai ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.9068867, lon=99.8332739, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=19.9068867, lon=99.8332739, type=administrative
#
# === Koh Samui ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.5013944, lon=99.9956193, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=9.5013944, lon=99.9956193, type=island
#
# === Phuket ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=7.9366015, lon=98.3529292, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=7.9366015, lon=98.3529292, type=administrative
#
# === Sukhothai ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.0109180, lon=99.8203682, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=17.0109180, lon=99.8203682, type=town
#
# === Koh Lipe ===
# Tiene osm_id: OSM:R15406584
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R15406584&format=json
#   → Respuesta API: {'place_id': 237573280, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 15406584, 'lat': '6.4875909', 'lon': '99.3024656', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17336833524071105, 'addresstype': 'island', 'name': 'เกาะหลีเป๊ะ', 'display_name': 'เกาะหลีเป๊ะ, บ้านเกาะหลีเป๊ะ, Mueang Satun, จังหวัดสตูล, ประเทศไทย', 'address': {'island': 'เกาะหลีเป๊ะ', 'village': 'บ้านเกาะหลีเป๊ะ', 'county': 'Mueang Satun', 'province': 'จังหวัดสตูล', 'ISO3166-2-lvl4': 'TH-91', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['6.4794166', '6.4958154', '99.2838267', '99.3111946']}
#   → Extraído: lat=6.4875909, lon=99.3024656, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=6.4875909, lon=99.3024656, type=island
#
# === Koh Tao ===
# Tiene osm_id: OSM:W23897168
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W23897168&format=json
#   → Respuesta API: {'place_id': 237369204, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23897168, 'lat': '10.0921822', 'lon': '99.8395362', 'class': 'boundary', 'type': 'administrative', 'place_rank': 14, 'importance': 0.4511118816665999, 'addresstype': 'island', 'name': 'เกาะเต่า', 'display_name': 'เกาะเต่า, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย', 'address': {'island': 'เกาะเต่า', 'county': 'Ko Pha-Ngan', 'province': 'จังหวัดสุราษฎร์ธานี', 'ISO3166-2-lvl4': 'TH-84', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['10.0580454', '10.1262155', '99.8150957', '99.8558193']}
#   → Extraído: lat=10.0921822, lon=99.8395362, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=10.0921822, lon=99.8395362, type=administrative
#
# === Krabi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.0634637, lon=98.9162345, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=8.0634637, lon=98.9162345, type=town
#
# === Krabi ===
# Tiene osm_id: OSM:R1908779
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R1908779&format=json
#   → Respuesta API: {'place_id': 237705197, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1908779, 'lat': '8.1111653', 'lon': '99.1097298', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5054086527540813, 'addresstype': 'province', 'name': 'จังหวัดกระบี่', 'display_name': 'จังหวัดกระบี่, ประเทศไทย', 'address': {'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.0760849', '8.6818403', '98.5996448', '99.4149930']}
#   → Extraído: lat=8.1111653, lon=99.1097298, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=8.1111653, lon=99.1097298, type=administrative
#
# === Phi Phi Islands ===
# Tiene osm_id: OSM:R6099530
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R6099530&format=json
#   → Respuesta API: {'place_id': 237365229, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6099530, 'lat': '7.7522403', 'lon': '98.7766434', 'class': 'place', 'type': 'archipelago', 'place_rank': 22, 'importance': 0.10670466849774927, 'addresstype': 'archipelago', 'name': 'หมู่เกาะพีพี', 'display_name': 'หมู่เกาะพีพี, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81210, ประเทศไทย', 'address': {'archipelago': 'หมู่เกาะพีพี', 'city': 'ตำบลอ่าวนาง', 'county': 'Mueang Krabi', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'postcode': '81210', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.6540154', '7.8213673', '98.7555058', '98.7981870']}
#   → Extraído: lat=7.7522403, lon=98.7766434, type=archipelago
#   → AÑADIENDO A LA ENTIDAD: lat=7.7522403, lon=98.7766434, type=archipelago
#
# === Chiang Mai ===
# Tiene osm_id: OSM:R19033670
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R19033670&format=json
#   → Respuesta API: {'place_id': 405364400, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 19033670, 'lat': '18.7874930', 'lon': '98.9672428', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.24006187914854654, 'addresstype': 'county', 'name': 'Mueang Chiang Mai', 'display_name': 'Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย', 'address': {'county': 'Mueang Chiang Mai', 'province': 'จังหวัดเชียงใหม่', 'ISO3166-2-lvl4': 'TH-50', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.6991899', '18.8758087', '98.8616668', '99.0485707']}
#   → Extraído: lat=18.7874930, lon=98.9672428, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=18.7874930, lon=98.9672428, type=administrative
#
# === Koh Phangan ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.7349503, lon=100.0305711, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=9.7349503, lon=100.0305711, type=island
#
# === Lopburi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.8023289, lon=100.6146858, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=14.8023289, lon=100.6146858, type=town
#
# === Pai ===
# Tiene osm_id: OSM:N262585787
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N262585787&format=json
#   → Respuesta API: {'place_id': 222342435, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 262585787, 'lat': '19.3581061', 'lon': '98.4405794', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.26511848687494144, 'addresstype': 'town', 'name': 'ปาย', 'display_name': 'ปาย, Pai, จังหวัดแม่ฮ่องสอน, 58130, ประเทศไทย', 'address': {'town': 'ปาย', 'county': 'Pai', 'province': 'จังหวัดแม่ฮ่องสอน', 'ISO3166-2-lvl4': 'TH-58', 'postcode': '58130', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['19.3181061', '19.3981061', '98.4005794', '98.4805794']}
#   → Extraído: lat=19.3581061, lon=98.4405794, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=19.3581061, lon=98.4405794, type=town
#
# === Phuket ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=7.9366015, lon=98.3529292, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=7.9366015, lon=98.3529292, type=administrative
#
# === Koh Lanta ===
# Tiene osm_id: OSM:W51250144
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W51250144&format=json
#   → Respuesta API: {'place_id': 235155264, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 51250144, 'lat': '7.5598420', 'lon': '99.0572888', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17338333485923552, 'addresstype': 'island', 'name': 'เกาะลันตาใหญ่', 'display_name': 'เกาะลันตาใหญ่, หาดคลองโขง, ศาลาด่าน, Ko Lanta, จังหวัดกระบี่, ประเทศไทย', 'address': {'island': 'เกาะลันตาใหญ่', 'village': 'หาดคลองโขง', 'municipality': 'ศาลาด่าน', 'county': 'Ko Lanta', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.4671015', '7.6515369', '99.0185148', '99.1110020']}
#   → Extraído: lat=7.5598420, lon=99.0572888, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=7.5598420, lon=99.0572888, type=island
#
# === Koh Chang ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=12.0546168, lon=102.3373426, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=12.0546168, lon=102.3373426, type=island
#
# === Pattaya ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=12.9366924, lon=100.8865002, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=12.9366924, lon=100.8865002, type=administrative
#
# === Kanchannaburi ===
# Tiene osm_id: OSM:N301331954
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N301331954&format=json
#   → Respuesta API: {'place_id': 234591091, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 301331954, 'lat': '14.0227073', 'lon': '99.5323173', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.42745565995384655, 'addresstype': 'town', 'name': 'กาญจนบุรี', 'display_name': 'กาญจนบุรี, ปากแพรก, Mueang Kanchanaburi, จังหวัดกาญจนบุรี, 71000, ประเทศไทย', 'address': {'town': 'กาญจนบุรี', 'municipality': 'ปากแพรก', 'county': 'Mueang Kanchanaburi', 'province': 'จังหวัดกาญจนบุรี', 'ISO3166-2-lvl4': 'TH-71', 'postcode': '71000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['13.9827073', '14.0627073', '99.4923173', '99.5723173']}
#   → Extraído: lat=14.0227073, lon=99.5323173, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=14.0227073, lon=99.5323173, type=town
#
# === Doi Inthanon ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.5884834, lon=98.4874637, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=18.5884834, lon=98.4874637, type=attraction
#
# === Kanchanaburi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.0227073, lon=99.5323173, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=14.0227073, lon=99.5323173, type=town
#
# === Phitsanulok ===
# Tiene osm_id: OSM:N8643175475
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N8643175475&format=json
#   → Respuesta API: {'place_id': 222183518, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8643175475, 'lat': '16.8157611', 'lon': '100.2634423', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.45539959252673184, 'addresstype': 'city', 'name': 'พิษณุโลก', 'display_name': 'พิษณุโลก, อรัญญิก, อำเภอเมืองพิษณุโลก, จังหวัดพิษณุโลก, 65000, ประเทศไทย', 'address': {'city': 'พิษณุโลก', 'municipality': 'อรัญญิก', 'county': 'อำเภอเมืองพิษณุโลก', 'province': 'จังหวัดพิษณุโลก', 'ISO3166-2-lvl4': 'TH-65', 'postcode': '65000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['16.6557611', '16.9757611', '100.1034423', '100.4234423']}
#   → Extraído: lat=16.8157611, lon=100.2634423, type=city
#   → AÑADIENDO A LA ENTIDAD: lat=16.8157611, lon=100.2634423, type=city
#
# === Similan Islands ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.6232726, lon=97.6408792, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=8.6232726, lon=97.6408792, type=island
#
# === Sukhothai Historical Park ===
# Tiene osm_id: OSM:W538179351
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W538179351&format=json
#   → Respuesta API: {'place_id': 222129217, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 538179351, 'lat': '17.0203334', 'lon': '99.7038571', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 0.415799664785045, 'addresstype': 'tourism', 'name': 'อุทยานประวัติศาสตร์สุโขทัย', 'display_name': 'อุทยานประวัติศาสตร์สุโขทัย, ถนนจรดวิถีถ่อง, บ้านศรีชุม, เมืองเก่า, Mueang Sukhothai, จังหวัดสุโขทัย, 64210, ประเทศไทย', 'address': {'tourism': 'อุทยานประวัติศาสตร์สุโขทัย', 'road': 'ถนนจรดวิถีถ่อง', 'hamlet': 'บ้านศรีชุม', 'town': 'เมืองเก่า', 'county': 'Mueang Sukhothai', 'province': 'จังหวัดสุโขทัย', 'ISO3166-2-lvl4': 'TH-64', 'postcode': '64210', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['17.0115920', '17.0252133', '99.6950686', '99.7127467']}
#   → Extraído: lat=17.0203334, lon=99.7038571, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=17.0203334, lon=99.7038571, type=attraction
#
# === Wat Rong Khun ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.8242473, lon=99.7632226, type=artwork
#   → AÑADIENDO A LA ENTIDAD: lat=19.8242473, lon=99.7632226, type=artwork
#
# === Koh Samet ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=12.5523080, lon=101.4482841, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=12.5523080, lon=101.4482841, type=island
#
# === Khao Sok National Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.0686898, lon=98.5738024, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=9.0686898, lon=98.5738024, type=national_park
#
# === Mae Hong Son ===
# Tiene osm_id: OSM:N301515447
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N301515447&format=json
#   → Respuesta API: {'place_id': 222350775, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 301515447, 'lat': '19.3015068', 'lon': '97.9666073', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3890858107442828, 'addresstype': 'town', 'name': 'แม่ฮ่องสอน', 'display_name': 'แม่ฮ่องสอน, จังหวัดแม่ฮ่องสอน, 58000, ประเทศไทย', 'address': {'town': 'แม่ฮ่องสอน', 'district': 'แม่ฮ่องสอน', 'province': 'จังหวัดแม่ฮ่องสอน', 'ISO3166-2-lvl4': 'TH-58', 'postcode': '58000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['19.2615068', '19.3415068', '97.9266073', '98.0066073']}
#   → Extraído: lat=19.3015068, lon=97.9666073, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=19.3015068, lon=97.9666073, type=town
#
# === Railay ===
# Tiene osm_id: OSM:N2421053017
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2421053017&format=json
#   → Respuesta API: {'place_id': 237511311, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2421053017, 'lat': '8.0106758', 'lon': '98.8396583', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.26074447183303784, 'addresstype': 'hamlet', 'name': 'อ่าวไร่เลย์', 'display_name': 'อ่าวไร่เลย์, Mueang Krabi, จังหวัดกระบี่, 81000, ประเทศไทย', 'address': {'hamlet': 'อ่าวไร่เลย์', 'county': 'Mueang Krabi', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'postcode': '81000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.9906758', '8.0306758', '98.8196583', '98.8596583']}
#   → Extraído: lat=8.0106758, lon=98.8396583, type=hamlet
#   → AÑADIENDO A LA ENTIDAD: lat=8.0106758, lon=98.8396583, type=hamlet
#
# === Doi Suthep ===
# Tiene osm_id: OSM:N2082718893
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2082718893&format=json
#   → Respuesta API: {'place_id': 221370761, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2082718893, 'lat': '18.8166077', 'lon': '98.8923600', 'class': 'natural', 'type': 'peak', 'place_rank': 18, 'importance': 0.29503227113851116, 'addresstype': 'peak', 'name': 'ดอยสุเทพ', 'display_name': 'ดอยสุเทพ, บ้านภูพิงค์ฯ, ป่าแดด, Mueang Chiang Mai, จังหวัดเชียงใหม่, ประเทศไทย', 'address': {'peak': 'ดอยสุเทพ', 'village': 'บ้านภูพิงค์ฯ', 'municipality': 'ป่าแดด', 'county': 'Mueang Chiang Mai', 'province': 'จังหวัดเชียงใหม่', 'ISO3166-2-lvl4': 'TH-50', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.8165577', '18.8166577', '98.8923100', '98.8924100']}
#   → Extraído: lat=18.8166077, lon=98.8923600, type=peak
#   → AÑADIENDO A LA ENTIDAD: lat=18.8166077, lon=98.8923600, type=peak
#
# === Koh Kood ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=11.6621551, lon=102.5681054, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=11.6621551, lon=102.5681054, type=island
#
# === Wat Pho ===
# Tiene osm_id: OSM:R11169995
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R11169995&format=json
#   → Respuesta API: {'place_id': 238377666, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11169995, 'lat': '13.7463456', 'lon': '100.4927381', 'class': 'amenity', 'type': 'place_of_worship', 'place_rank': 30, 'importance': 0.4193779508691581, 'addresstype': 'amenity', 'name': 'วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร', 'display_name': 'วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร, ถนนเจริญกรุง, ชุมชนท่าเตียน, แขวงพระบรมมหาราชวัง, เขตพระนคร, กรุงเทพมหานคร, 10200, ประเทศไทย', 'address': {'amenity': 'วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร', 'road': 'ถนนเจริญกรุง', 'neighbourhood': 'ชุมชนท่าเตียน', 'quarter': 'แขวงพระบรมมหาราชวัง', 'suburb': 'เขตพระนคร', 'city': 'กรุงเทพมหานคร', 'ISO3166-2-lvl4': 'TH-10', 'postcode': '10200', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['13.7441060', '13.7474768', '100.4911341', '100.4944294']}
#   → Extraído: lat=13.7463456, lon=100.4927381, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=13.7463456, lon=100.4927381, type=place_of_worship
#
# === Erawan Waterfalls ===
# Tiene osm_id: OSM:N2509420743
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2509420743&format=json
#   → Respuesta API: {'place_id': 234582234, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2509420743, 'lat': '14.3682867', 'lon': '99.1442969', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 4.0000762951049326e-05, 'addresstype': 'tourism', 'name': 'Erawan Waterfall', 'display_name': 'Erawan Waterfall, Bamboo Forest Nature Trail, เอราวัณ, Si Sawat, จังหวัดกาญจนบุรี, 71250, ประเทศไทย', 'address': {'tourism': 'Erawan Waterfall', 'road': 'Bamboo Forest Nature Trail', 'town': 'เอราวัณ', 'county': 'Si Sawat', 'province': 'จังหวัดกาญจนบุรี', 'ISO3166-2-lvl4': 'TH-71', 'postcode': '71250', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['14.3682367', '14.3683367', '99.1442469', '99.1443469']}
#   → Extraído: lat=14.3682867, lon=99.1442969, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=14.3682867, lon=99.1442969, type=attraction
#
# === Elephant Nature Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.2146830, lon=98.8616387, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=19.2146830, lon=98.8616387, type=attraction
#
# === Ao Nang ===
# Tiene osm_id: OSM:N633029474
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N633029474&format=json
#   → Respuesta API: {'place_id': 236717144, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 633029474, 'lat': '8.0321024', 'lon': '98.8225499', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.30544692142489355, 'addresstype': 'village', 'name': 'บ้านอ่าวนาง', 'display_name': 'บ้านอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81180, ประเทศไทย', 'address': {'village': 'บ้านอ่าวนาง', 'county': 'Mueang Krabi', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'postcode': '81180', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['8.0121024', '8.0521024', '98.8025499', '98.8425499']}
#   → Extraído: lat=8.0321024, lon=98.8225499, type=village
#   → AÑADIENDO A LA ENTIDAD: lat=8.0321024, lon=98.8225499, type=village
#
# === Wat Phra That Doi Suthep ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.8035942, lon=98.9202265, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.8035942, lon=98.9202265, type=place_of_worship
#
# === Nan ===
# Tiene osm_id: OSM:N924671402
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N924671402&format=json
#   → Respuesta API: {'place_id': 220790617, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 924671402, 'lat': '18.7778874', 'lon': '100.7737320', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3963890808788049, 'addresstype': 'town', 'name': 'น่าน', 'display_name': 'น่าน, ดู่ใต้, Mueang Nan, จังหวัดน่าน, 55000, ประเทศไทย', 'address': {'town': 'น่าน', 'municipality': 'ดู่ใต้', 'county': 'Mueang Nan', 'province': 'จังหวัดน่าน', 'ISO3166-2-lvl4': 'TH-55', 'postcode': '55000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.7378874', '18.8178874', '100.7337320', '100.8137320']}
#   → Extraído: lat=18.7778874, lon=100.7737320, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=18.7778874, lon=100.7737320, type=town
#
# === Koh Yao Noi ===
# Tiene osm_id: OSM:R6174290
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R6174290&format=json
#   → Respuesta API: {'place_id': 237231565, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6174290, 'lat': '8.1338522', 'lon': '98.6099377', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17338333485923552, 'addresstype': 'island', 'name': 'เกาะยาวน้อย', 'display_name': 'เกาะยาวน้อย, แหลมยาง, เกาะยาวใหญ่, Ko Yao, จังหวัดพังงา, ประเทศไทย', 'address': {'island': 'เกาะยาวน้อย', 'village': 'แหลมยาง', 'municipality': 'เกาะยาวใหญ่', 'county': 'Ko Yao', 'province': 'จังหวัดพังงา', 'ISO3166-2-lvl4': 'TH-82', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['8.0802498', '8.1872163', '98.5624657', '98.6389716']}
#   → Extraído: lat=8.1338522, lon=98.6099377, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=8.1338522, lon=98.6099377, type=island
#
# === Chumphon ===
# Tiene osm_id: OSM:R1908774
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R1908774&format=json
#   → Respuesta API: {'place_id': 237226111, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1908774, 'lat': '10.3782724', 'lon': '99.0077685', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5000467079218495, 'addresstype': 'province', 'name': 'จังหวัดชุมพร', 'display_name': 'จังหวัดชุมพร, ประเทศไทย', 'address': {'province': 'จังหวัดชุมพร', 'ISO3166-2-lvl4': 'TH-86', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['9.6008767', '11.0339420', '98.6276183', '100.0620950']}
#   → Extraído: lat=10.3782724, lon=99.0077685, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=10.3782724, lon=99.0077685, type=administrative
#
# === Wat Phra Singh ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.7882068, lon=98.9813773, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.7882068, lon=98.9813773, type=place_of_worship
#
# === Bahía de Phang Nga ===
# Tiene osm_id: OSM:N2463498683
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2463498683&format=json
#   → Respuesta API: {'place_id': 237154538, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2463498683, 'lat': '8.2916672', 'lon': '98.5527728', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.39284077117933514, 'addresstype': 'bay', 'name': 'Phang Nga Bay', 'display_name': 'Phang Nga Bay, จังหวัดพังงา, ประเทศไทย', 'address': {'bay': 'Phang Nga Bay', 'province': 'จังหวัดพังงา', 'ISO3166-2-lvl4': 'TH-82', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['8.2916172', '8.2917172', '98.5527228', '98.5528228']}
#   → Extraído: lat=8.2916672, lon=98.5527728, type=bay
#   → AÑADIENDO A LA ENTIDAD: lat=8.2916672, lon=98.5527728, type=bay
#
# === Maya Bay ===
# Tiene osm_id: OSM:N5314772921
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N5314772921&format=json
#   → Respuesta API: {'place_id': 237104024, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5314772921, 'lat': '7.6766252', 'lon': '98.7661169', 'class': 'tourism', 'type': 'viewpoint', 'place_rank': 30, 'importance': 9.99999999995449e-06, 'addresstype': 'tourism', 'name': 'อ่าวมาหยา', 'display_name': 'อ่าวมาหยา, ตำบลอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, ประเทศไทย', 'address': {'tourism': 'อ่าวมาหยา', 'city': 'ตำบลอ่าวนาง', 'county': 'Mueang Krabi', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.6765752', '7.6766752', '98.7660669', '98.7661669']}
#   → Extraído: lat=7.6766252, lon=98.7661169, type=viewpoint
#   → AÑADIENDO A LA ENTIDAD: lat=7.6766252, lon=98.7661169, type=viewpoint
#
# === James Bond Island ===
# Tiene osm_id: OSM:W239590609
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W239590609&format=json
#   → Respuesta API: {'place_id': 236863241, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 239590609, 'lat': '8.2754220', 'lon': '98.5005775', 'class': 'natural', 'type': 'coastline;cliff', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'islet', 'name': 'เขาตะปู', 'display_name': 'เขาตะปู, จังหวัดพังงา, ประเทศไทย', 'address': {'islet': 'เขาตะปู', 'province': 'จังหวัดพังงา', 'ISO3166-2-lvl4': 'TH-82', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['8.2753365', '8.2755005', '98.5004722', '98.5006783']}
#   → Extraído: lat=8.2754220, lon=98.5005775, type=coastline;cliff
#   → AÑADIENDO A LA ENTIDAD: lat=8.2754220, lon=98.5005775, type=coastline;cliff
#
# === Koh Yao Yai ===
# Tiene osm_id: OSM:W23513264
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W23513264&format=json
#   → Respuesta API: {'place_id': 405404788, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23513264, 'lat': '8.0029853', 'lon': '98.5955320', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.1341073487755671, 'addresstype': 'island', 'name': 'เกาะยาวใหญ่', 'display_name': 'เกาะยาวใหญ่, จังหวัดพังงา, 82160, ประเทศไทย', 'address': {'island': 'เกาะยาวใหญ่', 'province': 'จังหวัดพังงา', 'ISO3166-2-lvl4': 'TH-82', 'postcode': '82160', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.8881229', '8.1169459', '98.5246051', '98.6141180']}
#   → Extraído: lat=8.0029853, lon=98.5955320, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=8.0029853, lon=98.5955320, type=administrative
#
# === Koh Muk ===
# Tiene osm_id: OSM:R12088737
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R12088737&format=json
#   → Respuesta API: {'place_id': 237457124, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12088737, 'lat': '7.3718307', 'lon': '99.2973031', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17337083466849773, 'addresstype': 'island', 'name': 'เกาะมุก', 'display_name': 'เกาะมุก, หาดฝรั่ง, Kantang, จังหวัดตรัง, 92100, ประเทศไทย', 'address': {'island': 'เกาะมุก', 'village': 'หาดฝรั่ง', 'county': 'Kantang', 'province': 'จังหวัดตรัง', 'ISO3166-2-lvl4': 'TH-92', 'postcode': '92100', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.3527920', '7.3909317', '99.2806720', '99.3152471']}
#   → Extraído: lat=7.3718307, lon=99.2973031, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=7.3718307, lon=99.2973031, type=island
#
# === Railay ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.0106758, lon=98.8396583, type=hamlet
#   → AÑADIENDO A LA ENTIDAD: lat=8.0106758, lon=98.8396583, type=hamlet
#
# === Damnoen Saduak Floating Market ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.5190148, lon=99.9593460, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=13.5190148, lon=99.9593460, type=attraction
#
# === Khao Yai National Park ===
# Tiene osm_id: OSM:R2971358
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R2971358&format=json
#   → Respuesta API: {'place_id': 235775806, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2971358, 'lat': '14.3259499', 'lon': '101.5762598', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.4546765180868806, 'addresstype': 'national_park', 'name': 'อุทยานแห่งชาติเขาใหญ่', 'display_name': 'อุทยานแห่งชาติเขาใหญ่, จังหวัดปราจีนบุรี, ประเทศไทย', 'address': {'national_park': 'อุทยานแห่งชาติเขาใหญ่', 'province': 'จังหวัดปราจีนบุรี', 'ISO3166-2-lvl4': 'TH-25', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['14.0773073', '14.5746428', '101.1266613', '101.8960229']}
#   → Extraído: lat=14.3259499, lon=101.5762598, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=14.3259499, lon=101.5762598, type=national_park
#
# === White Temple ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.8239843, lon=99.7629125, type=artwork
#   → AÑADIENDO A LA ENTIDAD: lat=19.8239843, lon=99.7629125, type=artwork
#
# === Blue Temple ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.9233553, lon=99.8419600, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=19.9233553, lon=99.8419600, type=place_of_worship
#
# === Golden Triangle ===
# Tiene osm_id: OSM:N11010152466
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N11010152466&format=json
#   → Respuesta API: {'place_id': 222385434, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11010152466, 'lat': '20.3528484', 'lon': '100.0830641', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'tourism', 'name': 'Golden Triangle', 'display_name': 'Golden Triangle, ถนนเชียงแสน-แม่สาย, Ban Sob Ruak, อำเภอเชียงแสน, เวียง, Chiang Saen, จังหวัดเชียงราย, ประเทศไทย', 'address': {'tourism': 'Golden Triangle', 'road': 'ถนนเชียงแสน-แม่สาย', 'village': 'Ban Sob Ruak', 'town': 'อำเภอเชียงแสน', 'municipality': 'เวียง', 'county': 'Chiang Saen', 'province': 'จังหวัดเชียงราย', 'ISO3166-2-lvl4': 'TH-57', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['20.3527984', '20.3528984', '100.0830141', '100.0831141']}
#   → Extraído: lat=20.3528484, lon=100.0830641, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=20.3528484, lon=100.0830641, type=attraction
#
# === Wat Umong ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.7831026, lon=98.9525787, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.7831026, lon=98.9525787, type=place_of_worship
#
# === Wat Si Chum ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.0268269, lon=99.6931342, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=17.0268269, lon=99.6931342, type=attraction
#
# === Wat Chedi Luang ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.7871427, lon=98.9867840, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.7871427, lon=98.9867840, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=None, lon=None, type=None
#
# === Nakhon Si Thammarat ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.4327951, lon=99.9627967, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=8.4327951, lon=99.9627967, type=administrative
#
# === Sukhothai Historical Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.0203334, lon=99.7038571, type=attraction
#   → AÑADIENDO A LA ENTIDAD: lat=17.0203334, lon=99.7038571, type=attraction
#
# === Ayutthaya ===
# Tiene osm_id: OSM:W79265090
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W79265090&format=json
#   → Respuesta API: {'place_id': 237456734, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 79265090, 'lat': '14.3535461', 'lon': '100.5622548', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.40856033362278366, 'addresstype': 'park', 'name': 'อุทยานประวัติศาสตร์พระนครศรีอยุธยา', 'display_name': 'อุทยานประวัติศาสตร์พระนครศรีอยุธยา, ตำบลประตูชัย, เทศบาลนครพระนครศรีอยุธยา, อำเภอพระนครศรีอยุธยา, จังหวัดพระนครศรีอยุธยา, 13000, ประเทศไทย', 'address': {'park': 'อุทยานประวัติศาสตร์พระนครศรีอยุธยา', 'city_district': 'ตำบลประตูชัย', 'city': 'เทศบาลนครพระนครศรีอยุธยา', 'county': 'อำเภอพระนครศรีอยุธยา', 'province': 'จังหวัดพระนครศรีอยุธยา', 'ISO3166-2-lvl4': 'TH-14', 'postcode': '13000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['14.3462906', '14.3608863', '100.5495143', '100.5688463']}
#   → Extraído: lat=14.3535461, lon=100.5622548, type=park
#   → AÑADIENDO A LA ENTIDAD: lat=14.3535461, lon=100.5622548, type=park
#
# === Chiang Rai ===
# Tiene osm_id: OSM:R1908772
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R1908772&format=json
#   → Respuesta API: {'place_id': 222133378, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1908772, 'lat': '19.7589517', 'lon': '99.6734592', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.520347462498333, 'addresstype': 'province', 'name': 'จังหวัดเชียงราย', 'display_name': 'จังหวัดเชียงราย, ประเทศไทย', 'address': {'province': 'จังหวัดเชียงราย', 'ISO3166-2-lvl4': 'TH-57', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.9999028', '20.4648135', '99.2579856', '100.5784960']}
#   → Extraído: lat=19.7589517, lon=99.6734592, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=19.7589517, lon=99.6734592, type=administrative
#
# === Mae Hong Son ===
# Tiene osm_id: OSM:N301515447
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N301515447&format=json
#   → Respuesta API: {'place_id': 222350775, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 301515447, 'lat': '19.3015068', 'lon': '97.9666073', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3890858107442828, 'addresstype': 'town', 'name': 'แม่ฮ่องสอน', 'display_name': 'แม่ฮ่องสอน, จังหวัดแม่ฮ่องสอน, 58000, ประเทศไทย', 'address': {'town': 'แม่ฮ่องสอน', 'district': 'แม่ฮ่องสอน', 'province': 'จังหวัดแม่ฮ่องสอน', 'ISO3166-2-lvl4': 'TH-58', 'postcode': '58000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['19.2615068', '19.3415068', '97.9266073', '98.0066073']}
#   → Extraído: lat=19.3015068, lon=97.9666073, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=19.3015068, lon=97.9666073, type=town
#
# === Similan Islands ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.6232726, lon=97.6408792, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=8.6232726, lon=97.6408792, type=island
#
# === Ko Nang Yuan ===
# Tiene osm_id: OSM:R7155241
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R7155241&format=json
#   → Respuesta API: {'place_id': 237226227, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7155241, 'lat': '10.1150750', 'lon': '99.8141009', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.1333433333333333, 'addresstype': 'islet', 'name': 'เกาะนางยวน', 'display_name': 'เกาะนางยวน, Ko Pha-Ngan, จังหวัดสุราษฎร์ธานี, ประเทศไทย', 'address': {'islet': 'เกาะนางยวน', 'county': 'Ko Pha-Ngan', 'province': 'จังหวัดสุราษฎร์ธานี', 'ISO3166-2-lvl4': 'TH-84', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['10.1139591', '10.1184744', '99.8127565', '99.8162064']}
#   → Extraído: lat=10.1150750, lon=99.8141009, type=islet
#   → AÑADIENDO A LA ENTIDAD: lat=10.1150750, lon=99.8141009, type=islet
#
# === Suvarnabhumi Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.6818766, lon=100.7485803, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=13.6818766, lon=100.7485803, type=aerodrome
#
# === Don Muang Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.9122207, lon=100.6035314, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=13.9122207, lon=100.6035314, type=aerodrome
#
# === Hualamphong Station ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.7406695, lon=100.5170030, type=train_station
#   → AÑADIENDO A LA ENTIDAD: lat=13.7406695, lon=100.5170030, type=train_station
#
# === Erawan National Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.3486383, lon=99.0697259, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=14.3486383, lon=99.0697259, type=national_park
#
# === Ko Samui ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.5013944, lon=99.9956193, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=9.5013944, lon=99.9956193, type=island
#
# === Chiang Khan ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.8709175, lon=101.7237783, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=17.8709175, lon=101.7237783, type=administrative
#
# === Wat Pa Phu Kon ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.9226270, lon=102.1183172, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=17.9226270, lon=102.1183172, type=place_of_worship
#
# === Phanom Rung ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.5330357, lon=102.9418343, type=protected_area
#   → AÑADIENDO A LA ENTIDAD: lat=14.5330357, lon=102.9418343, type=protected_area
#
# === Kanchanaburi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.0227073, lon=99.5323173, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=14.0227073, lon=99.5323173, type=town
#
# === Templo Blanco (Wat Rong Khun) ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.8242473, lon=99.7632226, type=artwork
#   → AÑADIENDO A LA ENTIDAD: lat=19.8242473, lon=99.7632226, type=artwork
#
# === Buri Ram ===
# Tiene osm_id: OSM:N257904596
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N257904596&format=json
#   → Respuesta API: {'place_id': 353027651, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 257904596, 'lat': '14.9955693', 'lon': '103.1079187', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5113652439874941, 'addresstype': 'city', 'name': 'บุรีรัมย์', 'display_name': 'บุรีรัมย์, ตำบลในเมือง, เทศบาลนครบุรีรัมย์, อำเภอเมืองบุรีรัมย์, จังหวัดบุรีรัมย์, 31009, ประเทศไทย', 'address': {'city': 'บุรีรัมย์', 'municipality': 'เทศบาลนครบุรีรัมย์', 'county': 'อำเภอเมืองบุรีรัมย์', 'province': 'จังหวัดบุรีรัมย์', 'ISO3166-2-lvl4': 'TH-31', 'postcode': '31009', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['14.8355693', '15.1555693', '102.9479187', '103.2679187']}
#   → Extraído: lat=14.9955693, lon=103.1079187, type=city
#   → AÑADIENDO A LA ENTIDAD: lat=14.9955693, lon=103.1079187, type=city
#
# === Ao Nang ===
# Tiene osm_id: OSM:N633029474
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N633029474&format=json
#   → Respuesta API: {'place_id': 236717144, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 633029474, 'lat': '8.0321024', 'lon': '98.8225499', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.30544692142489355, 'addresstype': 'village', 'name': 'บ้านอ่าวนาง', 'display_name': 'บ้านอ่าวนาง, Mueang Krabi, จังหวัดกระบี่, 81180, ประเทศไทย', 'address': {'village': 'บ้านอ่าวนาง', 'county': 'Mueang Krabi', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'postcode': '81180', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['8.0121024', '8.0521024', '98.8025499', '98.8425499']}
#   → Extraído: lat=8.0321024, lon=98.8225499, type=village
#   → AÑADIENDO A LA ENTIDAD: lat=8.0321024, lon=98.8225499, type=village
#
# === Ratchaburi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.5390670, lon=99.8197035, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=13.5390670, lon=99.8197035, type=town
#
# === Samut Songkhram ===
# Tiene osm_id: OSM:N585128821
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N585128821&format=json
#   → Respuesta API: {'place_id': 238367849, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 585128821, 'lat': '13.4086617', 'lon': '100.0004940', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3680629685588618, 'addresstype': 'town', 'name': 'สมุทรสงคราม', 'display_name': 'สมุทรสงคราม, อำเภอเมืองสมุทรสงคราม, จังหวัดสมุทรสงคราม, 75000, ประเทศไทย', 'address': {'town': 'สมุทรสงคราม', 'county': 'อำเภอเมืองสมุทรสงคราม', 'province': 'จังหวัดสมุทรสงคราม', 'ISO3166-2-lvl4': 'TH-75', 'postcode': '75000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['13.3686617', '13.4486617', '99.9604940', '100.0404940']}
#   → Extraído: lat=13.4086617, lon=100.0004940, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=13.4086617, lon=100.0004940, type=town
#
# === Ang Thong ===
# Tiene osm_id: OSM:R2969425
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R2969425&format=json
#   → Respuesta API: {'place_id': 244700267, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2969425, 'lat': '9.5375403', 'lon': '99.6934068', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.39269469636639415, 'addresstype': 'national_park', 'name': 'อุทยานแห่งชาติหมู่เกาะอ่างทอง', 'display_name': 'อุทยานแห่งชาติหมู่เกาะอ่างทอง, Ko Samui, จังหวัดสุราษฎร์ธานี, ประเทศไทย', 'address': {'national_park': 'อุทยานแห่งชาติหมู่เกาะอ่างทอง', 'county': 'Ko Samui', 'province': 'จังหวัดสุราษฎร์ธานี', 'ISO3166-2-lvl4': 'TH-84', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['9.5053666', '9.7179240', '99.6529930', '99.7262207']}
#   → Extraído: lat=9.5375403, lon=99.6934068, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=9.5375403, lon=99.6934068, type=national_park
#
# === Ayutthaya Historical Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=14.3535461, lon=100.5622548, type=park
#   → AÑADIENDO A LA ENTIDAD: lat=14.3535461, lon=100.5622548, type=park
#
# === Chumphon ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=10.4961355, lon=99.1778731, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=10.4961355, lon=99.1778731, type=town
#
# === Pai ===
# Tiene osm_id: OSM:N262585787
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N262585787&format=json
#   → Respuesta API: {'place_id': 222342435, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 262585787, 'lat': '19.3581061', 'lon': '98.4405794', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.26511848687494144, 'addresstype': 'town', 'name': 'ปาย', 'display_name': 'ปาย, Pai, จังหวัดแม่ฮ่องสอน, 58130, ประเทศไทย', 'address': {'town': 'ปาย', 'county': 'Pai', 'province': 'จังหวัดแม่ฮ่องสอน', 'ISO3166-2-lvl4': 'TH-58', 'postcode': '58130', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['19.3181061', '19.3981061', '98.4005794', '98.4805794']}
#   → Extraído: lat=19.3581061, lon=98.4405794, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=19.3581061, lon=98.4405794, type=town
#
# === Koh Phi Phi Don ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=7.7522403, lon=98.7766434, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=7.7522403, lon=98.7766434, type=island
#
# === Templo de la Cueva del Tigre ===
# Tiene osm_id: OSM:N2736512416
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2736512416&format=json
#   → Respuesta API: {'place_id': 237080881, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2736512416, 'lat': '7.5230850', 'lon': '99.0641852', 'class': 'shop', 'type': 'ticket', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'shop', 'name': 'Tiger Cave', 'display_name': 'Tiger Cave, 4245, คลองนิน, ศาลาด่าน, Ko Lanta, จังหวัดกระบี่, 81150, ประเทศไทย', 'address': {'shop': 'Tiger Cave', 'road': '4245', 'village': 'คลองนิน', 'municipality': 'ศาลาด่าน', 'county': 'Ko Lanta', 'province': 'จังหวัดกระบี่', 'ISO3166-2-lvl4': 'TH-81', 'postcode': '81150', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.5230350', '7.5231350', '99.0641352', '99.0642352']}
#   → Extraído: lat=7.5230850, lon=99.0641852, type=ticket
#   → AÑADIENDO A LA ENTIDAD: lat=7.5230850, lon=99.0641852, type=ticket
#
# === Wat Rong Suea Ten ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.9233569, lon=99.8417552, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=19.9233569, lon=99.8417552, type=place_of_worship
#
# === Singha Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.8599618, lon=99.7323552, type=park
#   → AÑADIENDO A LA ENTIDAD: lat=19.8599618, lon=99.7323552, type=park
#
# === Khun Korn Waterfall ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.8825546, lon=99.6161595, type=waterfall
#   → AÑADIENDO A LA ENTIDAD: lat=19.8825546, lon=99.6161595, type=waterfall
#
# === Mae Fah Luang Garden ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=20.3353426, lon=99.8119339, type=garden
#   → AÑADIENDO A LA ENTIDAD: lat=20.3353426, lon=99.8119339, type=garden
#
# === Ko Yao Noi ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.1338522, lon=98.6099377, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=8.1338522, lon=98.6099377, type=island
#
# === Koh Poda ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=7.9712751, lon=98.8084777, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=7.9712751, lon=98.8084777, type=island
#
# === Koh Racha ===
# Tiene osm_id: OSM:R5660749
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=R5660749&format=json
#   → Respuesta API: {'place_id': 237595520, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5660749, 'lat': '7.6024486', 'lon': '98.3654233', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17334333333333332, 'addresstype': 'island', 'name': 'เกาะราชาใหญ่', 'display_name': 'เกาะราชาใหญ่, จังหวัดภูเก็ต, ประเทศไทย', 'address': {'island': 'เกาะราชาใหญ่', 'province': 'จังหวัดภูเก็ต', 'ISO3166-2-lvl4': 'TH-83', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['7.5877440', '7.6171693', '98.3534949', '98.3792333']}
#   → Extraído: lat=7.6024486, lon=98.3654233, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=7.6024486, lon=98.3654233, type=island
#
# === Surat Thani ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.1404136, lon=99.3241347, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=9.1404136, lon=99.3241347, type=administrative
#
# === Wat Pha Lat ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.7992260, lon=98.9340020, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.7992260, lon=98.9340020, type=place_of_worship
#
# === Tham Khao Luang ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.1360917, lon=99.9330325, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=13.1360917, lon=99.9330325, type=place_of_worship
#
# === Phi Phi Marine Park ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.0247395, lon=98.8143805, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=8.0247395, lon=98.8143805, type=national_park
#
# === Black Temple ===
# Tiene osm_id: OSM:W269747639
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W269747639&format=json
#   → Respuesta API: {'place_id': 222382864, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 269747639, 'lat': '19.9920756', 'lon': '99.8607194', 'class': 'tourism', 'type': 'gallery', 'place_rank': 30, 'importance': 5.245670252532261e-05, 'addresstype': 'tourism', 'name': 'มหาวิหาร', 'display_name': 'มหาวิหาร, ถนนบ้านดำ, บ้านนางแล, นางแล, Mueang Chiang Rai, จังหวัดเชียงราย, 57100, ประเทศไทย', 'address': {'tourism': 'มหาวิหาร', 'road': 'ถนนบ้านดำ', 'village': 'บ้านนางแล', 'municipality': 'นางแล', 'county': 'Mueang Chiang Rai', 'province': 'จังหวัดเชียงราย', 'ISO3166-2-lvl4': 'TH-57', 'postcode': '57100', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['19.9919877', '19.9922186', '99.8605095', '99.8609368']}
#   → Extraído: lat=19.9920756, lon=99.8607194, type=gallery
#   → AÑADIENDO A LA ENTIDAD: lat=19.9920756, lon=99.8607194, type=gallery
#
# === Khao San Road ===
# Tiene osm_id: OSM:N4319285389
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N4319285389&format=json
#   → Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /lookup?osm_ids=N4319285389&format=json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACF73B0400>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
#   → AÑADIENDO A LA ENTIDAD: lat=None, lon=None, type=None
#
# === Hellfire Pass ===
# Tiene osm_id: OSM:W505007490
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W505007490&format=json
#   → Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /lookup?osm_ids=W505007490&format=json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACF883E200>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
#   → AÑADIENDO A LA ENTIDAD: lat=None, lon=None, type=None
#
# === Chatuchak Market ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.8002651, lon=100.5511228, type=marketplace
#   → AÑADIENDO A LA ENTIDAD: lat=13.8002651, lon=100.5511228, type=marketplace
#
# === Lampang ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.2899489, lon=99.4958526, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=18.2899489, lon=99.4958526, type=administrative
#
# === Siam Paragon ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.7467785, lon=100.5349540, type=mall
#   → AÑADIENDO A LA ENTIDAD: lat=13.7467785, lon=100.5349540, type=mall
#
# === Central World ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=13.7465769, lon=100.5390414, type=mall
#   → AÑADIENDO A LA ENTIDAD: lat=13.7465769, lon=100.5390414, type=mall
#
# === Wat Chedi Luang Varavihara ===
# Tiene osm_id: OSM:W243018795
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W243018795&format=json
#   → Respuesta API: {'place_id': 221156848, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 243018795, 'lat': '18.7871427', 'lon': '98.9867840', 'class': 'amenity', 'type': 'place_of_worship', 'place_rank': 30, 'importance': 0.30929013509721104, 'addresstype': 'amenity', 'name': 'วัดเจดีย์หลวงวรวิหาร', 'display_name': 'วัดเจดีย์หลวงวรวิหาร, ถนนพระปกเกล้า ซอย 8, Muang Chiang Mai, เทศบาลนครเชียงใหม่, ฟ้าฮ่าม, Mueang Chiang Mai, จังหวัดเชียงใหม่, 55520, ประเทศไทย', 'address': {'amenity': 'วัดเจดีย์หลวงวรวิหาร', 'road': 'ถนนพระปกเกล้า ซอย 8', 'neighbourhood': 'Muang Chiang Mai', 'city': 'เทศบาลนครเชียงใหม่', 'municipality': 'ฟ้าฮ่าม', 'county': 'Mueang Chiang Mai', 'province': 'จังหวัดเชียงใหม่', 'ISO3166-2-lvl4': 'TH-50', 'postcode': '55520', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.7859601', '18.7879851', '98.9855674', '98.9881471']}
#   → Extraído: lat=18.7871427, lon=98.9867840, type=place_of_worship
#   → AÑADIENDO A LA ENTIDAD: lat=18.7871427, lon=98.9867840, type=place_of_worship
#
# === Koh Phayam ===
# Tiene osm_id: OSM:W241833200
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W241833200&format=json
#   → Respuesta API: {'place_id': 237339604, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 241833200, 'lat': '9.7405320', 'lon': '98.4036458', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17337083466849773, 'addresstype': 'island', 'name': 'เกาะพยาม', 'display_name': 'เกาะพยาม, อ่าวเกาะคยู, Mueang Ranong, จังหวัดระนอง, ประเทศไทย', 'address': {'island': 'เกาะพยาม', 'village': 'อ่าวเกาะคยู', 'county': 'Mueang Ranong', 'province': 'จังหวัดระนอง', 'ISO3166-2-lvl4': 'TH-85', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['9.7038473', '9.7770158', '98.3791422', '98.4274537']}
#   → Extraído: lat=9.7405320, lon=98.4036458, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=9.7405320, lon=98.4036458, type=island
#
# === Koh Larn ===
# Tiene osm_id: OSM:W23484541
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W23484541&format=json
#   → Respuesta API: {'place_id': 238244924, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23484541, 'lat': '12.9174502', 'lon': '100.7782008', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.37960663498012104, 'addresstype': 'island', 'name': 'เกาะล้าน', 'display_name': 'เกาะล้าน, เมืองพัทยา, จังหวัดชลบุรี, ประเทศไทย', 'address': {'island': 'เกาะล้าน', 'city': 'เมืองพัทยา', 'ISO3166-2-lvl7': 'TH-S', 'province': 'จังหวัดชลบุรี', 'ISO3166-2-lvl4': 'TH-20', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['12.8973784', '12.9376038', '100.7664761', '100.7901764']}
#   → Extraído: lat=12.9174502, lon=100.7782008, type=island
#   → AÑADIENDO A LA ENTIDAD: lat=12.9174502, lon=100.7782008, type=island
#
# === Koh Maak ===
# Tiene osm_id: OSM:W26690559
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W26690559&format=json
#   → Respuesta API: {'place_id': 405414304, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 26690559, 'lat': '11.8152540', 'lon': '102.4679720', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.2400350019073777, 'addresstype': 'island', 'name': 'เกาะหมาก', 'display_name': 'เกาะหมาก, จังหวัดตราด, ประเทศไทย', 'address': {'island': 'เกาะหมาก', 'province': 'จังหวัดตราด', 'ISO3166-2-lvl4': 'TH-23', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['11.7899922', '11.8405775', '102.4440585', '102.5116660']}
#   → Extraído: lat=11.8152540, lon=102.4679720, type=administrative
#   → AÑADIENDO A LA ENTIDAD: lat=11.8152540, lon=102.4679720, type=administrative
#
# === Koh Surin ===
# Tiene osm_id: OSM:W223725728
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W223725728&format=json
#   → Respuesta API: {'place_id': 237386842, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 223725728, 'lat': '9.4001641', 'lon': '97.8657727', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.38376885343645895, 'addresstype': 'national_park', 'name': 'อุทยานแห่งชาติหมู่เกาะสุรินทร์', 'display_name': 'อุทยานแห่งชาติหมู่เกาะสุรินทร์, Khura Buri, จังหวัดพังงา, ประเทศไทย', 'address': {'national_park': 'อุทยานแห่งชาติหมู่เกาะสุรินทร์', 'county': 'Khura Buri', 'province': 'จังหวัดพังงา', 'ISO3166-2-lvl4': 'TH-82', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['9.3583587', '9.4834707', '97.8180193', '97.9134729']}
#   → Extraído: lat=9.4001641, lon=97.8657727, type=national_park
#   → AÑADIENDO A LA ENTIDAD: lat=9.4001641, lon=97.8657727, type=national_park
#
# === Mae Kampong ===
# Tiene osm_id: OSM:N2488959421
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N2488959421&format=json
#   → Respuesta API: {'place_id': 221491443, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2488959421, 'lat': '18.8654341', 'lon': '99.3501499', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.13337083466849772, 'addresstype': 'hamlet', 'name': 'บ้านแม่กำปง', 'display_name': 'บ้านแม่กำปง, Mae On, จังหวัดเชียงใหม่, ประเทศไทย', 'address': {'hamlet': 'บ้านแม่กำปง', 'county': 'Mae On', 'province': 'จังหวัดเชียงใหม่', 'ISO3166-2-lvl4': 'TH-50', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['18.8454341', '18.8854341', '99.3301499', '99.3701499']}
#   → Extraído: lat=18.8654341, lon=99.3501499, type=hamlet
#   → AÑADIENDO A LA ENTIDAD: lat=18.8654341, lon=99.3501499, type=hamlet
#
# === Nong Khai ===
# Tiene osm_id: OSM:N257903226
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=N257903226&format=json
#   → Respuesta API: {'place_id': 221577718, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 257903226, 'lat': '17.8825057', 'lon': '102.7482277', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4982220028962136, 'addresstype': 'town', 'name': 'หนองคาย', 'display_name': 'หนองคาย, โพธิ์ชัย, อำเภอเมืองหนองคาย, จังหวัดหนองคาย, 43000, ประเทศไทย', 'address': {'town': 'หนองคาย', 'municipality': 'โพธิ์ชัย', 'county': 'อำเภอเมืองหนองคาย', 'province': 'จังหวัดหนองคาย', 'ISO3166-2-lvl4': 'TH-43', 'postcode': '43000', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['17.8425057', '17.9225057', '102.7082277', '102.7882277']}
#   → Extraído: lat=17.8825057, lon=102.7482277, type=town
#   → AÑADIENDO A LA ENTIDAD: lat=17.8825057, lon=102.7482277, type=town
#
# === Chiang Rai Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.9480922, lon=99.8794568, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=19.9480922, lon=99.8794568, type=aerodrome
#
# === Udon Thani Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.3858704, lon=102.7835249, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=17.3858704, lon=102.7835249, type=aerodrome
#
# === Trat Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=12.2808021, lon=102.3236367, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=12.2808021, lon=102.3236367, type=aerodrome
#
# === Chiang Mai International Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=18.7668427, lon=98.9648781, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=18.7668427, lon=98.9648781, type=aerodrome
#
# === Koh Samui Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.5488263, lon=100.0631993, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=9.5488263, lon=100.0631993, type=aerodrome
#
# === Mae Hong Son Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=19.3010740, lon=97.9758393, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=19.3010740, lon=97.9758393, type=aerodrome
#
# === Nakhon Si Thammarat Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.5361535, lon=99.9432125, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=8.5361535, lon=99.9432125, type=aerodrome
#
# === Phuket International Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.1101319, lon=98.3058153, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=8.1101319, lon=98.3058153, type=aerodrome
#
# === Rayong Utapao Rayong Pattaya Airport ===
# Tiene osm_id: OSM:W307565962
#   → URL: https://nominatim.openstreetmap.org/lookup?osm_ids=W307565962&format=json
#   → Respuesta API: {'place_id': 235303061, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 307565962, 'lat': '12.6847682', 'lon': '101.0093430', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.4445857017643156, 'addresstype': 'aeroway', 'name': 'ท่าอากาศยานนานาชาติอู่ตะเภา', 'display_name': 'ท่าอากาศยานนานาชาติอู่ตะเภา, 70, ถนนสุขุมวิท, พลา, Ban Chang, จังหวัดระยอง, 21130, ประเทศไทย', 'address': {'aeroway': 'ท่าอากาศยานนานาชาติอู่ตะเภา', 'house_number': '70', 'road': 'ถนนสุขุมวิท', 'municipality': 'พลา', 'county': 'Ban Chang', 'province': 'จังหวัดระยอง', 'ISO3166-2-lvl4': 'TH-21', 'postcode': '21130', 'country': 'ประเทศไทย', 'country_code': 'th'}, 'boundingbox': ['12.6595845', '12.7098640', '100.9908560', '101.0300197']}
#   → Extraído: lat=12.6847682, lon=101.0093430, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=12.6847682, lon=101.0093430, type=aerodrome
#
# === Hua Hin Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=12.6368253, lon=99.9510245, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=12.6368253, lon=99.9510245, type=aerodrome
#
# === Buri Ram Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=15.2251616, lon=103.2477758, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=15.2251616, lon=103.2477758, type=aerodrome
#
# === Trang Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=7.5082559, lon=99.6152278, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=7.5082559, lon=99.6152278, type=aerodrome
#
# === Surat Thani Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=9.1331733, lon=99.1361417, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=9.1331733, lon=99.1361417, type=aerodrome
#
# === Hat Yai Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=6.9290730, lon=100.3948000, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=6.9290730, lon=100.3948000, type=aerodrome
#
# === Krabi International Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=8.0964079, lon=98.9851238, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=8.0964079, lon=98.9851238, type=aerodrome
#
# === Sukhothai Airport ===
# Tiene nominatim_match
#   → Extraído de nominatim: lat=17.2355870, lon=99.8215677, type=aerodrome
#   → AÑADIENDO A LA ENTIDAD: lat=17.2355870, lon=99.8215677, type=aerodrome
#
# Proceso completado!

# %%
import json

input_file = "D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_8.jsonl"

with open(input_file, "r", encoding="utf-8") as fin:
    for line in fin:
        entity = json.loads(line)
        if not entity.get("lat") or not entity.get("lon"):
            print(entity.get("name", "SIN NOMBRE"))
# Out:
# Thailand
# Khao San Road
# Hellfire Pass

# %% [markdown]
# ## We plot the names and subtypes of the entities

# %%
import json

def print_entity_names_and_subtypes():
    # Lista para almacenar las entidades únicas
    entities = []
    
    # Leer el archivo JSONL
    with open('D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_9.jsonl', 'r', encoding='utf-8') as file:
        for line in file:
            try:
                data = json.loads(line.strip())
                
                # Extraer nombre y subtipo
                name = data.get('name', 'Sin nombre')
                subtype = data.get('subtype', 'Sin subtipo')
                
                # Crear tupla para evitar duplicados
                entity = (name, subtype)
                
                if entity not in entities:
                    entities.append(entity)
                    
            except json.JSONDecodeError:
                print(f"Error al parsear línea: {line}")
                continue
    
    # Ordenar por nombre
    entities.sort(key=lambda x: x[0])
    
    # Imprimir resultados
    print("ENTIDADES Y SUS SUBTIPOS:")
    print("=" * 50)
    
    for i, (name, subtype) in enumerate(entities, 1):
        print(f"{i:2d}. {name:<30} | {subtype}")
    
    print(f"\nTotal de entidades únicas: {len(entities)}")

# Ejecutar la función
if __name__ == "__main__":
    print_entity_names_and_subtypes()
# Out:
# ENTIDADES Y SUS SUBTIPOS:
# ==================================================
#  1. Ang Thong                      | natural park
#  2. Ao Nang                        | city
#  3. Ayutthaya                      | city
#  4. Ayutthaya Historical Park      | historic
#  5. Bahía de Phang Nga             | bay
#  6. Bangkok                        | city
#  7. Black Temple                   | museum
#  8. Blue Temple                    | temple
#  9. Buri Ram                       | city
# 10. Buri Ram Airport               | airport
# 11. Central World                  | mall
# 12. Chatuchak Market               | market
# 13. Chiang Khan                    | city
# 14. Chiang Mai                     | city
# 15. Chiang Mai International Airport | airport
# 16. Chiang Rai                     | city
# 17. Chiang Rai                     | province
# 18. Chiang Rai Airport             | airport
# 19. Chumphon                       | province
# 20. Chumphon                       | city
# 21. Damnoen Saduak Floating Market | floating market
# 22. Doi Inthanon                   | mountain
# 23. Doi Suthep                     | temple
# 24. Don Muang Airport              | airport
# 25. Elephant Nature Park           | sanctuary
# 26. Erawan National Park           | natural park
# 27. Erawan Waterfalls              | waterfall
# 28. Golden Triangle                | landmark
# 29. Hat Yai Airport                | airport
# 30. Hellfire Pass                  | historic
# 31. Hua Hin Airport                | airport
# 32. Hualamphong Station            | train station
# 33. James Bond Island              | island
# 34. Kanchanaburi                   | city
# 35. Khao San Road                  | street
# 36. Khao Sok National Park         | natural park
# 37. Khao Yai National Park         | natural park
# 38. Khun Korn Waterfall            | waterfall
# 39. Ko Nang Yuan                   | island
# 40. Koh Chang                      | island
# 41. Koh Kood                       | island
# 42. Koh Lanta                      | island
# 43. Koh Larn                       | island
# 44. Koh Lipe                       | island
# 45. Koh Maak                       | island
# 46. Koh Muk                        | island
# 47. Koh Phangan                    | island
# 48. Koh Phayam                     | island
# 49. Koh Phi Phi Don                | island
# 50. Koh Poda                       | island
# 51. Koh Racha                      | island
# 52. Koh Samet                      | island
# 53. Koh Samui                      | island
# 54. Koh Samui Airport              | airport
# 55. Koh Surin                      | natural park
# 56. Koh Tao                        | island
# 57. Koh Yao Noi                    | island
# 58. Koh Yao Yai                    | island
# 59. Krabi                          | city
# 60. Krabi                          | province
# 61. Krabi International Airport    | airport
# 62. Lampang                        | city
# 63. Lopburi                        | city
# 64. Mae Fah Luang Garden           | garden
# 65. Mae Hong Son                   | province
# 66. Mae Hong Son                   | city
# 67. Mae Hong Son Airport           | airport
# 68. Mae Kampong                    | city
# 69. Maya Bay                       | beach
# 70. Nakhon Si Thammarat            | city
# 71. Nakhon Si Thammarat Airport    | airport
# 72. Nan                            | city
# 73. Nong Khai                      | city
# 74. Pai                            | city
# 75. Pattaya                        | city
# 76. Phanom Rung                    | historic
# 77. Phi Phi Islands                | archipielago
# 78. Phi Phi Marine Park            | natural park
# 79. Phitsanulok                    | city
# 80. Phuket                         | island
# 81. Phuket                         | city
# 82. Phuket International Airport   | airport
# 83. Railay                         | beach
# 84. Railay                         | peninsula
# 85. Ratchaburi                     | city
# 86. Rayong Utapao Rayong Pattaya Airport | airport
# 87. Samut Songkhram                | province
# 88. Siam Paragon                   | mall
# 89. Similan Islands                | island
# 90. Similan Islands                | natural park
# 91. Singha Park                    | park
# 92. Sukhothai                      | city
# 93. Sukhothai Airport              | airport
# 94. Sukhothai Historical Park      | historic
# 95. Surat Thani                    | city
# 96. Surat Thani Airport            | airport
# 97. Suvarnabhumi Airport           | airport
# 98. Templo Blanco (Wat Rong Khun)  | temple
# 99. Templo de la Cueva del Tigre   | temple
# 100. Thailand                       | country
# 101. Tham Khao Luang                | cave
# 102. Trang Airport                  | airport
# 103. Trat Airport                   | airport
# 104. Udon Thani Airport             | airport
# 105. Wat Chedi Luang                | temple
# 106. Wat Chedi Luang Varavihara     | temple
# 107. Wat Pa Phu Kon                 | temple
# 108. Wat Pha Lat                    | temple
# 109. Wat Pho                        | temple
# 110. Wat Phra Singh                 | temple
# 111. Wat Phra That Doi Suthep       | temple
# 112. Wat Rong Khun                  | temple
# 113. Wat Rong Suea Ten              | temple
# 114. Wat Si Chum                    | temple
# 115. Wat Umong                      | temple
# 116. White Temple                   | temple
#
# Total de entidades únicas: 116

# %% [markdown]
# ## We match some same entities

# %%
import json
from collections import defaultdict

def clean_and_merge_entities():
    # Diccionario para almacenar entidades fusionadas
    merged_entities = {}
    
    # Mapeo de nombres para fusionar
    name_mapping = {
        'Kanchannaburi': 'Kanchanaburi',
        'Ko Samui': 'Koh Samui', 
        'Ko Yao Noi': 'Koh Yao Noi'
    }
    
    # Leer el archivo JSONL de entrada
    input_file = r'D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_8.jsonl'
    output_file = r'D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_9.jsonl'
    
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            try:
                data = json.loads(line.strip())
                
                name = data.get('name', 'Sin nombre')
                subtype = data.get('subtype', 'Sin subtipo')
                
                # Saltar entidades a eliminar
                if name == 'Ayutthaya' and subtype == 'historic':
                    continue
                
                # Aplicar mapeo de nombres
                if name in name_mapping:
                    name = name_mapping[name]
                
                # Crear clave única
                key = (name, subtype)
                
                if key not in merged_entities:
                    merged_entities[key] = {
                        'entity_type': data.get('entity_type', 'site'),
                        'name': name,
                        'subtype': subtype,
                        'description': data.get('description', ''),
                        'hierarchy': data.get('hierarchy', []),
                        'avg_visit_duration': data.get('avg_visit_duration', ''),
                        'normalized_name': data.get('normalized_name', name),
                        'appearances': data.get('appearances', 0),
                        'all_source_urls': data.get('all_source_urls', []),
                        'lat': data.get('lat', ''),
                        'lon': data.get('lon', ''),
                        'type': data.get('type', ''),
                        'wikidata_id': data.get('wikidata_id', '')
                    }
                else:
                    # Sumar appearances y combinar URLs
                    merged_entities[key]['appearances'] += data.get('appearances', 0)
                    
                    # Combinar URLs únicas
                    existing_urls = set(merged_entities[key]['all_source_urls'])
                    new_urls = set(data.get('all_source_urls', []))
                    merged_entities[key]['all_source_urls'] = list(existing_urls.union(new_urls))
                    
                    # Combinar descripciones (mantener la más larga)
                    if len(data.get('description', '')) > len(merged_entities[key]['description']):
                        merged_entities[key]['description'] = data.get('description', '')
                    
            except json.JSONDecodeError:
                print(f"Error al parsear línea: {line}")
                continue
    
    # Ordenar por nombre
    sorted_entities = sorted(merged_entities.values(), key=lambda x: x['name'])
    
    # Escribir el archivo de salida
    with open(output_file, 'w', encoding='utf-8') as outfile:
        for entity in sorted_entities:
            json.dump(entity, outfile, ensure_ascii=False)
            outfile.write('\n')
    
    # Imprimir resultados
    print("ENTIDADES LIMPIAS Y FUSIONADAS:")
    print("=" * 60)
    
    for i, entity in enumerate(sorted_entities, 1):
        print(f"{i:2d}. {entity['name']:<30} | {entity['subtype']:<15} | {entity['appearances']:2d} appearances")
    
    print(f"\nTotal de entidades únicas: {len(sorted_entities)}")
    print(f"Archivo guardado en: {output_file}")
    
    # Mostrar entidades fusionadas
    print("\nENTIDADES FUSIONADAS:")
    print("=" * 40)
    for original, mapped in name_mapping.items():
        print(f"'{original}' → '{mapped}'")
    
    return sorted_entities

# Ejecutar la función
if __name__ == "__main__":
    clean_and_merge_entities()
# Out:
# ENTIDADES LIMPIAS Y FUSIONADAS:
# ============================================================
#  1. Ang Thong                      | natural park    |  1 appearances
#  2. Ao Nang                        | city            |  4 appearances
#  3. Ayutthaya                      | city            | 26 appearances
#  4. Ayutthaya Historical Park      | historic        |  1 appearances
#  5. Bahía de Phang Nga             | bay             |  3 appearances
#  6. Bangkok                        | city            | 32 appearances
#  7. Black Temple                   | museum          |  1 appearances
#  8. Blue Temple                    | temple          |  2 appearances
#  9. Buri Ram                       | city            |  1 appearances
# 10. Buri Ram Airport               | airport         |  1 appearances
# 11. Central World                  | mall            |  1 appearances
# 12. Chatuchak Market               | market          |  1 appearances
# 13. Chiang Khan                    | city            |  1 appearances
# 14. Chiang Mai                     | city            | 12 appearances
# 15. Chiang Mai International Airport | airport         |  1 appearances
# 16. Chiang Rai                     | city            | 25 appearances
# 17. Chiang Rai                     | province        |  1 appearances
# 18. Chiang Rai Airport             | airport         |  1 appearances
# 19. Chumphon                       | province        |  3 appearances
# 20. Chumphon                       | city            |  1 appearances
# 21. Damnoen Saduak Floating Market | floating market |  2 appearances
# 22. Doi Inthanon                   | mountain        |  5 appearances
# 23. Doi Suthep                     | temple          |  3 appearances
# 24. Don Muang Airport              | airport         |  1 appearances
# 25. Elephant Nature Park           | sanctuary       |  3 appearances
# 26. Erawan National Park           | natural park    |  1 appearances
# 27. Erawan Waterfalls              | waterfall       |  3 appearances
# 28. Golden Triangle                | landmark        |  2 appearances
# 29. Hat Yai Airport                | airport         |  1 appearances
# 30. Hellfire Pass                  | historic        |  1 appearances
# 31. Hua Hin Airport                | airport         |  1 appearances
# 32. Hualamphong Station            | train station   |  1 appearances
# 33. James Bond Island              | island          |  3 appearances
# 34. Kanchanaburi                   | city            | 12 appearances
# 35. Khao San Road                  | street          |  1 appearances
# 36. Khao Sok National Park         | natural park    |  4 appearances
# 37. Khao Yai National Park         | natural park    |  2 appearances
# 38. Khun Korn Waterfall            | waterfall       |  1 appearances
# 39. Ko Nang Yuan                   | island          |  1 appearances
# 40. Koh Chang                      | island          |  7 appearances
# 41. Koh Kood                       | island          |  3 appearances
# 42. Koh Lanta                      | island          |  7 appearances
# 43. Koh Larn                       | island          |  1 appearances
# 44. Koh Lipe                       | island          | 19 appearances
# 45. Koh Maak                       | island          |  1 appearances
# 46. Koh Muk                        | island          |  2 appearances
# 47. Koh Phangan                    | island          | 12 appearances
# 48. Koh Phayam                     | island          |  1 appearances
# 49. Koh Phi Phi Don                | island          |  1 appearances
# 50. Koh Poda                       | island          |  1 appearances
# 51. Koh Racha                      | island          |  1 appearances
# 52. Koh Samet                      | island          |  4 appearances
# 53. Koh Samui                      | island          | 24 appearances
# 54. Koh Samui Airport              | airport         |  1 appearances
# 55. Koh Surin                      | natural park    |  1 appearances
# 56. Koh Tao                        | island          | 19 appearances
# 57. Koh Yao Noi                    | island          |  4 appearances
# 58. Koh Yao Yai                    | island          |  2 appearances
# 59. Krabi                          | city            | 15 appearances
# 60. Krabi                          | province        | 14 appearances
# 61. Krabi International Airport    | airport         |  1 appearances
# 62. Lampang                        | city            |  1 appearances
# 63. Lopburi                        | city            |  9 appearances
# 64. Mae Fah Luang Garden           | garden          |  1 appearances
# 65. Mae Hong Son                   | province        |  4 appearances
# 66. Mae Hong Son                   | city            |  1 appearances
# 67. Mae Hong Son Airport           | airport         |  1 appearances
# 68. Mae Kampong                    | city            |  1 appearances
# 69. Maya Bay                       | beach           |  3 appearances
# 70. Nakhon Si Thammarat            | city            |  1 appearances
# 71. Nakhon Si Thammarat Airport    | airport         |  1 appearances
# 72. Nan                            | city            |  3 appearances
# 73. Nong Khai                      | city            |  1 appearances
# 74. Pai                            | city            |  9 appearances
# 75. Pattaya                        | city            |  6 appearances
# 76. Phanom Rung                    | historic        |  1 appearances
# 77. Phi Phi Islands                | archipielago    | 13 appearances
# 78. Phi Phi Marine Park            | natural park    |  1 appearances
# 79. Phitsanulok                    | city            |  5 appearances
# 80. Phuket                         | island          | 21 appearances
# 81. Phuket                         | city            |  7 appearances
# 82. Phuket International Airport   | airport         |  1 appearances
# 83. Railay                         | beach           |  3 appearances
# 84. Railay                         | peninsula       |  2 appearances
# 85. Ratchaburi                     | city            |  1 appearances
# 86. Rayong Utapao Rayong Pattaya Airport | airport         |  1 appearances
# 87. Samut Songkhram                | province        |  1 appearances
# 88. Siam Paragon                   | mall            |  1 appearances
# 89. Similan Islands                | island          |  5 appearances
# 90. Similan Islands                | natural park    |  1 appearances
# 91. Singha Park                    | park            |  1 appearances
# 92. Sukhothai                      | city            | 19 appearances
# 93. Sukhothai Airport              | airport         |  1 appearances
# 94. Sukhothai Historical Park      | historic        |  5 appearances
# 95. Surat Thani                    | city            |  1 appearances
# 96. Surat Thani Airport            | airport         |  1 appearances
# 97. Suvarnabhumi Airport           | airport         |  1 appearances
# 98. Templo Blanco (Wat Rong Khun)  | temple          |  1 appearances
# 99. Templo de la Cueva del Tigre   | temple          |  1 appearances
# 100. Thailand                       | country         |  1 appearances
# 101. Tham Khao Luang                | cave            |  1 appearances
# 102. Trang Airport                  | airport         |  1 appearances
# 103. Trat Airport                   | airport         |  1 appearances
# 104. Udon Thani Airport             | airport         |  1 appearances
# 105. Wat Chedi Luang                | temple          |  2 appearances
# 106. Wat Chedi Luang Varavihara     | temple          |  1 appearances
# 107. Wat Pa Phu Kon                 | temple          |  1 appearances
# 108. Wat Pha Lat                    | temple          |  1 appearances
# 109. Wat Pho                        | temple          |  3 appearances
# 110. Wat Phra Singh                 | temple          |  3 appearances
# 111. Wat Phra That Doi Suthep       | temple          |  3 appearances
# 112. Wat Rong Khun                  | temple          |  4 appearances
# 113. Wat Rong Suea Ten              | temple          |  1 appearances
# 114. Wat Si Chum                    | temple          |  2 appearances
# 115. Wat Umong                      | temple          |  2 appearances
# 116. White Temple                   | temple          |  2 appearances
#
# Total de entidades únicas: 116
# Archivo guardado en: D:\TravelApp\Project\scripts\data\scraper_enrichment\enriched_data_9.jsonl
#
# ENTIDADES FUSIONADAS:
# ========================================
# 'Kanchannaburi' → 'Kanchanaburi'
# 'Ko Samui' → 'Koh Samui'
# 'Ko Yao Noi' → 'Koh Yao Noi'
